# %%
import numpy as np
import pandas as pd
import re

# %%
revs = pd.DataFrame.from_csv("./res.csv", encoding="cp1251")

initial_revs = revs.copy()
revs
# Out:
#        rating                                            content
# 0           5  Интересный сюжет, затягивает. Много времени ух...
# 1           4  Плюсы: \r\n1. Игра интересная 2. Образы учител...
# 2           3  Огорчил тот факт , что суть игры заключается в...
# 3           5  Была постоянная ошибка с подключением, почти н...
# 4           1  ... сделайте русскую озвучку и будет 5 звёзд :...
# 5           3                         Почему нет русского языка?
# 6           1                                                  !
# 7           1              Постоянные проблемы с подключением!!!
# 8           5  Все идеально но отсутствия русского языка даёт...
# 9           1          Где великий и могучий??? Сделайте русский
# 10          4  Thanks for the game, I fancy it pretty much, h...
# 11          2                  Добавьте русский язык пожалуйста(
# 12          5  Игра отличная, отсутствие русского языка не ме...
# 13          4                       Please add Russian language!
# 14          5  Everything was great till Wednesday night. Gam...
# 15          3                         Where Russian language ???
# 16          1  В описании приложения, написали что есть русск...
# 17          1              Пожалуйста сделайте русский язык!!!!!
# 18          2  Зашла в игру, поиграла ровно минуту и всё, эне...
# 19          2  Игра интересная, но как же достал connect erro...
# 20          1  Where is the Russian language? why the descrip...
# 21          4  Без русского играть невозможно. От выборы зави...
# 22          5  Почему игра не запускается, перекидывает на ст...
# 23          1  Когда же ждать заявленный в описании русский я...
# 24          2  Русского языка нет, но английский понимаю - та...
# 25          5  Товарищи, учите иностранные языки \r\nИгра зам...
# 26          3                 Always connection lost! Fix please
# 27          1  Заявлен русский язык. Заходишь в игре в Настро...
# 28          5  Очень продуманная, интересная игра, все сделан...
# 29          3  Игра нармуль. Разрабочики добавьте русский язык !
# ...       ...                                                ...
# 22463       5  Пользуюсь приложением не первый год, мобильное...
# 22464       5  Один из лучших онлайн магазинов! Купила много ...
# 22465       1  Господа разработчики, уберите из приложения да...
# 22466       4  Для айфона не очень удобное приложение. Листат...
# 22467       1  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       1  И цены конские. А их реклама «увеличьте свой ч...
# 22469       5  Отличный сайт и отличное приложение, пока толь...
# 22470       5  Приложение , сайт и вещи и вообще все просто с...
# 22471       1  Сделал заказ, сказали что доставка возможна то...
# 22472       5  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       1  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       5  Сразу все магазины в одном месте ? так как я в...
# 22475       2  Во вкладке «Избранное» дублируются товары. Три...
# 22476       5           Мне нравится. Удобно, быстро, недорого??
# 22477       5                                       Всё хорошо ?
# 22478       1  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       1  Вся обувь китайская подделка, через 15 минут р...
# 22480       1  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       1  Доставка от пони экспресс, портит все. Может в...
# 22482       1  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       1  Приложение где только не пиарят, увидела в вк ...
# 22484       1  Не стыдно врать то, никаких скидок на фирму не...
# 22485       1  Зачем изменили приложение, что за ненужное око...
# 22486       1                          Недобросовестная реклама.
# 22487       1  Приложение классное, но реклама на YouTube за*...
# 22488       4  Почините,пожалуйста,приложение, заходила два г...
# 22489       1  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       1  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22491       4  Отличное приложение, удобное в использовании, ...
# 22492       5                                             ??????
#
# [22493 rows x 2 columns]

# %% [markdown]
# Удаляем неподходящие отзывы: с рейтингов 3-4, с английским текстом, пустые

# %%
    #drop eng reviews
revs.drop(revs[revs.content.str.contains ("[A-Za-z]")].index, inplace=True)
    #drop reviews with rating 3-4
revs.drop(revs[(revs.rating == 3) | (revs.rating == 4)].index, inplace=True)
    #drop empty reviews
revs.drop(revs[revs.content == ""].index, inplace=True)

revs
# Out:
#        rating                                            content
# 0           5  Интересный сюжет, затягивает. Много времени ух...
# 4           1  ... сделайте русскую озвучку и будет 5 звёзд :...
# 6           1                                                  !
# 7           1              Постоянные проблемы с подключением!!!
# 8           5  Все идеально но отсутствия русского языка даёт...
# 9           1          Где великий и могучий??? Сделайте русский
# 11          2                  Добавьте русский язык пожалуйста(
# 16          1  В описании приложения, написали что есть русск...
# 17          1              Пожалуйста сделайте русский язык!!!!!
# 18          2  Зашла в игру, поиграла ровно минуту и всё, эне...
# 22          5  Почему игра не запускается, перекидывает на ст...
# 23          1  Когда же ждать заявленный в описании русский я...
# 24          2  Русского языка нет, но английский понимаю - та...
# 25          5  Товарищи, учите иностранные языки \r\nИгра зам...
# 27          1  Заявлен русский язык. Заходишь в игре в Настро...
# 28          5  Очень продуманная, интересная игра, все сделан...
# 33          5                              Добавьте русский язык
# 35          2                             Необходим русский язык
# 37          1                                       Русский язык
# 38          1                         Нет русского языка! Обман!
# 41          2  Вы написала есть русский а там его в игре нет ...
# 43          1  Алло, где русский язык??? \r\nНаписано же, что...
# 47          5  Игра выше всех моих ожиданий, и судя по отзыва...
# 48          1                              Где русский язык ????
# 51          1  Играть просто стыдно. Гейплей, сюжет отсутству...
# 53          5                  Добавьте русский язык пожалуйста!
# 54          1  Очень жду Русский язык ,написано что он есть ,...
# 57          5             Спасибо!!! Очень интересно играть! ???
# 58          1  В описании к игре Русский язык указан, фактиче...
# 59          1  Зачем указывать языки которых нет и ничего не ...
# ...       ...                                                ...
# 22459       5  Те кто пишет фу и всё такое, советую не слушат...
# 22460       5  Ламода- супер вариант для тех, кто не может по...
# 22461       5  Отличный магазин. Удобно. Быстро. Дёшево. Фейк...
# 22462       5                     Поиск по фото - просто огонь!!
# 22463       5  Пользуюсь приложением не первый год, мобильное...
# 22464       5  Один из лучших онлайн магазинов! Купила много ...
# 22465       1  Господа разработчики, уберите из приложения да...
# 22467       1  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       1  И цены конские. А их реклама «увеличьте свой ч...
# 22469       5  Отличный сайт и отличное приложение, пока толь...
# 22470       5  Приложение , сайт и вещи и вообще все просто с...
# 22471       1  Сделал заказ, сказали что доставка возможна то...
# 22472       5  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       1  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       5  Сразу все магазины в одном месте ? так как я в...
# 22475       2  Во вкладке «Избранное» дублируются товары. Три...
# 22476       5           Мне нравится. Удобно, быстро, недорого??
# 22477       5                                       Всё хорошо ?
# 22478       1  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       1  Вся обувь китайская подделка, через 15 минут р...
# 22480       1  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       1  Доставка от пони экспресс, портит все. Может в...
# 22482       1  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       1  Приложение где только не пиарят, увидела в вк ...
# 22484       1  Не стыдно врать то, никаких скидок на фирму не...
# 22485       1  Зачем изменили приложение, что за ненужное око...
# 22486       1                          Недобросовестная реклама.
# 22489       1  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       1  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22492       5                                             ??????
#
# [15949 rows x 2 columns]

# %% [markdown]
# Заменяем оценку 5 на класс "1" - позитивные отзывы, оценки 1-2 - на класс "0" - негативные отзывы

# %%
revs['rating'][(revs.rating == 1) | (revs.rating == 2)] = 0
revs['rating'][revs.rating == 5] = 1

revs
# Out:
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#        rating                                            content
# 0           1  Интересный сюжет, затягивает. Много времени ух...
# 4           0  ... сделайте русскую озвучку и будет 5 звёзд :...
# 6           0                                                  !
# 7           0              Постоянные проблемы с подключением!!!
# 8           1  Все идеально но отсутствия русского языка даёт...
# 9           0          Где великий и могучий??? Сделайте русский
# 11          0                  Добавьте русский язык пожалуйста(
# 16          0  В описании приложения, написали что есть русск...
# 17          0              Пожалуйста сделайте русский язык!!!!!
# 18          0  Зашла в игру, поиграла ровно минуту и всё, эне...
# 22          1  Почему игра не запускается, перекидывает на ст...
# 23          0  Когда же ждать заявленный в описании русский я...
# 24          0  Русского языка нет, но английский понимаю - та...
# 25          1  Товарищи, учите иностранные языки \r\nИгра зам...
# 27          0  Заявлен русский язык. Заходишь в игре в Настро...
# 28          1  Очень продуманная, интересная игра, все сделан...
# 33          1                              Добавьте русский язык
# 35          0                             Необходим русский язык
# 37          0                                       Русский язык
# 38          0                         Нет русского языка! Обман!
# 41          0  Вы написала есть русский а там его в игре нет ...
# 43          0  Алло, где русский язык??? \r\nНаписано же, что...
# 47          1  Игра выше всех моих ожиданий, и судя по отзыва...
# 48          0                              Где русский язык ????
# 51          0  Играть просто стыдно. Гейплей, сюжет отсутству...
# 53          1                  Добавьте русский язык пожалуйста!
# 54          0  Очень жду Русский язык ,написано что он есть ,...
# 57          1             Спасибо!!! Очень интересно играть! ???
# 58          0  В описании к игре Русский язык указан, фактиче...
# 59          0  Зачем указывать языки которых нет и ничего не ...
# ...       ...                                                ...
# 22459       1  Те кто пишет фу и всё такое, советую не слушат...
# 22460       1  Ламода- супер вариант для тех, кто не может по...
# 22461       1  Отличный магазин. Удобно. Быстро. Дёшево. Фейк...
# 22462       1                     Поиск по фото - просто огонь!!
# 22463       1  Пользуюсь приложением не первый год, мобильное...
# 22464       1  Один из лучших онлайн магазинов! Купила много ...
# 22465       0  Господа разработчики, уберите из приложения да...
# 22467       0  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       0  И цены конские. А их реклама «увеличьте свой ч...
# 22469       1  Отличный сайт и отличное приложение, пока толь...
# 22470       1  Приложение , сайт и вещи и вообще все просто с...
# 22471       0  Сделал заказ, сказали что доставка возможна то...
# 22472       1  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       0  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       1  Сразу все магазины в одном месте ? так как я в...
# 22475       0  Во вкладке «Избранное» дублируются товары. Три...
# 22476       1           Мне нравится. Удобно, быстро, недорого??
# 22477       1                                       Всё хорошо ?
# 22478       0  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       0  Вся обувь китайская подделка, через 15 минут р...
# 22480       0  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       0  Доставка от пони экспресс, портит все. Может в...
# 22482       0  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       0  Приложение где только не пиарят, увидела в вк ...
# 22484       0  Не стыдно врать то, никаких скидок на фирму не...
# 22485       0  Зачем изменили приложение, что за ненужное око...
# 22486       0                          Недобросовестная реклама.
# 22489       0  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       0  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22492       1                                             ??????
#
# [15949 rows x 2 columns]

# %% [markdown]
# Загружаем морфологический анализатор pymorphy2, стоп-слова из списка библиотеки nltk

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
stop_words = set(stopwords.words('russian'))

# %% [markdown]
# Лемматизация

# %%
def strtonormalform(line, should_delete = {'PREP', 'CONJ', 'PRCL'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None):#союзы, предлоги и т.п. не сохраняем
            ans = ans + ' ' + lex
    return ans

#revs_norm = revs.copy()
#revs_norm['content'] = revs_norm['content'].apply(strtonormalform)
    #drop empty reviews
#revs_norm.drop(revs_norm[revs_norm.content == ""].index, inplace=True)

#revs_norm

# %%
#revs_norm.to_csv("normalized_revs.csv")
revs_norm = pd.DataFrame.from_csv("./normalized_revs.csv", encoding="cp1251")
revs_norm
# Out:
#        rating                                            content
# 0           1   интересный сюжет затягивать много время уходи...
# 4           0   сделать русский озвучка быть звезда спасибо п...
# 7           0                    постоянный проблема подключение
# 8           1   весь идеально отсутствие русский язык давать ...
# 9           0                где великий могучий сделать русский
# 11          0                              добавить русский язык
# 16          0   описание приложение написать есть русский язы...
# 17          0                               сделать русский язык
# 18          0   зайти игра поиграть ровно минута весь энергия...
# 22          1   почему игра запускаться перекидывать страница...
# 23          0                ждать заявить описание русский язык
# 24          0   русский язык нет английский понимать небольшо...
# 25          1   товарищ учить иностранный язык игра замечател...
# 27          0   заявить русский язык заходить игра настройка ...
# 28          1   очень продумать интересный игра весь сделать ...
# 33          1                              добавить русский язык
# 35          0                           необходимый русский язык
# 37          0                                       русский язык
# 38          0                             нет русский язык обман
# 41          0   вы написать есть русский там он игра нет сдел...
# 43          0        алло где русский язык написать русский язык
# 47          1   игра выше весь мой ожидание судить отзыв она ...
# 48          0                                   где русский язык
# 51          0   играть стыдно гейплей сюжет отсутствовать так...
# 53          1                              добавить русский язык
# 54          0   очень ждать русский язык написать он есть он нет
# 57          1                     спасибо очень интересно играть
# 58          0   описание игра русский язык указанный фактичес...
# 59          0   зачем указывать язык который нет ничто менять...
# 60          0                              добавить русский язык
# ...       ...                                                ...
# 22458       1   я являться постоянный клиент магазин ламода ч...
# 22459       1   тот кто писать фу весь такой советовать слуша...
# 22460       1   ламода- супер вариант тот кто мочь позволить ...
# 22461       1   отличный магазин удобно быстро дёшево фейковы...
# 22462       1                                   поиск фото огонь
# 22463       1   пользоваться приложение один год мобильный уд...
# 22464       1   один хороший онлайн магазин купить много одеж...
# 22465       0   господин разработчик убрать приложение дата д...
# 22467       0   доставка стиль ой я знать вы попасть поэтому ...
# 22468       0   цена конский они реклама увеличить свой член ...
# 22469       1   отличный сайт отличный приложение пока оформи...
# 22470       1   приложение сайт вещий вообще весь супееееееее...
# 22471       0   сделать заказ сказать доставка возможный завт...
# 22472       1   довольно удобно цена гуд купон который сайт м...
# 22473       0   реклама это ширпотреб достать забавлять накру...
# 22474       1   сразу весь магазин один место я декрет очень ...
# 22475       0   вкладка избранный дублироваться товар три раз...
# 22476       1                 я нравиться удобно быстро недорого
# 22477       1                                        весь хорошо
# 22478       0   смысл это приложение покупать кот мешок дорог...
# 22479       0   весь обувь китайский подделка минута развалит...
# 22480       0   заказывать зимний ботинок сказать доставить ч...
# 22481       0   доставка пони экспресс портить весь мочь вооб...
# 22482       0   меняться плохой сторона многочисленный косяк ...
# 22483       0   приложение где пиарить увидеть вк рекламный р...
# 22484       0   стыдно врать никакой скидка фирма нет магазин...
# 22485       0   зачем изменить приложение ненужный окошко пос...
# 22486       0                           недобросовестный реклама
# 22489       0   цена такой уж маленькая качество изделие очен...
# 22490       0   умереть спид достать ваш реклама деньга вы от...
#
# [15566 rows x 2 columns]

# %%
def strtonormalform_with_neg(line, should_delete = {'PREP', 'CONJ', 'PRCL'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    flag = False
    for word in words:
        if (word in ["не", "Не", "без", "Без"]):
            flag = True
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None):#союзы, предлоги и т.п. не сохраняем
            if (flag):
                flag = False
                lex = "не_" + lex
            ans = ans + ' ' + lex
    return ans

#revs_norm_neg = revs.copy()
#revs_norm_neg['content'] = revs['content'].apply(strtonormalform_with_neg)
    #drop empty reviews
#revs_norm_neg.drop(revs_norm_neg[revs_norm_neg.content == ""].index, inplace=True)

#revs_norm_neg

# %%
#revs_norm_neg.to_csv("normalized_revs_with_neg.csv")
revs_norm_neg = pd.DataFrame.from_csv("./normalized_revs_with_neg.csv", encoding="cp1251")
revs_norm_neg
# Out:
#        rating                                            content
# 0           1   интересный сюжет затягивать много время уходи...
# 4           0   сделать русский озвучка быть звезда спасибо п...
# 7           0                    постоянный проблема подключение
# 8           1   весь идеально отсутствие русский язык давать ...
# 9           0                где великий могучий сделать русский
# 11          0                              добавить русский язык
# 16          0   описание приложение написать есть русский язы...
# 17          0                               сделать русский язык
# 18          0   зайти игра поиграть ровно минута весь энергия...
# 22          1   почему игра не_запускаться перекидывать стран...
# 23          0                ждать заявить описание русский язык
# 24          0   русский язык нет английский понимать небольшо...
# 25          1   товарищ учить иностранный язык игра замечател...
# 27          0   заявить русский язык заходить игра настройка ...
# 28          1   очень продумать интересный игра весь сделать ...
# 33          1                              добавить русский язык
# 35          0                           необходимый русский язык
# 37          0                                       русский язык
# 38          0                             нет русский язык обман
# 41          0   вы написать есть русский там он игра нет сдел...
# 43          0        алло где русский язык написать русский язык
# 47          1   игра выше весь мой ожидание судить отзыв она ...
# 48          0                                   где русский язык
# 51          0   играть стыдно гейплей сюжет отсутствовать так...
# 53          1                              добавить русский язык
# 54          0   очень ждать русский язык написать он есть он нет
# 57          1                     спасибо очень интересно играть
# 58          0   описание игра русский язык указанный фактичес...
# 59          0   зачем указывать язык который нет ничто не_мен...
# 60          0                              добавить русский язык
# ...       ...                                                ...
# 22458       1   я являться постоянный клиент магазин ламода ч...
# 22459       1   тот кто писать фу весь такой советовать не_сл...
# 22460       1   ламода- супер вариант тот кто не_мочь позволи...
# 22461       1   отличный магазин удобно быстро дёшево фейковы...
# 22462       1                                   поиск фото огонь
# 22463       1   пользоваться приложение не_один год мобильный...
# 22464       1   один хороший онлайн магазин купить много одеж...
# 22465       0   господин разработчик убрать приложение дата д...
# 22467       0   доставка стиль ой я не_знать вы попасть поэто...
# 22468       0   цена конский они реклама увеличить свой член ...
# 22469       1   отличный сайт отличный приложение пока оформи...
# 22470       1   приложение сайт вещий вообще весь супееееееее...
# 22471       0   сделать заказ сказать доставка возможный завт...
# 22472       1   довольно удобно цена гуд купон который сайт м...
# 22473       0   реклама это ширпотреб достать забавлять накру...
# 22474       1   сразу весь магазин один место я декрет очень ...
# 22475       0   вкладка избранный дублироваться товар три раз...
# 22476       1                 я нравиться удобно быстро недорого
# 22477       1                                        весь хорошо
# 22478       0   смысл это приложение покупать кот мешок дорог...
# 22479       0   весь обувь китайский подделка минута развалит...
# 22480       0   заказывать зимний ботинок сказать доставить ч...
# 22481       0   доставка пони экспресс портить весь мочь вооб...
# 22482       0   меняться плохой сторона многочисленный косяк ...
# 22483       0   приложение где не_пиарить увидеть вк рекламны...
# 22484       0   не_стыдно врать никакой скидка фирма нет мага...
# 22485       0   зачем изменить приложение ненужный окошко пос...
# 22486       0                           недобросовестный реклама
# 22489       0   цена не_такой уж маленькая качество изделие о...
# 22490       0   умереть спид достать ваш реклама деньга вы от...
#
# [15566 rows x 2 columns]

# %%
def strtonormalform_with_neg_stop(line, should_delete = {'PREP', 'CONJ', 'PRCL'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    flag = False
    for word in words:
        if (word in ["не", "Не", "без", "Без"]):
            flag = True
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None) and (word not in stop_words):#союзы, предлоги и т.п. не сохраняем
            if (flag):
                flag = False
                lex = "не_" + lex
            ans = ans + ' ' + lex
        if (lexInfo.tag.POS is should_delete) or (word in stop_words):
            flag = False
    return ans

#revs_norm_neg_stop = revs.copy()
#revs_norm_neg_stop['content'] = revs['content'].apply(strtonormalform_with_neg_stop)
    #drop empty reviews
#revs_norm_neg_stop.drop(revs_norm_neg_stop[revs_norm_neg_stop.content == ""].index, inplace=True)

#revs_norm_neg_stop

# %%
#revs_norm_neg_stop.to_csv("normalized_revs_with_neg_stop.csv")
revs_norm_neg_stop = pd.DataFrame.from_csv("./normalized_revs_with_neg_stop.csv", encoding="cp1251")
revs_norm_neg_stop
# Out:
#        rating                                            content
# 0           1   интересный сюжет затягивать много время уходи...
# 4           0   сделать русский озвучка звезда спасибо понимание
# 7           0                    постоянный проблема подключение
# 8           1   весь идеально отсутствие русский язык давать ...
# 9           0                где великий могучий сделать русский
# 11          0                              добавить русский язык
# 16          0   описание приложение написать русский язык фак...
# 17          0                               сделать русский язык
# 18          0   зайти игра поиграть ровно минута весь энергия...
# 22          1   почему игра запускаться перекидывать страница...
# 23          0                ждать заявить описание русский язык
# 24          0   русский язык английский понимать небольшой не...
# 25          1   товарищ учить иностранный язык игра замечател...
# 27          0   заявить русский язык заходить игра настройка ...
# 28          1    очень продумать интересный игра сделать здорово
# 33          1                              добавить русский язык
# 35          0                           необходимый русский язык
# 37          0                                       русский язык
# 38          0                             нет русский язык обман
# 41          0   вы написать русский игра сделать русский язык...
# 43          0            алло русский язык написать русский язык
# 47          1   игра выше мой ожидание судить отзыв русскоязы...
# 48          0                                   где русский язык
# 51          0   играть стыдно гейплей сюжет отсутствовать так...
# 53          1                              добавить русский язык
# 54          0                  очень ждать русский язык написать
# 57          1                     спасибо очень интересно играть
# 58          0   описание игра русский язык указанный фактичес...
# 59          0          зачем указывать язык который менять ждать
# 60          0                              добавить русский язык
# ...       ...                                                ...
# 22458       1   я являться постоянный клиент магазин ламода ч...
# 22459       1   тот писать фу весь такой советовать слушать з...
# 22460       1   ламода- супер вариант тот позволить ходить ма...
# 22461       1   отличный магазин удобно быстро дёшево фейковы...
# 22462       1                                   поиск фото огонь
# 22463       1   пользоваться приложение один год мобильный уд...
# 22464       1   один хороший онлайн магазин купить одежда сум...
# 22465       0   господин разработчик убрать приложение дата д...
# 22467       0   доставка стиль ой знать попасть поэтому бегат...
# 22468       0   цена конский реклама увеличить свой член дост...
# 22469       1   отличный сайт отличный приложение пока оформи...
# 22470       1   приложение сайт вещий вообще супееееееееееерр...
# 22471       0   сделать заказ сказать доставка возможный завт...
# 22472       1   довольно удобно цена гуд купон который сайт о...
# 22473       0   реклама ширпотреб достать забавлять накрутить...
# 22474       1   сразу магазин один место декрет очень удобно ...
# 22475       0   вкладка избранный дублироваться товар три раз...
# 22476       1                 я нравиться удобно быстро недорого
# 22477       1                                               весь
# 22478       0   смысл приложение покупать кот мешок дорогой м...
# 22479       0   весь обувь китайский подделка минута развалит...
# 22480       0   заказывать зимний ботинок сказать доставить ч...
# 22481       0   доставка пони экспресс портить мочь вообще пр...
# 22482       0   меняться плохой сторона многочисленный косяк ...
# 22483       0   приложение пиарить увидеть вк рекламный ролик...
# 22484       0   не_стыдно врать никакой скидка фирма магазин ...
# 22485       0   зачем изменить приложение ненужный окошко пос...
# 22486       0                           недобросовестный реклама
# 22489       0   цена такой маленькая качество изделие очень х...
# 22490       0   умереть спид достать ваш реклама деньга отдат...
#
# [15556 rows x 2 columns]

# %%
revs_norm_neg_stop.rating.describe()
# Out:
# count    15556.000000
# mean         0.514721
# std          0.499799
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: rating, dtype: float64

# %%
print ('Количество положительных отзывов составляет {}% от всей выборки'.format(round(float(sum(revs_norm_neg_stop.rating)) / len(revs_norm_neg_stop.rating) * 100, 2)))
print ('Количество положительных отзывов составляет {}% от всей выборки'.format(round(float(len(revs_norm_neg_stop.rating )- sum(revs_norm_neg_stop.rating)) / len(revs_norm_neg_stop.rating) * 100, 2)))
print ('Размер обучающей выборки: {}'.format(revs_norm_neg_stop.shape[0]))
# Out:
# Количество положительных отзывов составляет 51.47% от всей выборки
# Количество положительных отзывов составляет 48.53% от всей выборки
# Размер обучающей выборки: 15556

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.model_selection import RandomizedSearchCV
from nltk.corpus import stopwords
from sklearn.model_selection import cross_validate 
from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

import string

# %%
import sklearn.metrics

def trainTestClf(clf, X_train, y_train, X_test):
    clf.fit(X_train, y_train)
    return clf.predict(X_test)

def get_metrics(y_test, y_pred):
    accuracy = sklearn.metrics.accuracy_score(y_true = y_test, y_pred = y_pred)
    precision = sklearn.metrics.precision_score(y_true = y_test, y_pred = y_pred)
    recall = sklearn.metrics.recall_score(y_true = y_test, y_pred = y_pred)
    f1_score = sklearn.metrics.f1_score(y_true = y_test, y_pred = y_pred)
    
    return {
        "accuracy" : accuracy,
        "precision" : precision,
        "recall" : recall,
        "f1_score" : f1_score
    }


def print_metrics(metrics, vType ='-', cType='-'):
    print("Vectorizing: ", vType, ". Classifier: ", cType, sep='')

    print("accuracy = %.3f" % metrics["accuracy"])
    print("precision = %.3f" % metrics["precision"])
    print("recall = %.3f" % metrics["recall"])
    print("F-мера = %.3f" % metrics["f1_score"])

# %%
clf_svm = LinearSVC()
clf_nb = MultinomialNB()
clf_rf = RandomForestClassifier()
clf_lr = LogisticRegression(C=1e5)

scoring = ['accuracy', 'precision', 'recall', 'f1']

# %%
norm_texts = revs_norm.content.copy()
norm_texts_splitted = revs_norm.content.str.split().copy()

norm_texts_neg = revs_norm_neg.content.copy()
norm_texts_neg_splitted = revs_norm_neg.content.str.split().copy()

norm_texts_neg_stop = revs_norm_neg_stop.content.copy()
norm_texts_neg_stop_splitted = revs_norm_neg_stop.content.str.split().copy()

# %%
#from sklearn.feature_extraction.text import TfidfVectorizer

#tiv = TfidfVectorizer()
#nwd = tiv.fit_transform(norm_texts)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer_uni = CountVectorizer(binary = True, ngram_range=(1,1), max_features= 10000)
count_vectorizer_bi = CountVectorizer(binary = True, ngram_range=(2,2), max_features= 10000)
count_vectorizer_tri = CountVectorizer(binary = True, ngram_range=(3,3), max_features= 10000)
count_vectorizer_uni_bi = CountVectorizer(binary = True, ngram_range=(1,2), max_features= 10000)
count_vectorizer_uni_bi_tri = CountVectorizer(binary = True, ngram_range=(1,3), max_features= 10000)

cvect_uni = count_vectorizer_uni.fit_transform(norm_texts)
cvect_bi = count_vectorizer_bi.fit_transform(norm_texts)
cvect_tri = count_vectorizer_tri.fit_transform(norm_texts)
cvect_uni_bi = count_vectorizer_uni_bi.fit_transform(norm_texts)
cvect_uni_bi_tri = count_vectorizer_uni_bi_tri.fit_transform(norm_texts)

# %%
# без доп признаков

# униграммы
scores1_uni = pd.DataFrame(cross_validate(clf_svm, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni = pd.DataFrame(cross_validate(clf_rf, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni = pd.DataFrame(cross_validate(clf_lr, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni = pd.DataFrame(cross_validate(clf_nb, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# биграммы
scores1_bi = pd.DataFrame(cross_validate(clf_svm, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_bi = pd.DataFrame(cross_validate(clf_rf, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_bi = pd.DataFrame(cross_validate(clf_lr, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_bi = pd.DataFrame(cross_validate(clf_nb, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# триграммы
scores1_tri = pd.DataFrame(cross_validate(clf_svm, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_tri = pd.DataFrame(cross_validate(clf_rf, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_tri = pd.DataFrame(cross_validate(clf_lr, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_tri = pd.DataFrame(cross_validate(clf_nb, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# уни- и биграммы
scores1_uni_bi = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# уни-, би-, и триграммы
scores1_uni_bi_tri = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi_tri = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi_tri = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi_tri = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
# без доп признаков

# униграммы
#X_train, X_test, y_train, y_test = train_test_split(cvect_uni, revs.rating, test_size=0.1, random_state=42)
#metr1_uni = get_metrics(y_test, trainTestClf(clf_svm, X_train, y_train, X_test))
#metr2_uni = get_metrics(y_test, trainTestClf(clf_rf, X_train, y_train, X_test))
#metr3_uni = get_metrics(y_test, trainTestClf(clf_lr, X_train, y_train, X_test))

# %%
class_res_svm = pd.DataFrame({
    "униграммы" : scores1_uni.mean(),
    "биграммы" : scores1_bi.mean(),
    "триграммы" : scores1_tri.mean(),
    "уни- и биграммы" : scores1_uni_bi.mean(),
    "уни-, би- и триграммы" : scores1_uni_bi_tri.mean()
})

print("Результаты для svm")
class_res_svm
# Out:
# Результаты для svm
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        0.239970   0.604225         0.540777               0.508970
# score_time      0.004607   0.004604         0.005404               0.005404
# test_accuracy   0.753115   0.597520         0.830914               0.829950
# test_f1         0.784880   0.710565         0.838606               0.837511
# test_precision  0.712318   0.564395         0.824917               0.824644
# test_recall     0.874645   0.959086         0.854442               0.852196
#
#                 униграммы
# fit_time         0.684292
# score_time       0.005599
# test_accuracy    0.826802
# test_f1          0.834596
# test_precision   0.821275
# test_recall      0.849825

# %%
class_res_rf = pd.DataFrame({
    "униграммы" : scores2_uni.mean(),
    "биграммы" : scores2_bi.mean(),
    "триграммы" : scores2_tri.mean(),
    "уни- и биграммы" : scores2_uni_bi.mean(),
    "уни-, би- и триграммы" : scores2_uni_bi_tri.mean()
})
print("Результаты для random forest")
class_res_rf
# Out:
# Результаты для random forest
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        3.991835   4.411734         3.069780               2.881855
# score_time      0.506560   0.825787         0.101672               0.095864
# test_accuracy   0.743351   0.590261         0.825260               0.830335
# test_f1         0.778681   0.707832         0.823254               0.827306
# test_precision  0.700475   0.559430         0.858471               0.868279
# test_recall     0.877266   0.963576         0.791322               0.790449
#
#                 униграммы
# fit_time         3.687382
# score_time       0.100272
# test_accuracy    0.819866
# test_f1          0.817902
# test_precision   0.852140
# test_recall      0.786959

# %%
class_res_lr = pd.DataFrame({
    "униграммы" : scores3_uni.mean(),
    "биграммы" : scores3_bi.mean(),
    "триграммы" : scores3_tri.mean(),
    "уни- и биграммы" : scores3_uni_bi.mean(),
    "уни-, би- и триграммы" : scores3_uni_bi_tri.mean()
})


print("Результаты для linear regression")
class_res_lr
# Out:
# Результаты для linear regression
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        0.502554   0.174115         1.418208               1.398393
# score_time      0.005603   0.005203         0.007004               0.006205
# test_accuracy   0.739560   0.601889         0.788707               0.788642
# test_f1         0.769004   0.711756         0.799480               0.799798
# test_precision  0.707826   0.567608         0.783207               0.781412
# test_recall     0.842590   0.954221         0.818644               0.820639
#
#                 униграммы
# fit_time         5.024165
# score_time       0.005203
# test_accuracy    0.760182
# test_f1          0.771370
# test_precision   0.758143
# test_recall      0.786461

# %%
class_res_nb = pd.DataFrame({
    "униграммы" : scores4_uni.mean(),
    "биграммы" : scores4_bi.mean(),
    "триграммы" : scores4_tri.mean(),
    "уни- и биграммы" : scores4_uni_bi.mean(),
    "уни-, би- и триграммы" : scores4_uni_bi_tri.mean()
})


print("Результаты для naive bayes")
class_res_nb
# Out:
# Результаты для naive bayes
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        0.013010   0.012609         0.015211               0.016012
# score_time      0.006203   0.006404         0.006805               0.007405
# test_accuracy   0.785430   0.588655         0.860530               0.860402
# test_f1         0.809759   0.708639         0.862160               0.861669
# test_precision  0.745056   0.557955         0.876102               0.878092
# test_recall     0.887491   0.971060         0.849700               0.846832
#
#                 униграммы
# fit_time         0.014210
# score_time       0.006205
# test_accuracy    0.847745
# test_f1          0.849848
# test_precision   0.861947
# test_recall      0.839346

# %%
# результаты для всех классификаторов
scores_uni_bi = pd.DataFrame({
    "SVM" : scores1_uni_bi.mean(),
    "Random forest" : scores2_uni_bi.mean(),
    "Linear regression" : scores3_uni_bi.mean(),
    "Naive Bayes" : scores4_uni_bi.mean()
})

scores_uni_bi
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.418208     0.015211       3.069780  0.540777
# score_time               0.007004     0.006805       0.101672  0.005404
# test_accuracy            0.788707     0.860530       0.825260  0.830914
# test_f1                  0.799480     0.862160       0.823254  0.838606
# test_precision           0.783207     0.876102       0.858471  0.824917
# test_recall              0.818644     0.849700       0.791322  0.854442

# %% [markdown]
# Сочетание униграмм и биграм показывает лучшие результаты, будем использовать данный способ векторизации

# %% [markdown]
# Посмотрим на метрики классификации в текстах с обработкой отрицаний

# %%
cvect_uni_bi_neg = count_vectorizer_uni_bi.fit_transform(norm_texts_neg)


# уни- и биграммы
scores1_uni_bi_neg = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi_neg = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi_neg = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi_neg = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_uni_bi_neg = pd.DataFrame({
    "SVM" : scores1_uni_bi_neg.mean(),
    "Random forest" : scores2_uni_bi_neg.mean(),
    "Linear regression" : scores3_uni_bi_neg.mean(),
    "Naive Bayes" : scores4_uni_bi_neg.mean()
})

scores_uni_bi_neg
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.584025     0.018913       3.139402  0.683551
# score_time               0.007206     0.009806       0.115283  0.007405
# test_accuracy            0.797186     0.872865       0.834705  0.840807
# test_f1                  0.806725     0.873490       0.833001  0.848476
# test_precision           0.794094     0.893897       0.867032  0.832988
# test_recall              0.821635     0.855064       0.802302  0.866166

# %% [markdown]
# Удалим стоп-слова

# %%
cvect_uni_bi_neg_stop = count_vectorizer_uni_bi.fit_transform(norm_texts_neg_stop)


# уни- и биграммы
scores1_uni_bi_neg_stop = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi_neg_stop, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi_neg_stop = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi_neg_stop, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi_neg_stop = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi_neg_stop, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi_neg_stop = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi_neg_stop, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_uni_bi_neg_stop = pd.DataFrame({
    "SVM" : scores1_uni_bi_neg_stop.mean(),
    "Random forest" : scores2_uni_bi_neg_stop.mean(),
    "Linear regression" : scores3_uni_bi_neg_stop.mean(),
    "Naive Bayes" : scores4_uni_bi_neg_stop.mean()
})

scores_uni_bi_neg_stop
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 2.032646     0.025719       3.433674  0.506360
# score_time               0.008806     0.013009       0.114778  0.006112
# test_accuracy            0.792299     0.869312       0.837170  0.838069
# test_f1                  0.802112     0.870127       0.837872  0.845317
# test_precision           0.787711     0.888842       0.858153  0.831781
# test_recall              0.818665     0.853134       0.819290  0.860752

# %%
# Нахождение неверно классифицированных отзывов

def print_wrong_class(y_test, y_pred):
    inds = y_test[y_test.values != y_pred].index
    i = 0
    for idx, rev in revs_norm_neg_stop.iterrows():
        i+=1
        if (idx in inds):
            print (idx, "\tclass=", rev.rating, '\n', rev.content, '\n\n', initial_revs.ix[idx].content, "\n")

# %%
X_train, X_test, y_train, y_test = train_test_split(cvect_uni_bi_neg_stop, revs_norm_neg_stop.rating, test_size=0.1, random_state=42)
classifier = clf_svm.fit(X=X_train, y=y_train)
y_pred = classifier.predict(X_test)

print_wrong_class (y_test, y_pred)
# Out:
# 18 	class= 0
#   зайти игра поиграть ровно минута весь энергия кончиться нужно ждать несколько часы пока восстановиться шикарно
#
#  Зашла в игру, поиграла ровно минуту и всё, энергия кончилась, нужно ждать несколько часов пока восстановится. Шикарно ?
#
# 58 	class= 0
#   описание игра русский язык указанный фактически таковой игра добавить игра убрать описание
#
#  В описании к игре Русский язык указан, фактически такового в игре нет
# Добавьте в игру или уберите из описания
#
# 63 	class= 1
#   крутяга ещё русский добавить сложно постоянно нужно вспоминать английский
#
#  Крутяг
# Ещё бы русский добавили
# А то сложно ,постоянно нужно вспоминать английский )))
#
# 161 	class= 1
#   добавить русский язык
#
#  ДОБАВЬТЕ РУССКИЙ ЯЗЫК
#
# 271 	class= 1
#   плохо английский догадаться понять идти речь смысл
#
#  Даже если ты плохо знаешь английский, можно догадаться и понять о чем идёт речь по смыслу
#
# 296 	class= 0
#   игра супер
#
#  Игра супер
#
# 298 	class= 1
#   весь сделать русский
#
#  Все хорошо, но сделайте на русском!
#
# 449 	class= 0
#   не_понятно
#
#  Не понятно
#
# 603 	class= 1
#   время убить пока надоесть
#
#  Время убить можно, пока что не надоело
#
# 707 	class= 1
#   пацан вообще ребята
#
#  Пацаны вообще ребята
#
# 776 	class= 1
#   кровь пол дойти неделя итог заход игра начаться заново делать
#
#  10 кровей на полу из 10
# Но!
# Дошёл до 2 недели, в итоге сейчас при заходе в игру, все началось заново
# Что делать?
#
# 1182 	class= 0
#   невозможно пройти зомби вирус сложный уровень вирус мутировать заразить миллиард болезнь обнаружить делать лекарство распространение слишком слабый пройти скрытно симптом становиться невозможно не_хватать очки днк симптом
#
#  Невозможно пройти зомби вирус на сложном уровне, вирус просто мутирует когда заражено около 2 млрд и все: болезнь обнаружили, уже делают лекарство, а распространение слишком слабое. Пройти ни скрытно ни с симптомами становится невозможно. Не хватает очков ДНК на симптомы
#
# 1189 	class= 1
#   запуск игра любой режим карта мир загружаться чёрный синица экран нажимать пустота выбор место начать игра нету такой
#
#  При запуске игры в любом режиме карта мира не загружается ( чёрный или синиц экран и все ) и если нажимать в пустоту то выбора места начатая игры нету. Что такое ?
#
# 1377 	class= 1
#   играбельный
#
#  Но играбельно
#
# 1423 	class= 1
#   я понравиться дть версия купить полный пока пройти её пройти год её невозможно пройти целое нормальный почему полный версия реклама
#
#  Мне понравилась демо версия купил полную но все равно 1 лучше пока пройдешь её пройдет 10 лет её невозможно пройти но в целом нормально только вот почему в полной версии у меня реклама?
#
# 1654 	class= 1
#   скачать сначала дть версия игра прошлый минута затянула-сразу скачать полный версия график озвучка сюжет
#
#  Скачал сначала демо версию игры,не прошло и 5 минут как она меня затянула-сразу же скачал полную версию! Графика 5,озвучка 5,сюжет 5 ??
#
# 1856 	class= 0
#   обновлень перестать запускаться вообще пройти игра начинаться заново скука
#
#  После обновлени перестало запускаться, да и вообще после того как прошел. Игра начинается заново. Скука
#
# 1876 	class= 0
#   убить игра система прокачка никакой единственный неплохой музыка
#
#  Просто убили игру, система прокачки никакая. Единственный плюс - неплохая музыка.
#
# 1899 	class= 1
#   оторваться невозможно
#
#  Оторваться невозможно))
#
# 2240 	class= 0
#   я играть игра удовольствие реклама каждый смерть
#
#  Я играю в игры ради удовольствия,а не ради рекламы через каждые 3 смерти !!!!!!!!!!!!!!
#
# 2744 	class= 1
#   баг исправлять услуга работать сервис
#
#  Баги исправляют, все услуги работают — хорошо, что есть такой сервис!
#
# 3090 	class= 1
#   ужасный обновление фильтр портить весь тупить вернуть весь обратно
#
#  Ужасное обновление, фильтры только портят , всё тупит, верните всё обратно!
#
# 3156 	class= 0
#   ранний очень крутой обновление дизайн дизайн лайк глючить замедлить съёмка ранний весь идеально
#
#  Раньше было очень крутое обновление и дизайн! А теперь... Дизайн как в Лайке, и глючит при замедленной съёмке! Хотя раньше всё было идеально?
#
# 3212 	class= 1
#   вернуть старый версия дерьмоооооо
#
#  Верните старую версию,что это за дерьмоооооо
#
# 3251 	class= 0
#   сделать снова можно быть брать музыка приватный клип
#
#  СДЕЛАЙТЕ СНОВА ТАК, ЧТОБЫ МОЖНО БЫЛО БРАТЬ МУЗЫКУ ИЗ ПРИВАТНЫХ КЛИПОВ,ПОЖАЛУЙСТА
#
# 3295 	class= 1
#   новое обновление ужасный вернуть назад
#
#  Новое обновление ужасное! Как вернуть назад????
#
# 3458 	class= 0
#   жадный разраб фэйл игра
#
#  Жадный разраб -фэйл игра
#
# 3656 	class= 1
#   какой милый игра реклама смотреть игра столько милый спасибо ваш звезда
#
#  Какая милая игра??я даже на рекламы не смотрю ,игра на столько милая???????????????????????СПАСИБО!!!!!!
#
#      ??????????????????????????
#                    Это ваши звёзды
#                         ????????
#              ?????????
#
# 3714 	class= 0
#   хороший сделать вайбер скрытый чат месенджер пароль
#
#  Лучше бы сделали как в Вайбере скрытый чат или сам месенджер под паролем
#
# 3736 	class= 0
#   добавить возможность пересылать фото оригинальный размер качество
#
#  Когда добавите возможность пересылать фото в оригинальном размере и качестве?
#
# 4073 	class= 0
#   последний обновление вкладка показывать миниатюра активный сообщение приходить понятно кто
#
#  После последнего обновления когда вкладка «показывать миниатюры» не активна, сообщения приходят не понятно от кого!!!
#
# 4100 	class= 1
#   уважаемый разработчик вернуть обратно шторка возможность видеть пользователь писать сообщение функция скрытие текст заранее спасибо
#
#  Уважаемые разработчики верните пожалуйста обратно шторку с возможностью видеть что за пользователь мне пишет, а не просто сообщение. При функции скрытия текста. Заранее спасибо!
#
# 4119 	class= 1
#   вернуть нормальный миниатюра имя
#
#  Верните нормальные миниатюры, что бы имя было видно, а не как сейчас...
#
# 4124 	class= 0
#   входящая звонок отображаться сразу прощёный
#
#  Входящие звонки не отображаются, сразу прощеный
#
# 4195 	class= 1
#   надо лента
#
#  Надо в ленту
#
# 4228 	class= 0
#   нечего делать старый версия такой
#
#  Нечего делать старая версия такая же
#
# 4343 	class= 0
#   раковый опухоль интернет пространство
#
#  Раковая опухоль на интернет пространстве
#
# 4454 	class= 1
#   почему айфон льзить взять другой аудио
#
#  Почему у айфона не льзя взять у других аудио
#
# 4496 	class= 0
#   норма
#
#  Норм
#
# 4908 	class= 0
#   основной минус вообще понятно кома голова пришлый разбить операция совершать сб онлайн операция карта найти какой-либо расход очень сложно гораздо удобный видеть единый лента расход доход весь карта реализовать онлайн продукт другой банк заходить помощник требоваться несколько минута анализ расход очень неудобно операция провести сб онлайн получить чек операция мой помощник
#
#  Основные минусы:
# Вообще не понятно кому в голову пришло разбить операции, совершаемые в СБ Онлайн и операции по карте.
# Найти какой-либо расход очень сложно.
# Гораздо удобнее видеть единую ленту расходов и доходов по всем картам, как реализовано в онлайн продуктах других банков.
# Когда заходишь в мой помощник, ему требуется несколько минут (!) на анализ расходов. Очень неудобно.
# В операциях, проведённых в СБ Онлайн, можно получить чек, в операциях из моего помощника - нет.
#
# 4953 	class= 1
#   здравствовать добавить возможность копировать текст подробность операция свой лицевой счёт оплатить ранее счёт любой другой информация быть название инна бик пр спасибо
#
#  Здравствуйте. Добавьте пожалуйста возможность копировать текст из подробностей операции, скажем если надо свой лицевой счёт из оплаченных ранее счетов или любые другую информацию будь то название, ИНН, БИК и пр.
# Спасибо!
#
# 4967 	class= 1
#   почему состояние счёт карта наложение арест узнать арест стоя банкомат сделать инф человек видеть причина списать деньга наложить арест спасибо
#
#  Почему не видно состояние счетов и карт при наложении арестов? Узнаешь об аресте,стоя у банкомата! Сделайте инфу,чтобы человек видел,за что и по какой причине списаны деньги или наложен арест! Спасибо
#
# 4986 	class= 0
#   проходить глюк диалог диалог прочитать сразу удалить уведомление новый диалог оставаться уведомление висеть диалог удалить пробовать выходить уч запись приложение переустанавливать помочь можно исправить
#
#  Проходит глюк на диалогах. Если диалог не прочитать, а сразу удалить, то уведомление о новом диалоге остаётся. У меня так уже 2 уведомления висят, хотя все диалоги удалила. Пробовала выходить из уч записи и приложение переустанавливала, не помогло. Можно ли это исправить?
#
# 5256 	class= 0
#   я обновить приложение ползунок эмодзь появиться исправить
#
#  Я обновила приложение, но ползунок с эмодзи не появился , исправьте
#
# 5354 	class= 0
#   моросить невозможность
#
#  Моросит до невозможности
#
# 5366 	class= 1
#   не_заходить приложение аккаунт браузер писать извинить произойти ошибка делать вообще
#
#  Не заходит с приложения в аккаунт, только с браузера! Пишет «извините, произошла ошибка» что делать теперь вообще?
#
# 5399 	class= 0
#   не_мочь присоединить никто мочь добавить делать
#
#  Не могу присоединить никого, и меня не могут добавить. Что делать?
#
# 5534 	class= 0
#   я обновить приложение ползунок эмодзь появиться исправить
#
#  Я обновила приложение, но ползунок с эмодзи не появился , исправьте
#
# 5674 	class= 0
#   давать
#
#  -А давайте !
#
# 5730 	class= 0
#   очень важный функция ставить лайк обсуждение админ группа комментарий обсуждение группа поэтому такой оценка
#
#  Для меня очень важна функция ставить лайк в обсуждениях, как для админа группы. Не в комментариях, а именно в обсуждениях групп, но этого нет, поэтому такая оценка
#
# 5734 	class= 0
#   создатель вконтакте чудесный
#
#  Создатели Вконтакте, вы чудесны)
#
# 5943 	class= 0
#   ребята админ просить добавить тёмный тема вк
#
#  Ребята админы.
# Прошу добавьте пожалуйста тёмную тему для вк
#
# 6186 	class= 0
#   вызвать такси маршрут вокзал сделать водитель приехать принять заказ уехать вокзал мы багаж остаться вызвать транспорт приложение показывать идти заказ видеть карта кататься наш водитель маршрут вызвать другой машина мочь ехать тип водитель отвечать делать правильно опоздать поезд пользоваться служба такси
#
#  Вызвали такси. Маршрут до вокзала. И что сделал водитель? Приехал. Принял заказ и уехал на вокзал. Мы же с багажом остались без вызванного транспорта. В приложении показывает, что идёт заказ. Видим по карте как катается наш водитель по маршруту, вызвать другую машину не можем, так как едем - «типа». Водитель не отвечает. И что делать? Правильно - опоздать на поезд или пользоваться другой службой такси.
#
# 6383 	class= 1
#   идеальный сервис идеальный обслуживание достать этот реклама абсолютно вездеий мочь видеть яндекс такси айпада который пользоваться мочь видеть ролиииииик
#
#  Идеальный сервис. Идеальное обслуживание. Но так достала эта реклама абсолютно ВЕЗДЕЕЕ, я ее уже не могу видеть, у меня яндекс такси даже на айпаде есть которым я не пользуюсь, я уже не могу видеть этот один и тот же ролиииииик!!!!
#
# 6667 	class= 0
#   почему отказ поездка мочь отказ оформить приложение функция отказ поездка
#
#  Почему при отказе от поездки я не могу отказ оформить в приложении, нет функции отказ от поездки.
#
# 6700 	class= 0
#   игра вылетать айфон версия исправить гий
#
#  Игра вылетает на айфон 4 версии 7.1.2 исправьте поже
#
# 6838 	class= 1
#   я бояться заходить игра трусиха видеть видео другой понять игра супер
#
#  Я боюсь заходить в игру я трусиха но я видела видео других и поняла что игра супер)
#
# 7189 	class= 0
#   желать жизнь такой подарок не_вложение деньга играть нереально
#
#  Желаю вам в жизни только таких подарков!
# Без вложения денег играть нереально...
#
# 7196 	class= 1
#   обнова
#
#  Когда обнова?
#
# 7408 	class= 0
#   ужас не_мочь разместить объявление сдача номер коттедж постоянно блокировать модератор указывать новое причина выполнять менять итог объявление мой разместить ранний удобный простой сейчас очень расстраивать авить
#
#  Ужас! Не могу разместить объявление о сдаче номеров в коттедже! Постоянно блокируют модераторы, указывая новые причины, все выполняю , меняю, в итоге объявление мое не размещено!! Раньше было удобнее и проще. Сейчас очень расстраивает авито
#
# 7670 	class= 0
#   почему набирать объявлень конкретный город показывать объявление который находиться радиус километр город
#
#  Почему я набираю объявлени в конкретном городе,а мне показывает объявления которые находятся в радиусе 200 км от города?
#
# 7734 	class= 1
#   очень клевый портиться носить половина год
#
#  Очень клевые и не портятся, ношу уже почти пол года ??
#
# 7889 	class= 0
#   пока
#
#  Пока все хорошо!
#
# 8105 	class= 1
#   цена дорогой сойти
#
#  Цены дорогие. А так сойдет ?
#
# 8501 	class= 1
#   народ
#
#  За народ!
#
# 8533 	class= 1
#   ребята частый обновлять скидывать моросить продолжать
#
#  Ребят почаще обновляли скидывайте, а то моросить продолжает
#
# 8534 	class= 1
#   грузить фото
#
#  У меня не грузит фото
#
# 8546 	class= 0
#   телеграмма перестать работать последний версия обновляться делать не_мочь настроить проксить сервер дуров писать работать прежний режим видимо делать
#
#  Телеграмм перестал работать! До последней версии не обновлялась. Что делать?! Не могу настроить прокси сервер, хотя Дуров писал что все работает в прежнем режиме..но видимо не у меня.. Что делать?!
#
# 8639 	class= 1
#   красава продаться сам кома бороться плохой дорога преступность развивать инфраструктура город бороться террорист мессенджер самый дело свобода слово
#
#  Красава, не продался сами знаете кому. У нас сейчас вместо того, чтоб бороться с плохими дорогами, преступностью, развивать инфраструктуру в городах, борются с "террористами" в мессенджерах. А на самом деле со свободой слова.
#
# 8885 	class= 0
#   вляпаться яндекс музыка помочь отписаться ранний очень любить ваш программа быть ассоциироваться мерзкий яндекс музыка
#
#  «Благодаря» вам я вляпалась в яндекс музыку. Помогите отписаться. Раньше я очень любила вашу программу, теперь вы всегда будете ассоциироваться с мерзкой яндекс музыкой.
#
# 9334 	class= 0
#   никогда юла удаваться продать приложение удобный
#
#  Никогда на юле не удаётся что то продать,но приложение удобное.
#
# 9867 	class= 1
#   я один интересно трек обзорный видео
#
#  Мне одному интересно, что за треки в обзорных видео?
#
# 9887 	class= 1
#   игра отличный постоянный реклама звезда
#
#  Игра отличная
# Но 1 минус постоянная реклама, а так все хорошо 5 звёзд !
#
# 10205 	class= 1
#   товар приходить 3-4 месяц забывать нравиться доставка ужас полный
#
#  Товары приходят !но через 3-4 месяца,когда про них забываешь уже!!!все нравится,НО ВОТ ДОСТАВКА ЭТО УЖАС ПОЛНЫЙ!!!
#
# 10243 	class= 0
#   большинство заказ приходить мелочь всякий действительно ждёшь- увы ах заказ виноватый наш почта человек который работать приложение плохой отслеживание посылка доходить видеть смысл пользоваться деньга возвращать
#
#  Из большинства заказов приходят только мелочи всякие, а то что действительно ждёшь- увы и ах. Из 20 заказов только 10.... Скорее всего виновата наша Почта и люди которые там работают! Приложение не плохое, и отслеживание видно. Но так как посылки не доходят, не вижу смысла им пользоваться, хоть и деньги  возвращают.
#
# 10244 	class= 0
#   товар приходить хорошо хотябнуть деньга возвращать товар хотеться
#
#  90% товара не приходит. Хорошо что хотяб деньги возвращают, но товар хотелось бы больше
#
# 10388 	class= 0
#   заказ прийти хотябнуть деньга возвращать
#
#  Из 11 заказов пришёл только 1 (хотяб деньги возвращают)
#
# 10428 	class= 0
#   читать отзыв понимать прочесть заказ столько время ждать пришлый заказ время потерять
#
#  Читаю отзывы и понимаю, надо было прочесть перед заказом. Столько времени ждала, ничего не пришло. 5 заказов. Время потеряно. ??
#
# 10530 	class= 0
#   заказать часы месяц назад нету спасибо
#
#  Заказала Часы 2 МЕСЯЦА НАЗАД, даже больше!!!
# И где? А нету. Спасибо!
#
# 10562 	class= 0
#   ставить низкий цена товар человек покупать товар высылать деньга возвращать ссылаться задержка система вовсе отвечать не_покупать ничто вы кинуть мой подруга
#
#  Ставят низкие цены на товары, чтоб люди покупали! Товар не высылают и деньги не возвращают! Ссылались на задержки в системе , а теперь и Вовсе не отвечают! Не покупайте здесь НИЧЕГО! Вас кинут!!! Как меня и моих подруг.
#
# 10999 	class= 0
#   здравствовать разроботчик оброшяться просьба понизить цена товар потомучьто уш очень дорого самолёт каторый прославиться ютуба стыть 3000тысяча
#
#  Здравствуйте разроботчики я оброшяюсь к вам с просьбой  понизить цены на товар  потомучьто уш очень  дорого даже самолёт  каторый прославился в ютубе стоет теперь 3000тысячи
#
# 11086 	class= 1
#   ребята круто каждый разом начать показывать уровень заряд телефон ехать подлечить зарядка приезжать дело
#
#  Ребят, все круто. И с каждым разом все лучше и лучше, но начните показывать уровень заряда телефона. А то едешь не подлеченный к зарядке, приезжаешь куда то по делам - а у тебя 20%...
#
# 11150 	class= 0
#   не_правильно прокладывать маршрут крым территория украина
#
#  Не правильно прокладывает маршрут до Крыма. По территории Украины
#
# 11164 	class= 0
#   обновить появиться алиса весь пошло тан тот ра ры
#
#  Как обновил , появилась Алиса, и всё...... все пошло в тан та ра ры ))) все
#
# 11388 	class= 0
#   яндекс весь один место такси навигатор каждый обновление худой
#
#  А у яндекса всё через одно место что такси что навигатор с каждым обновлением только хуже!!
#
# 11483 	class= 0
#   треш показать короткий путь который отправиться объезд трасса м10 дорога разбитый ужасно выбираться 3х часы устать собака проклинать особенно навигатор спасибо разработчик забота пользователь
#
#  Это просто треш . Показал короткий путь по которому мы и отправились в объезд трассы м10. Дорога была разбита просто ужасно, выбирались около 3х часов, устали как собаки проклинали себя и особенно этот навигатор. Спасибо разработчикам за заботу о пользователях.
#
# 11527 	class= 0
#   треш показать короткий путь который отправиться объезд трасса м10 дорога разбитый ужасно выбираться 3х часы устать собака проклинать особенно навигатор спасибо разработчик забота пользователь
#
#  Это просто треш . Показал короткий путь по которому мы и отправились в объезд трассы м10. Дорога была разбита просто ужасно, выбирались около 3х часов, устали как собаки проклинали себя и особенно этот навигатор. Спасибо разработчикам за заботу о пользователях.
#
# 11563 	class= 0
#   не_переворачиваться карта
#
#  Не переворачивается карта на 180^
#
# 11670 	class= 1
#   я ваш реклама рота делать
#
#  Я ВАШУ РЕКЛАМУ В РОТ ДЕЛАЛ
#
# 11718 	class= 1
#   давать золотой яблоко
#
#  Что дают золотые яблоки ?
#
# 11762 	class= 0
#   вообще
#
#  Вообще
#
# 11859 	class= 0
#   хороший задумка отлично убивать время сброситься весь прогресс обновление сброситься рекорд обычный кидание прогресс челендж остаться открытый нож очень обидный
#
#  Хорошая задумка, отлично убивает время, но у меня сбросился весь прогресс после обновления. Сбросился рекорд в обычном кидании, прогресс в челенджах, зато остались открытые ножи. Очень обидно?
#
# 11907 	class= 0
#   реклама очень очень невозможный играть разработчик убрать реклама каждый раунд
#
#  Но рекламы очень очень много невозможна играть разработчики пожалуйста уберите рекламу но не после каждого раунда пожалуйста
#
# 11941 	class= 1
#   ребята хватить ныть реклама человек сделать игра бесплатный он нужный заработок свой идея продвигать далёкий ныть реклама платный приложение
#
#  Ребята хватит ныть что рекламы много. Человек и так сделал игру бесплатной. Ему нужен хоть какой заработок со своих идей ,чтобы продвигать это дальше. А вы только и ноете реклама, платные приложения
#
# 12035 	class= 0
#   один реклама игра отстой
#
#  Одна реклама. Игра отстой
#
# 12118 	class= 0
#   классный дизайн продумать мелочь лого коробочка милый наклейка поднимать настроение пицца ужасно сильно вкусный приятный вежливый курьер очень важный наш время спасибо вы
#
#  Классный дизайн, все продумано до мелочей))  лого, коробочки, милые наклейки - все это поднимает настроение!Пицца ужасно сильно вкусная!))Приятные и вежливые курьеры, что очень важно в наше время.Спасибо что Вы есть!
#
# 12138 	class= 1
#   не_действовать промокод
#
#  Не действует промокод 808
#
# 12203 	class= 0
#   доставка дать организация работать отказываться вообще товар отличный
#
#  Доставка данной организации работать похоже отказывается вообще, а так товары у вас отличные
#
# 12255 	class= 0
#   рекламировать ваш пицца возить район город тула столкнуться это ужасно быть заказывать друг быть советовать
#
#  Для чего рекламировать вашу пиццу и возить не во все районы города Тулы? Столкнулся с этим ужасно, более не буду заказывать и друзьям не буду советовать
#
# 12308 	class= 0
#   рекламировать ваш пицца возить район город тула столкнуться это ужасно быть заказывать друг быть советовать
#
#  Для чего рекламировать вашу пиццу и возить не во все районы города Тулы? Столкнулся с этим ужасно, более не буду заказывать и друзьям не буду советовать
#
# 12473 	class= 0
#   приложение хороший город курск выбрать жить человек добавить город тот который пользоваться
#
#  Приложение хорошее, но нет города Курска, чтоб выбрать где живет человек. Если добавите города те которых нет можно будет пользоваться
#
# 12548 	class= 0
#   сильно хотеть ваш пицца очень вкусный недорогой адрес временно обслуживаться пустить слеза понимать умереть голодный
#
#  я так сильно хотела вашу пиццу, потому что она очень вкусная и недорогая, но мой адрес временно не обслуживается (((( я даже пустила слезу понимаете я умру голодной
#
# 12649 	class= 0
#   господь весь игра построить рандома шанс выжить какой-то ситуация
#
#  Господи, вся игра построена на рандоме, иногда даже шанса нет чтобы выжить в какой-то ситуации
#
# 13011 	class= 0
#   тупой игрушка никчёмный
#
#  Тупая игрушка, никчемная
#
# 13181 	class= 0
#   каждый день меняться маска каждый день сделать какой ерунда вид маска игра что вообще быть здорово человек мочь сам выбирать любимый маска ненужный удалять
#
#  Каждый день меняются маски, просто каждый день, сделали какую то ерунду в виде «Масок игр» к чему вообще это....? Было бы здорово, если бы люди могли бы сами выбирать любимые маски, а ненужные удалять
#
# 13288 	class= 0
#   день мочь ответить сообщение посмотреть стори решить проблема удалять ничто
#
#  5 дней не могу ответить на сообщения и посмотреть стори! Как решить проблему. Удаляла 7 раз. Ничего
#
# 13304 	class= 0
#   заходить приложение телефон сразу отключаться
#
#  Захожу в приложение и телефон сразу отключается хоть там 100%
#
# 13443 	class= 0
#   рианна
#
#  За Рианну!
#
# 13497 	class= 0
#   оставить эффект датойя время плёнка снимать единственный нормальный эффект
#
#  Оставьте уже наконец пожалуйста эффект с датойи временем, будто на пленку снимают?? единственный нормальный эффект.
#
# 13587 	class= 0
#   работодатель сетевой магазин перекрывать вакансия поиск работа превращаться мерзопакостный залипание прокрутка вакансия вниз почему один приложение скрыть интересовать работодатель найти ты действительно нужно мать ваш бомбить
#
#  Работодатели сетевых магазинов перекрывают все вакансии и поиск работы превращается в просто мерзопакостное залипание и прокруткой вакансий вниз.
# Почему ни в одном приложении просто нельзя скрыть не интересующих тебя работодателей и найти то, что тебе действительно нужно?!
# Мать вашу, аж бомбит от вас!
#
# 13664 	class= 1
#   почему вакансия модерация висеть часы
#
#  Почему вакансия на модерации висит уже 5 часов?
#
# 13836 	class= 1
#   положительный
#
#  Положительный
#
# 13930 	class= 0
#   поисковик работать адекватно работа основное студент коекакер приложение конкурентный отношение существующий
#
#  Поисковик работает не адекватно, работа в основном для студентов и коекакеров, Приложение совсем не конкурентное по отношению к уже существующем...
#
# 13931 	class= 0
#   вбивать поиск должность разрешать использовать геолокация дополнительно ручной вбивать свой местоположение итог жить питер определить геолокация настройка какой фига выдать вакансия остальной москва
#
#  Вбиваю в поиск должность, разрешаю использовать геолокацию и дополнительно в ручную вбиваю своё местоположение. В итоге.
# Живу в Питере, он это определил по геолокации ну и настройки, так какого то фига выдал мне 2 вакансии как надо, остальное в Москве.
#
# 14354 	class= 1
#   нравиться постоянный отслеживание мой расположение
#
#  Но не нравится постоянное отслеживание моего расположения
#
# 14736 	class= 1
#   здравствовать добавить описание мост график развод спб нереально полезно график работа станция метро отдельный спасибо
#
#  Здравствуйте, добавьте пожалуйста в описание к мостам график их развода в спб. Это было бы нереально полезно.
# За график работы станций метро отдельное спасибо)
#
# 14978 	class= 1
#   раз столько год подводить
#
#  Ни разу за столько лет не подводила.
#
# 15195 	class= 1
#   хватить просить оценка достать оценивать посмотреть один письмо неделя постоянно оценить оценить себя оценить разраб
#
#  Хватит уже просить оценку. Достали. 300 раз уже оценивал!!! Посмотришь одно письмо раз в неделю и постоянно ОЦЕНИТЕ ДА ОЦЕНИТЕ. Себя оцените,разрабы.
#
# 15274 	class= 1
#   огонёк
#
#  Огоньки!!!!
#
# 15342 	class= 1
#   добавить нормальный чёрный список версия браузер иной отправитель мочь написать письмо сразу попадать спам корзина вообще приходить ставить звезда автомат
#
#  Когда вы уже добавите нормальный черный список, как в версии с браузера??? Чтоб тот, или иной отправитель не мог написать, но и письма его сразу попадали не в спам, и не в корзину, а вообще не приходили? Ставлю 5 звезд автоматом...
#
# 15489 	class= 1
#   весь прекрасно реклама раздражать отключить
#
#  Всё прекрасно, но реклама прям раздражает.
# Как ее отключить?
#
# 15768 	class= 0
#   это пользоваться
#
#  Как этим пользоваться???
#
# 15771 	class= 1
#   теперь прийтись слушать музыка вк половина час
#
#  Теперь не прийдется  слушать музыку через вк пол часа.
#
# 16029 	class= 1
#   приложение вообще понятный эксплуатация не_работать деньга снимать мочь знать обратно вернуть деньга
#
#  Приложение вообще не понятное по эксплуатации ! Не работает ! А деньги за него снимают ! Может кто знает как обратно вернуть деньги ?
#
# 16174 	class= 0
#   двойной тапа удержание регулировать масштаб карта один рука добавить ток двойной тапа исправить
#
#  При двойном тапе и удержании возможно регулировать масштабы Карты одной рукой
# У вас добавили ток: двойной тап
# Исправьте пожалуйста
#
# 16408 	class= 1
#   стать делать функция навигация добавить установка промежуточный точка яндекс навигатор
#
#  Если уж стали делать функции навигации, хорошо бы тогда добавить установку промежуточных точек как в яндекс навигаторе.
#
# 16487 	class= 1
#   убрать идиотический панель сюда отсюда фотка появляется-она убрать перезагрузка
#
#  Уберите идиотическую панель сюда отсюда с фоткой внизу-если она появляется-ее никак не убрать.Только перезагрузка
#
# 16529 	class= 0
#   появиться назойливый реклама карта многий другой приложение яндекс счастие качественный замена отказаться весь сервис яндекс продолжать дух ребята потерять ещё пользователь
#
#  Появилась назойливая реклама. И не только в Картах, но и во многих других приложениях Яндекса. К счастью сейчас есть качественная замена и я отказался от ВСЕХ сервисов Яндекса. Продолжайте в том же духе, ребята, и потеряете ещё больше пользователей ?
#
# 16766 	class= 0
#   починить приложение подводить самый нужный момент деньга плач
#
#  Почините приложение, подводит в самый нужный момент , за что деньги плачу?
#
# 16999 	class= 0
#   купить подписка мочь синхронизировать приложение вк
#
#  Купила подписку, но не могу синхронизировать приложение с вк
#
# 17102 	class= 0
#   почему версия обновляться автоматически я нравиться предыдущий я свой настройка включать ранний такой
#
#  Почему версия обновляется автоматически. Мне больше нравится предыдущая. Я в своих настройках ничего не включала. Раньше такого не было.
#
# 17486 	class= 1
#   последний обновление стать маленький тормозить
#
#  В последние обновления стало меньше тормозить)
#
# 17530 	class= 0
#   убрать реклама надоесть фуууууа
#
#  Уберите рекламу надоело!!!фуууууу
# ?????????????
#
# 17585 	class= 0
#   весь ужасо нормальный музыка послушать
#
#  всё ужасо нормально музыку нельзя послушать
# .
#
# 17843 	class= 1
#   пара год перепробовать эпл гуглиузик яндекс хороший
#
#  За пару лет перепробовал все: эпл и гуглиузик, яндекс лучший.
#
# 18306 	class= 1
#   много реклама
#
#  Много рекламы
#
# 18682 	class= 1
#   идти эротический маршрут
#
#  Иди ты сам по эротическому маршруту.
#
# 18771 	class= 1
#   каждый день обнова
#
#  Каждый день обновы
#
# 18802 	class= 0
#   разработчик просьба увеличить размер приложение очень память использоваться мегабайт вообще око особенно интернет лиметировать просьба увеличить размер гб
#
#  Разработчики, просьба увеличить размер приложения. У меня очень много памяти не используется, 300 мегабайт для меня вообще ни очам особенно когда интернет лиметированный. Просьба увеличить размер до 1,5 Гб ))
#
# 18815 	class= 1
#   отличный обновление создатель виновный плохой тупить телефон
#
#  Отличное обновление! Создатели не виновны, что у вас плохой, тупящий телефон!
#
# 19154 	class= 0
#   раздуть невероятный размер
#
#  Раздули до невероятных размеров
#
# 19294 	class= 0
#   заколебать игра делать навязывание купить ладный реклама купить алмаз ждать время пока жизнь обновиться один игра крутой ждать мина обновиться жизнь
#
#  Заколебали, все игры делают с навязыванием купить, ладно бы только реклама, а тут надо купить алмазы, чтобы не ждать время пока жизни обновятся. Первые игры крутые, но сейчас ждёшь по 20 мин чтоб обновилась жизнь
#
# 19601 	class= 1
#   игра привязать фейсбук страничка фейсбук деактивировать обновление игра открываться прийтись удалить установить заново прогресс сохраниться как-то весь восстановить
#
#  У меня игра была привязана к фейсбук,но страничку в фейсбук деактивировали,после обновления,игра не открывалась,пришлось удалить и установить заново,прогресс не сохранился(можно как-то всё восстановить???
#
# 19622 	class= 0
#   я мочь войти игра
#
#  Я не могу войти в игру!
#
# 19634 	class= 0
#   господин видеореклама автозапуск который встроить громкий звук- знать какой слово называть тот сделать каждый ночь кровать вскакивать такой вопль вместе ребёнок сосед
#
#  Господа, видеореклама с автозапуском в которой встроен громкий звук- я даже не знаю каким словом называть тех, кто это сделал. Чтоб вам каждую ночь с кровати вскакивать под такие вопли. Вместе с детьми и соседями.
#
# 19650 	class= 1
#   обновление грузиться
#
#  После обновления не грузится
#
# 19906 	class= 0
#   один петух зц
#
#  Одни петухи зц
#
# 20002 	class= 0
#   обещать машина приехать 5-10 минута ехать двое долгий очень часто терять клиент приходиться пересаживаться каршеринг писать реальный цифра ожидание
#
#  Обещают что машина приедет через 5-10 минут а она едет в двое дольше и так очень часто.из за этого вы теряете клиентов,приходится пересаживаться каршерингом.ПИШИТЕ РЕАЛЬНЫЕ ЦИФРЫ ОЖИДАНИЯ.
#
# 20269 	class= 0
#   работать ранний стабильно спасать последний время почему слишком долго грузиться вбивать предложение минута два приходить интернет высокий проверять
#
#  Работал раньше стабильно, всегда спасал, но в последнее время почему слишком долго грузится(вбиваю предложение, а перед через минуту или две приходил), хотя интернет высокий(проверял)
#
# 20272 	class= 1
#   не_видеть сеть сегоднешний день постоянно крутиться загрузка весь смотреть один такой начаться точно надзор сюдый добраться утро ещё местами переводить вечер весь заглохлый думать приложение слететь удалить заново установить тож самый защёл сюда отзыв читать последний точно дело самый программа печалька скоро быть точно жить северный корея весь заблокированный нужно
#
#  Не видит сеть с сегоднешнего дня,постоянно крутиться загрузка и всё,я смотрю не у меня одного такое началось,точно надзор и до сюдого добрался похоже,с утра ещё местами то переводил то нет,а к вечеру совсем всё заглохло,думал приложение слетело,удалил и заново установил и опять тож самое,защёл сюда отзывы читаю последние и точно дело не в самой программе значит,печалька короче,скоро будем точно жить как в северной корее,уже всё заблокированно что нужно было.??????
#
# 20318 	class= 0
#   доработать чудо переводить примерно избавляться токсичный дождь машина стоить заправка тд доработать супер честно говорить плоховато
#
#  Когда вы доработаете это чудо?
# Переводит примерно так: избавляться от токсичный дождь; Машина стоит заправка и тд. Доработайте его и будет супер, а так честно говоря плоховато !
#
# 20319 	class= 1
#   сделать перевод текст сообщение автоматически вибер вацап месегисса
#
#  Сделайте перевод текста в сообщениях автоматически Вибер вацап месегисс
#
# 20364 	class= 1
#   включить возможность перевод буфер обмен андроид надеяться вы читать отзыв каждый три просить
#
#  Включите возможность перевода с буфера обмена, как на Андроиде, надеемся Вы читаете отзывы, каждый третий просит об этом.
#
# 20421 	class= 1
#   некоторый слово неправильно перевести
#
#  Некоторые слова неправильно переведены
#
# 20468 	class= 0
#   отзыв
#
#  Отзыв
#
# 20795 	class= 0
#   пробовать почта вконтакте каждый итог писать этот почта принадлежать другой пользователь
#
#  Пробовала все почты и через вконтакте и каждый раз в итоге пишет что эта Почта принадлежит другому пользователю
#
# 20827 	class= 0
#   обновление мочь найти поездка набирать город мочь вставить
#
#  После обновления не могу найти поездку, набираю город, но не могу его вставить
#
# 20944 	class= 0
#   очень коммерческий перевозка приложение
#
#  Очень много коммерческих перевозок в приложении
#
# 20947 	class= 0
#   бесить программа автоматически выставлять качество промежуточный точка населить пункт который попадаться путь следование ездить работа заезжать туда время желание произвольно автоматически меняться цена проезд
#
#  Бесит, что программа автоматически выставляет в качестве промежуточных точек все населённые пункты, которые попадаются на пути следования(я езжу на работу, мне заезжать туда нет ни времени, ни желания). Вследствие чего, произвольно и автоматически меняется цена проезда.
#
# 21697 	class= 0
#   бомба приложение
#
#  Бомба приложение!!!!!!!! 100/100
#
# 21713 	class= 0
#   я мочь сохранить видео нажатие экспортировать выходить страничка предложение купить платный версия покупка сохранить видео мочь очень нравиться приложение пользоваться она давно появиться такой проблема надеяться исправить
#
#  Я не могу сохранить видео, так как при нажатии на "экспортировать" выходит страничка с предложением купить платную версию, без ее покупки ты сохранить видео просто НЕ МОЖЕШЬ! Очень нравится это приложение, пользуюсь ею давно, но появилась такая проблема :( Надеюсь вы исправите и как можно скорее!
#
# 21750 	class= 0
#   играть
#
#  Играть не возможно
#
# 21826 	class= 1
#   я считать блистательный идея вспоминать прошлое год великолепно
#
#  Я считаю что просто блистательная идея. Вспоминать прошлое в 2015 году великолепно!
#
# 21841 	class= 0
#   типо дть версия игра платный
#
#  Это что то типо демо версии игра платная
#
# 21869 	class= 0
#   ага
#
#  Ага
#
# 22309 	class= 0
#   интернет магазин одежда цена космический бутик тот самый одежда дешёвый
#
#  Для интернет магазина одежды цены космические, даже в бутиках та же самая одежда дешевле
#
# 22322 	class= 1
#   уже давно пользоваться приложение подобный проблема сегодня твориться что-то понятный фильтр сортировка вообще работать невозможно найти нужный товар исправить вообще приложение крутой очень удобный поиск хороший рубрикатор весь понятно цена порядок порой дешёвый магазин
#
#  Уже давно пользуюсь приложением, и никогда подобных проблем не было. Но сегодня творится что-то не понятное. Фильтры и сортировка вообще не работают. Невозможно найти нужный товар. Исправьте ну.
# А вообще, приложение крутое. Очень удобный поиск, хороший рубрикатор. Все просто и понятно. С ценами все в порядке, порой, дешевле чем в магазинах.
#
# 22340 	class= 0
#   скидка заказ применяться весь заказ выкуп отказаться чего-то прощать кусок скидка вещий итог скидка выйти смешной заказ оформлять воскресение привезти вторник куртка стоить заказ проваливаться внутрь артикул футболка такой ерунда здорово итог обмануть никто рекомендовать пользоваться это сервис
#
#  Скидка 1000? на заказ применяется ко всему заказу до выкупа. Если отказались от чего-то, то прощай кусок скидки от это вещи. В итоге скидка вышла смешная - 200?. Заказ оформлял в воскресенье, привезли во вторник. Куртка стоит 12900 в заказе, «проваливаемся» внутрь артикула, а там она уже 10300! С футболкой такая же ерунда. Здорово, в итоге обманули почти на 4000. Никому не рекомендую пользоваться этим сервисом.
#
# 22416 	class= 0
#   цена раз 5-2 раз дорогой магазин зря время потратить
#
#  Цены раза в 1,5-2 раза дороже чем в магазине((( зря только время потратил
#
# 22430 	class= 1
#   пара покупка делать ламода сервис примерка доставка отменный единственный последний время напрягать обилие реклама вечер включать ребёнок мультик ютуба включаться пока ваш реклама пройти мочь исключить контент ваш реклама показывать думать ребёнок пойти покупка
#
#  Пару покупок делал в ламоде, сервис с примеркой и Доставкой отменный.
# Единственное что в последнее время напрягает обилие рекламы, по вечерам включаю ребёнку мультики на ютубе, а они не включаются пока ваша реклама не пройдёт, вы же можете исключить контент где вашу рекламу показывают, неужели правда думаете что дети пойдут за покупками к вам.
#
# 22479 	class= 0
#   весь обувь китайский подделка минута развалиться кроссовок не_покупать возврат делать очень сложно
#
#  Вся обувь китайская подделка, через 15 минут развалились кроссовки!!! Не покупайте у них ничего! Возврат делать очень сложно !

# %% [markdown]
# Считываем словарь тональностей из файла

# %%
sent = pd.read_csv('words_sent.csv', sep=';', header=None, names =['word', 'sent', '1', '2', '3'])

# %%
Dict = sent.groupby('word')['sent'].mean().to_dict()

# %%
tone = np.zeros((len(norm_texts_neg_stop), 4))

# %%
Dict.get('ужасный', 0)
# Out:
# -1.25

# %% [markdown]
# Определяем общее значение тональности по словарю

# %%
# нормальзованное значение тональности
for i, text in enumerate(norm_texts_neg_stop_splitted):
    count = 0
    for j, word in enumerate(text):        
        neg = False
        if (word.startswith("не_")):
            s = Dict.get(word[3:], 0)
            neg = True
        else:
            s = Dict.get(word, 0)

        if s != 0:
            count += 1
            if (neg):
                tone[i, 0] += -s
            else:
                tone[i, 0] += s
        if (s == 0 and neg):
            tone[i, 0] += -0.1
    if count:
        tone[i, 0] = tone[i, 0]/count

# %%
tone = tone - tone.min()
tone = tone /tone.max()

# %%
from scipy import sparse

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0].reshape(tone[:, 0].shape[0], 1))))

# %%
scores1_tone_dict_norm = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_tone_dict_norm = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_tone_dict_norm = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_tone_dict_norm = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_tone_dict_norm = pd.DataFrame({
    "SVM" : scores1_tone_dict_norm.mean(),
    "Random forest" : scores2_tone_dict_norm.mean(),
    "Linear regression" : scores3_tone_dict_norm.mean(),
    "Naive Bayes" : scores4_tone_dict_norm.mean()
})

scores_tone_dict_norm
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.825856     0.021519       3.572651  0.717901
# score_time               0.007401     0.008204       0.174531  0.030526
# test_accuracy            0.793713     0.871304       0.842185  0.837941
# test_f1                  0.802818     0.873233       0.838662  0.845005
# test_precision           0.790870     0.883997       0.882081  0.832332
# test_recall              0.817042     0.863625       0.800184  0.859629

# %%
#class_result_svm = class_result_svm.append(pd.Series(metr1, name="+ тональный словарь"))
#class_result_rf = class_result_rf.append(pd.Series(metr2, name="+ тональный словарь"))
#class_result_lr = class_result_lr.append(pd.Series(metr3, name="+ тональный словарь"))

#print("---svm---", class_result_svm)
#print("---lr---", class_result_rf)
#print("---rf---", class_result_lr)

# %%
tone = np.zeros((len(norm_texts_neg_stop), 4))

# общее значение тональности
for i, text in enumerate(norm_texts_neg_stop_splitted):
    count = 0
    for j, word in enumerate(text):  
        neg = False
        if (word.startswith("не_")):
            s = Dict.get(word[3:], 0)
            neg = True
        else:
            s = Dict.get(word, 0)

        if s != 0:
            count += 1
            if (neg):
                tone[i, 0] += -s
            else:
                tone[i, 0] += s
        if (s == 0 and neg):
            tone[i, 0] += -0.1

# %%
for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()
# Out:
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()

# %%
tone
# Out:
# array([[ 0.5843724 ,         nan,         nan,         nan],
#        [ 0.55527847,         nan,         nan,         nan],
#        [ 0.47963425,         nan,         nan,         nan],
#        ...,
#        [ 0.47429046,         nan,         nan,         nan],
#        [ 0.49044057,         nan,         nan,         nan],
#        [ 0.46716542,         nan,         nan,         nan]])

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0].reshape(tone[:, 0].shape[0], 1))))

# %%
scores1_tone_dict = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_tone_dict = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_tone_dict = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_tone_dict = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_tone_dict = pd.DataFrame({
    "SVM" : scores1_tone_dict.mean(),
    "Random forest" : scores2_tone_dict.mean(),
    "Linear regression" : scores3_tone_dict.mean(),
    "Naive Bayes" : scores4_tone_dict.mean()
})

scores_tone_dict
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.947382     0.019914       3.283521  0.624508
# score_time               0.008006     0.013910       0.114986  0.005905
# test_accuracy            0.790179     0.870147       0.842893  0.838262
# test_f1                  0.800507     0.871783       0.840949  0.845362
# test_precision           0.785050     0.884724       0.876345  0.832536
# test_recall              0.818291     0.860128       0.808800  0.860128

# %% [markdown]
# Ненормализованная разметка тональности работает лучше

# %%
# количество слов

for i, text in enumerate(norm_texts_neg_stop_splitted):
    tone[i, 1] = len(text)

for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0:1])))

scores1_words_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_words_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_words_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_words_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_words_num = pd.DataFrame({
    "SVM" : scores1_words_num.mean(),
    "Random forest" : scores2_words_num.mean(),
    "Linear regression" : scores3_words_num.mean(),
    "Naive Bayes" : scores4_words_num.mean()
})

scores_words_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.707014     0.016112       3.347423  0.688489
# score_time               0.007405     0.008006       0.106969  0.015473
# test_accuracy            0.790179     0.870147       0.847521  0.838262
# test_f1                  0.800507     0.871783       0.846276  0.845362
# test_precision           0.785050     0.884724       0.878130  0.832536
# test_recall              0.818291     0.860128       0.817167  0.860128

# %% [markdown]
# Признак ухудшает качество классификации для метода Случайного леса, для остальных не меняет - плохой признак, не будем включать

# %%
#class_result_svm = class_result_svm.append(pd.Series(metr1, name="+ количество слов"))
#class_result_rf = class_result_rf.append(pd.Series(metr2, name="+ количество слов"))
#class_result_lr = class_result_lr.append(pd.Series(metr3, name="+ количество слов"))

#print("---svm---", class_result_svm)
#print("---lr---", class_result_rf)
#print("---rf---", class_result_lr)

# %% [markdown]
# Считаем количество восклицательных знаков

# %%
initial_left_revs = initial_revs.drop(initial_revs.index.difference(revs_norm_neg_stop.index))
initial_left_revs['rating'] = revs_norm_neg_stop['rating']

for i, text in enumerate(initial_left_revs.content):
    num = 0
    for e in text:
        if e == '!':
            num += 1
            #tone[i, 1] = 1
    tone[i, 1] = num

# %%
for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0:1])))

scores1_excl_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_excl_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_excl_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_excl_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_excl_num = pd.DataFrame({
    "SVM" : scores1_excl_num.mean(),
    "Random forest" : scores2_excl_num.mean(),
    "Linear regression" : scores3_excl_num.mean(),
    "Naive Bayes" : scores4_excl_num.mean()
})

scores_excl_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.708017     0.018213       3.350076  0.659572
# score_time               0.007405     0.009607       0.113177  0.006610
# test_accuracy            0.790179     0.870147       0.845078  0.838262
# test_f1                  0.800507     0.871783       0.842592  0.845362
# test_precision           0.785050     0.884724       0.881385  0.832536
# test_recall              0.818291     0.860128       0.807677  0.860128

# %% [markdown]
# норм, оставим

# %% [markdown]
# Считаем количество глаголов в повелительном наклонении (встречаются часто в отрицательных отзывах)

# %%
def getImperatives(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = 0
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        if (lexInfo.tag.POS == 'VERB'):
            if (lexInfo.tag.mood == 'impr'):
                ans += 1
    if (ans > 0):
        return ans
    else:
        return 0
    return ans

initial_left_revs['imps'] = [getImperatives(line) for line in initial_left_revs.content]

# %%
initial_revs
# Out:
#        rating                                            content
# 0           5  Интересный сюжет, затягивает. Много времени ух...
# 1           4  Плюсы: \r\n1. Игра интересная 2. Образы учител...
# 2           3  Огорчил тот факт , что суть игры заключается в...
# 3           5  Была постоянная ошибка с подключением, почти н...
# 4           1  ... сделайте русскую озвучку и будет 5 звёзд :...
# 5           3                         Почему нет русского языка?
# 6           1                                                  !
# 7           1              Постоянные проблемы с подключением!!!
# 8           5  Все идеально но отсутствия русского языка даёт...
# 9           1          Где великий и могучий??? Сделайте русский
# 10          4  Thanks for the game, I fancy it pretty much, h...
# 11          2                  Добавьте русский язык пожалуйста(
# 12          5  Игра отличная, отсутствие русского языка не ме...
# 13          4                       Please add Russian language!
# 14          5  Everything was great till Wednesday night. Gam...
# 15          3                         Where Russian language ???
# 16          1  В описании приложения, написали что есть русск...
# 17          1              Пожалуйста сделайте русский язык!!!!!
# 18          2  Зашла в игру, поиграла ровно минуту и всё, эне...
# 19          2  Игра интересная, но как же достал connect erro...
# 20          1  Where is the Russian language? why the descrip...
# 21          4  Без русского играть невозможно. От выборы зави...
# 22          5  Почему игра не запускается, перекидывает на ст...
# 23          1  Когда же ждать заявленный в описании русский я...
# 24          2  Русского языка нет, но английский понимаю - та...
# 25          5  Товарищи, учите иностранные языки \r\nИгра зам...
# 26          3                 Always connection lost! Fix please
# 27          1  Заявлен русский язык. Заходишь в игре в Настро...
# 28          5  Очень продуманная, интересная игра, все сделан...
# 29          3  Игра нармуль. Разрабочики добавьте русский язык !
# ...       ...                                                ...
# 22463       5  Пользуюсь приложением не первый год, мобильное...
# 22464       5  Один из лучших онлайн магазинов! Купила много ...
# 22465       1  Господа разработчики, уберите из приложения да...
# 22466       4  Для айфона не очень удобное приложение. Листат...
# 22467       1  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       1  И цены конские. А их реклама «увеличьте свой ч...
# 22469       5  Отличный сайт и отличное приложение, пока толь...
# 22470       5  Приложение , сайт и вещи и вообще все просто с...
# 22471       1  Сделал заказ, сказали что доставка возможна то...
# 22472       5  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       1  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       5  Сразу все магазины в одном месте ? так как я в...
# 22475       2  Во вкладке «Избранное» дублируются товары. Три...
# 22476       5           Мне нравится. Удобно, быстро, недорого??
# 22477       5                                       Всё хорошо ?
# 22478       1  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       1  Вся обувь китайская подделка, через 15 минут р...
# 22480       1  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       1  Доставка от пони экспресс, портит все. Может в...
# 22482       1  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       1  Приложение где только не пиарят, увидела в вк ...
# 22484       1  Не стыдно врать то, никаких скидок на фирму не...
# 22485       1  Зачем изменили приложение, что за ненужное око...
# 22486       1                          Недобросовестная реклама.
# 22487       1  Приложение классное, но реклама на YouTube за*...
# 22488       4  Почините,пожалуйста,приложение, заходила два г...
# 22489       1  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       1  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22491       4  Отличное приложение, удобное в использовании, ...
# 22492       5                                             ??????
#
# [22493 rows x 2 columns]

# %%
tone[:,2] = list(initial_left_revs['imps'])

for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0:2])))

scores1_imper_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_imper_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_imper_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_imper_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_imper_num = pd.DataFrame({
    "SVM" : scores1_imper_num.mean(),
    "Random forest" : scores2_imper_num.mean(),
    "Linear regression" : scores3_imper_num.mean(),
    "Naive Bayes" : scores4_imper_num.mean()
})

scores_imper_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.699627     0.017212       3.025412  0.586125
# score_time               0.006005     0.007405       0.101176  0.007201
# test_accuracy            0.792299     0.870147       0.843149  0.838712
# test_f1                  0.802220     0.871783       0.840594  0.845742
# test_precision           0.787384     0.884724       0.879521  0.833126
# test_recall              0.819290     0.860128       0.806304  0.860253

# %% [markdown]
# вроде норм

# %% [markdown]
# Считаем количество вопросительных слов. Встречаются в негативных отзывах ("Пропала кнопка вызова. Где её найти?!?!")

# %%
interrogative_words = ["где", "как", "зачем", "почему", "какой"]

for i, text in enumerate(norm_texts_neg_stop_splitted):
    count = 0
    for j, word in enumerate(text):        
        if (word in interrogative_words):
            count += 1
    tone[i, 3] = count

# %%
for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0:3])))

scores1_interr_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_interr_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_interr_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_interr_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_interr_num = pd.DataFrame({
    "SVM" : scores1_interr_num.mean(),
    "Random forest" : scores2_interr_num.mean(),
    "Linear regression" : scores3_interr_num.mean(),
    "Naive Bayes" : scores4_interr_num.mean()
})

scores_interr_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.658277     0.016412       3.088578  0.604234
# score_time               0.007005     0.007505       0.101977  0.006905
# test_accuracy            0.792749     0.870083       0.844500  0.838776
# test_f1                  0.802579     0.871684       0.841759  0.845869
# test_precision           0.788189     0.884906       0.880199  0.832916
# test_recall              0.819290     0.859753       0.807931  0.860752

# %%
result_metrics_svm = pd.DataFrame({
    "0 униграммы и биграммы" : scores_uni_bi['SVM'],
    "1 + обработка отрицаний" : scores_uni_bi_neg['SVM'],
    "2 + удаление стоп слов" : scores_uni_bi_neg_stop['SVM'],
    "3 + словарь тональности" : scores_tone_dict['SVM'],
    "4 + количество восклицательных знаков" : scores_excl_num['SVM'],
    "5 + количество глаголов в повел. накл." : scores_imper_num['SVM'],
    "6 + количество вопросительных слов" : scores_interr_num['SVM']
    
})

result_metrics_svm
# Out:
#                 0 униграммы и биграммы  1 + обработка отрицаний  \
# fit_time                      0.540777                 0.683551
# score_time                    0.005404                 0.007405
# test_accuracy                 0.830914                 0.840807
# test_f1                       0.838606                 0.848476
# test_precision                0.824917                 0.832988
# test_recall                   0.854442                 0.866166
#
#                 2 + удаление стоп слов  3 + словарь тональности  \
# fit_time                      0.506360                 0.624508
# score_time                    0.006112                 0.005905
# test_accuracy                 0.838069                 0.838262
# test_f1                       0.845317                 0.845362
# test_precision                0.831781                 0.832536
# test_recall                   0.860752                 0.860128
#
#                 4 + количество восклицательных знаков  \
# fit_time                                     0.659572
# score_time                                   0.006610
# test_accuracy                                0.838262
# test_f1                                      0.845362
# test_precision                               0.832536
# test_recall                                  0.860128
#
#                 5 + количество глаголов в повел. накл.  \
# fit_time                                      0.586125
# score_time                                    0.007201
# test_accuracy                                 0.838712
# test_f1                                       0.845742
# test_precision                                0.833126
# test_recall                                   0.860253
#
#                 6 + количество вопросительных слов
# fit_time                                  0.604234
# score_time                                0.006905
# test_accuracy                             0.838776
# test_f1                                   0.845869
# test_precision                            0.832916
# test_recall                               0.860752

# %%
result_metrics_nb = pd.DataFrame({
    "0 униграммы и биграммы" : scores_uni_bi['Naive Bayes'],
    "1 + обработка отрицаний" : scores_uni_bi_neg['Naive Bayes'],
    "2 + удаление стоп слов" : scores_uni_bi_neg_stop['Naive Bayes'],
    "3 + словарь тональности" : scores_tone_dict['Naive Bayes'],
    "4 + количество восклицательных знаков" : scores_excl_num['Naive Bayes'],
    "5 + количество глаголов в повел. накл." : scores_imper_num['Naive Bayes'],
    "6 + количество вопросительных слов" : scores_interr_num['Naive Bayes']

})

result_metrics_nb
# Out:
#                 0 униграммы и биграммы  1 + обработка отрицаний  \
# fit_time                      0.015211                 0.018913
# score_time                    0.006805                 0.009806
# test_accuracy                 0.860530                 0.872865
# test_f1                       0.862160                 0.873490
# test_precision                0.876102                 0.893897
# test_recall                   0.849700                 0.855064
#
#                 2 + удаление стоп слов  3 + словарь тональности  \
# fit_time                      0.025719                 0.019914
# score_time                    0.013009                 0.013910
# test_accuracy                 0.869312                 0.870147
# test_f1                       0.870127                 0.871783
# test_precision                0.888842                 0.884724
# test_recall                   0.853134                 0.860128
#
#                 4 + количество восклицательных знаков  \
# fit_time                                     0.018213
# score_time                                   0.009607
# test_accuracy                                0.870147
# test_f1                                      0.871783
# test_precision                               0.884724
# test_recall                                  0.860128
#
#                 5 + количество глаголов в повел. накл.  \
# fit_time                                      0.017212
# score_time                                    0.007405
# test_accuracy                                 0.870147
# test_f1                                       0.871783
# test_precision                                0.884724
# test_recall                                   0.860128
#
#                 6 + количество вопросительных слов
# fit_time                                  0.016412
# score_time                                0.007505
# test_accuracy                             0.870083
# test_f1                                   0.871684
# test_precision                            0.884906
# test_recall                               0.859753

# %%
result_metrics_rf = pd.DataFrame({
    "0 униграммы и биграммы" : scores_uni_bi['Random forest'],
    "1 + обработка отрицаний" : scores_uni_bi_neg['Random forest'],
    "2 + удаление стоп слов" : scores_uni_bi_neg_stop['Random forest'],
    "3 + словарь тональности" : scores_tone_dict['Random forest'],
    "4 + количество восклицательных знаков" : scores_excl_num['Random forest'],
    "5 + количество глаголов в повел. накл." : scores_imper_num['Random forest'],
    "6 + количество вопросительных слов" : scores_interr_num['Random forest']

})

result_metrics_rf
# Out:
#                 0 униграммы и биграммы  1 + обработка отрицаний  \
# fit_time                      3.069780                 3.139402
# score_time                    0.101672                 0.115283
# test_accuracy                 0.825260                 0.834705
# test_f1                       0.823254                 0.833001
# test_precision                0.858471                 0.867032
# test_recall                   0.791322                 0.802302
#
#                 2 + удаление стоп слов  3 + словарь тональности  \
# fit_time                      3.433674                 3.283521
# score_time                    0.114778                 0.114986
# test_accuracy                 0.837170                 0.842893
# test_f1                       0.837872                 0.840949
# test_precision                0.858153                 0.876345
# test_recall                   0.819290                 0.808800
#
#                 4 + количество восклицательных знаков  \
# fit_time                                     3.350076
# score_time                                   0.113177
# test_accuracy                                0.845078
# test_f1                                      0.842592
# test_precision                               0.881385
# test_recall                                  0.807677
#
#                 5 + количество глаголов в повел. накл.  \
# fit_time                                      3.025412
# score_time                                    0.101176
# test_accuracy                                 0.843149
# test_f1                                       0.840594
# test_precision                                0.879521
# test_recall                                   0.806304
#
#                 6 + количество вопросительных слов
# fit_time                                  3.088578
# score_time                                0.101977
# test_accuracy                             0.844500
# test_f1                                   0.841759
# test_precision                            0.880199
# test_recall                               0.807931

# %%
result_metrics_lr = pd.DataFrame({
    "0 униграммы и биграммы" : scores_uni_bi['Linear regression'],
    "1 + обработка отрицаний" : scores_uni_bi_neg['Linear regression'],
    "2 + удаление стоп слов" : scores_uni_bi_neg_stop['Linear regression'],
    "3 + словарь тональности" : scores_tone_dict['Linear regression'],
    "4 + количество восклицательных знаков" : scores_excl_num['Linear regression'],
    "5 + количество глаголов в повел. накл." : scores_imper_num['Linear regression'],
    "6 + количество вопросительных слов" : scores_interr_num['Linear regression']

})

result_metrics_lr
# Out:
#                 0 униграммы и биграммы  1 + обработка отрицаний  \
# fit_time                      1.418208                 1.584025
# score_time                    0.007004                 0.007206
# test_accuracy                 0.788707                 0.797186
# test_f1                       0.799480                 0.806725
# test_precision                0.783207                 0.794094
# test_recall                   0.818644                 0.821635
#
#                 2 + удаление стоп слов  3 + словарь тональности  \
# fit_time                      2.032646                 1.947382
# score_time                    0.008806                 0.008006
# test_accuracy                 0.792299                 0.790179
# test_f1                       0.802112                 0.800507
# test_precision                0.787711                 0.785050
# test_recall                   0.818665                 0.818291
#
#                 4 + количество восклицательных знаков  \
# fit_time                                     1.708017
# score_time                                   0.007405
# test_accuracy                                0.790179
# test_f1                                      0.800507
# test_precision                               0.785050
# test_recall                                  0.818291
#
#                 5 + количество глаголов в повел. накл.  \
# fit_time                                      1.699627
# score_time                                    0.006005
# test_accuracy                                 0.792299
# test_f1                                       0.802220
# test_precision                                0.787384
# test_recall                                   0.819290
#
#                 6 + количество вопросительных слов
# fit_time                                  1.658277
# score_time                                0.007005
# test_accuracy                             0.792749
# test_f1                                   0.802579
# test_precision                            0.788189
# test_recall                               0.819290

# %%
X_train, X_test, y_train, y_test = train_test_split(train, revs_norm_neg_stop.rating, test_size=0.1) #random_state = 42
classifier = clf_nb.fit(X=X_train, y=y_train)
y_pred = classifier.predict(X_test)

print_wrong_class (y_test, y_pred)
# Out:
# 22 	class= 1
#   почему игра запускаться перекидывать страница авторизация фейсбук авторизироваться снова открываться приложение снова фейсбук направлять несколько день замкнутый круг
#
#  Почему игра не запускается, перекидывает на страницу авторизации в фейсбуке, когда авторизируюсь снова открывается приложение, а из него снова на фейсбук направляет... И так уже несколько дней. Замкнутый круг.
#
# 63 	class= 1
#   крутяга ещё русский добавить сложно постоянно нужно вспоминать английский
#
#  Крутяг
# Ещё бы русский добавили
# А то сложно ,постоянно нужно вспоминать английский )))
#
# 145 	class= 0
#   добавить русский язык звезда
#
#  Добавьте пожалуйста русский язык,тогда будет 5 звёзд
#
# 158 	class= 0
#   игра стоящий она играть понимать идти речь
#
#  Видно , что игра стоящая , но как в неё играть не понимая о чем идёт речь
#
# 247 	class= 1
#   добавить русский язык
#
#  Добавьте пожалуйста русский язык ?
#
# 275 	class= 1
#   язык английский трудно
#
#  Но с языком с английским трудно
#
# 296 	class= 0
#   игра супер
#
#  Игра супер
#
# 443 	class= 0
#   нету русский язык
#
#  Нету русского языка.
#
# 468 	class= 0
#   руссиана лангуага плеас
#
#  руссиан лангуаге плеасе
#
# 547 	class= 0
#   игра довольно забавный крайне однообразный примитивный
#
#  Игра довольно забавна, но крайне однообразна и примитивна.
#
# 558 	class= 1
#   ебучих металлист аду
#
#  10/10 ебучих металлистов в аду
#
# 596 	class= 1
#   наткнуться игра совершенно случайно описание заинтересовать дать игра купить её игра затянуть час неплохо
#
#  Наткнулась на эту игру совершенно случайно. Против описание, меня заинтересовала данная игра и я купила её. Игра затянула меня на час, неплохо ???
#
# 629 	class= 1
#   почему игра обойтись указать
#
#  Почему игра обошлась в 130?, а не в 15?, как было указано?
#
# 664 	class= 1
#   понимать смысл нужный деньга смысл вкладывать задание смерть происходить ещё понимать значение другой всадник апокалипсис конкурент мой босс смерть почему мочь работать нужный очки который давать выполнение задание
#
#  Но не совсем понимаю смысла, зачем нужны деньги и какой смысл их вкладывать задания смерти, если от этого ничего не происходит) и ещё не понимаю значение других всадников апокалипсиса. Если они конкуренты моего босса - смерти, то почему я иногда могу работать на них, и зачем мне нужны очки, которые дают за выполнение их заданий?
#
# 712 	class= 0
#   автор очень умный сделать атмосфера игра увлекательный контент интеллект хватить выпустить сырой продукт типо человек схавать не_платить посредственность копейка
#
#  Автор не очень то и умен, сделал атмосферу игры, а на увлекательный контент интеллекта не хватило, выпустил сырой продукт, типо люди схавают.
# Не платите за эту посредственность ни копейки.
#
# 963 	class= 0
#   считать параноик весь автор игра сделать такой игра платной легко доступный человек покупают денежка автор сыпаться почему купить лаборатория сделать огромный вирус который сбрасывать самолёт грипп наш страна бункер планета сделать отчаяние допустить близкие умереть кампания распасться умереть жестокий пытка жалоба игра
#
#  Только не считайте что я параноик,но всё же...
# Если автор игры сделал такую игру платнои и легко доступной,люди ее покупаюта и денежки автору сыпятся,почему бы ему не купить лабораторию?Или сделать огромный вирус,который будет сбрасывать с самолетов этот грипп на наши страны,а сам будет,там,где то в бункере или на другой планете?И сделает он это от отчаяния(допустим близкие умерли или кампания распалась)и мы умрем,в жестоких пытках.
# Жалоба на игру и все...
#
# 991 	class= 0
#   время убить самый донат размер рубль сценарий по-моему очень игра телефон многие уровень пройти явный намёк донат мочь пройти платить
#
#  Время убить самое то. Донат в размере 1000 рублей за все сценарии - это, по-моему, очень много, тем более за игру на телефон. Многие уровни просто не возможно пройти, прям явный намёк на донат (не можешь пройти - плати).
#
# 1393 	class= 1
#   пройти донат кошмарный много бесполезный иконка
#
#  Прошли без доната на кошмарном. Много бесполезных иконок
#
# 1671 	class= 0
#   жать один кнопка весь игра
#
#  Жмешь одну кнопку вот и вся игра.
#
# 1724 	class= 0
#   игра что
#
#  игра не о чём
#
# 1732 	class= 0
#   скукота игра пройти один кнопка кручение стрельба нормальный никакой бонус совершенно тупой езда протяжение уровень
#
#  Скукота, игру можно пройти одной кнопкой...ни кручения ни стрельбы нормальной, никаких бонусов, совершенно тупая езда на протяжении всех уровней.
#
# 1747 	class= 0
#   очень однообразно
#
#  Даже очень однообразно.
#
# 1806 	class= 1
#   игра заставлять продолжать играть каждый следующий попытка трудно остановиться
#
#  Игра заставляет продолжать играть после каждой следующей попытки... Трудно остановиться!
#
# 2103 	class= 0
#   игрушка хороший подвисать проигрывать мячик становиться неконтролируемый жалко
#
#  Игрушка хорошая, но подвисает иногда и из-за этого иногда проигрываешь, ибо мячик становится неконтролируемым. Жалко!
#
# 2156 	class= 0
#   хороший игра играть реклама
#
#  Хорошая игра, но играть не возможно из за рекламы
#
# 2240 	class= 0
#   я играть игра удовольствие реклама каждый смерть
#
#  Я играю в игры ради удовольствия,а не ради рекламы через каждые 3 смерти !!!!!!!!!!!!!!
#
# 2264 	class= 0
#   понасувалить реклама играть лагаета этот самый реклама играбельный авиа-режим
#
#  Понасували реклам, что играть не возможно. И лагает из-за этих самых реклам. Играбельна только в авиа-режиме.
#
# 2297 	class= 0
#   игра супер реклама слишком заделать маленький слишком говорить слишком очень очень
#
#  Игра супер но рекламы слишком много заделайте поменьше но слишком ее там много и говоря слишком это очень очень много
#
# 2398 	class= 1
#   не_жаловаться реклама разработчик выставить ап стор игра бесплатно создать приложение загрузить сюда нужно купить платный подписка прога разработка другой приложение игра вылить апп стор реклама оплата труд
#
#  Не жалуйтесь на рекламу. Разработчики выставили в Ап Стор игру БЕСПЛАТНО. Чтобы создать приложение и загрузить его сюда, нужно купить платную подписку на прогу, для разработки других приложений/игр и вылить это в Апп Стор. Реклама - это оплата за труд
#
# 2522 	class= 1
#   подсказать почему обновление старый версия появиться ещё значок
#
#  Подскажите почему после обновления старой версии появился ещё один значок?
#
# 2568 	class= 1
#   обновление вылетать невозможно запустить восстановить работоспособность прошлый софтина глючил функциональность восстановить юзать далёкий
#
#  После обновления на 11.3.1, вылетает. Невозможно запустить.
# Восстановите работоспособность.
# Прошлая софтина так не глючила.
# Функциональность восстановлена. Юзаю дальше.
#
# 3012 	class= 1
#   господь каждый обновление худой худой сначала убрать самый популярный видео как-то появиться стать снимать наушник спасибо вернуть блин прожить мочь ценность мой телефон этот видео рыдать фото длинный волос нету черта подрать этот клип жизнь меняться январь человек куча воспоминание музыка вернуть просить смысл приложение
#
#  господи, с каждым обновлением все хуже и хуже? сначала убрали самые популярные видео, потом как-то они появились
# потом стало нельзя снимать в наушниках. спасибо, вернули
# но блин, без всего того я прожить могла. ценность моего телефона в этих видео. я просто рыдаю. у меня нет фото, где я еще с длинными волосами. нету, черт подери. в этих клипах моя жизнь, как я менялась с января, я там другой человек. куча воспоминаний, музыки. верните, прошу вас, если нет - смысл приложения?
#
# 3151 	class= 1
#   почему новое эффект обновить ещё мьюзикл я предлагать обновить
#
#  Почему? У всех уже новые эффекты, а у меня не обновлён ещё мьюзикл. Мне даже не предлагают обновить?
#
# 3269 	class= 0
#   я понимать новое эффект очень круто дело некоторый вещий который пользоваться старый версия нужно исключать понизить свой рейтинг сделать вывод обновлять мочь добавить новое эффект немного изменить оформление убирать важный вещий многий человек вы мочь оставить новое функция весь старое вернуть
#
#  Я конечно понимаю, что новые эффекты это очень круто и все дела, но все же некоторые вещи, которыми я пользовалась в старой версии, не нужно было исключать, из-за этого вы понизили свой рейтинг ;) Сделала выводы, что лучше бы я не обновляла :) Могли бы просто добавить эти новые эффекты, НЕМНОГО изменить оформление, но не убирать важные вещи для многих людей...
#
# Вы можете оставить новые функции, но всё же старые пожалуйста верните!!!!
#
# 3447 	class= 1
#   игра понравиться очень количество реклама перебор нафиг такой игра сидеть половина час реклама смотреть
#
#  Игра мне понравилась даже очень , но количество рекламы это уже перебор , нафиг такие игры если сидишь по пол часа рекламу смотришь
#
# 3469 	class= 1
#   игра классный реклама бесить авий режим отлично играть вопрос быть уровень быть вообще
#
#  Игра классная реклама бесила , но включая авия режим отлично можно по играть ) вопрос когда же будут уровни и будут ли они вообще )
#
# 3674 	class= 1
#   почему выключать показывать миниатюра показывать кто сообщение очень неудодно
#
#  Почему когда выключаю «показывать миниатюры», он не показывает от кого сообщение?(( очень неудодно(
#
# 3784 	class= 0
#   добавить аватарка телеграмма понятно писать читать имя ада групповой беседа вообще цвет нормальный сделать очень грязный некрасиво
#
#  Добавьте аватарки, как в телеграмме, чтоб понятно было кто пишет не читая имя. Это ад в групповых беседах и вообще. И цвета нормальные сделайте, эти очень грязные, некрасиво)
#
# 3898 	class= 1
#   получение сообщение уведомление писаться имя контакт крайне неудобно
#
#  При получении Сообщения при уведомлении не пишется имя контакта. Это крайне неудобно.
#
# 4047 	class= 1
#   сделать возможность ставить уведомление купить звук
#
#  Сделайте возможность ставить на уведомления купленные звуки
#
# 4121 	class= 1
#   сделать отправка сообщение расписание тот забыть отправить сообщение нужный промежуток время поставить время который сообщение автоматически отправиться
#
#  Сделать отправку сообщений по расписанию, те чтобы не забыть отправить сообщение в нужный промежуток времени, можно было бы поставить время, в которое это сообщение автоматически отправится.
#
# 4196 	class= 1
#   создать нормальный качество маска получиться кошка петух
#
#  Как создать нормальное качество?! На маске я получилась не кошка а петух какой то!!!?
#
# 4197 	class= 0
#   я понять эффект делать сложно подсказать
#
#  Я не поняла как эффекты делать если не сложно подскажите
#
# 4206 	class= 0
#   гавный
#
#  Гавна
#
# 4224 	class= 1
#   пока ставить исправить ближний врать исправить
#
#  Пока ставлю 5 но исправлю на 1 если в ближайшее врем не исправите
#
# 4477 	class= 0
#   приложение умственно отсталый школьница
#
#  Приложение для умственно отсталых школьниц
#
# 4865 	class= 1
#   разработчик сделать скрыть пункт такой предложение банка кредит счёт плата настройка выбирать пункт скрыть очень мешать
#
#  Разработчики сделайте пожалуйста что бы можно было скрыть все пункты такие как предложение банка, кредиты, счета, и и.п. Что бы можно было в настройках выбирать какой пункт скрыть какой нет. Очень мешают!
#
# 4906 	class= 1
#   разработчик сделать скрыть пункт такой предложение банка кредит счёт плата настройка выбирать пункт скрыть очень мешать
#
#  Разработчики сделайте пожалуйста что бы можно было скрыть все пункты такие как предложение банка, кредиты, счета, и и.п. Что бы можно было в настройках выбирать какой пункт скрыть какой нет. Очень мешают!
#
# 5010 	class= 1
#   уважаемый разработчик сделать возможность черновик почта иногда бывать ошибиться буква приходиться делать заново
#
#  Уважаемые разработчики. Сделайте возможность черновика как на почте. Иногда бывает ошибешься в букве и приходился все делать заново.
#
# 5047 	class= 1
#   куда подеваться диалог обновление
#
#  Куда подевались диалоги после обновления?
#
# 5143 	class= 0
#   выпилить никто нужный функционал диалог он реально никто нужный реально никто пользоваться пока приложение оценка
#
#  Выпилите этот никому не нужный функционал диалога. Он реально никому не нужен и им реально никто не пользуется. Пока он будет в приложении моя оценка ??
#
# 5241 	class= 1
#   статистика активность упасть нуль этот обновление такой делать происходить
#
#  Статистика и активность упала до нуля с этими обновлениями!!!
# Что вы такого делаете, что так происходит?!
#
# 5287 	class= 1
#   почему мой аккаунт трансляция нету маска телефон другой аккаунт исправить
#
#  Почему под моим аккаунтом в трансляции нету масок? С этого же телефона под другим аккаунтом они есть , как мне это исправить ?
#
# 5288 	class= 1
#   один мочь преглашать друг эфир вести вместе мочь разобраться
#
#  Но есть одно но, я не могу преглашать друзей к себе в эфир, что бы вести вместе, не могу разобраться
#
# 5495 	class= 1
#   не_мочь разблокировать человек который чёрный список исправить
#
#  Не могу разблокировать человека у которого я в чёрном списке!!! Когда это исправят?!
#
# 5514 	class= 1
#   я жить инстаграмм
#
#  Я живу в Инстаграмме..)))
#
# 5556 	class= 1
#   не_мочь зайти инстогра возить номер происходить помочь
#
#  Не могу зайти Инстограм вожу номер и не чего не происходит(((((( помогите!!!!!!!!
#
# 5648 	class= 0
#   сделать синхронизация конец конец весь ещё работать синхронизация вк
#
#  Сделайте синхронизацию в конце концов! Всё ещё не работает синхронизация с вк((
#
# 5740 	class= 0
#   очень часто вылетать платформа сам топ
#
#  Очень часто вылетает а платформа сама топ)
#
# 6104 	class= 1
#   сегодняшний день видеть запись стена они другой
#
#  С сегодняшнего дня я не вижу записи на стене. Их будто нет. Не у меня, ни у других.
#
# 6249 	class= 0
#   весь отлично один город абакан адрес улица пирятинский 1а 7а исправить надоесть каждый водитель объяснять почему адрес
#
#  Все отлично, но есть одно но, в городе Абакане нет адреса улица Пирятинская 1а, есть 7а! Исправьте, а то надоело каждому водителю объяснять, почему адрес другой!
#
# 6551 	class= 1
#   обновление пропасть история поездка
#
#  После обновления пропала история поездок :(
#
# 6580 	class= 0
#   я ваш ма иметь ох1рел1
#
#  Я вашу ма... имел !!!!вы что там ох1рел1 ?!
#
# 6853 	class= 1
#   помочь игра работать звук
#
#  Помогите, в игре не работает звук((
#
# 7286 	class= 1
#   рынок подержать медицинский прибор огромный инвалид нигде найти открыть доступ объявление продажа подержать медицинский аппарат
#
#  Рынок подержанных медицинских приборов огромен. Но инвалиду их нигде не найти:( откройте доступ к объявлениям по продаже подержанных медицинских аппаратов.
#
# 8060 	class= 1
#   долгий доставка
#
#  Долгая доставка
#
# 8127 	class= 0
#   супер
#
#  Супер
#
# 8258 	class= 0
#   работать нестабильный нафиг телега подружиться ркн оба прикол
#
#  Работает нестабильно. Нафиг телегу. Подружитесь с РКН, а то обоим же не по приколу.
#
# 8301 	class= 1
#   не_работать проксить получаться
#
#  Не работает, даже через прокси не получается
#
# 8368 	class= 1
#   вернуть предыдущий версия
#
#  Верните предыдущую версию пожалуйста
#
# 8533 	class= 1
#   ребята частый обновлять скидывать моросить продолжать
#
#  Ребят почаще обновляли скидывайте, а то моросить продолжает
#
# 8581 	class= 0
#   оно ещё функционировать
#
#  Оно ещё функционирует?
#
# 8586 	class= 1
#   рнк лох
#
#  РНК лох
#
# 8598 	class= 0
#   весь почить смерть храбрый телега работать
#
#  Все, почила смертью храбрых телега( не работает
#
# 8610 	class= 1
#   телеграмма заблокировать
#
#  Телеграмм что заблокировали?
#
# 8683 	class= 0
#   ранний хороший сервис поддерживать ркн менять дилер ихний совет ценник выше граммовка беда сильный россия наш поставщик
#
#  Раньше был хороший сервис но теперь поддерживаю РКН и меняю дилера по ихнему совету! Ценник там хоть и выше и с граммовкой беда но я за сильную Россию и за нашего поставщика!!
#
# 8723 	class= 1
#   оценить знать один слово- збс
#
#  5 из 5. Как еще, оценить, не знаю. Одно слово- ЗБС
#
# 9185 	class= 0
#   отрывок трек вариант давать
#
#  На 1 отрывок трека 5 вариантов даёт!
#
# 9726 	class= 1
#   уважаемый разработчик исправт вылетать айфон иос
#
#  Уважаемые разработчики Исправте пожалуйста вылетает на айфоне 5 иос 10.3
#
# 10001 	class= 0
#   весь супер два прохождение уровень игра вылетать исправить игра классный вылет исправить
#
#  Все супер , после двух прохождений уровней , игра вылетает , Исправьте , а так игра классная , ВЫЛЕТЫ ИСПРАВЬТЕ!!!
#
# 10012 	class= 0
#   не_мочь играть
#
#  Не могу играть:(
#
# 10107 	class= 0
#   качество низкий
#
#  Качество низкое
#
# 10201 	class= 0
#   добрый день быть приложение поиск фото
#
#  Добрый день! Будет ли в этом приложении поиск по фото?
#
# 10248 	class= 1
#   всегда получать заказ последний время дошлый посылка деньга вернуть проблема надеяться наладиться
#
#  Всегда получал заказы .
# Но в последние время не дошло 8 посылок.
# Деньги вернули без проблем .
# Надеюсь все наладится .
#
# 10273 	class= 0
#   разработчик добавить переписка продавец количество товар купить продавец
#
#  Разработчики добавьте пожалуйста !
# 1 переписку с продавцом
# 2 Количество товаров купленных у продавца
#
# 10361 	class= 1
#   добрый день заказать ряд товар приложение часть поступить срок часть поступить деньга вернуть течение 2-3 день неделя два окончание срок доставка товар прийти обратный связь связаться администрация приложение предложить оплатить поступить товар денежный средство принять отказаться пояснить мочь расценивать подарок связь просрочка поставка приятно лёгкое смущение ща неосновательный обогащение весь товар поступить упаковать часть положить почтовый ящик часть получить почта заказывать кукольный мебель аксессуар кукла вакуумный баночка массаж лицо товар кукольный мебель аксессуар исправный запах несколько слабоватый крепление стоить небольшой деньга дочь пока ещё сломать фактический поставка товар срок упаковка качество товар который полностью соответствовать скромный стоимость ставить твёрдый спасибо
#
#  Добрый день! Заказала ряд товаров в приложении. Часть поступила в срок, часть не поступила. Деньги вернули в течении 2-3 дней. Недели через две после окончания срока доставки товар все же пришёл. По обратной связи я связалась с администрацией приложения и предложила оплатить поступивши товар. Денежные средства принять отказались, пояснив, что я могу расценивать это как подарок в связи с просрочкой поставки)))) приятно, но легкое смущение ща неосновательное обогащение все же есть. Весь товар поступил хорошо упакованным. Часть положили в почтовый ящик, часть получила на почте. Заказывала кукольную мебель, аксессуары для кукол, вакуумные баночки для массажа лица. Товар ( кукольная мебель и аксессуары) исправный, без запаха. Несколько слабоват в креплениях, но и стоит небольших денег. Дочь пока ничего ещё не сломала. За все же фактическую поставку товара, пусть и не в срок, упаковку, качество товара, которое полностью соответствует скромной стоимости ставлю твёрдую 5. У меня все, спасибо)
#
# 10549 	class= 0
#   идти очень долго примерно 3-4 месяц
#
#  Шёл очень долго , примерно 3-4 месяца
#
# 10583 	class= 1
#   заказать один продавец пять товар отправить каждый отдельный посылка прошлый неделя пришлый товар вчера ещё сегодня следующий неделя видимо побежать последний почему функция товар один продавец отправлять один посылка дополнить отзыв сейчас программа нравиться найти товар дешёвый посылка время приходить
#
#  Заказала у одного продавца пять товаров, он их отправил каждую отдельной посылкой! На прошлой недели пришло два товара, вчера ещё один, сегодня опять один! На следующей неделе видимо побегу за последним. Почему нет такой функции как на али, чтоб все товары одного продавца отправляли одной посылкой?
# Дополню отзыв:
# Сейчас мне программа нравиться, много нашла товаров дешевле, чем на али, и Посылки во время приходят
#
# 11047 	class= 0
#   хотеться
#
#  Хотелось
#
# 11170 	class= 0
#   нет функция выбор категория автомобиль лично интересовать выбор грузовик сделать
#
#  Нет функции выбор категории автомобиля. А именно, лично меня интересует выбор грузовика. Сделаете будет 5+
#
# 11229 	class= 0
#   ребята че сделать момент обновление работать ура работать
#
#  Ребят и че вы сделали? До момента обновления все работало на ура.... а после ничего не работает.....
#
# 11333 	class= 1
#   здравствовать сделать масштаб близкий медленный средний скорость движение авто непонятно далеко поворот проезжать постоянно далёкий ход вглядываться местность экран определение поворот очень удобно плотный поток идти транспорт уведомление поворот самый перекрёсток метр 20-30 пролетать
#
#  Здравствуйте. Сделайте пожалуйста масштаб  ближе при медленной и средней скорости при движении на авто ! Непонятно как далеко до поворота и проезжаешь его постоянно , кажется что он дальше. На ходу вглядываться на местность в экране для определения поворота не очень удобно при плотном потоке идущего транспорта !!!! И уведомление о повороте не на самом перекрестке а за метров 20-30 хотя бы. А то тоже пролетаешь его !!!
#
# 11863 	class= 1
#   оооочень реклама
#
#  Оооочень много рекламы!!!
#
# 11946 	class= 1
#   реклама бесить купить режим реклама поддержать разработчик надеяться быстрый выйти новое босс режим
#
#  Реклама бесила , купил режим без рекламы , поддержал разработчиков, надеюсь как можно быстрее выйдут новые боссы и режим
#
# 12073 	class= 0
#   игра вначале нравиться день надоесть стрелять нож дерево ещё дофига реклама убивать босс открываться реклама босс забрасываться
#
#  Игра вначале нравилась но через день уже надоело стрелять ножом по дереву ещё дофига рекламы когда убиваешь босса открывается реклама и босс забрасывается
#
# 12138 	class= 1
#   не_действовать промокод
#
#  Не действует промокод 808
#
# 12768 	class= 0
#   игра хороший реклама полностью убивать
#
#  Игра хорошая, но реклама полностью ее убивает
#
# 13306 	class= 0
#   работать вайфай
#
#  У меня работает только через вайфай ??
#
# 13478 	class= 0
#   самый красивый фильтр убрать вернуть
#
#  САМЫЙ КРАСИВЫЙ ФИЛЬТР И ТО УБРАЛИ!!! ВЕРНИТЕ!!!!
#
# 13494 	class= 0
#   хотеться видеть маска взрослый детский сад надоесть
#
#  Хочется видеть больше масок и для взрослых.. детский сад надоел.
#
# 13610 	class= 0
#   не_тема
#
#  Без темы
#
# 13707 	class= 1
#   найти работа приложение маленький минус- найти удалять диалог удалить анкета поиск
#
#  Нашла работу через это приложение, маленький минус- не нашла как удалять диалоги и как удалить анкету, так как я уже не в поиске
#
# 14078 	class= 1
#   зависать секунда работа
#
#  Зависает через 2 секунды работы
#
# 14676 	class= 1
#   здравствовать купить авто тесло магнитола стоить свой оболочка климат контроль она мочь выбрать вид транспорт перенести вид транспорт альтернатива боковой консоль
#
#  Здравствуйте, купил себе в авто тесла магнитолу но там стоит своя оболочка на климат контроль, из-за неё я не могу выбрать вид транспорта, перенесите вид транспорта как альтернативу на боковую консоль.
#
# 14950 	class= 0
#   мой город
#
#  Моего города нет(
#
# 15160 	class= 1
#   нормальный
#
#  Нормально
#
# 15495 	class= 1
#   реклама убрать вообще шикарно
#
#  Вот рекламу бы, убрать и вообще шикарно
#
# 15771 	class= 1
#   теперь прийтись слушать музыка вк половина час
#
#  Теперь не прийдется  слушать музыку через вк пол часа.
#
# 15860 	class= 1
#   скачивать музыка почему вкладка снизу медиатека поиск загрузка решить проблема ответить
#
#  Как скачивать музыку то? Почему у всех все хорошо, а у меня нет вкладок снизу( медиатека, поиск, загрузки). Как решить эту проблему ? Ответьте пожалуйста ??
#
# 15947 	class= 0
#   пока работать надеяться далёкий работать
#
#  А так пока работает. Надеюсь и дальше будет работать.
#
# 15969 	class= 1
#   интернет послушать музыка спокойно
#
#  Наконец-то без интернета можно послушать музыку спокойно?
#
# 16136 	class= 1
#   здравствовать сделать масштаб близкий медленный средний скорость движение авто непонятно далеко поворот проезжать постоянно далёкий ход вглядываться местность экран определение поворот очень удобно плотный поток идти транспорт уведомление поворот самый перекрёсток метр 20-30 пролетать
#
#  Здравствуйте. Сделайте пожалуйста масштаб  ближе при медленной и средней скорости при движении на авто ! Непонятно как далеко до поворота и проезжаешь его постоянно , кажется что он дальше. На ходу вглядываться на местность в экране для определения поворота не очень удобно при плотном потоке идущего транспорта !!!! И уведомление о повороте не на самом перекрестке а за метров 20-30 хотя бы. А то тоже пролетаешь его !!!
#
# 16162 	class= 1
#   приложение прекрасный оно развиваться очень радовать знать вход здание яндекс такси оно использовать яндекс карта каждый построить маршрут заканчиваться карта один сторона мой дом подъезд находиться сторона таксист сообразительный приходиться идти пешком звонить объяснять проехать куда обратиться проблема
#
#  Приложение прекрасное. И то, что оно развивается очень радует. Но знает ли про входы в здания яндекс.такси? Оно использует яндекс.карты? Просто каждый раз построенный маршрут заканчивается на карте с одной стороны моего дома, а все подъезды находятся с другой стороны. И не все таксисты сообразительные, иногда приходится идти к ним пешком или звонить и объяснять как проехать. Куда обратиться с этой проблемой?
#
# 16182 	class= 1
#   ведение маршрут очень тихий стать голос ведущий максимальный громкость слышный ранний такой проверить несколько устройство везде слышный
#
#  При ведении по маршруту очень тихим стал голос ведущего. При максимальной громкости ничего не слышно. Раньше такого не было. Проверил на нескольких устройствах. Везде не слышно
#
# 16487 	class= 1
#   убрать идиотический панель сюда отсюда фотка появляется-она убрать перезагрузка
#
#  Уберите идиотическую панель сюда отсюда с фоткой внизу-если она появляется-ее никак не убрать.Только перезагрузка
#
# 16535 	class= 1
#   смысл показывать балл пробка минута ехать домой работа далёкий мочь пользоваться это приложение
#
#  Так а в чем смысл? У меня показывает только сколько баллов пробки, и сколько минут ехать домой и на работу? А дальше? Как я могу пользоваться этим приложением?
#
# 16644 	class= 1
#   хотеться видеть музыка количество скатить минута удобно смотреть сначала показывать мина каждый день музыка качать
#
#  Хотелось бы видеть сколько музыки по количеству скачено , в минутах не удобно смотреть и сначала он показывал 947 мин потом 935 ,а сейчас 907 ,хотя я каждый день музыку качаю
#
# 16739 	class= 1
#   сегодня как-то очень плохо работать поиск песня количество аудио весь вк решить переустановить приложение итог мочь войти приложение вк
#
#  Сегодня как-то очень плохо работал поиск песен от всего количества аудио во всем вк и я решил переустановить приложение. В итоге я не могу войти в это приложение через вк.
#
# 17187 	class= 0
#   жевать подписка
#
#  Жуй вам а не подписку
#
# 17245 	class= 0
#   внизу
#
#  Внизу
#
# 17298 	class= 1
#   ответ предыдущий отзыв-купить нормальный телефон ослиный тупой
#
#  Ответ на предыдущий отзыв-купи себе нормальный телефон ослина тупая))))
#
# 17431 	class= 1
#   исправить недочёт
#
#  ?? исправили все недочеты
#
# 17734 	class= 1
#   дорогой разработчик обращение музыка тот который хотеть сделать раздел писать дать песнь её добавлять возможность импортировать песнь вк
#
#  Дорогие разработчики, обращение к вам музыки той которой я хочу нет!((( Сделайте раздел что-ли чтобы вам можно было писать если данной песни нет и вы её бы добавляли )))
# Или возможность импортировать песни с вк )
#
# 17788 	class= 1
#   дорогой разработчик обращение музыка тот который хотеть сделать раздел писать дать песнь её добавлять возможность импортировать песнь вк
#
#  Дорогие разработчики, обращение к вам музыки той которой я хочу нет!((( Сделайте раздел что-ли чтобы вам можно было писать если данной песни нет и вы её бы добавляли )))
# Или возможность импортировать песни с вк )
#
# 17865 	class= 1
#   последний обновление стать замечательный необходимый добавить возможность ставить лайк заблокировать экран указывать жанр название альбом группа как-то отсортировать альбом сингл вкладка новое релиз
#
#  С последними обновлениями все стало замечательно. Необходимо добавить возможность ставить лайк на заблокированном экране, указывать жанр под названием альбома и группы и как-то отсортировать альбомы и синглы во вкладке новые релизы.
#
# 17888 	class= 0
#   чебурнуть
#
#  ЧЕБУРНЕТ
#
# 18040 	class= 0
#   работать интернет
#
#  Работает только с интернетом(((((((
#
# 18064 	class= 1
#   рубль месяц музыка идеально
#
#  100 рублей за месяц музыки? – Идеально!
#
# 18191 	class= 1
#   нормальный
#
#  Нормально
#
# 18329 	class= 1
#   подключаться
#
#  Не всегда подключается
#
# 18407 	class= 1
#   жаль жадный
#
#  Жаль жадные ?
#
# 18682 	class= 1
#   идти эротический маршрут
#
#  Иди ты сам по эротическому маршруту.
#
# 18802 	class= 0
#   разработчик просьба увеличить размер приложение очень память использоваться мегабайт вообще око особенно интернет лиметировать просьба увеличить размер гб
#
#  Разработчики, просьба увеличить размер приложения. У меня очень много памяти не используется, 300 мегабайт для меня вообще ни очам особенно когда интернет лиметированный. Просьба увеличить размер до 1,5 Гб ))
#
# 18850 	class= 0
#   интерфейс приложение весьма сильно запутанный определённо нужный справочник высокий образование разобраться
#
#  Интерфейс приложения весьма сильно запутан, мне определенно нужен справочник и два высших образования чтобы разобраться здесь.
#
# 18914 	class= 0
#   несказанно рад
#
#  И несказанно рад!
#
# 19080 	class= 0
#   слабо раздуть приложение гигабайт
#
#  А слабо раздуть приложение на 1 ГИГАБАЙТ?
#
# 19208 	class= 1
#   обновление вообще загружаться
#
#  После обновления вообще не загружается.
#
# 19318 	class= 0
#   игра классный начало утопать жадность создатель шедевр приз урезаться задание усложняться глючить постоянно вложение сделать начинать вздумать совет
#
#  Игра классная,но...начала утопать в ЖАДНОСТИ создателей этого шедевра!призы урезаются,задания усложняются,глючит постоянно,без вложений ничего не сделаешь!если не начинали то и не вздумайте мой вам совет!
#
# 19576 	class= 1
#   не_запускаться
#
#  Не запускается
#
# 19587 	class= 1
#   не_запускаться послый обновть
#
#  Не запускается после посл обновл
#
# 19661 	class= 0
#   сабж
#
#  сабж
#
# 19753 	class= 1
#   сложно выслать форма смена оценка водитель звезда
#
#  Если не сложно, вышлите форму смены оценки водителя)))) 5 звёзд если что))))
#
# 20526 	class= 0
#   мгновенный перевод работать фотографирование исправить пж
#
#  Мгновенный перевод не работает, только после фотографирования!! Исправьте пж
#
# 20535 	class= 0
#   трудно дабавитя татарский ток татарский звезда
#
#  Что так трудно дабавить татарский ток за татарский 1 звезда
#
# 21099 	class= 1
#   неделя два назад писать приложение постоянно требовать ввести логин пароль пользовиться невозможно сейчас стать весь отлично не_знать думать исправить
#
#  Недели две назад писал о том, что приложение постоянно требуют ввести логин и пароль. Пользоватся было невозможно. Сейчас стало всё отлично. Не знаю уж как но думаю что они исправили
#
# 21128 	class= 1
#   я нравиться максимальный сумма выставлять приложение потому некоторый водитель слишком сильно загибать цена
#
#  Мне нравится, Что максимальную сумму выставляет приложение. Потому что некоторые водители слишком сильно загибают цену.
#
# 21129 	class= 1
#   я хотеть оставить мнение отменять бронь минута отправление вовсе приходить отвечать рейтинг понижать следующий водитель видеть риска
#
#  Я бы тоже хотел оставить мнение о том, что тем кто отменяет бронь за 5 минут до отправления или тем кто вовсе не приходит или не отвечает тоже можно было бы рейтинг понижать. Для того, чтоб следующий Водитель видел риски.
#
# 21634 	class= 0
#   приложение очень понравиться смонтировать видео видео фотография удалиться я особо советовать скачать приложение
#
#  Приложение мне не очень понравилась потому что когда я смонтировала видео а потом все видео фотографии у меня удалились!!! Я не особо советую скачать это приложение!
#
# 21852 	class= 1
#   теперь брэнд
#
#  Теперь брэнд
#
# 21948 	class= 0
#   физик график плохой
#
#  Физика и графика плохая
#
# 22082 	class= 1
#   что-то работать несколько день починить
#
#  Что-то не работает уже несколько дней, почините пожалуйста....
#
# 22207 	class= 0
#   рынок садовод загонять барахло
#
#  Как будто с рынка Садовод загоняют барахло:)
#
# 22257 	class= 1
#   я ваш постоянный клиент почему казбековский район доставлять товар очень разочаровать
#
#  Я ваш постоянный клиент.. почему то вы в Казбековский район не доставляете товар.. очень разочарована !!!
#
# 22317 	class= 1
#   тот устать тц
#
#  Для тех, кто устал от ТЦ
#
# 22480 	class= 0
#   заказывать зимний ботинок сказать доставить час позвонить курьер сказать доставка осуществлять южный бутовый договориться решить осуществить доставка попросить перенести доставить заказывать зимний ботинок получить следующий год особо хотеться нужный вы позиционировать магазин который осуществить доставка любой время любой место факт
#
#  Заказывал 25.11 зимние ботинки, сказали, что доставят 27.11 с 9 до 21. В 4 часа позвонил курьер и сказал, что доставку осуществляют в Южном Бутово с 4 до 6 и больше никак. Договорились на 29.11. 30.11 мне решили осуществить доставку, я попросил перенести на 3.12. Так ничего и не доставили. Заказывал зимние ботинки, получить их следующем году не особо хочется, мне они нужны сейчас. Вы позиционируете себя, как магазин, который осуществит доставку в любую время и в любое место, но по факту это не так.
