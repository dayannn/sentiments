# %%
import numpy as np
import pandas as pd
import re

# %%
revs = pd.DataFrame.from_csv("./res.csv", encoding="cp1251")

initial_revs = revs.copy()
revs
# Out:
#        rating                                            content
# 0           5  Интересный сюжет, затягивает. Много времени ух...
# 1           4  Плюсы: \r\n1. Игра интересная 2. Образы учител...
# 2           3  Огорчил тот факт , что суть игры заключается в...
# 3           5  Была постоянная ошибка с подключением, почти н...
# 4           1  ... сделайте русскую озвучку и будет 5 звёзд :...
# 5           3                         Почему нет русского языка?
# 6           1                                                  !
# 7           1              Постоянные проблемы с подключением!!!
# 8           5  Все идеально но отсутствия русского языка даёт...
# 9           1          Где великий и могучий??? Сделайте русский
# 10          4  Thanks for the game, I fancy it pretty much, h...
# 11          2                  Добавьте русский язык пожалуйста(
# 12          5  Игра отличная, отсутствие русского языка не ме...
# 13          4                       Please add Russian language!
# 14          5  Everything was great till Wednesday night. Gam...
# 15          3                         Where Russian language ???
# 16          1  В описании приложения, написали что есть русск...
# 17          1              Пожалуйста сделайте русский язык!!!!!
# 18          2  Зашла в игру, поиграла ровно минуту и всё, эне...
# 19          2  Игра интересная, но как же достал connect erro...
# 20          1  Where is the Russian language? why the descrip...
# 21          4  Без русского играть невозможно. От выборы зави...
# 22          5  Почему игра не запускается, перекидывает на ст...
# 23          1  Когда же ждать заявленный в описании русский я...
# 24          2  Русского языка нет, но английский понимаю - та...
# 25          5  Товарищи, учите иностранные языки \r\nИгра зам...
# 26          3                 Always connection lost! Fix please
# 27          1  Заявлен русский язык. Заходишь в игре в Настро...
# 28          5  Очень продуманная, интересная игра, все сделан...
# 29          3  Игра нармуль. Разрабочики добавьте русский язык !
# ...       ...                                                ...
# 22463       5  Пользуюсь приложением не первый год, мобильное...
# 22464       5  Один из лучших онлайн магазинов! Купила много ...
# 22465       1  Господа разработчики, уберите из приложения да...
# 22466       4  Для айфона не очень удобное приложение. Листат...
# 22467       1  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       1  И цены конские. А их реклама «увеличьте свой ч...
# 22469       5  Отличный сайт и отличное приложение, пока толь...
# 22470       5  Приложение , сайт и вещи и вообще все просто с...
# 22471       1  Сделал заказ, сказали что доставка возможна то...
# 22472       5  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       1  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       5  Сразу все магазины в одном месте ? так как я в...
# 22475       2  Во вкладке «Избранное» дублируются товары. Три...
# 22476       5           Мне нравится. Удобно, быстро, недорого??
# 22477       5                                       Всё хорошо ?
# 22478       1  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       1  Вся обувь китайская подделка, через 15 минут р...
# 22480       1  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       1  Доставка от пони экспресс, портит все. Может в...
# 22482       1  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       1  Приложение где только не пиарят, увидела в вк ...
# 22484       1  Не стыдно врать то, никаких скидок на фирму не...
# 22485       1  Зачем изменили приложение, что за ненужное око...
# 22486       1                          Недобросовестная реклама.
# 22487       1  Приложение классное, но реклама на YouTube за*...
# 22488       4  Почините,пожалуйста,приложение, заходила два г...
# 22489       1  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       1  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22491       4  Отличное приложение, удобное в использовании, ...
# 22492       5                                             ??????
#
# [22493 rows x 2 columns]

# %% [markdown]
# Удаляем неподходящие отзывы: с рейтингов 3-4, с английским текстом, пустые

# %%
    #drop eng reviews
revs.drop(revs[revs.content.str.contains ("[A-Za-z]")].index, inplace=True)
    #drop reviews with rating 3-4
revs.drop(revs[(revs.rating == 3) | (revs.rating == 4)].index, inplace=True)
    #drop empty reviews
revs.drop(revs[revs.content == ""].index, inplace=True)

revs
# Out:
#        rating                                            content
# 0           5  Интересный сюжет, затягивает. Много времени ух...
# 4           1  ... сделайте русскую озвучку и будет 5 звёзд :...
# 6           1                                                  !
# 7           1              Постоянные проблемы с подключением!!!
# 8           5  Все идеально но отсутствия русского языка даёт...
# 9           1          Где великий и могучий??? Сделайте русский
# 11          2                  Добавьте русский язык пожалуйста(
# 16          1  В описании приложения, написали что есть русск...
# 17          1              Пожалуйста сделайте русский язык!!!!!
# 18          2  Зашла в игру, поиграла ровно минуту и всё, эне...
# 22          5  Почему игра не запускается, перекидывает на ст...
# 23          1  Когда же ждать заявленный в описании русский я...
# 24          2  Русского языка нет, но английский понимаю - та...
# 25          5  Товарищи, учите иностранные языки \r\nИгра зам...
# 27          1  Заявлен русский язык. Заходишь в игре в Настро...
# 28          5  Очень продуманная, интересная игра, все сделан...
# 33          5                              Добавьте русский язык
# 35          2                             Необходим русский язык
# 37          1                                       Русский язык
# 38          1                         Нет русского языка! Обман!
# 41          2  Вы написала есть русский а там его в игре нет ...
# 43          1  Алло, где русский язык??? \r\nНаписано же, что...
# 47          5  Игра выше всех моих ожиданий, и судя по отзыва...
# 48          1                              Где русский язык ????
# 51          1  Играть просто стыдно. Гейплей, сюжет отсутству...
# 53          5                  Добавьте русский язык пожалуйста!
# 54          1  Очень жду Русский язык ,написано что он есть ,...
# 57          5             Спасибо!!! Очень интересно играть! ???
# 58          1  В описании к игре Русский язык указан, фактиче...
# 59          1  Зачем указывать языки которых нет и ничего не ...
# ...       ...                                                ...
# 22459       5  Те кто пишет фу и всё такое, советую не слушат...
# 22460       5  Ламода- супер вариант для тех, кто не может по...
# 22461       5  Отличный магазин. Удобно. Быстро. Дёшево. Фейк...
# 22462       5                     Поиск по фото - просто огонь!!
# 22463       5  Пользуюсь приложением не первый год, мобильное...
# 22464       5  Один из лучших онлайн магазинов! Купила много ...
# 22465       1  Господа разработчики, уберите из приложения да...
# 22467       1  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       1  И цены конские. А их реклама «увеличьте свой ч...
# 22469       5  Отличный сайт и отличное приложение, пока толь...
# 22470       5  Приложение , сайт и вещи и вообще все просто с...
# 22471       1  Сделал заказ, сказали что доставка возможна то...
# 22472       5  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       1  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       5  Сразу все магазины в одном месте ? так как я в...
# 22475       2  Во вкладке «Избранное» дублируются товары. Три...
# 22476       5           Мне нравится. Удобно, быстро, недорого??
# 22477       5                                       Всё хорошо ?
# 22478       1  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       1  Вся обувь китайская подделка, через 15 минут р...
# 22480       1  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       1  Доставка от пони экспресс, портит все. Может в...
# 22482       1  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       1  Приложение где только не пиарят, увидела в вк ...
# 22484       1  Не стыдно врать то, никаких скидок на фирму не...
# 22485       1  Зачем изменили приложение, что за ненужное око...
# 22486       1                          Недобросовестная реклама.
# 22489       1  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       1  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22492       5                                             ??????
#
# [15949 rows x 2 columns]

# %% [markdown]
# Заменяем оценку 5 на класс "1" - позитивные отзывы, оценки 1-2 - на класс "0" - негативные отзывы

# %%
revs['rating'][(revs.rating == 1) | (revs.rating == 2)] = 0
revs['rating'][revs.rating == 5] = 1

revs
# Out:
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#        rating                                            content
# 0           1  Интересный сюжет, затягивает. Много времени ух...
# 4           0  ... сделайте русскую озвучку и будет 5 звёзд :...
# 6           0                                                  !
# 7           0              Постоянные проблемы с подключением!!!
# 8           1  Все идеально но отсутствия русского языка даёт...
# 9           0          Где великий и могучий??? Сделайте русский
# 11          0                  Добавьте русский язык пожалуйста(
# 16          0  В описании приложения, написали что есть русск...
# 17          0              Пожалуйста сделайте русский язык!!!!!
# 18          0  Зашла в игру, поиграла ровно минуту и всё, эне...
# 22          1  Почему игра не запускается, перекидывает на ст...
# 23          0  Когда же ждать заявленный в описании русский я...
# 24          0  Русского языка нет, но английский понимаю - та...
# 25          1  Товарищи, учите иностранные языки \r\nИгра зам...
# 27          0  Заявлен русский язык. Заходишь в игре в Настро...
# 28          1  Очень продуманная, интересная игра, все сделан...
# 33          1                              Добавьте русский язык
# 35          0                             Необходим русский язык
# 37          0                                       Русский язык
# 38          0                         Нет русского языка! Обман!
# 41          0  Вы написала есть русский а там его в игре нет ...
# 43          0  Алло, где русский язык??? \r\nНаписано же, что...
# 47          1  Игра выше всех моих ожиданий, и судя по отзыва...
# 48          0                              Где русский язык ????
# 51          0  Играть просто стыдно. Гейплей, сюжет отсутству...
# 53          1                  Добавьте русский язык пожалуйста!
# 54          0  Очень жду Русский язык ,написано что он есть ,...
# 57          1             Спасибо!!! Очень интересно играть! ???
# 58          0  В описании к игре Русский язык указан, фактиче...
# 59          0  Зачем указывать языки которых нет и ничего не ...
# ...       ...                                                ...
# 22459       1  Те кто пишет фу и всё такое, советую не слушат...
# 22460       1  Ламода- супер вариант для тех, кто не может по...
# 22461       1  Отличный магазин. Удобно. Быстро. Дёшево. Фейк...
# 22462       1                     Поиск по фото - просто огонь!!
# 22463       1  Пользуюсь приложением не первый год, мобильное...
# 22464       1  Один из лучших онлайн магазинов! Купила много ...
# 22465       0  Господа разработчики, уберите из приложения да...
# 22467       0  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       0  И цены конские. А их реклама «увеличьте свой ч...
# 22469       1  Отличный сайт и отличное приложение, пока толь...
# 22470       1  Приложение , сайт и вещи и вообще все просто с...
# 22471       0  Сделал заказ, сказали что доставка возможна то...
# 22472       1  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       0  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       1  Сразу все магазины в одном месте ? так как я в...
# 22475       0  Во вкладке «Избранное» дублируются товары. Три...
# 22476       1           Мне нравится. Удобно, быстро, недорого??
# 22477       1                                       Всё хорошо ?
# 22478       0  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       0  Вся обувь китайская подделка, через 15 минут р...
# 22480       0  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       0  Доставка от пони экспресс, портит все. Может в...
# 22482       0  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       0  Приложение где только не пиарят, увидела в вк ...
# 22484       0  Не стыдно врать то, никаких скидок на фирму не...
# 22485       0  Зачем изменили приложение, что за ненужное око...
# 22486       0                          Недобросовестная реклама.
# 22489       0  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       0  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22492       1                                             ??????
#
# [15949 rows x 2 columns]

# %% [markdown]
# Загружаем морфологический анализатор pymorphy2, стоп-слова из списка библиотеки nltk

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
stop_words = {"быть", "вдруг" "вы", "всегда", "все", "другой", "если", "есть", "здесь", "зачем", "иногда", "конечно", "между", "наконец", "раз", "разве", "только", "тот", "уже", "хоть", "чуть", "этот", "это", "я", "ты", "он", "оно", "каждый", "весь", "это", "ваш", "пока", "свой", "вообще"}
#stop_words = set(stopwords.words('russian'))

# %% [markdown]
# Лемматизация

# %%
def strtonormalform(line, should_delete = {'PREP', 'CONJ', 'PRCL'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None):#союзы, предлоги и т.п. не сохраняем
            ans = ans + ' ' + lex
    return ans

#revs_norm = revs.copy()
#revs_norm['content'] = revs_norm['content'].apply(strtonormalform)
    #drop empty reviews
#revs_norm.drop(revs_norm[revs_norm.content == ""].index, inplace=True)

#revs_norm

# %%
#revs_norm.to_csv("normalized_revs.csv")
revs_norm = pd.DataFrame.from_csv("./normalized_revs.csv", encoding="cp1251")
revs_norm
# Out:
#        rating                                            content
# 0           1   интересный сюжет затягивать много время уходи...
# 4           0   сделать русский озвучка быть звезда спасибо п...
# 7           0                    постоянный проблема подключение
# 8           1   весь идеально отсутствие русский язык давать ...
# 9           0                где великий могучий сделать русский
# 11          0                              добавить русский язык
# 16          0   описание приложение написать есть русский язы...
# 17          0                               сделать русский язык
# 18          0   зайти игра поиграть ровно минута весь энергия...
# 22          1   почему игра запускаться перекидывать страница...
# 23          0                ждать заявить описание русский язык
# 24          0   русский язык нет английский понимать небольшо...
# 25          1   товарищ учить иностранный язык игра замечател...
# 27          0   заявить русский язык заходить игра настройка ...
# 28          1   очень продумать интересный игра весь сделать ...
# 33          1                              добавить русский язык
# 35          0                           необходимый русский язык
# 37          0                                       русский язык
# 38          0                             нет русский язык обман
# 41          0   вы написать есть русский там он игра нет сдел...
# 43          0        алло где русский язык написать русский язык
# 47          1   игра выше весь мой ожидание судить отзыв она ...
# 48          0                                   где русский язык
# 51          0   играть стыдно гейплей сюжет отсутствовать так...
# 53          1                              добавить русский язык
# 54          0   очень ждать русский язык написать он есть он нет
# 57          1                     спасибо очень интересно играть
# 58          0   описание игра русский язык указанный фактичес...
# 59          0   зачем указывать язык который нет ничто менять...
# 60          0                              добавить русский язык
# ...       ...                                                ...
# 22458       1   я являться постоянный клиент магазин ламода ч...
# 22459       1   тот кто писать фу весь такой советовать слуша...
# 22460       1   ламода- супер вариант тот кто мочь позволить ...
# 22461       1   отличный магазин удобно быстро дёшево фейковы...
# 22462       1                                   поиск фото огонь
# 22463       1   пользоваться приложение один год мобильный уд...
# 22464       1   один хороший онлайн магазин купить много одеж...
# 22465       0   господин разработчик убрать приложение дата д...
# 22467       0   доставка стиль ой я знать вы попасть поэтому ...
# 22468       0   цена конский они реклама увеличить свой член ...
# 22469       1   отличный сайт отличный приложение пока оформи...
# 22470       1   приложение сайт вещий вообще весь супееееееее...
# 22471       0   сделать заказ сказать доставка возможный завт...
# 22472       1   довольно удобно цена гуд купон который сайт м...
# 22473       0   реклама это ширпотреб достать забавлять накру...
# 22474       1   сразу весь магазин один место я декрет очень ...
# 22475       0   вкладка избранный дублироваться товар три раз...
# 22476       1                 я нравиться удобно быстро недорого
# 22477       1                                        весь хорошо
# 22478       0   смысл это приложение покупать кот мешок дорог...
# 22479       0   весь обувь китайский подделка минута развалит...
# 22480       0   заказывать зимний ботинок сказать доставить ч...
# 22481       0   доставка пони экспресс портить весь мочь вооб...
# 22482       0   меняться плохой сторона многочисленный косяк ...
# 22483       0   приложение где пиарить увидеть вк рекламный р...
# 22484       0   стыдно врать никакой скидка фирма нет магазин...
# 22485       0   зачем изменить приложение ненужный окошко пос...
# 22486       0                           недобросовестный реклама
# 22489       0   цена такой уж маленькая качество изделие очен...
# 22490       0   умереть спид достать ваш реклама деньга вы от...
#
# [15566 rows x 2 columns]

# %%
def strtonormalform_with_neg(line, should_delete = {'PREP', 'CONJ', 'PRCL'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    flag = False
    for word in words:
        if (word in ["не", "Не", "без", "Без"]):
            flag = True
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None):#союзы, предлоги и т.п. не сохраняем
            if (flag):
                flag = False
                lex = "не_" + lex
            ans = ans + ' ' + lex
    return ans

#revs_norm_neg = revs.copy()
#revs_norm_neg['content'] = revs['content'].apply(strtonormalform_with_neg)
    #drop empty reviews
#revs_norm_neg.drop(revs_norm_neg[revs_norm_neg.content == ""].index, inplace=True)

#revs_norm_neg

# %%
#revs_norm_neg.to_csv("normalized_revs_with_neg.csv")
revs_norm_neg = pd.DataFrame.from_csv("./normalized_revs_with_neg.csv", encoding="cp1251")
revs_norm_neg
# Out:
#        rating                                            content
# 0           1   интересный сюжет затягивать много время уходи...
# 4           0   сделать русский озвучка быть звезда спасибо п...
# 7           0                    постоянный проблема подключение
# 8           1   весь идеально отсутствие русский язык давать ...
# 9           0                где великий могучий сделать русский
# 11          0                              добавить русский язык
# 16          0   описание приложение написать есть русский язы...
# 17          0                               сделать русский язык
# 18          0   зайти игра поиграть ровно минута весь энергия...
# 22          1   почему игра не_запускаться перекидывать стран...
# 23          0                ждать заявить описание русский язык
# 24          0   русский язык нет английский понимать небольшо...
# 25          1   товарищ учить иностранный язык игра замечател...
# 27          0   заявить русский язык заходить игра настройка ...
# 28          1   очень продумать интересный игра весь сделать ...
# 33          1                              добавить русский язык
# 35          0                           необходимый русский язык
# 37          0                                       русский язык
# 38          0                             нет русский язык обман
# 41          0   вы написать есть русский там он игра нет сдел...
# 43          0        алло где русский язык написать русский язык
# 47          1   игра выше весь мой ожидание судить отзыв она ...
# 48          0                                   где русский язык
# 51          0   играть стыдно гейплей сюжет отсутствовать так...
# 53          1                              добавить русский язык
# 54          0   очень ждать русский язык написать он есть он нет
# 57          1                     спасибо очень интересно играть
# 58          0   описание игра русский язык указанный фактичес...
# 59          0   зачем указывать язык который нет ничто не_мен...
# 60          0                              добавить русский язык
# ...       ...                                                ...
# 22458       1   я являться постоянный клиент магазин ламода ч...
# 22459       1   тот кто писать фу весь такой советовать не_сл...
# 22460       1   ламода- супер вариант тот кто не_мочь позволи...
# 22461       1   отличный магазин удобно быстро дёшево фейковы...
# 22462       1                                   поиск фото огонь
# 22463       1   пользоваться приложение не_один год мобильный...
# 22464       1   один хороший онлайн магазин купить много одеж...
# 22465       0   господин разработчик убрать приложение дата д...
# 22467       0   доставка стиль ой я не_знать вы попасть поэто...
# 22468       0   цена конский они реклама увеличить свой член ...
# 22469       1   отличный сайт отличный приложение пока оформи...
# 22470       1   приложение сайт вещий вообще весь супееееееее...
# 22471       0   сделать заказ сказать доставка возможный завт...
# 22472       1   довольно удобно цена гуд купон который сайт м...
# 22473       0   реклама это ширпотреб достать забавлять накру...
# 22474       1   сразу весь магазин один место я декрет очень ...
# 22475       0   вкладка избранный дублироваться товар три раз...
# 22476       1                 я нравиться удобно быстро недорого
# 22477       1                                        весь хорошо
# 22478       0   смысл это приложение покупать кот мешок дорог...
# 22479       0   весь обувь китайский подделка минута развалит...
# 22480       0   заказывать зимний ботинок сказать доставить ч...
# 22481       0   доставка пони экспресс портить весь мочь вооб...
# 22482       0   меняться плохой сторона многочисленный косяк ...
# 22483       0   приложение где не_пиарить увидеть вк рекламны...
# 22484       0   не_стыдно врать никакой скидка фирма нет мага...
# 22485       0   зачем изменить приложение ненужный окошко пос...
# 22486       0                           недобросовестный реклама
# 22489       0   цена не_такой уж маленькая качество изделие о...
# 22490       0   умереть спид достать ваш реклама деньга вы от...
#
# [15566 rows x 2 columns]

# %%
def strtonormalform_with_neg_stop(line, should_delete = {'PREP', 'CONJ', 'PRCL'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    flag = False
    for word in words:
        if (word in ["не", "Не", "без", "Без"]):
            flag = True
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None) and (lex not in stop_words):#союзы, предлоги и т.п. не сохраняем
            if (flag):
                flag = False
                lex = "не_" + lex
            ans = ans + ' ' + lex
        if (lexInfo.tag.POS is should_delete) or (lex in stop_words):
            flag = False
    return ans

#revs_norm_neg_stop = revs.copy()
#revs_norm_neg_stop['content'] = revs['content'].apply(strtonormalform_with_neg_stop)
    #drop empty reviews
#revs_norm_neg_stop.drop(revs_norm_neg_stop[revs_norm_neg_stop.content == ""].index, inplace=True)

#revs_norm_neg_stop

# %%
#revs_norm_neg_stop.to_csv("normalized_revs_with_neg_stop.csv")
#revs_norm_neg_stop = pd.DataFrame.from_csv("./normalized_revs_with_neg_stop.csv", encoding="cp1251")
#revs_norm_neg_stop

# %%
def strtonormalform_with_neg_stop(line, should_delete = {'PREP', 'CONJ', 'PRCL'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    flag = False
    for word in words:
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lex not in stop_words):#союзы, предлоги и т.п. не сохраняем
            ans = ans + ' ' + lex
    return ans

revs_norm_neg_stop = revs_norm_neg.copy()
revs_norm_neg_stop['content'] = revs_norm_neg['content'].apply(strtonormalform_with_neg_stop)
    #drop empty reviews
revs_norm_neg_stop.drop(revs_norm_neg_stop[revs_norm_neg_stop.content == ""].index, inplace=True)

revs_norm_neg_stop
# Out:
#        rating                                            content
# 0           1   интересный сюжет затягивать много время уходи...
# 4           0   сделать русский озвучка звезда спасибо понимание
# 7           0                    постоянный проблема подключение
# 8           1   идеально отсутствие русский язык давать себя ...
# 9           0                где великий могучий сделать русский
# 11          0                              добавить русский язык
# 16          0   описание приложение написать русский язык фак...
# 17          0                               сделать русский язык
# 18          0   зайти игра поиграть ровно минута энергия конч...
# 22          1   почему игра не_запускаться перекидывать стран...
# 23          0                ждать заявить описание русский язык
# 24          0   русский язык нет английский понимать небольшо...
# 25          1   товарищ учить иностранный язык игра замечател...
# 27          0   заявить русский язык заходить игра настройка ...
# 28          1    очень продумать интересный игра сделать здорово
# 33          1                              добавить русский язык
# 35          0                           необходимый русский язык
# 37          0                                       русский язык
# 38          0                             нет русский язык обман
# 41          0   вы написать русский там игра нет сделать русс...
# 43          0        алло где русский язык написать русский язык
# 47          1   игра выше мой ожидание судить отзыв она много...
# 48          0                                   где русский язык
# 51          0   играть стыдно гейплей сюжет отсутствовать так...
# 53          1                              добавить русский язык
# 54          0              очень ждать русский язык написать нет
# 57          1                     спасибо очень интересно играть
# 58          0   описание игра русский язык указанный фактичес...
# 59          0   указывать язык который нет ничто не_менять мо...
# 60          0                              добавить русский язык
# ...       ...                                                ...
# 22458       1   являться постоянный клиент магазин ламода что...
# 22459       1   кто писать фу такой советовать не_слушать они...
# 22460       1   ламода- супер вариант кто не_мочь позволить с...
# 22461       1   отличный магазин удобно быстро дёшево фейкова...
# 22462       1                                   поиск фото огонь
# 22463       1   пользоваться приложение не_один год мобильный...
# 22464       1   один хороший онлайн магазин купить много одеж...
# 22465       0   господин разработчик убрать приложение дата д...
# 22467       0   доставка стиль ой не_знать вы попасть поэтому...
# 22468       0   цена конский они реклама увеличить член доста...
# 22469       1   отличный сайт отличный приложение оформить за...
# 22470       1   приложение сайт вещий супеееееееееееррррррррр...
# 22471       0   сделать заказ сказать доставка возможный завт...
# 22472       1   довольно удобно цена гуд купон который сайт м...
# 22473       0   реклама ширпотреб достать забавлять накрутить...
# 22474       1   сразу магазин один место декрет очень удобно ...
# 22475       0   вкладка избранный дублироваться товар три пов...
# 22476       1                   нравиться удобно быстро недорого
# 22477       1                                             хорошо
# 22478       0   смысл приложение покупать кот мешок дорогой м...
# 22479       0   обувь китайский подделка минута развалиться к...
# 22480       0   заказывать зимний ботинок сказать доставить ч...
# 22481       0   доставка пони экспресс портить мочь не_прийти...
# 22482       0   меняться плохой сторона многочисленный косяк ...
# 22483       0   приложение где не_пиарить увидеть вк рекламны...
# 22484       0   не_стыдно врать никакой скидка фирма нет мага...
# 22485       0   изменить приложение ненужный окошко постоянно...
# 22486       0                           недобросовестный реклама
# 22489       0   цена не_така уж маленький качество изделие оч...
# 22490       0   умереть спид достать реклама деньга вы отдать...
#
# [15557 rows x 2 columns]

# %%
revs_norm_neg_stop.rating.describe()
# Out:
# count    15557.000000
# mean         0.515009
# std          0.499791
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: rating, dtype: float64

# %%
print ('Количество положительных отзывов составляет {}% от всей выборки'.format(round(float(sum(revs_norm_neg_stop.rating)) / len(revs_norm_neg_stop.rating) * 100, 2)))
print ('Количество положительных отзывов составляет {}% от всей выборки'.format(round(float(len(revs_norm_neg_stop.rating )- sum(revs_norm_neg_stop.rating)) / len(revs_norm_neg_stop.rating) * 100, 2)))
print ('Размер обучающей выборки: {}'.format(revs_norm_neg_stop.shape[0]))
# Out:
# Количество положительных отзывов составляет 51.5% от всей выборки
# Количество положительных отзывов составляет 48.5% от всей выборки
# Размер обучающей выборки: 15557

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.model_selection import RandomizedSearchCV
from nltk.corpus import stopwords
from sklearn.model_selection import cross_validate 
from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

import string
# Out:
# C:\Users\dayan\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import sklearn.metrics

def trainTestClf(clf, X_train, y_train, X_test):
    clf.fit(X_train, y_train)
    return clf.predict(X_test)

def get_metrics(y_test, y_pred):
    accuracy = sklearn.metrics.accuracy_score(y_true = y_test, y_pred = y_pred)
    precision = sklearn.metrics.precision_score(y_true = y_test, y_pred = y_pred)
    recall = sklearn.metrics.recall_score(y_true = y_test, y_pred = y_pred)
    f1_score = sklearn.metrics.f1_score(y_true = y_test, y_pred = y_pred)
    
    return {
        "accuracy" : accuracy,
        "precision" : precision,
        "recall" : recall,
        "f1_score" : f1_score
    }


def print_metrics(metrics, vType ='-', cType='-'):
    print("Vectorizing: ", vType, ". Classifier: ", cType, sep='')

    print("accuracy = %.3f" % metrics["accuracy"])
    print("precision = %.3f" % metrics["precision"])
    print("recall = %.3f" % metrics["recall"])
    print("F-мера = %.3f" % metrics["f1_score"])

# %%
clf_svm = LinearSVC() 
clf_nb = MultinomialNB()
clf_rf = RandomForestClassifier()
clf_lr = LogisticRegression(C=1e5)

scoring = ['accuracy', 'precision', 'recall', 'f1']

# %%
norm_texts = revs_norm.content.copy()
norm_texts_splitted = revs_norm.content.str.split().copy()

norm_texts_neg = revs_norm_neg.content.copy()
norm_texts_neg_splitted = revs_norm_neg.content.str.split().copy()

norm_texts_neg_stop = revs_norm_neg_stop.content.copy()
norm_texts_neg_stop_splitted = revs_norm_neg_stop.content.str.split().copy()

# %%
#from sklearn.feature_extraction.text import TfidfVectorizer

#tiv = TfidfVectorizer()
#nwd = tiv.fit_transform(norm_texts)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer_uni = CountVectorizer(binary = True, ngram_range=(1,1), max_features= 10000)
count_vectorizer_bi = CountVectorizer(binary = True, ngram_range=(2,2), max_features= 10000)
count_vectorizer_tri = CountVectorizer(binary = True, ngram_range=(3,3), max_features= 10000)
count_vectorizer_uni_bi = CountVectorizer(binary = True, ngram_range=(1,2), max_features= 10000)
count_vectorizer_uni_bi_tri = CountVectorizer(binary = True, ngram_range=(1,3), max_features= 10000)

cvect_uni = count_vectorizer_uni.fit_transform(norm_texts)
cvect_bi = count_vectorizer_bi.fit_transform(norm_texts)
cvect_tri = count_vectorizer_tri.fit_transform(norm_texts)
cvect_uni_bi = count_vectorizer_uni_bi.fit_transform(norm_texts)
cvect_uni_bi_tri = count_vectorizer_uni_bi_tri.fit_transform(norm_texts)

# %%
# без доп признаков

# униграммы
scores1_uni = pd.DataFrame(cross_validate(clf_svm, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni = pd.DataFrame(cross_validate(clf_rf, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni = pd.DataFrame(cross_validate(clf_lr, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni = pd.DataFrame(cross_validate(clf_nb, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# биграммы
scores1_bi = pd.DataFrame(cross_validate(clf_svm, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_bi = pd.DataFrame(cross_validate(clf_rf, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_bi = pd.DataFrame(cross_validate(clf_lr, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_bi = pd.DataFrame(cross_validate(clf_nb, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# триграммы
scores1_tri = pd.DataFrame(cross_validate(clf_svm, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_tri = pd.DataFrame(cross_validate(clf_rf, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_tri = pd.DataFrame(cross_validate(clf_lr, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_tri = pd.DataFrame(cross_validate(clf_nb, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# уни- и биграммы
scores1_uni_bi = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# уни-, би-, и триграммы
scores1_uni_bi_tri = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi_tri = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi_tri = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi_tri = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
# без доп признаков

# униграммы
#X_train, X_test, y_train, y_test = train_test_split(cvect_uni, revs.rating, test_size=0.1, random_state=42)
#metr1_uni = get_metrics(y_test, trainTestClf(clf_svm, X_train, y_train, X_test))
#metr2_uni = get_metrics(y_test, trainTestClf(clf_rf, X_train, y_train, X_test))
#metr3_uni = get_metrics(y_test, trainTestClf(clf_lr, X_train, y_train, X_test))

# %%
class_res_svm = pd.DataFrame({
    "униграммы" : scores1_uni.mean(),
    "биграммы" : scores1_bi.mean(),
    "триграммы" : scores1_tri.mean(),
    "уни- и биграммы" : scores1_uni_bi.mean(),
    "уни-, би- и триграммы" : scores1_uni_bi_tri.mean()
})

print("Результаты для svm")
class_res_svm
# Out:
# Результаты для svm
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        0.244209   0.543112         0.789617               0.479634
# score_time      0.007998   0.005017         0.006003               0.007005
# test_accuracy   0.753115   0.597520         0.830914               0.829950
# test_f1         0.784880   0.710565         0.838606               0.837511
# test_precision  0.712318   0.564395         0.824917               0.824644
# test_recall     0.874645   0.959086         0.854442               0.852196
#
#                 униграммы
# fit_time         0.531864
# score_time       0.029662
# test_accuracy    0.826802
# test_f1          0.834596
# test_precision   0.821275
# test_recall      0.849825

# %%
class_res_rf = pd.DataFrame({
    "униграммы" : scores2_uni.mean(),
    "биграммы" : scores2_bi.mean(),
    "триграммы" : scores2_tri.mean(),
    "уни- и биграммы" : scores2_uni_bi.mean(),
    "уни-, би- и триграммы" : scores2_uni_bi_tri.mean()
})
print("Результаты для random forest")
class_res_rf
# Out:
# Результаты для random forest
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        4.037200   4.356153         3.054008               2.715535
# score_time      0.528569   0.784167         0.106501               0.093660
# test_accuracy   0.742386   0.590453         0.820635               0.826482
# test_f1         0.778224   0.707593         0.818175               0.824112
# test_precision  0.699435   0.559676         0.855275               0.860986
# test_recall     0.878015   0.961955         0.784712               0.790949
#
#                 униграммы
# fit_time         3.385429
# score_time       0.104117
# test_accuracy    0.820442
# test_f1          0.819672
# test_precision   0.847863
# test_recall      0.793943

# %%
class_res_lr = pd.DataFrame({
    "униграммы" : scores3_uni.mean(),
    "биграммы" : scores3_bi.mean(),
    "триграммы" : scores3_tri.mean(),
    "уни- и биграммы" : scores3_uni_bi.mean(),
    "уни-, би- и триграммы" : scores3_uni_bi_tri.mean()
})


print("Результаты для linear regression")
class_res_lr
# Out:
# Результаты для linear regression
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        0.667465   0.173455         1.373482               1.314812
# score_time      0.008430   0.008640         0.009668               0.005213
# test_accuracy   0.739560   0.601889         0.788707               0.788642
# test_f1         0.769004   0.711756         0.799480               0.799798
# test_precision  0.707826   0.567608         0.783207               0.781412
# test_recall     0.842590   0.954221         0.818644               0.820639
#
#                 униграммы
# fit_time         4.504603
# score_time       0.009000
# test_accuracy    0.760182
# test_f1          0.771370
# test_precision   0.758143
# test_recall      0.786461

# %%
class_res_nb = pd.DataFrame({
    "униграммы" : scores4_uni.mean(),
    "биграммы" : scores4_bi.mean(),
    "триграммы" : scores4_tri.mean(),
    "уни- и биграммы" : scores4_uni_bi.mean(),
    "уни-, би- и триграммы" : scores4_uni_bi_tri.mean()
})


print("Результаты для naive bayes")
class_res_nb
# Out:
# Результаты для naive bayes
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        0.015411   0.010001         0.014658               0.013245
# score_time      0.009407   0.010001         0.008424               0.009041
# test_accuracy   0.785430   0.588655         0.860530               0.860402
# test_f1         0.809759   0.708639         0.862160               0.861669
# test_precision  0.745056   0.557955         0.876102               0.878092
# test_recall     0.887491   0.971060         0.849700               0.846832
#
#                 униграммы
# fit_time         0.020690
# score_time       0.005225
# test_accuracy    0.847745
# test_f1          0.849848
# test_precision   0.861947
# test_recall      0.839346

# %%
# результаты для всех классификаторов
scores_uni_bi = pd.DataFrame({
    "SVM" : scores1_uni_bi.mean(),
    "Random forest" : scores2_uni_bi.mean(),
    "Linear regression" : scores3_uni_bi.mean(),
    "Naive Bayes" : scores4_uni_bi.mean()
})

scores_uni_bi
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.373482     0.014658       3.054008  0.789617
# score_time               0.009668     0.008424       0.106501  0.006003
# test_accuracy            0.788707     0.860530       0.820635  0.830914
# test_f1                  0.799480     0.862160       0.818175  0.838606
# test_precision           0.783207     0.876102       0.855275  0.824917
# test_recall              0.818644     0.849700       0.784712  0.854442

# %% [markdown]
# Сочетание униграмм и биграм показывает лучшие результаты, будем использовать данный способ векторизации

# %% [markdown]
# Посмотрим на метрики классификации в текстах с обработкой отрицаний

# %%
cvect_uni_bi_neg = count_vectorizer_uni_bi.fit_transform(norm_texts_neg)

# %%
# уни- и биграммы
scores1_uni_bi_neg = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi_neg = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi_neg = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi_neg = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_uni_bi_neg = pd.DataFrame({
    "SVM" : scores1_uni_bi_neg.mean(),
    "Random forest" : scores2_uni_bi_neg.mean(),
    "Linear regression" : scores3_uni_bi_neg.mean(),
    "Naive Bayes" : scores4_uni_bi_neg.mean()
})

scores_uni_bi_neg
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.373652     0.016804       2.672456  0.477643
# score_time               0.007997     0.007019       0.094701  0.003838
# test_accuracy            0.792689     0.872351       0.835154  0.840871
# test_f1                  0.802789     0.872937       0.833355  0.848583
# test_precision           0.788065     0.893557       0.868201  0.832206
# test_recall              0.819389     0.854316       0.801928  0.866789

# %%
from scipy import sparse

# %% [markdown]
# Удалим стоп-слова

# %%
cvect_uni_bi_neg_stop = count_vectorizer_uni_bi.fit_transform(norm_texts_neg_stop)


# уни- и биграммы
scores1_uni_bi_neg_stop = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi_neg_stop, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi_neg_stop = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi_neg_stop, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi_neg_stop = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi_neg_stop, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi_neg_stop = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi_neg_stop, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_uni_bi_neg_stop = pd.DataFrame({
    "SVM" : scores1_uni_bi_neg_stop.mean(),
    "Random forest" : scores2_uni_bi_neg_stop.mean(),
    "Linear regression" : scores3_uni_bi_neg_stop.mean(),
    "Naive Bayes" : scores4_uni_bi_neg_stop.mean()
})

scores_uni_bi_neg_stop
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.388208     0.016621       2.733623  0.384520
# score_time               0.007200     0.004422       0.100525  0.004472
# test_accuracy            0.789033     0.865271       0.835574  0.838594
# test_f1                  0.799947     0.866454       0.835286  0.846284
# test_precision           0.782154     0.883463       0.861383  0.830912
# test_recall              0.820524     0.851104       0.811665  0.863585

# %%
revs_norm_neg_stop = revs_norm_neg
cvect_uni_bi_neg_stop = cvect_uni_bi_neg
norm_texts_neg_stop = norm_texts_neg
norm_texts_neg_stop_splitted = norm_texts_neg_splitted

# %%
# Нахождение неверно классифицированных отзывов

def print_wrong_class(y_test, y_pred):
    inds = y_test[y_test.values != y_pred].index
    i = 0
    for idx, rev in revs_norm_neg_stop.iterrows():
        i+=1
        if (idx in inds):
            print (idx, "\tclass=", rev.rating, '\n', rev.content, '\n\n', initial_revs.ix[idx].content, "\n")

# %%
cvect_uni_bi_neg_stop.shape
# Out:
# (15566, 10000)

# %%
X_train, X_test, y_train, y_test = train_test_split(cvect_uni_bi_neg_stop, revs_norm_neg_stop.rating, test_size=0.1, random_state=42)
classifier = clf_svm.fit(X=X_train, y=y_train)
y_pred = classifier.predict(X_test)

print_wrong_class (y_test, y_pred)
# Out:
# 18 	class= 0
#   зайти игра поиграть ровно минута весь энергия кончиться нужно ждать несколько часы пока восстановиться шикарно
#
#  Зашла в игру, поиграла ровно минуту и всё, энергия кончилась, нужно ждать несколько часов пока восстановится. Шикарно ?
#
# 58 	class= 0
#   описание игра русский язык указанный фактически таковой игра нет добавить игра убрать описание
#
#  В описании к игре Русский язык указан, фактически такового в игре нет
# Добавьте в игру или уберите из описания
#
# 63 	class= 1
#   крутяга ещё русский добавить сложно постоянно нужно вспоминать английский
#
#  Крутяг
# Ещё бы русский добавили
# А то сложно ,постоянно нужно вспоминать английский )))
#
# 76 	class= 1
#   добавить русский язык игра супер график сожаление я не_мочь она играть потому не_понимать они я французский знать английски плохо
#
#  Добавьте русский язык пожалуйста, игра просто супер и графика! Но к сожалению я не могу в неё играть потому что не понимаю что они говорят((( Я французский знаю, а английски плохо(((
#
# 161 	class= 1
#   добавить русский язык
#
#  ДОБАВЬТЕ РУССКИЙ ЯЗЫК
#
# 271 	class= 1
#   ты плохо английский можно догадаться понять идти речь смысл
#
#  Даже если ты плохо знаешь английский, можно догадаться и понять о чем идёт речь по смыслу
#
# 296 	class= 0
#   игра супер
#
#  Игра супер
#
# 449 	class= 0
#   не_понятно
#
#  Не понятно
#
# 462 	class= 0
#   русский добавить
#
#  Русский добавьте
#
# 506 	class= 1
#   звонок стажёра
#
#  5 звонков стажёра из 5
#
# 603 	class= 1
#   время убить можно пока не_надоесть
#
#  Время убить можно, пока что не надоело
#
# 707 	class= 1
#   пацан вообще ребята
#
#  Пацаны вообще ребята
#
# 725 	class= 1
#   кайфовый игра начало действительно чуть скучноватый потом появление куча условие катаклизм становиться крайне весело единственный обидный не_успевать толком фраза читать таймер
#
#  Кайфовая игра) если в начале действительно чуть скучновато, то потом, с появлением кучи условий и катаклизмов, становится крайне весело) единственное обидно, что не успеваешь толком фразы читать — таймер же
#
# 1189 	class= 1
#   запуск игра любой режим карта мир не_загружаться чёрный синица экран весь нажимать пустота выбор место начать игра нету такой
#
#  При запуске игры в любом режиме карта мира не загружается ( чёрный или синиц экран и все ) и если нажимать в пустоту то выбора места начатая игры нету. Что такое ?
#
# 1223 	class= 0
#   игра великолепный хотеться большой разнообразие он очень мало хотеть большой платить убрать донат поставить звезда заранее спасибо
#
#  Игра великолепная, но хочется больше разнообразия (его очень мало)! Хотите больше? Платите!!!! Уберёте Донат поставлю 5 звёзд!
# Заранее спасибо!!!
#
# 1305 	class= 1
#   мочь приврать эпидемия скука ты очередь весь платный дополнение можно открыть прохождение хард
#
#  Может приврать эпидемию скуки если ты в очереди например, все платные дополнения можно открыть за прохождение на харде!
#
# 1377 	class= 1
#   играбельный
#
#  Но играбельно
#
# 1423 	class= 1
#   я понравиться дть версия купить полный весь хороший пока пройти её пройти год её невозможно пройти целое нормальный почему полный версия я реклама
#
#  Мне понравилась демо версия купил полную но все равно 1 лучше пока пройдешь её пройдет 10 лет её невозможно пройти но в целом нормально только вот почему в полной версии у меня реклама?
#
# 1654 	class= 1
#   скачать сначала дть версия игра не_прошлый минута она я затянула-сразу скачать полный версия график озвучка сюжет
#
#  Скачал сначала демо версию игры,не прошло и 5 минут как она меня затянула-сразу же скачал полную версию! Графика 5,озвучка 5,сюжет 5 ??
#
# 1853 	class= 1
#   снять карта два цена ошибка вернуть нет вы мелкий беспринципный наглый вор быть последний мой платный приложение
#
#  Сняли с карты две цены. Если ошибка, то верните, если нет, то вы мелкие, беспринципные,наглые воры и это было последнее мое платное приложение.
#
# 2112 	class= 1
#   не_понимать зачем человек писать много реклама вырубить интернет
#
#  Не понимаю зачем люди пишут что много рекламы?????!!! Просто вырубите интернет!
#
# 2354 	class= 0
#   плюс залипнуть сей пора играть не_надоедать минус немного бесить конец умераесть реклама реклама реклама
#
#  Плюсы: залип до сих пор играю ,не надоедает
# Минусы:немного бесит когда на конце умераешь, реклама реклама реклама
#
# 2402 	class= 0
#   интересный игрушка столько много реклама навязчивый я не_встречать нигде сыграть кон удалить огромный негатив оставить приложение
#
#  Возможно интересная игрушка, но столько много рекламы навязчивой я не встречал нигде, сыграл 3 кона и удалил, огромный негатив оставило приложение
#
# 2520 	class= 1
#   забыть уже длинный очередь заявление не_правильно не_заполнить очень довольный программа много экономить время деньга
#
#  Забыл уже про длинные очереди. Плюс заявление не правильно не заполнишь очень доволен программой много экономит времени и денег.
#
# 2587 	class= 0
#   не_мочь уже два неделя отправить дать проверка писать технический работа ещё ждать
#
#  Не могу уже вторую неделю отправить данные на проверку! Пишет , что технические работы
# Сколько ещё ждать !!????
#
# 2810 	class= 0
#   неделя каждый день что-то
#
#  Неделю каждый день «что-то не так»!
#
# 2963 	class= 1
#   обновление полный ужас хотеть оно быть старое весь остальной норма
#
#  Обновление просто полный ужас хочу чтобы оно было старым.А всё остальное норм.
#
# 2980 	class= 0
#   приложение очень классный обновление
#
#  Приложение очень классное, но после обновления....
#
# 3631 	class= 0
#   достать уже
#
#  Достали уже
#
# 4073 	class= 0
#   последний обновление вкладка показывать миниатюра не_активный сообщение приходить не_понятно кто
#
#  После последнего обновления когда вкладка «показывать миниатюры» не активна, сообщения приходят не понятно от кого!!!
#
# 4195 	class= 1
#   надо лента
#
#  Надо в ленту
#
# 4224 	class= 1
#   пока ставить исправить ближний врать не_исправить
#
#  Пока ставлю 5 но исправлю на 1 если в ближайшее врем не исправите
#
# 4228 	class= 0
#   нечего делать старый версия такой
#
#  Нечего делать старая версия такая же
#
# 4339 	class= 0
#   попробовать надо регистрироваться удалять
#
#  Чтобы попробовать надо регистрироваться, удаляю.
#
# 4358 	class= 1
#   скачать урааа
#
#  Скачала урааа
#
# 4654 	class= 0
#   чисто тот подушить удав
#
#  Чисто для того чтобы подушить удава
#
# 4754 	class= 1
#   последний обновление куда-то деться информация доход заходить мой помощник расход есть доход месяц нет они куда-то переехать
#
#  После последнего обновления куда-то делась информация о доходах. Заходишь в «мой помощник», расходы есть, а доходов за месяц нет. Или они куда-то «переехали»?
#
# 4771 	class= 0
#   ужасный банк вы плевать клиент ваш нет мобильный приложение онлайн чат где можно проблема решить оперативно телефон дозвониться ты скинуть ты не_найти нужный пункт ты скинуть оператор вообще не_дожить трубка брать специалист понимать он нулина ленивый нулина который твой проблема слушать не_хотеть решение проблема заблочили карта перевыпуск весь легко думать отвалить классный ребята отвечать ваш банк колено ползать видимо надо быв адекватно начать помогать тьфу не_большой количество мой знакомый уйти люба другой банк я не_мочь уже терпение не_хватать
#
#  Ужасный банк, вам плевать на клиентов ваших.
# Нет в мобильном приложении онлайн чата, где можно проблемы решить оперативно
# По телефону если дозвонишься , тебя либо скинут, либо ты не найдёшь нужный пункт и тебя скинут
# До оператора вообще не дожить
# А когда трубку берет специалист , понимаешь что он нулина, просто ленивая нулина, которая твои проблемы и слушать не хочет
# Вместо решения проблемы, заблочили карту и на перевыпуск, и все и легко
# И думаете отвалили. Классные ребята
# Отвечаю перед вашим банком на коленях ползать видимо надо, что быв адекватно начали помогать
# Тьфу, если б не большое количество моих знакомых, ушёл бы в любой другой банк
# Я ж не могу уже , терпения не хватает
#
# 4794 	class= 1
#   весь очень неплохо не_мочь избавиться навязчивый реклама кредитный карта не_нужный она я глаз мозолить главный страница
#
#  Все очень неплохо, но не могу избавиться от навязчивой рекламы кредитной карты, ну не нужна она мне, а глаза мозолит на главной странице.
#
# 4826 	class= 1
#   обновление попытка зайти приложение оно стать вылетать начинать загружаться просить приложить палец приходить смс вход этот момент вылетать
#
#  После обновления, при попытке зайти в приложение, оно стало вылетать. Начинает загружаться, просит приложить палец, приходит смс о входе и в этот момент вылетает.
#
# 4869 	class= 1
#   обновление попытка зайти приложение оно стать вылетать начинать загружаться просить приложить палец приходить смс вход этот момент вылетать
#
#  После обновления, при попытке зайти в приложение, оно стало вылетать. Начинает загружаться, просит приложить палец, приходит смс о входе и в этот момент вылетает.
#
# 4975 	class= 0
#   обновление перестать показывать последний операция показывать сумма который я совершать несколько день назад исправт
#
#  После обновления перестало показывать последние 10 операций. Показывает суммы которые я совершал несколько дней назад. Исправте!!!
#
# 5083 	class= 0
#   почему постоянно выкидывать приложение
#
#  Почему постоянно выкидывает из приложения ????
#
# 5089 	class= 0
#   уже несколько день пытаться создать сберегательный счёт создать цель ранний это быть весь простой сейчас ждать ответ ничто
#
#  Уже несколько дней пытаюсь создать сберегательный счёт или создать цель....раньше с этим было все проще... а сейчас ждите ответ ... но ничего ...
#
# 5119 	class= 1
#   просить добавить возможность расход название торговый точка посмотреть она адрес том некоторый торговый точка непонятно называться
#
#  Прошу добавить возможность в расходах по названию торговой точки посмотреть ее адрес. Т к некоторые торговые точки непонятно называются.
#
# 5170 	class= 0
#   хотеть раз день видеть предложение натянуть вы тугой тогда инстагра он реклама вы
#
#  Хотите 10 раз на дню видеть предложения натянуть вас потуже? Тогда Инстаграм с его рекламой для вас
#
# 5318 	class= 1
#   этот уже два месяц год десятилетие вы мочь подписываться хештег что-то тип тот
#
#  Ну хотя бы на этот - «уже как два месяца (года, десятилетия), Вы можете подписываться на хештеги.» Ну или что-то типа того))
#
# 5453 	class= 1
#   писать отсутствовать подключение сеть бред весь включиный
#
#  Пишет отсутствует подключение сети что за бред все включино
#
# 5728 	class= 1
#   почему я отмениться подписка музыка не_возобновляться
#
#  Почему у меня отменилась подписка на музыку и не возобновляется?!
#
# 5828 	class= 0
#   спасибо большой приложение очень радовать
#
#  Спасибо большое, приложение очень радует!
#
# 5894 	class= 0
#   добавить упоминание человек конференция тогда быть балл
#
#  Добавьте упоминание человека в конференции через @
# Тогда и будет 5 баллов
#
# 6012 	class= 0
#   молодец испоганить приложение надо постараться мой оценка держать оказываться жизнь день весь есть
#
#  Просто молодцы, так испоганить приложение это надо постараться ! Моя оценка -10 из 10. Так держать, оказывается жизнь на дне все таки есть ?
#
# 6032 	class= 0
#   обновление дизайн стать откровенно блевотный приложение начать жрать память свой ебучить кеш прямо инстагра совпадение который нельзя удалить не_удалить приложение часто вылетать майла ру научиться делать удобный клиент не_такой который нравиться вы я не_эксперт по-моему вы есть задача пользователь быть приятно удобно пользоваться ваш приложение
#
#  После обновления дизайн стал откровенно блевотным. Приложение начало жрать память своим ебучим кешем (прямо как инстаграм, совпадение?..), который нельзя удалить не удалив приложение. Часто вылетает. Майл.ру, научитесь пожалуйста делать удобные клиенты, а не такие, которые нравятся вам. Я конечно не эксперт, но по-моему у вас есть задача, что бы пользователям было приятно и удобно пользоваться вашим приложением.
#
# 6056 	class= 0
#   красиво грамотно бать весь приложение парашка стать
#
#  Так красиво и грамотно у*бать все приложение, парашкой стало
#
# 6057 	class= 0
#   последний обновление весь тупить дуров вернуть стен
#
#  С последним обновлением все тупит. Дуров верни стену
#
# 6551 	class= 1
#   обновление пропасть история поездка
#
#  После обновления пропала история поездок :(
#
# 6691 	class= 1
#   надо опракинуть ваза бабка прибежать открыть дверь надо сать кравати надо прятиться кравать вылезать она багнец
#
#  Надо опракинуть вазу бабка прибежит когда откроет дверь то надо в сать из под кравати и надо прятатся под кравать и вылезать и она багнеца
#
# 6709 	class= 1
#   я удалить очень страшный я испукалс уранил тилифон я баюс очинь очинь страшный играаа
#
#  Я удалю очень страшна я испукалса и уранил тилифон я баюс очинь очинь страшная играаа
#
# 6718 	class= 1
#   быть обнова потому уже скукота
#
#  Когда будет обнова потому уже скукота
#
# 6889 	class= 1
#   чётко играть полтора час почти открыть дверь пойти кусачки 2-ой этаж проволиться умереть быть последний жизнь
#
#  Чётко. Играю полтора часа, почти открыл дверь, пошел за кусачками на 2-ой этаж. Проволился. Умер. Была последняя жизнь.
#
# 7078 	class= 1
#   игра хороший интересный график сожаление нет русский язык
#
#  Игра хорошая, интересная графика. Но к сожалению нет русского языка.
#
# 7125 	class= 1
#   игра хороший интересный график сожаление нет русский язык
#
#  Игра хорошая, интересная графика. Но к сожалению нет русского языка.
#
# 7176 	class= 1
#   открыться обновить стоянка грузовик склад переполненный ничто это поделать нереал наживать кнопка увеличить склад реакция нет
#
#  Открылась обновлённая стоянка грузовиков и склад переполнен и ничего с этим поделать нереал наживаешь кнопку увеличить склад а реакции нет
#
# 7408 	class= 0
#   ужас не_мочь разместить объявление сдача номер коттедж постоянно блокировать модератор указывать новое причина весь выполнять менять итог объявление мой не_разместить ранний быть удобный простой сейчас очень расстраивать авить
#
#  Ужас! Не могу разместить объявление о сдаче номеров в коттедже! Постоянно блокируют модераторы, указывая новые причины, все выполняю , меняю, в итоге объявление мое не размещено!! Раньше было удобнее и проще. Сейчас очень расстраивает авито
#
# 7456 	class= 0
#   самый интересный хороший отзыв писать не_реальный пользователь реальный работник модератор создавать видимость хорошеть работа компания сотрудник весь особенно модератор
#
#  Самое интересное что хорошие отзывы пишут не реальные пользователи. Точнее реальные работники и модераторы создают видимость хорошей работы компании и сотрудников. Минус всем, особенно модераторам
#
# 7467 	class= 1
#   можно гадить подавать объявление он отклонять тип не_верный вино номер деньга брать ау авто
#
#  Сколько можно гадить. Подаю объявление его отклоняют типа не верный вин номер но деньги берут ау авто
#
# 7503 	class= 0
#   приниматься платный объявление бесплатный сразу отклоняться модератор
#
#  Принимаются только платные объявления !! Бесплатные сразу отклоняются модератором!
#
# 8246 	class= 0
#   заходить фризита нажимать весь могу- ничо она делать
#
#  захожу,фризит нажимаю на все что могу- ничо ее делает
#
# 8449 	class= 0
#   не_мочь зарегистрироваться писать проверить соединение попробовать поздний делать
#
#  Не могу зарегистрироваться, пишут, проверьте соединение и попробуйте позже. Что делать?
#
# 8534 	class= 1
#   я не_грузить фото
#
#  У меня не грузит фото
#
# 8546 	class= 0
#   телеграмма перестать работать последний версия не_обновляться делать не_мочь настроить проксить сервер дуров писать весь работать прежний режим видимо не_я делать
#
#  Телеграмм перестал работать! До последней версии не обновлялась. Что делать?! Не могу настроить прокси сервер, хотя Дуров писал что все работает в прежнем режиме..но видимо не у меня.. Что делать?!
#
# 8643 	class= 1
#   пламенный патриот напомню- коперник сжечь закон легитимный власть весь делать гитлер- тоже быть законно территория германия закон вы мочь сесть год украсть жвачка супермаркет время сердюк васильев избежать наказание воровство мрлд рубль тоже закон
#
#  Пламенным патриотам напомню- Коперника сожги по закону легитимные власти.
# Всё, что делал Гитлер- тоже было законно на территории Германии.
# По закону вы можете сесть лет на 5 за украденную жвачку в супермаркете, и в то же время Сердюков и Васильева избежали наказание за воровство 2 мрлд руб тоже по закону.
#
# 8732 	class= 0
#   жабушко
#
#  жабушка
#
# 8739 	class= 1
#   почему не_производить песнь полностью исправить айфон
#
#  Почему не производит песни полностью?!  Исправьте!!! 5 айфон
#
# 8885 	class= 0
#   вы я вляпаться яндекс музыка помочь отписаться ранний я очень любить ваш программа теперь вы всегда быть ассоциироваться мерзкий яндекс музыка
#
#  «Благодаря» вам я вляпалась в яндекс музыку. Помогите отписаться. Раньше я очень любила вашу программу, теперь вы всегда будете ассоциироваться с мерзкой яндекс музыкой.
#
# 8958 	class= 0
#   я старик сказать ранний быть хороший очень расстроить автоматический режим тобыть цепочка трек подряд ничто не_находить ранний болгарка ряд реж находить люба трек сейчас упор поднести источник не_найти дать бог попытка получиться интерфейс смах палец сторона неудобный
#
#  Да я старик и скажу, что раньше было лучше. Очень расстроен. В автоматическом режиме, тоесть по цепочке, когда треки подряд ничего не находит. Раньше хоть болгаркой рядом реж находил любой трек, сейчас хоть в упор поднеси к источнику, не найдет, дай бог с 3 попытки получится. Интерфейс смахом пальца в сторону неудобен
#
# 9037 	class= 0
#   писать очередь она оттуда избавить
#
#  Пишет что в очереди. Как ее оттуда избавить?
#
# 9149 	class= 0
#   приложение работать старик тормозить долго думать выбрасывать пока распознать песня мочь проебать песня пока зайти приложение
#
#  Приложение работает как старик тормозит долго думает выбрасывай пока распознаешь песню можешь и проебать песню Пока зайдёшь приложения
#
# 9192 	class= 0
#   мой учётный запись уже который раз не_мочь войти найти музыка
#
#  Что с моей учетной записью, уже который раз не могу войти и найти музыку
#
# 9553 	class= 1
#   можно продать приобрести необходимый вещий
#
#  Можно продать и приобрести необходимые вещи
#
# 9954 	class= 0
#   добавить ясный погода солнечный весь время ночь вечер
#
#  Добавьте ясную погоду, солнечную, а то все время ночь и вечер
#
# 10078 	class= 0
#   лаг яблоко я асфальт не_лагаета производительность плохааааааий
#
#  Лаги на 10 яблоке , у меня даже асфальт 9 не лагает!!!!! Производительность плохааааааая
#
# 10194 	class= 1
#   цена низкий качество пока не_проверять
#
#  Цены низкие. По качеству пока не проверял.
#
# 10248 	class= 1
#   всегда получать заказ последний время не_дошлый посылка деньга вернуть не_проблема надеяться весь наладиться
#
#  Всегда получал заказы .
# Но в последние время не дошло 8 посылок.
# Деньги вернули без проблем .
# Надеюсь все наладится .
#
# 10350 	class= 0
#   один посылка не_пришлый
#
#  Ни одна из 25 посылок не пришла
#
# 10564 	class= 0
#   приходить 20-25 день джума два месяц
#
#  С али приходят за 20-25 дней ,с джума два месяца
#
# 10576 	class= 0
#   не_открываться главный страница заказ решить заново сказать приложение итог теперь не_мочь войти свой профиль
#
#  Не открывается главная страница и заказы. Решила заново сказать приложение и в итоге теперь не могу войти в свой профиль
#
# 10782 	class= 0
#   абсолютно ничто
#
#  Вот абсолютно ничего
#
# 10917 	class= 1
#   хороший приложение ценник стать дорогой быть качество вещий снизиться сам приложение удобный хороший
#
#  Хорошее приложение. Ценник стал дороже чем был и качество вещей снизилось, но само приложение удобное и хорошее
#
# 10999 	class= 0
#   здравствовать разроботчик я оброшяться вы просьба понизить цена товар потомучьто уш очень дорого самолёт каторый прославиться ютуба стыть теперь 3000тысяча
#
#  Здравствуйте разроботчики я оброшяюсь к вам с просьбой  понизить цены на товар  потомучьто уш очень  дорого даже самолёт  каторый прославился в ютубе стоет теперь 3000тысячи
#
# 11440 	class= 1
#   не_работать алиса нормальный говорить она команда она весь не_мочь закончить игра город
#
#  Не работает Алиса нормально ,говорю ей команду ,а она все не может закончить игру в города
#
# 11567 	class= 0
#   хотеться навигатор показывать не_маршрут намного большой он я вести город писать час 20минута ехать каду я еда 30-35 минута можно добавить функция разный маршрут я мочь сам выбрать я ехать
#
#  Хотелось бы чтоб навигатор показывал не только 3 маршрута а намного больше так например он меня ведёт через город и пишет 1 час 20минут ехать а по каду я еду за 30-35 минут. Если можно добавьте функцию разных маршрутов чтоб я мог сам выбрать как мне ехать!
#
# 11832 	class= 1
#   дурак реклама можно отключить бесплатно говорить не_быть
#
#  ДУРАКИ РЕКЛАМУ МОЖНО ОТКЛЮЧИТЬ БЕСПЛАТНО (говорить не буду)
#
# 12036 	class= 1
#   я добиться больший результат этот игра она затянуть я месяц раз игра затягивать однозначно звезда
#
#  Я добился больших результатов в этой игре, так как она затянула меня на месяц, а раз игра затягивает то это однозначно 5 звёзд
#
# 12099 	class= 0
#   сам компания хороший курьер красавчик вид бонус промокод заказать паперонить сантиметр промокод привезти оплатить открывать колбаса нижний слой тест подгореть итальянский сантиметр рубль нормальный весь норма подгореть тесто немного гавайский ранний заказывать быть хорошо отличный пицца заказать сегодня привезти пересушить пицца начинка печь пересушить итог заказ номер доставка привезти мина ранний сумма заказ рубль
#
#  Сама компания хорошая,Курьеры красавчики.
# Но виде бонуса по промокоду заказал
# Паперони 25 см по промокоду привезли оплатил открываю колбаса и нижний слой теста подгорел.
# Итальянская 35 см 692 руб нормальная все норм но подгорела тесто немного.
# Гавайская раньше заказывал было хорошо отличная пицца Заказала сегодня
# Привезли пересушенную пиццу начинку в печи пересушили.
# Итог 3/3 Заказ номер 260 доставку привезли за 30 мин раньше.
# Сумма заказа 1300 руб.
#
# 12696 	class= 0
#   интересный игра запаганиля реклама звезда
#
#  Интересную игру запаганили рекламой((( за это 1 звезду
#
# 13011 	class= 0
#   тупой игрушка никчёмный
#
#  Тупая игрушка, никчемная
#
# 13228 	class= 0
#   такой проблема не_я телефон обновить приложение тоже весь прекрасно сообщение не_отправляться писать интернет нет не_хорошо
#
#  Такая проблема не только у меня .Телефон обновлён .Приложение тоже .Все прекрасно ,но Сообщения не отправляются ,пишет ,что интернета нет .Не хорошо )
#
# 13261 	class= 0
#   обновление мало жрать зарядка убирать крутой маска ранний быть хороший
#
#  Обновления мало!
# Жрёт зарядку
# Убирают крутые маски
# Раньше было лучше!
# ??????????????????
#
# 13642 	class= 1
#   где разместить вакансия можно я не_найти
#
#  А где разместить вакансию можно ? Я не нашла что то
#
# 13680 	class= 1
#   выбрать диапазон зарплата какой я нужный
#
#  Как Выбрать диапазон зарплаты какой мне нужен
#
# 13894 	class= 0
#   алеооо народ вы что исправить интересно обновление весь полететь просить заново регистрироваться бардак
#
#  Алеооо,народ вы чего так исправили интересно??после обновления все полетело,и просит заново регистрироваться!???бардак!
#
# 14062 	class= 0
#   ребята вы тестировать свой приложуха прежде обновление продиться пускать обновление касса не_захотеть открывать один карту-вылетать весь обновление весь работать часы огорчить
#
#  Ребята, вы хоть тестируйте свою приложуху, прежде чем обновление в прод пускать. После обновления на кассе не захотело открывать ни одну карту-вылетает и все, хотя до обновления все работало как часы. Огорчили...
#
# 14177 	class= 1
#   пользоваться регулярно
#
#  Пользуюсь регулярно!
#
# 14690 	class= 0
#   целое приложение полезный никакой нерв не_хватать пока оно тупить подвисать процесс неимоверно долго грузиться другой приложение программист работать ускорение работа здесь весь наоборот каждый обновление весь худой лишний раз стараться не_загружать нерв дорогой
#
#  В целом приложение полезное, но! Никаких нервов не хватает, пока оно тупит, подвисает в процессе и неимоверно долго грузится. Если в других приложениях программисты работают над ускорением работы, то здесь все наоборот. С каждым обновлением все только хуже. Лишний раз стараюсь не загружать. Нервы дороже.
#
# 14738 	class= 1
#   незаменимый программа телефон не_она никуда
#
#  Незаменимая программа на телефоне, без неё никуда
#
# 14822 	class= 0
#   приложух общий не_плохой не_слать авость политический разработчик вернуть карта донецк уро ы
#
#  Приложуха в общем не плохая , если бы не шлю*авость политическая разработчиков. Верните карту Донецка уро*ы.
#
# 14846 	class= 1
#   добавить трасса нижневартовск-сургут стрежевой
#
#  Добавьте пожалуйста трасса Нижневартовск-Сургут. и Стрежевой
#
# 15274 	class= 1
#   огонёк
#
#  Огоньки!!!!
#
# 15568 	class= 0
#   цена программа 200р месяц подписка автор программа вы адекватный такой цена ставить один дело цена программа 200р навсегда извинить месяц я эплмьюзик 170р подключить хороший
#
#  Цена программы 200р в месяц по подписке, автор программы, вы адекватны такие цены ставить?
# Одно дело если цена программы 200р навсегда, но извините в месяц?!! Я эплмьюзик за 170р подключу лучше
#
# 15686 	class= 0
#   обида боль разочарование
#
#  (((( обида боль разочарование
#
# 15768 	class= 0
#   это пользоваться
#
#  Как этим пользоваться???
#
# 15771 	class= 1
#   теперь не_прийтись слушать музыка вк половина час
#
#  Теперь не прийдется  слушать музыку через вк пол часа.
#
# 16117 	class= 0
#   жаль мало город страна допустить греция страна есть маршрут нет
#
#  Жаль что так мало городов и стран. Допустим Греция. Страна то есть, а маршрута нет.
#
# 16168 	class= 1
#   всегда я всегда рука не_приложение один поездка не_обходиться
#
#  Всегда со мной! Всегда под рукой!! Без приложения ни одна поездка не обходится !!
#
# 16357 	class= 1
#   отключить настройка оценка организация пушить продолжать приходить ужасно раздражать
#
#  Отключил в настройках оценку организаций, однако пуши продолжают приходить. Ужасно раздражает
#
# 16487 	class= 1
#   убрать идиотический панель сюда отсюда фотка она появляется-она не_убрать перезагрузка
#
#  Уберите идиотическую панель сюда отсюда с фоткой внизу-если она появляется-ее никак не убрать.Только перезагрузка
#
# 16489 	class= 1
#   весь очень довольный есть проблёмкий хотеться установить офлайна карта московский область выдавать ошибка не_достаточно память телефон ещё гб свободный место делать заранее благодарный
#
#  Всем очень доволен, но есть проблемка.. Хочется установить офлайн карту Московской области, но выдаёт ошибку, не достаточно памяти. На телефоне ещё 5 ГБ свободного места, что делать? Заранее благодарен.
#
# 16502 	class= 0
#   долго грузиться не_показывать пробка не_показывать правильно время работа объект
#
#  Долго грузятся. Не показывают пробки. Не показывают правильно время работы объектов.
#
# 16822 	class= 1
#   почему приложение ничто не_грузить ерунда
#
#  Почему приложение ничего не грузит что за ерунда
#
# 17081 	class= 0
#   не_мочь повернуть фото исправить телефон оно ровно загрузить сюда оно набок лечь
#
#  Не могу повернуть фото , как исправить, на телефоне оно ровно, а загрузил сюда, оно набок легло
#
# 17102 	class= 0
#   почему версия обновляться автоматически я большой нравиться предыдущий я свой настройка ничто не_включать ранний такой не_быть
#
#  Почему версия обновляется автоматически. Мне больше нравится предыдущая. Я в своих настройках ничего не включала. Раньше такого не было.
#
# 17192 	class= 0
#   вернуть деньга подключать пробный период день услуга невидимка сегодня смотреть баланс карта
#
#  Верните деньги !, Подключал пробный период в 3 дня на услугу «Невидимка» ,
# Сегодня смотрю баланс карты, -269.
#
# 17194 	class= 0
#   почему приложение стать платный ужас
#
#  Почему приложение стало платным?? Это ужас
#
# 17297 	class= 1
#   сначала программа работать отлично быть год 2-3 назад я слушать музыка отправлять различный смайлик друг обновление смайлик стать платный музыка появиться реклама нельзя быть её слушать находиться не_предложение надо быть платить не_считать программа нормальный пока мочь дать звезда
#
#  Сначала программа работала отлично ( это было года 2-3 назад) . Я слушала музыку отправляла различные смайлики друзьям. После обновления смайлики стали платными и в музыке появилась реклама и нельзя было её слушать находясь не в предложении. За это надо было платить. .
# А если это не считать то программа нормальная .
# Пока могу дать только 4 звёзды.
#
# 17367 	class= 1
#   обновление тупить сильно
#
#  После обновления тупит сильно
#
# 17432 	class= 0
#   почему я закрытый профиль получать смс исправить ошибка
#
#  Почему я при закрытом профиле получаю смс ??! Исправьте ошибку ???
#
# 17698 	class= 0
#   ранний мы не_платить слушать музыка приложение это исполнитель не_быть терять свой день говориться запретный плод сладкий опять пойти скоро волна бесплатный приложение музыка ещё один пиар ход отмывание деньга жаль последний год весь поменяться очень жаль ставить жирный кола один минус цена человек пустота отдавать деньга надо присекать
#
#  Раньше мы не платили за то что слушаем музыку в приложении, от этого исполнители никак не будут терять свои день, а как говорится запретный плод сладок и опять пойдёт скоро волна бесплатных приложений для музыки, либо это ещё один пиар ход и отмывание денег, жаль что за последние 2 года все поменялось, очень жаль, ставлю жирный кол только из-за одного минуса это цена, люди просто в пустоту отдают деньги а это надо присекать
#
# 17883 	class= 1
#   написать можно скачать музыка телефон специально это скачать приложение оно скачивать сам приложение зачем писать можно скачать слушать скачиваться можно сам приложение
#
#  Написано можно скачать музыку на телефон , специально для этого и скачала приложение , а оно просто якобы скачивает в само же приложение . Зачем пишите , что можно скачать , если слушать и скачиваться только можно в само приложение !
#
# 17918 	class= 1
#   пк рубль потом быть не_знать учёт тот весь становиться платный здесь большой нравиться вк более апплмюзик яндекс общий почти молодец весь яндекс такси не_давать водитель нормальный работать зарабатывать цена плинтус процент адский я машина миллион стоить я должный возить этот нищеброд который сто рубль лезть пятер два ребёнок вернуть точка яндекс
#
#  На ПК за 99 рублей. Что потом будет и сколько не знаю. Но с учетом того что всё становится платным здесь больше нравится чем в вк и тем более чем в апплмюзик. Яндекс в общем почти молодцы во всём кроме яндекс.такси. Ну не дают водителям нормально работать и зарабатывать. Цены ниже плинтуса, процент просто адский. У меня машина миллион стоит и я должен возить этих нищебродов которые за сто рублей лезут в пятером с двумя детьми?! И верни точку Б, Яндекс !!!
#
# 18035 	class= 1
#   хороший конкурент другой платформа есть один который я прямо вымораживать весь нет нету самый важность мнение многий эквалайзер тут он сильно не_хватать просить он следующий обновление добавить большой спасибо уделить время который вы потратить время чтение мой отзыв
#
#  Хороший конкурент других платформ но есть один минус который меня прямо вымораживает. Вот все вроде нет но нету самого важностей по мнению многих и это Эквалайзер вот тут его сильно не хватает прошу его в следующем обновлении добавить. Большое спасибо за уделённое время которые вы потратили на время чтения моего отзыва. ?
#
# 18071 	class= 0
#   нравиться смотреть реклама вперёд качать разраб убить себя стульчак унитаз
#
#  Нравиться смотреть рекламу вперёд качай, разраб убей себя стульчаком от унитаза
#
# 18086 	class= 1
#   игра ужас играть не_логаета
#
#  Игра просто ужас играть не возможно , логает
#
# 18329 	class= 1
#   не_всегда подключаться
#
#  Не всегда подключается
#
# 18359 	class= 0
#   вздумать качать есть куча бесплатный аналог хороший производительность
#
#  НЕ ВЗДУМАЙТЕ КАЧАТЬ ЕСТЬ КУЧА БЕСПЛАТНЫХ АНАЛОГОВ С ЛУЧШЕЙ ПРОИЗВОДИТЕЛЬНОСТЬЮ!!!
#
# 18393 	class= 1
#   быстро подкодчаетсч позволять зайти любой сайт подсказать купить подписка платный отключиться реклама это загрузка сайт стать быстрый
#
#  Быстро подкодчаетсч, позволяет зайти на любые сайты. Подскажите, если купить подписку платную, то отключится реклама или плюс к этому загрузка сайтов станет быстрее?)
#
# 18680 	class= 0
#   достать уже этот бестолковый навязчивый обновление
#
#  Достали уже эти бестолковые навязчивые обновления!!!!!
#
# 18771 	class= 1
#   каждый день обнова
#
#  Каждый день обновы
#
# 18815 	class= 1
#   отличный обновление создатель не_виновный вы плохой тупить телефон
#
#  Отличное обновление! Создатели не виновны, что у вас плохой, тупящий телефон!
#
# 18853 	class= 0
#   дно весь соцсеть натуральный беня
#
#  Просто дно всех соцсетей, натуральная бо€бень!
#
# 18876 	class= 0
#   мочь хватить обновление раз половина год вполне достаточно
#
#  Может хватит обновлений, раз в пол года вполне достаточно!
#
# 19091 	class= 0
#   почему незнакомый человек становиться мой друг
#
#  ПОЧЕМУ НЕЗНАКОМЫЕ ЛЮДИ СТАНОВЯТСЯ МОИМИ ДРУЗЬЯМИ А?
#
# 19154 	class= 0
#   раздуть невероятный размер
#
#  Раздули до невероятных размеров
#
# 19477 	class= 1
#   не_мочь обновить причина обновить
#
#  Не могу обновить!!! Причина ? Как обновить?
#
# 19621 	class= 1
#   я вы не_нравиться
#
#  Я вам не нравлюсь
#
# 19635 	class= 0
#   играть уже несколько год сейчас думать удалить игра обидный последний обновление игра загружаться медленно не_давать пройти один предложить состязание сразу выкидывать приложение уже несколько день потерять нерв предел далёкий весь худой худой
#
#  Играю уже несколько лет,но сейчас думаю удалить игру. Обидно!!! После последнего обновления игра загружается медленно и не даёт пройти ни одно из предложенных состязаний,сразу выкидывает из приложения(уже несколько дней потеряно)нервы на пределе,чем дальше всё хуже  и хуже...
#
# 19661 	class= 0
#   сабж
#
#  сабж
#
# 19698 	class= 0
#   выставить штраф глючил программа никогда большой не_быть пользоваться ваш предложение ранний любить теперь чао сказать спасибо водитель евгений
#
#  Выставили штраф, за то, что глючила программа . Никогда больше не буду пользоваться вашим предложением. Раньше любил, но теперь чао . Скажите спасибо Водителю Евгений
#
# 19842 	class= 0
#   водитель привозить не_адрес скидывать заказ доставить называть свой сумма который хотеть водитель хам дорога не_знать
#
#  Водители привозят не по адресу скидывают заказ как доставлен ,называют свою сумму которую хотят.Водители хамы.дорог не знают.
#
# 20019 	class= 0
#   поддержка мы понимать должный быть неудобно яндекс отличный работа убивать далёкий приложение основный конкурент удачный сделка
#
#  В поддержке говорят «Мы понимаем, как это должно быть неудобно»
#
# Яндекс, отличная работа!!!! Убивайте дальше приложение основного конкурента, удачная сделка!
#
# 20209 	class= 1
#   перестать переводить сразу выходить ошибка не_подключить интернет интернет весь нормальный жаль хорошо весь быть
#
#  Перестал переводить, сразу выходит ошибка, что не подключён к интернету, но с интернетом все нормально, жаль так хорошо все было........
#
# 20254 	class= 0
#   платно
#
#  ПЛАТНО???
#
# 20269 	class= 0
#   работать ранний стабильно всегда спасать последний время почему слишком долго грузиться вбивать предложение минута два приходить интернет высокий проверять
#
#  Работал раньше стабильно, всегда спасал, но в последнее время почему слишком долго грузится(вбиваю предложение, а перед через минуту или две приходил), хотя интернет высокий(проверял)
#
# 20447 	class= 1
#   сделать регулировка скорость голосовой перевод бывать не_разобрать говорить переводчик
#
#  Сделайте регулировку скорости голосового перевода пожалуйста.  Бывает не разобрать что говорит переводчик.
#
# 20468 	class= 0
#   отзыв
#
#  Отзыв
#
# 20829 	class= 0
#   здравствовать сказать почему мой аккаунт быть заблокировать почитать правило пользование я не_нарушать ничто считать быть заблокировать неразумно не_гуманно ждать ответ сторона разработчик быть курс почему я заблокировать очень давно пользоваться ваш приложение такой впервые я оценка приложение я очень вымокать почти весь не_считать один отзыв спасибо внимание
#
#  Здравствуйте, скажите пожалуйста, почему мой аккаунт был заблокирован? Почитав правила пользования, я не нарушала ничего и считаю что была заблокировала неразумно и не гуманно. Жду ответа со стороны разработчиков, чтобы хотя бы быть в курсе почему меня заблокировали.
# Очень давно пользуюсь вашим приложением и такое впервые у меня, оценка в приложении у меня очень вымокая, почти все 5, не считая одного отзыва на 4.
# Спасибо за внимание.
#
# 20835 	class= 0
#   приложение полностью превратиться приложение заказ маршрутка теперь прежде поехать автовокзал мы бронировать поездка здесь желать поездка реальный водитель нормальный машина нет бла бла кара такой нет здесь убитый маршрутка водил обслуживание плинтус вероятность тот поездка состояться ты забронировать время водитель поехать время стремиться нуль бла бла кара насрать кто пользоваться они приложение водитель не_проверять не_контролировать спасибо такой чудный приложение я сделать уже десять бронь сегодня десять раз они отменить я сей пора не_выехать город еда автовокзал потому попросту предложить поездка не_существовать не_дозвониться водить
#
#  Приложение полностью превратилось в приложение для заказа маршрутки. Теперь прежде чем поехать на автовокзал, мы бронируем поездку здесь. Желаете поездку с реальными водителями? На нормальной машине? Нет. В бла бла кар такого нет, здесь только убитые маршрутки и водилы, обслуживание ниже плинтуса. Вероятность того, что поездка состоится, даже если ты забронировал время, что водитель поедет в это именно время, стремиться к нулю. Бла бла кару НАСРАТЬ на то, кто пользуется их приложением. Водителей не проверяют, не контролируют. Спасибо за такое чудное приложение. Я сделала уже десять броней за сегодня и десять раз их отменила. Я до сих пор не выехала из города, еду на автовокзал, потому что попросту предложенных поездок то не существует, то не дозвонишься до водил.
#
# 20856 	class= 0
#   каждый обновление весь большой большой неполадка
#
#  С каждым обновлением все больше и больше неполадок
#
# 21149 	class= 1
#   зарегистрироваться не_получаться полностью бред мой номер отправлять смс код подтверждение смс не_приходить не_понимать поэтому не_получаться забронировать поездка конец не_зареган получаться программа бесполезный
#
#  Зарегистрироваться не получается полностью, бред... На мой номер отправляет смс кода для подтверждения, а смс не приходит... не понимаю. И поэтому не получается забронировать поездку, так как до конца не зареган..((( получается программа бесполезна...
#
# 21663 	class= 1
#   я очень нравиться долго искать приложение брат посоветовать нравиться оно бесплатный предисловие скачать один приложение не_быть говорить какой восстановить весь свой покупка не_водянка знак не_убраться музыка не_открыться деньга вернуть быть пользоваться продолжать тот дух не_забывать приложение обновлять он спасибо огромный
#
#  Мне очень нравится. Долго искала это приложение, брат посоветовал! Нравится то, что оно бесплатное.
# Предисловие: скачала одно приложение(не буду говорить какое), восстановила все свои покупки, и не водянок знак не убрался, музыка не открылась(Деньги вернули)
#
# Буду пользоваться!!! Продолжайте в том же духе, не забывайте про приложение( обновляйте его)! Спасибо огромное
#
# 21990 	class= 0
#   мир
#
#  В мире
#
# 22131 	class= 0
#   возврат я надо указывать реквизит ждать тд не_сервис прощать
#
#  При возврате мне надо указывать реквизиты,ждать и тд!!это не сервис прощайте
#
# 22207 	class= 0
#   рынок садовод загонять барахло
#
#  Как будто с рынка Садовод загоняют барахло:)
#
# 22341 	class= 0
#   цена бешеный магазин реально дешёвый можно купить
#
#  Цены просто бешеные, в магазинах реально дешевле можно купить.
#
# 22430 	class= 1
#   пара покупка делать ламода сервис примерка доставка отменный единственный последний время напрягать обилие реклама вечер включать ребёнок мультик ютуба они не_включаться пока ваш реклама не_пройти вы мочь исключить контент где ваш реклама показывать думать ребёнок пойти покупка вы
#
#  Пару покупок делал в ламоде, сервис с примеркой и Доставкой отменный.
# Единственное что в последнее время напрягает обилие рекламы, по вечерам включаю ребёнку мультики на ютубе, а они не включаются пока ваша реклама не пройдёт, вы же можете исключить контент где вашу рекламу показывают, неужели правда думаете что дети пойдут за покупками к вам.
#
# 22479 	class= 0
#   весь обувь китайский подделка минута развалиться кроссовок не_покупать они ничто возврат делать очень сложно
#
#  Вся обувь китайская подделка, через 15 минут развалились кроссовки!!! Не покупайте у них ничего! Возврат делать очень сложно !

# %% [markdown]
# Считываем словарь тональностей из файла

# %%
sent = pd.read_csv('words_sent.csv', sep=';', header=None, names =['word', 'sent', '1', '2', '3'])

# %%
Dict = sent.groupby('word')['sent'].mean().to_dict()

# %%
tone = np.zeros((len(norm_texts_neg_stop), 4))

# %%
Dict.get('ужасный', 0)
# Out:
# -1.25

# %% [markdown]
# Определяем общее значение тональности по словарю

# %%
# нормальзованное значение тональности
for i, text in enumerate(norm_texts_neg_stop_splitted):
    count = 0
    for j, word in enumerate(text):        
        neg = False
        if (word.startswith("не_")):
            s = Dict.get(word[3:], 0)
            neg = True
        else:
            s = Dict.get(word, 0)

        if s != 0:
            count += 1
            if (neg):
                tone[i, 0] += -s
            else:
                tone[i, 0] += s
        if (s == 0 and neg):
            tone[i, 0] += -0.3
    if count:
        tone[i, 0] = tone[i, 0]/count

# %%
for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    print (i, tone[:, i].max())
    tone[:, i] = tone[:, i] /tone[:, i].max()
# Out:
# 0 4.16666666667
# 1 0.0
# 2 0.0
# 3 0.0
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: invalid value encountered in true_divide

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0].reshape(tone[:, 0].shape[0], 1))))

# %%
scores1_tone_dict = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_tone_dict = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_tone_dict = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_tone_dict = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_tone_dict = pd.DataFrame({
    "SVM" : scores1_tone_dict.mean(),
    "Random forest" : scores2_tone_dict.mean(),
    "Linear regression" : scores3_tone_dict.mean(),
    "Naive Bayes" : scores4_tone_dict.mean()
})

scores_tone_dict
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.271330     0.019102       3.215584  0.628848
# score_time               0.009064     0.003401       0.116686  0.006821
# test_accuracy            0.802132     0.874022       0.843186  0.841450
# test_f1                  0.810888     0.875742       0.839420  0.848292
# test_precision           0.799683     0.888172       0.885489  0.836271
# test_recall              0.824005     0.864544       0.798938  0.862050

# %% [raw]
# tone = np.zeros((len(norm_texts_neg_stop), 4))
#
# # общее значение тональности
# for i, text in enumerate(norm_texts_neg_stop_splitted):
#     count = 0
#     for j, word in enumerate(text):
#         neg = False
#         if (word.startswith("не_")):
#             s = Dict.get(word[3:], 0)
#             neg = True
#         else:
#             s = Dict.get(word, 0)
#
#         if s != 0:
#             count += 1
#             if (neg):
#                 tone[i, 0] += -s
#             else:
#                 tone[i, 0] += s
#         if (s == 0 and neg):
#             tone[i, 0] += -0.3

# %% [raw]
# for i in range(tone.shape[1]):
#     tone[:, i] = tone[:, i] - tone[:, i].min()
#     tone[:, i] = tone[:, i] /tone[:, i].max()

# %% [raw]
# tone

# %% [raw]
# train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0].reshape(tone[:, 0].shape[0], 1))))

# %% [raw]
# scores1_tone_dict = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
# scores2_tone_dict = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
# scores3_tone_dict = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
# scores4_tone_dict = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %% [raw]
# scores_tone_dict = pd.DataFrame({
#     "SVM" : scores1_tone_dict.mean(),
#     "Random forest" : scores2_tone_dict.mean(),
#     "Linear regression" : scores3_tone_dict.mean(),
#     "Naive Bayes" : scores4_tone_dict.mean()
# })
#
# scores_tone_dict

# %% [markdown]
# Ненормализованная разметка тональности работает лучше

# %%
# количество слов

for i, text in enumerate(norm_texts_neg_stop_splitted):
    tone[i, 1] = len(text)

for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()

# %%
#train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0:1])))
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 1].reshape(tone[:, 1].shape[0], 1))))

scores1_words_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_words_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_words_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_words_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_words_num = pd.DataFrame({
    "SVM" : scores1_words_num.mean(),
    "Random forest" : scores2_words_num.mean(),
    "Linear regression" : scores3_words_num.mean(),
    "Naive Bayes" : scores4_words_num.mean()
})

scores_words_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 2.411731     0.017053       3.039663  0.606985
# score_time               0.024215     0.006400       0.103240  0.006709
# test_accuracy            0.794359     0.872351       0.834384  0.840807
# test_f1                  0.803998     0.872937       0.829580  0.848531
# test_precision           0.790651     0.893557       0.881212  0.832095
# test_recall              0.819265     0.854316       0.784466  0.866789

# %% [markdown]
# Признак ухудшает качество классификации для метода Случайного леса, для остальных не меняет - плохой признак, не будем включать

# %%
#class_result_svm = class_result_svm.append(pd.Series(metr1, name="+ количество слов"))
#class_result_rf = class_result_rf.append(pd.Series(metr2, name="+ количество слов"))
#class_result_lr = class_result_lr.append(pd.Series(metr3, name="+ количество слов"))

#print("---svm---", class_result_svm)
#print("---lr---", class_result_rf)
#print("---rf---", class_result_lr)

# %% [markdown]
# Считаем количество восклицательных знаков

# %%
initial_left_revs = initial_revs.drop(initial_revs.index.difference(revs_norm_neg_stop.index))
initial_left_revs['rating'] = revs_norm_neg_stop['rating']

for i, text in enumerate(initial_left_revs.content):
    num = 0
    for e in text:
        if e == '!':
            num += 1
            #tone[i, 1] = 1
    tone[i, 1] = num

# %%
for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    print(i, tone[:, i].max())
    tone[:, i] = tone[:, i] /tone[:, i].max()
# Out:
# 0 1.0
# 1 262.0
# 2 nan
# 3 nan

# %%
#train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0:1])))
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 1].reshape(tone[:, 1].shape[0], 1))))

scores1_excl_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_excl_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_excl_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_excl_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_excl_num = pd.DataFrame({
    "SVM" : scores1_excl_num.mean(),
    "Random forest" : scores2_excl_num.mean(),
    "Linear regression" : scores3_excl_num.mean(),
    "Naive Bayes" : scores4_excl_num.mean()
})

scores_excl_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.702181     0.019076       3.034394  0.827940
# score_time               0.006456     0.005763       0.124100  0.005403
# test_accuracy            0.793203     0.872416       0.834448  0.840293
# test_f1                  0.803341     0.873012       0.832831  0.848176
# test_precision           0.788294     0.893572       0.866008  0.831115
# test_recall              0.820262     0.854440       0.802926  0.867163

# %% [markdown]
# норм, оставим

# %% [markdown]
# Считаем количество глаголов в повелительном наклонении (встречаются часто в отрицательных отзывах)

# %%
def getImperatives(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = 0
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        if (lexInfo.tag.POS == 'VERB'):
            if (lexInfo.tag.mood == 'impr'):
                ans += 1
    if (ans > 0):
        return ans
    else:
        return 0
    return ans

initial_left_revs['imps'] = [getImperatives(line) for line in initial_left_revs.content]

# %%
initial_revs
# Out:
#        rating                                            content
# 0           5  Интересный сюжет, затягивает. Много времени ух...
# 1           4  Плюсы: \r\n1. Игра интересная 2. Образы учител...
# 2           3  Огорчил тот факт , что суть игры заключается в...
# 3           5  Была постоянная ошибка с подключением, почти н...
# 4           1  ... сделайте русскую озвучку и будет 5 звёзд :...
# 5           3                         Почему нет русского языка?
# 6           1                                                  !
# 7           1              Постоянные проблемы с подключением!!!
# 8           5  Все идеально но отсутствия русского языка даёт...
# 9           1          Где великий и могучий??? Сделайте русский
# 10          4  Thanks for the game, I fancy it pretty much, h...
# 11          2                  Добавьте русский язык пожалуйста(
# 12          5  Игра отличная, отсутствие русского языка не ме...
# 13          4                       Please add Russian language!
# 14          5  Everything was great till Wednesday night. Gam...
# 15          3                         Where Russian language ???
# 16          1  В описании приложения, написали что есть русск...
# 17          1              Пожалуйста сделайте русский язык!!!!!
# 18          2  Зашла в игру, поиграла ровно минуту и всё, эне...
# 19          2  Игра интересная, но как же достал connect erro...
# 20          1  Where is the Russian language? why the descrip...
# 21          4  Без русского играть невозможно. От выборы зави...
# 22          5  Почему игра не запускается, перекидывает на ст...
# 23          1  Когда же ждать заявленный в описании русский я...
# 24          2  Русского языка нет, но английский понимаю - та...
# 25          5  Товарищи, учите иностранные языки \r\nИгра зам...
# 26          3                 Always connection lost! Fix please
# 27          1  Заявлен русский язык. Заходишь в игре в Настро...
# 28          5  Очень продуманная, интересная игра, все сделан...
# 29          3  Игра нармуль. Разрабочики добавьте русский язык !
# ...       ...                                                ...
# 22463       5  Пользуюсь приложением не первый год, мобильное...
# 22464       5  Один из лучших онлайн магазинов! Купила много ...
# 22465       1  Господа разработчики, уберите из приложения да...
# 22466       4  Для айфона не очень удобное приложение. Листат...
# 22467       1  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       1  И цены конские. А их реклама «увеличьте свой ч...
# 22469       5  Отличный сайт и отличное приложение, пока толь...
# 22470       5  Приложение , сайт и вещи и вообще все просто с...
# 22471       1  Сделал заказ, сказали что доставка возможна то...
# 22472       5  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       1  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       5  Сразу все магазины в одном месте ? так как я в...
# 22475       2  Во вкладке «Избранное» дублируются товары. Три...
# 22476       5           Мне нравится. Удобно, быстро, недорого??
# 22477       5                                       Всё хорошо ?
# 22478       1  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       1  Вся обувь китайская подделка, через 15 минут р...
# 22480       1  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       1  Доставка от пони экспресс, портит все. Может в...
# 22482       1  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       1  Приложение где только не пиарят, увидела в вк ...
# 22484       1  Не стыдно врать то, никаких скидок на фирму не...
# 22485       1  Зачем изменили приложение, что за ненужное око...
# 22486       1                          Недобросовестная реклама.
# 22487       1  Приложение классное, но реклама на YouTube за*...
# 22488       4  Почините,пожалуйста,приложение, заходила два г...
# 22489       1  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       1  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22491       4  Отличное приложение, удобное в использовании, ...
# 22492       5                                             ??????
#
# [22493 rows x 2 columns]

# %%
tone[:,2] = list(initial_left_revs['imps'])

for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    print(i, tone[:, i].max())
    tone[:, i] = tone[:, i] /tone[:, i].max()
# Out:
# 0 1.0
# 1 1.0
# 2 7.0
# 3 nan

# %%
#train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0:2])))
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 2].reshape(tone[:, 2].shape[0], 1))))

scores1_imper_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_imper_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_imper_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_imper_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_imper_num = pd.DataFrame({
    "SVM" : scores1_imper_num.mean(),
    "Random forest" : scores2_imper_num.mean(),
    "Linear regression" : scores3_imper_num.mean(),
    "Naive Bayes" : scores4_imper_num.mean()
})

scores_imper_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.718228     0.025220       3.192849  0.692750
# score_time               0.006605     0.018412       0.112990  0.040882
# test_accuracy            0.793717     0.872480       0.834769  0.840807
# test_f1                  0.803886     0.873069       0.833148  0.848601
# test_precision           0.788676     0.893784       0.866199  0.831950
# test_recall              0.821011     0.854316       0.803301  0.867163

# %% [markdown]
# вроде норм

# %% [markdown]
# Считаем количество вопросительных слов. Встречаются в негативных отзывах ("Пропала кнопка вызова. Где её найти?!?!")

# %%
revs_for_interrog_words = revs_norm_neg.drop(revs_norm_neg.index.difference(revs_norm_neg_stop.index))
split_texts_for_interrog = revs_for_interrog_words.content.str.split()

# %%
revs.ix[0].content
# Out:
# 'Интересный сюжет, затягивает. Много времени уходит на уроки, которые можно бы было сделать по разнообразнее. И зачем продолжать полеты на метле до 3-4 курса?? Чему там можно учиться. Насколько я помню, в книгах они быстренько закончили этот курс. \r\nХотелось бы иногда больше свободы действий. Например пропускать какие-то задания, выучить что-то самостоятельно, контактировать с другими персонажами или что-то подобное.\r\nДля начала очень неплохая игра'

# %%
tone[:, 3]
# Out:
# array([ nan,  nan,  nan, ...,  nan,  nan,  nan])

# %%
interrogative_words = ["где", "как", "зачем", "почему", "какой"]

for i, text in enumerate(split_texts_for_interrog):
    count = 0
    for j, word in enumerate(text):        
        if (word in interrogative_words):
            count += 1
    tone[i, 3] = count
        
for i, text in enumerate(initial_left_revs.content):
    num = 0
    for e in text:
        if e == '?':
            num += 1
            #tone[i, 1] = 1
    tone[i, 3] += num

# %%
for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    print (i, tone[:, i].max())
    tone[:, i] = tone[:, i] /tone[:, i].max()
# Out:
# 0 1.0
# 1 1.0
# 2 1.0
# 3 115.0

# %%
#train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0:3])))
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 3].reshape(tone[:, 3].shape[0], 1))))

scores1_interr_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_interr_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_interr_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_interr_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_interr_num = pd.DataFrame({
    "SVM" : scores1_interr_num.mean(),
    "Random forest" : scores2_interr_num.mean(),
    "Linear regression" : scores3_interr_num.mean(),
    "Naive Bayes" : scores4_interr_num.mean()
})

scores_interr_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.909753     0.020615       3.568472  0.540784
# score_time               0.009207     0.010807       0.121684  0.006008
# test_accuracy            0.793588     0.872608       0.835988  0.840743
# test_f1                  0.803828     0.873237       0.834917  0.848508
# test_precision           0.788525     0.893612       0.865656  0.831863
# test_recall              0.821136     0.854815       0.807292  0.867038

# %%
len(initial_left_revs)
# Out:
# 15566

# %%
initial_left_revs.content[0]
# Out:
# 'Интересный сюжет, затягивает. Много времени уходит на уроки, которые можно бы было сделать по разнообразнее. И зачем продолжать полеты на метле до 3-4 курса?? Чему там можно учиться. Насколько я помню, в книгах они быстренько закончили этот курс. \r\nХотелось бы иногда больше свободы действий. Например пропускать какие-то задания, выучить что-то самостоятельно, контактировать с другими персонажами или что-то подобное.\r\nДля начала очень неплохая игра'

# %%
def count_nums(line):
    count = 0
    for letter in line:
        if letter >= "0" and letter <= "9":
            count += 1
    return count

digits_num = np.zeros((len (initial_left_revs), 1))
i = 0
for line in initial_left_revs.content:
    digits_num[i] = count_nums(line)
    i += 1
    
digits_num = digits_num - digits_num.min()
print(digits_num.max())
digits_num = digits_num /digits_num.max()
# Out:
# 71.0

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), digits_num)))

scores1_digits_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_digits_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_digits_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_digits_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_digits_num = pd.DataFrame({
    "SVM" : scores1_digits_num.mean(),
    "Random forest" : scores2_digits_num.mean(),
    "Linear regression" : scores3_digits_num.mean(),
    "Naive Bayes" : scores4_digits_num.mean()
})

scores_digits_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.540490     0.015011       3.075740  0.811639
# score_time               0.006604     0.011408       0.102881  0.006004
# test_accuracy            0.793396     0.872544       0.833805  0.840807
# test_f1                  0.803455     0.873126       0.831278  0.848569
# test_precision           0.788806     0.893801       0.869901  0.832021
# test_recall              0.820138     0.854440       0.796688  0.867038

# %%
def count_capital_letters(line):
    count = 0
    for letter in line:
        if letter >= "А" and letter <= "Я":
            count += 1
    return count

capital_letters_num = np.zeros((len (initial_left_revs), 1))
i = 0
for line in initial_left_revs.content:
    capital_letters_num[i] = count_capital_letters(line)
    i += 1
    
capital_letters_num = capital_letters_num - capital_letters_num.min()
capital_letters_num = capital_letters_num /capital_letters_num.max()

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), capital_letters_num)))

scores1_capital_letters_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_capital_letters_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_capital_letters_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_capital_letters_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_capital_letters_num = pd.DataFrame({
    "SVM" : scores1_capital_letters_num.mean(),
    "Random forest" : scores2_capital_letters_num.mean(),
    "Linear regression" : scores3_capital_letters_num.mean(),
    "Naive Bayes" : scores4_capital_letters_num.mean()
})

scores_capital_letters_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.670184     0.018614       2.847939  0.600626
# score_time               0.006805     0.008204       0.096253  0.007205
# test_accuracy            0.793460     0.872351       0.830722  0.840743
# test_f1                  0.803518     0.872937       0.829243  0.848458
# test_precision           0.788827     0.893557       0.861192  0.832078
# test_recall              0.820138     0.854316       0.800433  0.866664

# %%
def find_elongated_words(word):
    if (word == ""):
        return False
    
    prev_letter = word[0]
    flag = 0
    count = 0
    for letter in word[1:]:
        if letter == prev_letter:
            count += 1
        else:
            count = 0;
            prev_letter = letter
        if count >= 2:
            flag = 1
    return flag

elongated_words_presense = np.zeros((len (initial_left_revs), 1))
i = 0
for line in initial_left_revs.content:
    elongated_words_presense[i] = find_elongated_words(line)
    i += 1

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), elongated_words_presense)))

scores1_elongated_words_presense = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_elongated_words_presense = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_elongated_words_presense = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_elongated_words_presense = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_elongated_words_presense = pd.DataFrame({
    "SVM" : scores1_elongated_words_presense.mean(),
    "Random forest" : scores2_elongated_words_presense.mean(),
    "Linear regression" : scores3_elongated_words_presense.mean(),
    "Naive Bayes" : scores4_elongated_words_presense.mean()
})

scores_elongated_words_presense
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.619009     0.016015       2.943810  0.725452
# score_time               0.006204     0.007001       0.099476  0.006004
# test_accuracy            0.794809     0.872416       0.831170  0.839908
# test_f1                  0.804523     0.873024       0.830016  0.847714
# test_precision           0.790847     0.893564       0.860856  0.831011
# test_recall              0.820013     0.854440       0.802051  0.866290

# %%
def getPastTenseVerbs(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = 0
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        if (lexInfo.tag.POS == 'VERB'):
            if (lexInfo.tag.tense == 'past'):
                ans += 1
    if (ans > 0):
        return ans
    else:
        return 0
    return ans


past_tense_words_num = np.zeros((len (initial_left_revs), 1))
i = 0
for line in initial_left_revs.content:
    past_tense_words_num[i] = getPastTenseVerbs(line)
    i += 1
    
past_tense_words_num = past_tense_words_num - past_tense_words_num.min()
past_tense_words_num = past_tense_words_num /past_tense_words_num.max()

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), past_tense_words_num)))

scores1_past_tense_words_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_past_tense_words_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_past_tense_words_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_past_tense_words_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_past_tense_words_num = pd.DataFrame({
    "SVM" : scores1_past_tense_words_num.mean(),
    "Random forest" : scores2_past_tense_words_num.mean(),
    "Linear regression" : scores3_past_tense_words_num.mean(),
    "Naive Bayes" : scores4_past_tense_words_num.mean()
})

scores_past_tense_words_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.504487     0.021470       3.389095  0.621799
# score_time               0.008587     0.011675       0.114791  0.030906
# test_accuracy            0.794038     0.872287       0.829886  0.840422
# test_f1                  0.804224     0.872852       0.826911  0.848176
# test_precision           0.788948     0.893641       0.867464  0.831641
# test_recall              0.821385     0.854066       0.790575  0.866539

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone, elongated_words_presense, digits_num)))

# %%
scores1_all_features = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_all_features = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_all_features = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_all_features = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
train.shape
# Out:
# (15566, 10006)

# %%
scores_all_features = pd.DataFrame({
    "SVM" : scores1_all_features.mean(),
    "Random forest" : scores2_all_features.mean(),
    "Linear regression" : scores3_all_features.mean(),
    "Naive Bayes" : scores4_all_features.mean()
})

scores_all_features
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 2.001776     0.015236       2.913022  0.759014
# score_time               0.003425     0.008001       0.097154  0.005013
# test_accuracy            0.802968     0.874022       0.842801  0.840679
# test_f1                  0.811094     0.875745       0.838028  0.847477
# test_precision           0.802193     0.888199       0.890637  0.835928
# test_recall              0.821885     0.864544       0.792076  0.860802

# %%
result_metrics_svm = pd.DataFrame({
    "00 униграммы и биграммы" : scores_uni_bi['SVM'],
    "01 + обработка отрицаний" : scores_uni_bi_neg['SVM'],
    "02 + удаление стоп слов" : scores_uni_bi_neg_stop['SVM'],
    "03 + словарь тональности" : scores_tone_dict['SVM'],
    "04 + количество восклицательных знаков" : scores_excl_num['SVM'],
    "05 + количество глаголов в повел. накл." : scores_imper_num['SVM'],
    "06 + количество вопросительных слов" : scores_interr_num['SVM'],
    "07 + количество слов" : scores_words_num['SVM'], 
    "08 + наличие слов с повторяющимися буквами" : scores_elongated_words_presense['SVM'],
    "09 + количество заглавных букв" : scores_capital_letters_num['SVM'],
    "10 + количство глаголов прошедшего времени" : scores_past_tense_words_num['SVM'],
    "11 + количество цифр" : scores_digits_num['SVM'],
    "12 все признаки" : scores_all_features['SVM']
    
})

result_metrics_svm
# Out:
#                 00 униграммы и биграммы  01 + обработка отрицаний  \
# fit_time                       0.789617                  0.477643
# score_time                     0.006003                  0.003838
# test_accuracy                  0.830914                  0.840871
# test_f1                        0.838606                  0.848583
# test_precision                 0.824917                  0.832206
# test_recall                    0.854442                  0.866789
#
#                 02 + удаление стоп слов  03 + словарь тональности  \
# fit_time                       0.384520                  0.628848
# score_time                     0.004472                  0.006821
# test_accuracy                  0.838594                  0.841450
# test_f1                        0.846284                  0.848292
# test_precision                 0.830912                  0.836271
# test_recall                    0.863585                  0.862050
#
#                 04 + количество восклицательных знаков  \
# fit_time                                      0.827940
# score_time                                    0.005403
# test_accuracy                                 0.840293
# test_f1                                       0.848176
# test_precision                                0.831115
# test_recall                                   0.867163
#
#                 05 + количество глаголов в повел. накл.  \
# fit_time                                       0.692750
# score_time                                     0.040882
# test_accuracy                                  0.840807
# test_f1                                        0.848601
# test_precision                                 0.831950
# test_recall                                    0.867163
#
#                 06 + количество вопросительных слов  07 + количество слов  \
# fit_time                                   0.540784              0.606985
# score_time                                 0.006008              0.006709
# test_accuracy                              0.840743              0.840807
# test_f1                                    0.848508              0.848531
# test_precision                             0.831863              0.832095
# test_recall                                0.867038              0.866789
#
#                 08 + наличие слов с повторяющимися буквами  \
# fit_time                                          0.725452
# score_time                                        0.006004
# test_accuracy                                     0.839908
# test_f1                                           0.847714
# test_precision                                    0.831011
# test_recall                                       0.866290
#
#                 09 + количество заглавных букв  \
# fit_time                              0.600626
# score_time                            0.007205
# test_accuracy                         0.840743
# test_f1                               0.848458
# test_precision                        0.832078
# test_recall                           0.866664
#
#                 10 + количство глаголов прошедшего времени  \
# fit_time                                          0.621799
# score_time                                        0.030906
# test_accuracy                                     0.840422
# test_f1                                           0.848176
# test_precision                                    0.831641
# test_recall                                       0.866539
#
#                 11 + количество цифр  12 все признаки
# fit_time                    0.811639         0.759014
# score_time                  0.006004         0.005013
# test_accuracy               0.840807         0.840679
# test_f1                     0.848569         0.847477
# test_precision              0.832021         0.835928
# test_recall                 0.867038         0.860802

# %%
result_metrics_nb = pd.DataFrame({
    "00 униграммы и биграммы" : scores_uni_bi['Naive Bayes'],
    "01 + обработка отрицаний" : scores_uni_bi_neg['Naive Bayes'],
    "02 + удаление стоп слов" : scores_uni_bi_neg_stop['Naive Bayes'],
    "03 + словарь тональности" : scores_tone_dict['Naive Bayes'],
    "04 + количество восклицательных знаков" : scores_excl_num['Naive Bayes'],
    "05 + количество глаголов в повел. накл." : scores_imper_num['Naive Bayes'],
    "06 + количество вопросительных слов" : scores_interr_num['Naive Bayes'],
    "07 + количество слов" : scores_words_num['Naive Bayes'],
    "08 + наличие слов с повторяющимися буквами" : scores_elongated_words_presense['Naive Bayes'],
    "09 + количество заглавных букв" : scores_capital_letters_num['Naive Bayes'],
    "10 + количство глаголов прошедшего времени" : scores_past_tense_words_num['Naive Bayes'],
    "11 + количество цифр" : scores_digits_num['Naive Bayes'],
    "12 все признаки" : scores_all_features['Naive Bayes']

})

result_metrics_nb
# Out:
#                 00 униграммы и биграммы  01 + обработка отрицаний  \
# fit_time                       0.014658                  0.016804
# score_time                     0.008424                  0.007019
# test_accuracy                  0.860530                  0.872351
# test_f1                        0.862160                  0.872937
# test_precision                 0.876102                  0.893557
# test_recall                    0.849700                  0.854316
#
#                 02 + удаление стоп слов  03 + словарь тональности  \
# fit_time                       0.016621                  0.019102
# score_time                     0.004422                  0.003401
# test_accuracy                  0.865271                  0.874022
# test_f1                        0.866454                  0.875742
# test_precision                 0.883463                  0.888172
# test_recall                    0.851104                  0.864544
#
#                 04 + количество восклицательных знаков  \
# fit_time                                      0.019076
# score_time                                    0.005763
# test_accuracy                                 0.872416
# test_f1                                       0.873012
# test_precision                                0.893572
# test_recall                                   0.854440
#
#                 05 + количество глаголов в повел. накл.  \
# fit_time                                       0.025220
# score_time                                     0.018412
# test_accuracy                                  0.872480
# test_f1                                        0.873069
# test_precision                                 0.893784
# test_recall                                    0.854316
#
#                 06 + количество вопросительных слов  07 + количество слов  \
# fit_time                                   0.020615              0.017053
# score_time                                 0.010807              0.006400
# test_accuracy                              0.872608              0.872351
# test_f1                                    0.873237              0.872937
# test_precision                             0.893612              0.893557
# test_recall                                0.854815              0.854316
#
#                 08 + наличие слов с повторяющимися буквами  \
# fit_time                                          0.016015
# score_time                                        0.007001
# test_accuracy                                     0.872416
# test_f1                                           0.873024
# test_precision                                    0.893564
# test_recall                                       0.854440
#
#                 09 + количество заглавных букв  \
# fit_time                              0.018614
# score_time                            0.008204
# test_accuracy                         0.872351
# test_f1                               0.872937
# test_precision                        0.893557
# test_recall                           0.854316
#
#                 10 + количство глаголов прошедшего времени  \
# fit_time                                          0.021470
# score_time                                        0.011675
# test_accuracy                                     0.872287
# test_f1                                           0.872852
# test_precision                                    0.893641
# test_recall                                       0.854066
#
#                 11 + количество цифр  12 все признаки
# fit_time                    0.015011         0.015236
# score_time                  0.011408         0.008001
# test_accuracy               0.872544         0.874022
# test_f1                     0.873126         0.875745
# test_precision              0.893801         0.888199
# test_recall                 0.854440         0.864544

# %%
result_metrics_rf = pd.DataFrame({
    "00 униграммы и биграммы" : scores_uni_bi['Random forest'],
    "01 + обработка отрицаний" : scores_uni_bi_neg['Random forest'],
    "02 + удаление стоп слов" : scores_uni_bi_neg_stop['Random forest'],
    "03 + словарь тональности" : scores_tone_dict['Random forest'],
    "04 + количество восклицательных знаков" : scores_excl_num['Random forest'],
    "05 + количество глаголов в повел. накл." : scores_imper_num['Random forest'],
    "06 + количество вопросительных слов" : scores_interr_num['Random forest'],
    "07 + количество слов" : scores_words_num['Random forest'],
    "08 + наличие слов с повторяющимися буквами" : scores_elongated_words_presense['Random forest'],
    "09 + количество заглавных букв" : scores_capital_letters_num['Random forest'],
    "10 + количство глаголов прошедшего времени" : scores_past_tense_words_num['Random forest'],
    "11 + количество цифр" : scores_digits_num['Random forest'],
    "12 все признаки" : scores_all_features['Random forest']

})

result_metrics_rf
# Out:
#                 00 униграммы и биграммы  01 + обработка отрицаний  \
# fit_time                       3.054008                  2.672456
# score_time                     0.106501                  0.094701
# test_accuracy                  0.820635                  0.835154
# test_f1                        0.818175                  0.833355
# test_precision                 0.855275                  0.868201
# test_recall                    0.784712                  0.801928
#
#                 02 + удаление стоп слов  03 + словарь тональности  \
# fit_time                       2.733623                  3.215584
# score_time                     0.100525                  0.116686
# test_accuracy                  0.835574                  0.843186
# test_f1                        0.835286                  0.839420
# test_precision                 0.861383                  0.885489
# test_recall                    0.811665                  0.798938
#
#                 04 + количество восклицательных знаков  \
# fit_time                                      3.034394
# score_time                                    0.124100
# test_accuracy                                 0.834448
# test_f1                                       0.832831
# test_precision                                0.866008
# test_recall                                   0.802926
#
#                 05 + количество глаголов в повел. накл.  \
# fit_time                                       3.192849
# score_time                                     0.112990
# test_accuracy                                  0.834769
# test_f1                                        0.833148
# test_precision                                 0.866199
# test_recall                                    0.803301
#
#                 06 + количество вопросительных слов  07 + количество слов  \
# fit_time                                   3.568472              3.039663
# score_time                                 0.121684              0.103240
# test_accuracy                              0.835988              0.834384
# test_f1                                    0.834917              0.829580
# test_precision                             0.865656              0.881212
# test_recall                                0.807292              0.784466
#
#                 08 + наличие слов с повторяющимися буквами  \
# fit_time                                          2.943810
# score_time                                        0.099476
# test_accuracy                                     0.831170
# test_f1                                           0.830016
# test_precision                                    0.860856
# test_recall                                       0.802051
#
#                 09 + количество заглавных букв  \
# fit_time                              2.847939
# score_time                            0.096253
# test_accuracy                         0.830722
# test_f1                               0.829243
# test_precision                        0.861192
# test_recall                           0.800433
#
#                 10 + количство глаголов прошедшего времени  \
# fit_time                                          3.389095
# score_time                                        0.114791
# test_accuracy                                     0.829886
# test_f1                                           0.826911
# test_precision                                    0.867464
# test_recall                                       0.790575
#
#                 11 + количество цифр  12 все признаки
# fit_time                    3.075740         2.913022
# score_time                  0.102881         0.097154
# test_accuracy               0.833805         0.842801
# test_f1                     0.831278         0.838028
# test_precision              0.869901         0.890637
# test_recall                 0.796688         0.792076

# %%
result_metrics_lr = pd.DataFrame({
    "00 униграммы и биграммы" : scores_uni_bi['Linear regression'],
    "01 + обработка отрицаний" : scores_uni_bi_neg['Linear regression'],
    "02 + удаление стоп слов" : scores_uni_bi_neg_stop['Linear regression'],
    "03 + словарь тональности" : scores_tone_dict['Linear regression'],
    "04 + количество восклицательных знаков" : scores_excl_num['Linear regression'],
    "05 + количество глаголов в повел. накл." : scores_imper_num['Linear regression'],
    "06 + количество вопросительных слов" : scores_interr_num['Linear regression'],
    "07 + количество слов" : scores_words_num['Linear regression'],
    "08 + наличие слов с повторяющимися буквами" : scores_elongated_words_presense['Linear regression'],
    "09 + количество заглавных букв" : scores_capital_letters_num['Linear regression'],
    "10 + количство глаголов прошедшего времени" : scores_past_tense_words_num['Linear regression'],
    "11 + количество цифр" : scores_digits_num['Linear regression'],
    "12 все признаки" : scores_all_features['Linear regression']

})

result_metrics_lr
# Out:
#                 00 униграммы и биграммы  01 + обработка отрицаний  \
# fit_time                       1.373482                  1.373652
# score_time                     0.009668                  0.007997
# test_accuracy                  0.788707                  0.792689
# test_f1                        0.799480                  0.802789
# test_precision                 0.783207                  0.788065
# test_recall                    0.818644                  0.819389
#
#                 02 + удаление стоп слов  03 + словарь тональности  \
# fit_time                       1.388208                  1.271330
# score_time                     0.007200                  0.009064
# test_accuracy                  0.789033                  0.802132
# test_f1                        0.799947                  0.810888
# test_precision                 0.782154                  0.799683
# test_recall                    0.820524                  0.824005
#
#                 04 + количество восклицательных знаков  \
# fit_time                                      1.702181
# score_time                                    0.006456
# test_accuracy                                 0.793203
# test_f1                                       0.803341
# test_precision                                0.788294
# test_recall                                   0.820262
#
#                 05 + количество глаголов в повел. накл.  \
# fit_time                                       1.718228
# score_time                                     0.006605
# test_accuracy                                  0.793717
# test_f1                                        0.803886
# test_precision                                 0.788676
# test_recall                                    0.821011
#
#                 06 + количество вопросительных слов  07 + количество слов  \
# fit_time                                   1.909753              2.411731
# score_time                                 0.009207              0.024215
# test_accuracy                              0.793588              0.794359
# test_f1                                    0.803828              0.803998
# test_precision                             0.788525              0.790651
# test_recall                                0.821136              0.819265
#
#                 08 + наличие слов с повторяющимися буквами  \
# fit_time                                          1.619009
# score_time                                        0.006204
# test_accuracy                                     0.794809
# test_f1                                           0.804523
# test_precision                                    0.790847
# test_recall                                       0.820013
#
#                 09 + количество заглавных букв  \
# fit_time                              1.670184
# score_time                            0.006805
# test_accuracy                         0.793460
# test_f1                               0.803518
# test_precision                        0.788827
# test_recall                           0.820138
#
#                 10 + количство глаголов прошедшего времени  \
# fit_time                                          1.504487
# score_time                                        0.008587
# test_accuracy                                     0.794038
# test_f1                                           0.804224
# test_precision                                    0.788948
# test_recall                                       0.821385
#
#                 11 + количество цифр  12 все признаки
# fit_time                    1.540490         2.001776
# score_time                  0.006604         0.003425
# test_accuracy               0.793396         0.802968
# test_f1                     0.803455         0.811094
# test_precision              0.788806         0.802193
# test_recall                 0.820138         0.821885

# %%
X_train, X_test, y_train, y_test = train_test_split(train, revs_norm_neg_stop.rating, test_size=0.1) #random_state = 42
classifier = clf_nb.fit(X=X_train, y=y_train)
y_pred = classifier.predict(X_test)

import pickle

with open('dumped_nb_classifier.pkl', 'wb') as fid:
    pickle.dump(classifier, fid) 

count_vectorizer_uni_bi = CountVectorizer(binary = True, ngram_range=(1,2), max_features= 10000)
cvect_uni_bi_neg = count_vectorizer_uni_bi.fit(norm_texts_neg)
    
    
with open('dumped_count_vectorizer.pkl', 'wb') as fid:
    pickle.dump(cvect_uni_bi_neg, fid)
    
print_wrong_class (y_test, y_pred)
# Out:
# 53 	class= 1
#   добавить русский язык
#
#  Добавьте русский язык пожалуйста!
#
# 125 	class= 1
#   нет русский язык исправт
#
#  Нет русского языка. Исправте пожалуйста.
#
# 170 	class= 1
#   почему написать русский есть он нет
#
#  Почему написано что русский есть когда его нет?!!
#
# 247 	class= 1
#   добавить русский язык
#
#  Добавьте пожалуйста русский язык ?
#
# 267 	class= 1
#   добавить русский язык
#
#  Добавьте пожалуйста русский язык ?
#
# 333 	class= 0
#   не_русский язык игра не_интересный
#
#  без русского языка игра не интересна
#
# 462 	class= 0
#   русский добавить
#
#  Русский добавьте
#
# 829 	class= 0
#   весь интересно она иероглиф
#
#  Все интересно только она на иероглифах.
#
# 1182 	class= 0
#   невозможно пройти зомби вирус сложный уровень вирус мутировать заразить миллиард весь болезнь обнаружить уже делать лекарство распространение слишком слабый пройти скрытно симптом становиться невозможно не_хватать очки днк симптом
#
#  Невозможно пройти зомби вирус на сложном уровне, вирус просто мутирует когда заражено около 2 млрд и все: болезнь обнаружили, уже делают лекарство, а распространение слишком слабое. Пройти ни скрытно ни с симптомами становится невозможно. Не хватает очков ДНК на симптомы
#
# 1223 	class= 0
#   игра великолепный хотеться большой разнообразие он очень мало хотеть большой платить убрать донат поставить звезда заранее спасибо
#
#  Игра великолепная, но хочется больше разнообразия (его очень мало)! Хотите больше? Платите!!!! Уберёте Донат поставлю 5 звёзд!
# Заранее спасибо!!!
#
# 1489 	class= 0
#   не_стоить делать два часть она жалкий подобие один расстраивать фанат один часть
#
#  Не стоило делать вторую часть,она жалкое подобие первой
# Только расстраиваете фанатов первой части
#
# 1893 	class= 0
#   один часть хороший минус два части-похожий локация абгрейд один тот один часть локация быть разный каждый машина быть индивидуальный этот часть разработчик полениться бал
#
#  Первая часть лучше.из минусов второй части-похожие локации,абгрейд один и тот же...в первой части и локации были разные и каждая машина была индивидуальна.а в этой части разработчики поленились!так что,2 бала!
#
# 2007 	class= 0
#   игра не_нравиться игра я не_нравиться
#
#  Игра не нравится игра мне не нравится
#
# 2103 	class= 0
#   игрушка хороший подвисать иногда это иногда проигрывать мячик становиться неконтролируемый жалко
#
#  Игрушка хорошая, но подвисает иногда и из-за этого иногда проигрываешь, ибо мячик становится неконтролируемым. Жалко!
#
# 2156 	class= 0
#   хороший игра играть не_реклама
#
#  Хорошая игра, но играть не возможно из за рекламы
#
# 2216 	class= 0
#   я вы убить хотеть
#
#  Я вас убить хочу
#
# 2240 	class= 0
#   я играть игра удовольствие не_реклама каждый смерть
#
#  Я играю в игры ради удовольствия,а не ради рекламы через каждые 3 смерти !!!!!!!!!!!!!!
#
# 2340 	class= 1
#   сначала настройка отключить сотовый связь один реклама не_видеть игра затягивать уровень пошлый не_понять усложнение происходить какой-то всего уровень игра
#
#  Когда сначала в настройках отключила сотовую связь, ни одной Рекламы не видела?? игра затягивает 123 уровень пошла, только не пойму усложнение происходит  какое-то? И сколько всего уровней в игре?
#
# 2367 	class= 1
#   реклама мешать выключить интернет не_говорить не_качать реклама заебал тд
#
#  Если реклама мешает просто выключите интернет. И не говорите мол не качайте реклама заебала и тд.
#
# 2464 	class= 0
#   пропасть скидка штраф не_прошлый половина срок другой приложение весь нормальный можно косякнуть
#
#  Пропала скидка 50% на штрафы, не прошло и пол срока! В других приложениях всё нормально, как можно так косякнуть
#
# 2908 	class= 1
#   оплатить штраф иногда небьзить
#
#  Оплатить Штрафы, иногда небьзя(((
#
# 3151 	class= 1
#   почему весь уже новое эффект я не_обновить ещё мьюзикл я не_предлагать обновить
#
#  Почему? У всех уже новые эффекты, а у меня не обновлён ещё мьюзикл. Мне даже не предлагают обновить?
#
# 3258 	class= 0
#   приложение становиться квать оформление хромать я обновление
#
#  Это приложение становится квай,оформление хромает(если что я про обновление 13.05.18)
#
# 3295 	class= 1
#   новое обновление ужасный вернуть назад
#
#  Новое обновление ужасное! Как вернуть назад????
#
# 3784 	class= 0
#   добавить аватарка телеграмма понятно быть кто писать не_читать имя ада групповой беседа вообще цвет нормальный сделать этот очень грязный некрасиво
#
#  Добавьте аватарки, как в телеграмме, чтоб понятно было кто пишет не читая имя. Это ад в групповых беседах и вообще. И цвета нормальные сделайте, эти очень грязные, некрасиво)
#
# 3898 	class= 1
#   получение сообщение уведомление не_писаться имя контакт крайне неудобно
#
#  При получении Сообщения при уведомлении не пишется имя контакта. Это крайне неудобно.
#
# 3977 	class= 1
#   я один последний обновление не_кто пришлый сообщение имя не_писать
#
#  У меня одного после последнего обновления не видно от кого пришло сообщение? Имя даже не пишет.
#
# 4100 	class= 1
#   уважаемый разработчик вернуть обратно шторка возможность видеть пользователь я писать не_сообщение функция скрытие текст заранее спасибо
#
#  Уважаемые разработчики верните пожалуйста обратно шторку с возможностью видеть что за пользователь мне пишет, а не просто сообщение. При функции скрытия текста. Заранее спасибо!
#
# 4280 	class= 0
#   неработать вообский
#
#  Неработает вообсче
#
# 4454 	class= 1
#   почему айфон не_льзить взять другой аудио
#
#  Почему у айфона не льзя взять у других аудио
#
# 4495 	class= 0
#   спаитееееий
#
#  Спаитееееее
#
# 4496 	class= 0
#   норма
#
#  Норм
#
# 4778 	class= 0
#   зачем прекрасный приложение добавить ненужный функция мессенджер функция функция приложение смс дополнительно сообщать совершенный перевод зачем напрягать жуткий тормоз запуск приложение появиться введение новое функционал
#
#  Зачем в прекраснейшее приложение добавили ненужную функцию мессенджера? Функция ради функции? Приложение, помимо смс, дополнительно сообщает о совершенных переводах - зачем? Также напрягают жуткие тормоза при запуске приложения, появившиеся после введения нового «функционала».
#
# 4784 	class= 1
#   вызов функция повторить платёж приложение вылетать зависать белые экран
#
#  При вызове функции «Повторить платёж» приложение вылетает или зависает с белым экраном.
#
# 4812 	class= 1
#   почему не_приходить смс код установить приложение мобильный банк подключить
#
#  Почему не приходит смс с кодом чтобы установить приложение. Мобильный банк подключён.
#
# 4967 	class= 1
#   почему не_состояние счёт карта наложение арест узнать арест стоя банкомат сделать инф человек видеть какой причина списать деньга наложить арест спасибо
#
#  Почему не видно состояние счетов и карт при наложении арестов? Узнаешь об аресте,стоя у банкомата! Сделайте инфу,чтобы человек видел,за что и по какой причине списаны деньги или наложен арест! Спасибо
#
# 5274 	class= 1
#   не_мочь пригласить друг прямая эфир нет это значок
#
#  Не могу пригласить друзей в прямой эфир так как нет этого значка !!!
#
# 5281 	class= 1
#   я не_отображаться новое маска они уже 2-3 неделя ход весь обновление установить
#
#  У меня не отображаются новые маски, хотя они уже 2-3 недели как в ходу. Все обновления установлены.
#
# 5453 	class= 1
#   писать отсутствовать подключение сеть бред весь включиный
#
#  Пишет отсутствует подключение сети что за бред все включино
#
# 5461 	class= 1
#   почему пропасть функция закрытый аккаунт
#
#  Почему пропала функция закрытого аккаунта?
#
# 5564 	class= 1
#   почему мой аккаунт трансляция нету маска это телефон другой аккаунт они есть я исправить
#
#  Почему под моим аккаунтом в трансляции нету масок? С этого же телефона под другим аккаунтом они есть , как мне это исправить ?
#
# 5831 	class= 0
#   молодец весь загадить
#
#  Молодцы , все загадили ??
#
# 5926 	class= 0
#   добавить возможность выключить ваш замечательный звонок
#
#  Добавьте, пожалуйста, возможность выключить ваши замечательные звонки.
#
# 5955 	class= 0
#   давать
#
#  -А давайте !
#
# 6206 	class= 0
#   почему мой отзыв не_напечатать хороший вы человек
#
#  Почему мой отзыв не напечатали???
# ( хорошие вы люди)
#
# 6207 	class= 0
#   хуевой приложение
#
#  хуевая приложения
#
# 6297 	class= 1
#   ставить пять не_вы сервис который нет не_вы жёсткий отбор водитель потому это тоже нет ставить вы заслужить этот оценка никто вы заставить мы клиент мириться весь вы захотеть сделать потому цена поездка не_далеко двое вы стоить разница рубль дорогой автобус следовать вы поднять сервис набрать квалифицировать персонал тогда оценка пять быть стоять не_цена качество сейчас вы не_хороший старое гниловатый сарай
#
#  Ставлю пять просто так, не за то, что у вас сервис, которого нет, не за то, что у вас жесткий отбор водителей, потому что этого тоже нет, а ставлю просто так. Вы заслужили эту оценку как никто, вы заставили нас клиентов мириться со всем, что только вы захотите сделать, лишь потому что цена поездки не далеко на двоих у вас стоит с разницей в 22 рубля дороже чем на автобусе. Но следовало бы вам поднять сервис и набрать квалифицированного персонала и тогда оценка пять будет стоять не за цену, а за качество. А сейчас вы не лучше старого и гниловатого сарая!
#
# 6581 	class= 0
#   вернуть функция заказ два машина очень удобный быть функция работа спасать большой компания
#
#  Когда вернут функцию заказа второй машины???? Очень удобная была функция, по работе спасала и когда большая компания.
#
# 6623 	class= 1
#   вчера поездка яндекс такси карта не_хватить деньга её оплата прийтись расплатиться наличный сегодня деньга появиться сумма повторно списаться карта звонок служба поддержать средство вернуться минута огромный спасибо уважение я большинство знакомый вы стоить будущее вы пример подражание
#
#  Вчера после поездки на Яндекс такси на карте не хватило денег для её оплаты. Пришлось расплатится наличными. Сегодня же, когда деньги появились, сумма повторно списалась с карты. По звонку в службу поддержи средства вернулись через 10 минут. Огромное спасибо и уважение от меня и большинства знакомых, за вами стоит будущее, вы — пример для подражания??
#
# 6900 	class= 0
#   быть новое обновление
#
#  Когда будет новое обновление?????!!!!
#
# 7196 	class= 1
#   обнова
#
#  Когда обнова?
#
# 7436 	class= 0
#   отлично уебанскай техподдержка один бабнуть рубить народ похуй
#
#  Отлично. Уебанская техподдержка. Только одно бабло рубят. А на народ похуй.
#
# 8336 	class= 1
#   не_работать проксить не_получаться
#
#  Не работает, даже через прокси не получается
#
# 8368 	class= 1
#   вернуть предыдущий версия
#
#  Верните предыдущую версию пожалуйста
#
# 8424 	class= 1
#   хороший мессенджер мыть подъезд есть проблема я не_загружаться часть непрочитанный сообщение нет никакой маркер пропуск понять кусок хистори пропустить не_всегда не_сразу удаваться пропадать список чатик хистори теряться один конф я весь участник чатик пропадать всечь олин тот исправить
#
#  лучший мессенджер в моем подъезде, но есть проблема - у меня не загружается часть непрочитанных сообщений и нет никакого маркера пропуска - понять, что кусок хистори пропущен, не всегда и не сразу удается;
# также пропадают из списка чатики
#
# точнее - хистори теряется только в одной конфе (и только у меня из всех участников) и чатик пропадает всегла олин и тот же
#
# как бы это исправить?
#
# 8531 	class= 1
#   скачивать потому он запретить
#
#  Скачиваю лишь потому что его запретили.
#
# 8547 	class= 1
#   блин скачивание вводить номер выдавать проверить интернет подключение он есть
#
#  Блин , при скачивании ввожу номер: выдаёт - проверьте интернет подключение , хотя он есть
#
# 8586 	class= 1
#   рнк лох
#
#  РНК лох
#
# 9702 	class= 1
#   иметь весь шанс победить тот помойка мы авить звать
#
#  Имеет все шансы победить ту помойку, что мы авито зовем
#
# 9967 	class= 1
#   выбор уровень не_мочь нажать кнопка играть потому кнопка не_влезать размер экран исправить
#
#  После выбора уровня, не могу нажать на кнопку «Играть»
# Потому что кнопка не влезает в размер экрана
# Исправьте!
#
# 10107 	class= 0
#   качество низкий
#
#  Качество низкое
#
# 10187 	class= 1
#   мой чехол должный быть прийти май не_прислать я должный быть возвратить деньга май чехол прислать я захотеть деньга не_возвращать как-то не_вежливый получиться я сказать отменить возврат невозможно подарок джума самый крутой интернет-сайт
#
#  Мои чехлы должны были прийти 20 мая, но не пришли и мне должны были возвратить деньги, но 22 мая чехлы пришли и я захотела, чтобы денег не возвращали ( как-то не вежливо получилось бы), но мне сказали, что отменить возврат невозможно и это подарок от Джума. Самый крутой интернет-сайт!!!
#
# 10228 	class= 1
#   заказывать много разный стоимость не_прислать течение день всего пара заказ я они вернуть сразу деньга потом прийти товар всего виноватый наш почта россия один посылочка вскрыть почта сортировка быть писать жалоба почта посылка весь дошлый весь вопрос сайт всегда своевременно получать ответ решать весь проблема спасибо большой
#
#  Заказываю много.Разной стоимости.Не пришли в течении 60 дней всего пару заказов.Мне за них вернули сразу же деньги.И потом пришёл товар.Скорее всего виновата наша Почта России!) даже одну посылочку вскрыли!) на почте или на сортировке.Буду писать жалобу на почту.но посылка все же  дошла. А так на все вопросы на сайте ,всегда своевременно получаю ответы.Решают все проблемы) спасибо большое)))
#
# 10305 	class= 1
#   заказывать мнооий раз не_раз не_пришлый ничто не_пришлый очень досадный деньга естественно вернуть истечение день ожидание не_оправдаться
#
#  Заказывала мнооого раз и не разу не пришло!ничего не пришло!очень досадно,деньги естественно вернули по истечению 75 дней..но ожидание не оправдались
#
# 10579 	class= 1
#   сделать заказ разный продавец день товар не_получить написать поддержка течение два день возместить весь средство ещё два позвонить почта сказать я уже месяц лежать пакет любимый почта всегда тупить приложение работать отлично итог я получить заказ остаться деньга
#
#  Сделала 4 заказа у разных продавцов , после 75 дней товар не получила , написала в поддержку , в течении двух дней возместили все средства , а ещё через два позвонили с Почты и сказали что для меня уже месяц лежат 4 пакета . «Любимая» Почта как всегда тупит , а приложение работает отлично !
# В итоге я получила заказы и осталась при деньгах :)
#
# 10631 	class= 1
#   каждый обновление весь худой оформление стать себя вылетать переодичёска надеяться исправить
#
#  С каждым обновлением все хуже. Оформление стало так себе. Вылетает переодически. Ну надеюсь, это исправят.
#
# 10634 	class= 1
#   часто перевод слово неправильный
#
#  Часто перевод слов неправильный.
#
# 10912 	class= 1
#   нормальный работать
#
#  Нормально работает!
#
# 11351 	class= 1
#   приложение запускать сечь вылетаел
#
#  Приложение запускаешь через 5 сек вылетаел
#
# 11469 	class= 0
#   голосовой ассистент алиса не_включаться навигатор говорить она голос
#
#  Голосовой ассистент Алиса не включается, навигатор говорит только ее голосом.
#
# 11513 	class= 0
#   голосовой ассистент алиса не_включаться навигатор говорить она голос
#
#  Голосовой ассистент Алиса не включается, навигатор говорит только ее голосом.
#
# 11608 	class= 0
#   сам задумка игра супер время пролетать незаметно этот реклама выводить себя постоянно таскать страница весь время приходиться перезапускать игра поэтому разработчик оценка
#
#  Сама задумка и игра просто супер, время пролетает незаметно.Но......
# Эта реклама выводит из себя, постоянно таскает по страницам и все время приходится перезапускать игру.
# Поэтому ,разработчики, только (Оценка 1)
#
# 11714 	class= 1
#   реклама очень бесить
#
#  Реклама очень бесит
#
# 11874 	class= 1
#   человек не_жаловаться ерунда реклама я её почти нет
#
#  Люди!!! Не жалуйтесь на ерунду! Это же реклама!!! У меня её почти нет!!!
#
# 11875 	class= 0
#   вообще игра хороший я нравиться убрать реклама давать большой яблоко сделать редкий эпик частый не_обязательно сделать лёгкий исправить я поставить отзыв звезда
#
#  Вообще , игра хорошая , мне нравится,НО:
# 1) уберите рекламу
# 2) давайте больше яблок
# 3)сделайте редкие и эпики почаще
# 4) ( не обязательно) сделайте полегче
#         Если исправите я поставлю 10 отзывов с 5 звёздами!!!
#
# 11877 	class= 0
#   игра норма
#
#  Игра норм
#
# 12059 	class= 0
#   отключать интернет телефон запуск игра
#
#  ОТКЛЮЧАЙТЕ ИНТЕРНЕТ НА ТЕЛЕФОНЕ перед запуском игры!
#
# 12156 	class= 1
#   выйти
#
#  Наконец-то, вышло
#
# 12171 	class= 0
#   не_очень
#
#  Не очень.
#
# 12199 	class= 0
#   нет комментарий онлайн весь работать не_перчатка жутковатый аппетит пропадать
#
#  Нет комментариев онлайн и все работают без перчаток это жутковато , аппетит пропадает (
#
# 12530 	class= 0
#   не_доработать поэтому
#
#  Не доработали,поэтому только 1.
#
# 12548 	class= 0
#   я сильно хотеть ваш пицца потому она очень вкусный недорогой мой адрес временно не_обслуживаться я пустить слеза понимать я умереть голодный
#
#  я так сильно хотела вашу пиццу, потому что она очень вкусная и недорогая, но мой адрес временно не обслуживается (((( я даже пустила слезу понимаете я умру голодной
#
# 12942 	class= 0
#   игра интересный мочь быть не_сложность самый начало большой скорость
#
#  Игра интересная могла бы быть, если б не сложность с самого начала и большая скорость
#
# 12972 	class= 1
#   реклама
#
#  Минус только реклама
#
# 12988 	class= 0
#   чёт маловато реклама давать-ка её посереди игра пихать хороший
#
#  Чёт маловато рекламы, давайте-ка её и посереди игры пихать лучше, а)
#
# 13316 	class= 1
#   аллооо приложение обычный фильтр прежде всего соц сеть там точно классно можно пообщаться любить снэпчат бесить человек качать он маска
#
#  аллОоо,снэпчат-не приложение с обычными фильтрами,это прежде всего СОЦ.СЕТЬ,там точно также классно можно пообщаться.
# люблю снэпчат,и как же бесит,что люди качают его только ради масок!!
#
# 13476 	class= 1
#   вернуть сердечко
#
#  Верните сердечки ?????????
#
# 13956 	class= 0
#   очень мало вакансия не_раскрутить
#
#  Очень мало вакансий не раскручено
#
# 14063 	class= 1
#   очень удобно служба поддержка оперативно реагировать обновление начать приложение вылетать отписать сп отреагировать буквально течение 30-60 минута
#
#  Очень удобно! + служба поддержки оперативно реагирует, после обновления начало приложение вылетать, отписал в СП отреагировали буквально в течение 30-60 минут
#
# 14778 	class= 0
#   не_видеть координата воронежский область
#
#  Не видит координаты в воронежской области
#
# 14840 	class= 0
#   почему такой вы говорить крутой программа весь город
#
#  Почему в такой как вы говорите крутой программе  ни все города ?
#
# 15018 	class= 1
#   ранний весь хорошо быть сейчас попытка отправить фото предлагать сначала запустить сам приложение открывать приложение почему предлагать самый
#
#  Раньше все хорошо было. Сейчас при попытке отправить фото, предлагает сначала запустить само приложение. Открываю приложение, но почему предлагает то же самое...
#
# 15051 	class= 0
#   отлично улучшить приложение теперь нельзя отправить сафари письмо самый себя
#
#  Отлично улучшили приложение. Теперь нельзя отправить из Сафари письмо самому себе
#
# 15222 	class= 0
#   взламывать
#
#  Взламывают !!!
#
# 15777 	class= 0
#   почему видио не_грузиться зайцев
#
#  Почему видио не грузиться через зайцев?
#
# 16233 	class= 0
#   не_переворачиваться карта
#
#  Не переворачивается карта на 180^
#
# 16430 	class= 0
#   балл цензура защищать оленевод бан неделя
#
#  Балл за цензуру, защищают оленевода, бан на неделю
#
# 16467 	class= 1
#   яндекс карта подключить вай фай дом показывать мой местоположение точно пользование мегафон мой оператор местоположение показывать несколько километр сторона проблема
#
#  Яндекс.Карты при подключённом вай фай дома показывает мое местоположение точно, при пользовании от МегаФон, это мой оператор, местоположение показывает на несколько километров в сторону
# В чем проблема?
#
# 16510 	class= 0
#   наверняка я не_один такой сделать возможность проложение маршрут наземный транспорт
#
#  Наверняка я не один такой. Сделайте, пожалуйста, возможность проложения маршрута только наземным транспортом.
#
# 16575 	class= 1
#   я искренне удивлять человек который вопить повод тот музыка платный весь дело ребята кончиться халява пора раскошелиться слушать музыка удобство весь быть замечательный стать смущать один момент замереть количество скатить минута песня ещё не_скачать число не_меняться думать обновить надо обновление-то нет исправить этот момент остальной нарекание нет
#
#  Меня искренне удивляют люди,которые вопят по поводу того,что музыка платная и все дела.
# Ребята,да,кончилась халява,пора и раскошелиться,чтобы слушать музыку в удобстве.
# Все было замечательно,но стал смущать один момент. Замерло количество скаченных минут,сколько бы песен ещё не скачала,число не меняется.
# Думала,что,мол,обновить надо,а обновления-то и нет.
# Если исправить,то только этот момент,в остальном нареканий нет)
#
# 16589 	class= 0
#   хавный
#
#  Хавно))
#
# 16662 	class= 1
#   читать отзыв поражаться какой мы человек жлоб надо зажать месяц хлеб разработчик смех
#
#  Читаю отзывы и поражаюсь какие у нас люди жлобы , это ж надо зажать 150 в месяц на хлеб разработчикам , просто смех ???
#
# 16755 	class= 0
#   долгий время радовать бум пройти день разочаровать не_играть музыка бывать не_весь раз приходиться выклый вкл приложение помогать очень редко исправт
#
#  Долгое время радовал бум. Но за прошедший день разочаровал. Не играет музыка, бывает не вся, а через раз. Приходиться выкл и вкл приложение, помогает, но очень редко. Исправте
#
# 16873 	class= 1
#   почему не_входить высвечиваться белый экран потом вылетать главный делать день назад весь хорошо работать
#
#  Почему не входит?
# Высвечивается белый экран, а потом вылетает на главную, что делать? День назад все хорошо работало .
#
# 17164 	class= 1
#   здравствовать сказать почему я не_успеть зарегистрироваться тут я блокировать причина подозрительный активность какой активность идти речь я регистрироваться пара часы я уже блокировать уже раз такой ощущение сидеть человек который ненавидеть я выискивать пока не_зарегистрироваться тут блокировать ранний очень любить ваш сайт теперь увы разочароваться самый главный ничто такой плохой я не_делать общий один разочарование
#
#  Здравствуйте. Скажите пожалуйста, почему я не успев зарегистрироваться, тут же меня блокируют? Причина «подозрительная активность». О какой активности идёт речь, если я регистрируюсь и через пару часов меня уже блокируют. И так уже сколько раз. Такое ощущение, что сидит человек, который ненавидит меня, выискивает пока не зарегистрируюсь и тут же блокирует. Раньше очень любила ваш сайт, а теперь увы разочаровалась. Самое главное, что ничего такого плохого я не делаю!!! В общем одно РАЗОЧАРОВАНИЕ!!!!
#
# 17298 	class= 1
#   ответ предыдущий отзыв-купить себя нормальный телефон ослиный тупой
#
#  Ответ на предыдущий отзыв-купи себе нормальный телефон ослина тупая))))
#
# 17428 	class= 0
#   спасибо
#
#  Спасибо
#
# 17505 	class= 0
#   отключить весь уведомление нет весь приходить новый публикация друг ещё какой-то хрень вы хотеть ваш приложение пользоваться перестать хитрить сделать удобный полезный приложение не_тупой способ заработок
#
#  Отключил все уведомления, так нет же, всё равно приходит, то новая публикация у друга, то ещё какая-то хрень. Если вы хотите, чтобы вашим приложением пользовались, перестаньте хитрить и сделайте удобное и полезное приложение, а не тупой способ заработка.
#
# 17556 	class= 0
#   здравствовать добавить настройка отключить включить возможный друг более чтение контрактант возможный друг
#
#  Здравствуйте, добавьте настройки о отключить или включить возможные друзья и тем более чтение из контрактантов о возможных друзьях.
#
# 17799 	class= 0
#   жалкий пародия реально полезный музыкальный сервис больший часть отсутствовать весь годный нудный музыка медленный скорость загрузка музыка редкий пополнение дорогой оплата
#
#  Жалкая пародия на реально полезный музыкальный сервис .
# По большей части отсутствует вся годная и нудная Музыка
# Медленная скорость загрузки музыки
# Редкие пополнения
# Дорогая оплата
#
# 18186 	class= 1
#   быть проблема подключение игра скачать ваш приложение теперь мой нерв порядок
#
#  Была проблема с подключением в игре, скачала ваше приложение, теперь мои нервы в порядке)
#
# 19124 	class= 0
#   нужный функция очистка документ дать
#
#  Нужна функция очистки "документов и данных"
#
# 19346 	class= 1
#   каждый половина час приходить оповещение игра настройка не_найти они отменить
#
#  Каждые пол часа приходят оповещения от игры, в настройках не нашла как их отменить
#
# 19398 	class= 0
#   игра перестать открываться целое очень ничто
#
#  Игра перестала открываться ????? а в целом очень даже ничего ?
#
# 19477 	class= 1
#   не_мочь обновить причина обновить
#
#  Не могу обновить!!! Причина ? Как обновить?
#
# 19661 	class= 0
#   сабж
#
#  сабж
#
# 19664 	class= 0
#   жестокий вымогание донат
#
#  Жесточайшее вымогание на донат!!!
#
# 19795 	class= 0
#   сервис еле тянуть
#
#  Сервис еле тянет
#
# 19968 	class= 1
#   неточный геолокация
#
#  Неточная геолокация
#
# 20012 	class= 0
#   не_отображаться карта год санкт-петербург приложение серый экран булавка не_улица дом ничто исправить баг
#
#  Не отображается карта г. Санкт-Петербург в приложении, просто серый экран с булавкой. Не видно ни улиц, ни домов, ничего! Исправьте баг!
#
# 20272 	class= 1
#   не_видеть сеть сегоднешний день постоянно крутиться загрузка весь я смотреть не_я один такой начаться точно надзор сюдый добраться утро ещё местами переводить нет вечер совсем весь заглохлый думать приложение слететь удалить заново установить опять тож самый защёл сюда отзыв читать последний точно дело не_самый программа печалька скоро быть точно жить северный корея уже весь заблокированный нужно быть
#
#  Не видит сеть с сегоднешнего дня,постоянно крутиться загрузка и всё,я смотрю не у меня одного такое началось,точно надзор и до сюдого добрался похоже,с утра ещё местами то переводил то нет,а к вечеру совсем всё заглохло,думал приложение слетело,удалил и заново установил и опять тож самое,защёл сюда отзывы читаю последние и точно дело не в самой программе значит,печалька короче,скоро будем точно жить как в северной корее,уже всё заблокированно что нужно было.??????
#
# 20320 	class= 1
#   сделать язык клавиатура меняться автоматически тот язык который быть переводиться слово
#
#  Сделайте пожалуйста так чтобы язык на клавиатуре менялся автоматически на тот язык с которого будет переводится слово
#
# 20630 	class= 0
#   весь хорошо есть неправильный перевод руский корейский язык очень много ошибка тот самый рис переводить не_правильно исправт заранее спасибо
#
#  все хорошо. но есть неправильные переводы с руского на корейский язык( очень много ошибок) даже тот же
# самый рис переводит не правильно.исправте пожалуйста,заранее спасибо.
#
# 21215 	class= 1
#   играть нереально сложно
#
#  Играть просто нереально сложно.....
#
# 21221 	class= 0
#   хз
#
#  Хз
#
# 21391 	class= 1
#   обновиться перестать сохранять отстой какой-то
#
#  Обновилось и перестало сохранять ( отстой какой-то
#
# 21563 	class= 1
#   нажимать покупка выдавать ошибка
#
#  Нажимаю покупка и выдаёт ошибку
#
# 21922 	class= 0
#   неплохо весь сделать физик низок уровень разочаровать
#
#  Неплохо все сделано. Но физика на низком уровне, разочаровало.
#
# 21943 	class= 0
#   добавить новое трасса
#
#  Добавьте новые трассы
#
# 21957 	class= 1
#   игра хороший обновление пропасть возраст чекпоинт удваивание очки
#
#  Игра хорошая??вот после обновления пропали возрасты на чекпоинт и удваивание очков ??
#
# 22257 	class= 1
#   я ваш постоянный клиент почему вы казбековский район не_доставлять товар очень разочаровать
#
#  Я ваш постоянный клиент.. почему то вы в Казбековский район не доставляете товар.. очень разочарована !!!
#
# 22312 	class= 0
#   я пользоваться приложение год пара год очень активно уже заработать скидка чуть чуть нахватать нооооо я быть очень разочаровать балл стать уходить такой невероятный скорость я год не_слишком активный покупка остаться не_свой платиновый почти бриллиантовый скидка том е балл не_фиксироваться скидка сохраниться нужно заказывать постоянно невероятный скорость теперь пропасть желание
#
#  Я пользуюсь приложением около 3 лет.Пару лет очень активно и уже заработала скидку 15% и чуть чуть нахватало до 20% НООООО
# я была очень разочарована, когда баллы стали уходить в минус с такой невероятной скоростью, что я за год не слишком активных покупок осталась без своей платиновой и почти бриллиантовой скидки. Т.е баллы не фиксируются!!!!чтоб скидка сохранилась, нужно заказывать постоянно и с невероятной скоростью!!! Теперь просто даже пропало желание((((

# %%
digits_num.ndim
# Out:
# 2

# %%
train = np.hstack((tone, elongated_words_presense, digits_num, capital_letters_num, past_tense_words_num))

# %%
train.shape
# Out:
# (15566, 8)

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS

clf = MultinomialNB()

efs1 = EFS(clf, 
           min_features=1,
           max_features=8,
           scoring='f1',
           print_progress=True,
           cv=5)

efs1 = efs1.fit(train, revs_norm_neg_stop.rating)
# Out:
# Features: 255/255

# %%
print('Best f1 score: %.2f' % efs1.best_score_)
print('Best subset:', efs1.best_idx_)
# Out:
# Best f1 score: 0.69
# Best subset: (0, 1, 3, 5, 6, 7)

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, 0:1], digits_num)))
scores_selected_features = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_selected_features.mean()
# Out:
# fit_time          0.043944
# score_time        0.021010
# test_accuracy     0.874086
# test_f1           0.875799
# test_precision    0.888304
# test_recall       0.864544
# dtype: float64

# %%
importances_num = pd.DataFrame(importances)
importances_num = importances_num.drop(importances_num[importances_num[0] > 0.001].index)
importances_num

# %%
new_matr = pd.DataFrame(train.todense())

# %%
new_matr = new_matr.drop(importances_num.index, axis =1)
new_matr

# %%
train_clean = sparse.csr_matrix(new_matr)

scores_nb_clean = pd.DataFrame(cross_validate(clf_nb, train_clean, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_nb_clean.mean()

# %%
train01 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, [0,1]])))
train02 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, [0,2]])))
train03 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, [0,3]])))
train12 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, [1,2]])))
train13 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, [1,3]])))
train23 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, [2,3]])))

train012 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, [0,1,2]])))
train013 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, [0,1,3]])))
train123 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, [1,2,3]])))
train023 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone[:, [0,2,3]])))

train0123 = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg_stop.todense(), tone)))

# %%
scores_nb01 = pd.DataFrame(cross_validate(clf_nb, train01, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores_nb02 = pd.DataFrame(cross_validate(clf_nb, train02, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores_nb03 = pd.DataFrame(cross_validate(clf_nb, train03, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores_nb12 = pd.DataFrame(cross_validate(clf_nb, train12, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores_nb13 = pd.DataFrame(cross_validate(clf_nb, train13, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores_nb23 = pd.DataFrame(cross_validate(clf_nb, train23, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

scores_nb012 = pd.DataFrame(cross_validate(clf_nb, train012, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores_nb013 = pd.DataFrame(cross_validate(clf_nb, train013, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores_nb123 = pd.DataFrame(cross_validate(clf_nb, train123, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))
scores_nb023 = pd.DataFrame(cross_validate(clf_nb, train023, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

scores_nb0123 = pd.DataFrame(cross_validate(clf_nb, train0123, revs_norm_neg_stop.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
feat_comb_results = pd.DataFrame({
    "01" : scores_nb01.mean(),
    "02" : scores_nb02.mean(),
    "03" : scores_nb03.mean(),
    "12" : scores_nb12.mean(),
    "13" : scores_nb13.mean(),
    "23" : scores_nb23.mean(),
    
    "012" : scores_nb012.mean(),
    "013" : scores_nb013.mean(),
    "123" : scores_nb123.mean(),
    "023" : scores_nb023.mean(),
    
    "0123" : scores_nb0123.mean(),
})

feat_comb_results
