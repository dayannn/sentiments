# %%
import numpy as np
import pandas as pd
import re

# %%
revs = pd.DataFrame.from_csv("./res.csv", encoding="cp1251")

initial_revs = revs.copy()
revs
# Out:
#        rating                                            content
# 0           5  Интересный сюжет, затягивает. Много времени ух...
# 1           4  Плюсы: \r\n1. Игра интересная 2. Образы учител...
# 2           3  Огорчил тот факт , что суть игры заключается в...
# 3           5  Была постоянная ошибка с подключением, почти н...
# 4           1  ... сделайте русскую озвучку и будет 5 звёзд :...
# 5           3                         Почему нет русского языка?
# 6           1                                                  !
# 7           1              Постоянные проблемы с подключением!!!
# 8           5  Все идеально но отсутствия русского языка даёт...
# 9           1          Где великий и могучий??? Сделайте русский
# 10          4  Thanks for the game, I fancy it pretty much, h...
# 11          2                  Добавьте русский язык пожалуйста(
# 12          5  Игра отличная, отсутствие русского языка не ме...
# 13          4                       Please add Russian language!
# 14          5  Everything was great till Wednesday night. Gam...
# 15          3                         Where Russian language ???
# 16          1  В описании приложения, написали что есть русск...
# 17          1              Пожалуйста сделайте русский язык!!!!!
# 18          2  Зашла в игру, поиграла ровно минуту и всё, эне...
# 19          2  Игра интересная, но как же достал connect erro...
# 20          1  Where is the Russian language? why the descrip...
# 21          4  Без русского играть невозможно. От выборы зави...
# 22          5  Почему игра не запускается, перекидывает на ст...
# 23          1  Когда же ждать заявленный в описании русский я...
# 24          2  Русского языка нет, но английский понимаю - та...
# 25          5  Товарищи, учите иностранные языки \r\nИгра зам...
# 26          3                 Always connection lost! Fix please
# 27          1  Заявлен русский язык. Заходишь в игре в Настро...
# 28          5  Очень продуманная, интересная игра, все сделан...
# 29          3  Игра нармуль. Разрабочики добавьте русский язык !
# ...       ...                                                ...
# 22463       5  Пользуюсь приложением не первый год, мобильное...
# 22464       5  Один из лучших онлайн магазинов! Купила много ...
# 22465       1  Господа разработчики, уберите из приложения да...
# 22466       4  Для айфона не очень удобное приложение. Листат...
# 22467       1  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       1  И цены конские. А их реклама «увеличьте свой ч...
# 22469       5  Отличный сайт и отличное приложение, пока толь...
# 22470       5  Приложение , сайт и вещи и вообще все просто с...
# 22471       1  Сделал заказ, сказали что доставка возможна то...
# 22472       5  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       1  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       5  Сразу все магазины в одном месте ? так как я в...
# 22475       2  Во вкладке «Избранное» дублируются товары. Три...
# 22476       5           Мне нравится. Удобно, быстро, недорого??
# 22477       5                                       Всё хорошо ?
# 22478       1  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       1  Вся обувь китайская подделка, через 15 минут р...
# 22480       1  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       1  Доставка от пони экспресс, портит все. Может в...
# 22482       1  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       1  Приложение где только не пиарят, увидела в вк ...
# 22484       1  Не стыдно врать то, никаких скидок на фирму не...
# 22485       1  Зачем изменили приложение, что за ненужное око...
# 22486       1                          Недобросовестная реклама.
# 22487       1  Приложение классное, но реклама на YouTube за*...
# 22488       4  Почините,пожалуйста,приложение, заходила два г...
# 22489       1  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       1  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22491       4  Отличное приложение, удобное в использовании, ...
# 22492       5                                             ??????
#
# [22493 rows x 2 columns]

# %% [markdown]
# Удаляем неподходящие отзывы: с рейтингов 3-4, с английским текстом, пустые

# %%
    #drop eng reviews
revs.drop(revs[revs.content.str.contains ("[A-Za-z]")].index, inplace=True)
    #drop reviews with rating 3-4
revs.drop(revs[(revs.rating == 3) | (revs.rating == 4)].index, inplace=True)
    #drop empty reviews
revs.drop(revs[revs.content == ""].index, inplace=True)

revs
# Out:
#        rating                                            content
# 0           5  Интересный сюжет, затягивает. Много времени ух...
# 4           1  ... сделайте русскую озвучку и будет 5 звёзд :...
# 6           1                                                  !
# 7           1              Постоянные проблемы с подключением!!!
# 8           5  Все идеально но отсутствия русского языка даёт...
# 9           1          Где великий и могучий??? Сделайте русский
# 11          2                  Добавьте русский язык пожалуйста(
# 16          1  В описании приложения, написали что есть русск...
# 17          1              Пожалуйста сделайте русский язык!!!!!
# 18          2  Зашла в игру, поиграла ровно минуту и всё, эне...
# 22          5  Почему игра не запускается, перекидывает на ст...
# 23          1  Когда же ждать заявленный в описании русский я...
# 24          2  Русского языка нет, но английский понимаю - та...
# 25          5  Товарищи, учите иностранные языки \r\nИгра зам...
# 27          1  Заявлен русский язык. Заходишь в игре в Настро...
# 28          5  Очень продуманная, интересная игра, все сделан...
# 33          5                              Добавьте русский язык
# 35          2                             Необходим русский язык
# 37          1                                       Русский язык
# 38          1                         Нет русского языка! Обман!
# 41          2  Вы написала есть русский а там его в игре нет ...
# 43          1  Алло, где русский язык??? \r\nНаписано же, что...
# 47          5  Игра выше всех моих ожиданий, и судя по отзыва...
# 48          1                              Где русский язык ????
# 51          1  Играть просто стыдно. Гейплей, сюжет отсутству...
# 53          5                  Добавьте русский язык пожалуйста!
# 54          1  Очень жду Русский язык ,написано что он есть ,...
# 57          5             Спасибо!!! Очень интересно играть! ???
# 58          1  В описании к игре Русский язык указан, фактиче...
# 59          1  Зачем указывать языки которых нет и ничего не ...
# ...       ...                                                ...
# 22459       5  Те кто пишет фу и всё такое, советую не слушат...
# 22460       5  Ламода- супер вариант для тех, кто не может по...
# 22461       5  Отличный магазин. Удобно. Быстро. Дёшево. Фейк...
# 22462       5                     Поиск по фото - просто огонь!!
# 22463       5  Пользуюсь приложением не первый год, мобильное...
# 22464       5  Один из лучших онлайн магазинов! Купила много ...
# 22465       1  Господа разработчики, уберите из приложения да...
# 22467       1  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       1  И цены конские. А их реклама «увеличьте свой ч...
# 22469       5  Отличный сайт и отличное приложение, пока толь...
# 22470       5  Приложение , сайт и вещи и вообще все просто с...
# 22471       1  Сделал заказ, сказали что доставка возможна то...
# 22472       5  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       1  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       5  Сразу все магазины в одном месте ? так как я в...
# 22475       2  Во вкладке «Избранное» дублируются товары. Три...
# 22476       5           Мне нравится. Удобно, быстро, недорого??
# 22477       5                                       Всё хорошо ?
# 22478       1  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       1  Вся обувь китайская подделка, через 15 минут р...
# 22480       1  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       1  Доставка от пони экспресс, портит все. Может в...
# 22482       1  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       1  Приложение где только не пиарят, увидела в вк ...
# 22484       1  Не стыдно врать то, никаких скидок на фирму не...
# 22485       1  Зачем изменили приложение, что за ненужное око...
# 22486       1                          Недобросовестная реклама.
# 22489       1  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       1  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22492       5                                             ??????
#
# [15949 rows x 2 columns]

# %% [markdown]
# Заменяем оценку 5 на класс "1" - позитивные отзывы, оценки 1-2 - на класс "0" - негативные отзывы

# %%
revs['rating'][(revs.rating == 1) | (revs.rating == 2)] = 0
revs['rating'][revs.rating == 5] = 1

revs
# Out:
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#        rating                                            content
# 0           1  Интересный сюжет, затягивает. Много времени ух...
# 4           0  ... сделайте русскую озвучку и будет 5 звёзд :...
# 6           0                                                  !
# 7           0              Постоянные проблемы с подключением!!!
# 8           1  Все идеально но отсутствия русского языка даёт...
# 9           0          Где великий и могучий??? Сделайте русский
# 11          0                  Добавьте русский язык пожалуйста(
# 16          0  В описании приложения, написали что есть русск...
# 17          0              Пожалуйста сделайте русский язык!!!!!
# 18          0  Зашла в игру, поиграла ровно минуту и всё, эне...
# 22          1  Почему игра не запускается, перекидывает на ст...
# 23          0  Когда же ждать заявленный в описании русский я...
# 24          0  Русского языка нет, но английский понимаю - та...
# 25          1  Товарищи, учите иностранные языки \r\nИгра зам...
# 27          0  Заявлен русский язык. Заходишь в игре в Настро...
# 28          1  Очень продуманная, интересная игра, все сделан...
# 33          1                              Добавьте русский язык
# 35          0                             Необходим русский язык
# 37          0                                       Русский язык
# 38          0                         Нет русского языка! Обман!
# 41          0  Вы написала есть русский а там его в игре нет ...
# 43          0  Алло, где русский язык??? \r\nНаписано же, что...
# 47          1  Игра выше всех моих ожиданий, и судя по отзыва...
# 48          0                              Где русский язык ????
# 51          0  Играть просто стыдно. Гейплей, сюжет отсутству...
# 53          1                  Добавьте русский язык пожалуйста!
# 54          0  Очень жду Русский язык ,написано что он есть ,...
# 57          1             Спасибо!!! Очень интересно играть! ???
# 58          0  В описании к игре Русский язык указан, фактиче...
# 59          0  Зачем указывать языки которых нет и ничего не ...
# ...       ...                                                ...
# 22459       1  Те кто пишет фу и всё такое, советую не слушат...
# 22460       1  Ламода- супер вариант для тех, кто не может по...
# 22461       1  Отличный магазин. Удобно. Быстро. Дёшево. Фейк...
# 22462       1                     Поиск по фото - просто огонь!!
# 22463       1  Пользуюсь приложением не первый год, мобильное...
# 22464       1  Один из лучших онлайн магазинов! Купила много ...
# 22465       0  Господа разработчики, уберите из приложения да...
# 22467       0  Доставка в стиле «ой я не знаю как к вам попас...
# 22468       0  И цены конские. А их реклама «увеличьте свой ч...
# 22469       1  Отличный сайт и отличное приложение, пока толь...
# 22470       1  Приложение , сайт и вещи и вообще все просто с...
# 22471       0  Сделал заказ, сказали что доставка возможна то...
# 22472       1  Довольно таки удобно, цены гуд , по купонам ко...
# 22473       0  Реклама этого ширпотреба достала. Еще забавляе...
# 22474       1  Сразу все магазины в одном месте ? так как я в...
# 22475       0  Во вкладке «Избранное» дублируются товары. Три...
# 22476       1           Мне нравится. Удобно, быстро, недорого??
# 22477       1                                       Всё хорошо ?
# 22478       0  Смысл этого приложения. Покупаешь кота в мешке...
# 22479       0  Вся обувь китайская подделка, через 15 минут р...
# 22480       0  Заказывал 25.11 зимние ботинки, сказали, что д...
# 22481       0  Доставка от пони экспресс, портит все. Может в...
# 22482       0  Точнее, меняется, но в худшую сторону.\r\nИз-з...
# 22483       0  Приложение где только не пиарят, увидела в вк ...
# 22484       0  Не стыдно врать то, никаких скидок на фирму не...
# 22485       0  Зачем изменили приложение, что за ненужное око...
# 22486       0                          Недобросовестная реклама.
# 22489       0  Цены не такие уж и маленькие. \r\nКачество изд...
# 22490       0  Умрите от СПИДа, достала ваша реклама! Сколько...
# 22492       1                                             ??????
#
# [15949 rows x 2 columns]

# %% [markdown]
# Загружаем морфологический анализатор pymorphy2, стоп-слова из списка библиотеки nltk

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
stop_words = set(stopwords.words('russian'))

# %% [markdown]
# Лемматизация

# %%
def strtonormalform(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None) and (word not in stop_words) :#союзы, предлоги и т.п. не сохраняем
            ans = ans + ' ' + lex
    return ans

#revs_norm = revs.copy()
#revs_norm['content'] = revs_norm['content'].apply(strtonormalform)
    #drop empty reviews
#revs_norm.drop(revs_norm[revs_norm.content == ""].index, inplace=True)

#revs_norm

# %%
#revs_norm.to_csv("normalized_revs.csv")
revs_norm = pd.DataFrame.from_csv("./normalized_revs.csv", encoding="cp1251")
revs_norm
# Out:
#        rating                                            content
# 0           1   интересный сюжет затягивать много время уходи...
# 4           0           сделать русский озвучка звезда понимание
# 7           0                    постоянный проблема подключение
# 8           1   весь идеально отсутствие русский язык давать ...
# 9           0                где великий могучий сделать русский
# 11          0                              добавить русский язык
# 16          0   описание приложение написать русский язык фак...
# 17          0                               сделать русский язык
# 18          0   зайти игра поиграть ровно минута весь энергия...
# 22          1   почему игра запускаться перекидывать страница...
# 23          0                ждать заявить описание русский язык
# 24          0   русский язык английский понимать небольшой не...
# 25          1   товарищ учить иностранный язык игра замечател...
# 27          0   заявить русский язык заходить игра настройка ...
# 28          1            очень продумать интересный игра сделать
# 33          1                              добавить русский язык
# 35          0                           необходимый русский язык
# 37          0                                       русский язык
# 38          0                             нет русский язык обман
# 41          0   вы написать русский игра сделать русский язык...
# 43          0                 русский язык написать русский язык
# 47          1   игра выше мой ожидание судить отзыв русскоязы...
# 48          0                                   где русский язык
# 51          0   играть стыдно гейплей сюжет отсутствовать так...
# 53          1                              добавить русский язык
# 54          0                  очень ждать русский язык написать
# 57          1                             очень интересно играть
# 58          0   описание игра русский язык указанный фактичес...
# 59          0          зачем указывать язык который менять ждать
# 60          0                              добавить русский язык
# ...       ...                                                ...
# 22458       1   я являться постоянный клиент магазин ламода ч...
# 22459       1   тот писать весь такой советовать слушать загр...
# 22460       1   ламода- супер вариант тот позволить ходить ма...
# 22461       1   отличный магазин удобно быстро дёшево фейковы...
# 22462       1                                   поиск фото огонь
# 22463       1   пользоваться приложение один год мобильный уд...
# 22464       1   один хороший онлайн магазин купить одежда сум...
# 22465       0   господин разработчик убрать приложение дата д...
# 22467       0   доставка стиль знать попасть поэтому бегать я...
# 22468       0   цена конский реклама увеличить свой член дост...
# 22469       1   отличный сайт отличный приложение пока оформи...
# 22470       1   приложение сайт вещий вообще супееееееееееерр...
# 22471       0   сделать заказ сказать доставка возможный завт...
# 22472       1   довольно удобно цена гуд купон который сайт о...
# 22473       0   реклама ширпотреб достать забавлять накрутить...
# 22474       1   сразу магазин один место декрет очень удобно ...
# 22475       0   вкладка избранный дублироваться товар три раз...
# 22476       1                 я нравиться удобно быстро недорого
# 22477       1                                               весь
# 22478       0   смысл приложение покупать кот мешок дорогой м...
# 22479       0   весь обувь китайский подделка минута развалит...
# 22480       0   заказывать зимний ботинок сказать доставить ч...
# 22481       0   доставка пони экспресс портить мочь вообще пр...
# 22482       0   меняться плохой сторона многочисленный косяк ...
# 22483       0   приложение пиарить увидеть вк рекламный ролик...
# 22484       0   стыдно врать никакой скидка фирма магазин деш...
# 22485       0   зачем изменить приложение ненужный окошко пос...
# 22486       0                           недобросовестный реклама
# 22489       0   цена такой маленькая качество изделие очень х...
# 22490       0   умереть спид достать ваш реклама деньга отдат...
#
# [15481 rows x 2 columns]

# %%
def strtonormalform_with_neg(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    flag = False
    for word in words:
        if (word == "не"):
            flag = True
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None) and (word not in stop_words) :#союзы, предлоги и т.п. не сохраняем
            if (flag):
                flag = False
                lex = "не_" + lex
            ans = ans + ' ' + lex
    return ans

#revs_norm_neg = revs.copy()
#revs_norm_neg['content'] = revs['content'].apply(strtonormalform_with_neg)
    #drop empty reviews
#revs_norm_neg.drop(revs_norm_neg[revs_norm_neg.content == ""].index, inplace=True)

#revs_norm_neg

# %%
#revs_norm_neg.to_csv("normalized_revs_with_neg.csv")
revs_norm_neg = pd.DataFrame.from_csv("./normalized_revs_with_neg.csv", encoding="cp1251")
revs_norm_neg
# Out:
#        rating                                            content
# 0           1   интересный сюжет затягивать много время уходи...
# 4           0           сделать русский озвучка звезда понимание
# 7           0                    постоянный проблема подключение
# 8           1   весь идеально отсутствие русский язык давать ...
# 9           0                где великий могучий сделать русский
# 11          0                              добавить русский язык
# 16          0   описание приложение написать русский язык фак...
# 17          0                               сделать русский язык
# 18          0   зайти игра поиграть ровно минута весь энергия...
# 22          1   почему игра не_запускаться перекидывать стран...
# 23          0                ждать заявить описание русский язык
# 24          0   русский язык английский понимать небольшой не...
# 25          1   товарищ учить иностранный язык игра замечател...
# 27          0   заявить русский язык заходить игра настройка ...
# 28          1            очень продумать интересный игра сделать
# 33          1                              добавить русский язык
# 35          0                           необходимый русский язык
# 37          0                                       русский язык
# 38          0                             нет русский язык обман
# 41          0   вы написать русский игра сделать русский язык...
# 43          0                 русский язык написать русский язык
# 47          1   игра выше мой ожидание судить отзыв русскоязы...
# 48          0                                   где русский язык
# 51          0   играть стыдно гейплей сюжет отсутствовать так...
# 53          1                              добавить русский язык
# 54          0                  очень ждать русский язык написать
# 57          1                             очень интересно играть
# 58          0   описание игра русский язык указанный фактичес...
# 59          0       зачем указывать язык который не_менять ждать
# 60          0                              добавить русский язык
# ...       ...                                                ...
# 22458       1   я являться постоянный клиент магазин ламода ч...
# 22459       1   тот писать весь такой советовать не_слушать з...
# 22460       1   ламода- супер вариант тот не_позволить ходить...
# 22461       1   отличный магазин удобно быстро дёшево фейковы...
# 22462       1                                   поиск фото огонь
# 22463       1   пользоваться приложение не_один год мобильный...
# 22464       1   один хороший онлайн магазин купить одежда сум...
# 22465       0   господин разработчик убрать приложение дата д...
# 22467       0   доставка стиль не_знать попасть поэтому бегат...
# 22468       0   цена конский реклама увеличить свой член дост...
# 22469       1   отличный сайт отличный приложение пока оформи...
# 22470       1   приложение сайт вещий вообще супееееееееееерр...
# 22471       0   сделать заказ сказать доставка возможный завт...
# 22472       1   довольно удобно цена гуд купон который сайт о...
# 22473       0   реклама ширпотреб достать забавлять накрутить...
# 22474       1   сразу магазин один место декрет очень удобно ...
# 22475       0   вкладка избранный дублироваться товар три раз...
# 22476       1                 я нравиться удобно быстро недорого
# 22477       1                                               весь
# 22478       0   смысл приложение покупать кот мешок дорогой м...
# 22479       0   весь обувь китайский подделка минута развалит...
# 22480       0   заказывать зимний ботинок сказать доставить ч...
# 22481       0   доставка пони экспресс портить мочь вообще не...
# 22482       0   меняться плохой сторона многочисленный косяк ...
# 22483       0   приложение не_пиарить увидеть вк рекламный ро...
# 22484       0   стыдно врать никакой скидка фирма магазин деш...
# 22485       0   зачем изменить приложение ненужный окошко пос...
# 22486       0                           недобросовестный реклама
# 22489       0   цена не_такой маленькая качество изделие очен...
# 22490       0   умереть спид достать ваш реклама деньга отдат...
#
# [15481 rows x 2 columns]

# %%
revs_norm.rating.describe()
# Out:
# count    15481.000000
# mean         0.512693
# std          0.499855
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: rating, dtype: float64

# %%
print ('Количество положительных отзывов составляет {}% от всей выборки'.format(round(float(sum(revs_norm.rating)) / len(revs_norm.rating) * 100, 2)))
print ('Количество положительных отзывов составляет {}% от всей выборки'.format(round(float(len(revs_norm.rating )- sum(revs_norm.rating)) / len(revs_norm.rating) * 100, 2)))
print ('Размер обучающей выборки: {}'.format(revs_norm.shape[0]))
# Out:
# Количество положительных отзывов составляет 51.27% от всей выборки
# Количество положительных отзывов составляет 48.73% от всей выборки
# Размер обучающей выборки: 15481

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.model_selection import RandomizedSearchCV
from nltk.corpus import stopwords
from sklearn.model_selection import cross_validate 
from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

import string

# %%
import sklearn.metrics

def trainTestClf(clf, X_train, y_train, X_test):
    clf.fit(X_train, y_train)
    return clf.predict(X_test)

def get_metrics(y_test, y_pred):
    accuracy = sklearn.metrics.accuracy_score(y_true = y_test, y_pred = y_pred)
    precision = sklearn.metrics.precision_score(y_true = y_test, y_pred = y_pred)
    recall = sklearn.metrics.recall_score(y_true = y_test, y_pred = y_pred)
    f1_score = sklearn.metrics.f1_score(y_true = y_test, y_pred = y_pred)
    
    return {
        "accuracy" : accuracy,
        "precision" : precision,
        "recall" : recall,
        "f1_score" : f1_score
    }


def print_metrics(metrics, vType ='-', cType='-'):
    print("Vectorizing: ", vType, ". Classifier: ", cType, sep='')

    print("accuracy = %.3f" % metrics["accuracy"])
    print("precision = %.3f" % metrics["precision"])
    print("recall = %.3f" % metrics["recall"])
    print("F-мера = %.3f" % metrics["f1_score"])

# %%
clf_svm = LinearSVC()
clf_nb = MultinomialNB()
clf_rf = RandomForestClassifier()
clf_lr = LogisticRegression(C=1e5)

scoring = ['accuracy', 'precision', 'recall', 'f1']

# %%
norm_texts = revs_norm.content.copy()
norm_texts_splitted = revs_norm.content.str.split().copy()

norm_texts_neg = revs_norm_neg.content.copy()
norm_texts_neg_splitted = revs_norm_neg.content.str.split().copy()

# %%
#from sklearn.feature_extraction.text import TfidfVectorizer

#tiv = TfidfVectorizer()
#nwd = tiv.fit_transform(norm_texts)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer_uni = CountVectorizer(binary = True, ngram_range=(1,1), max_features= 10000)
count_vectorizer_bi = CountVectorizer(binary = True, ngram_range=(2,2), max_features= 10000)
count_vectorizer_tri = CountVectorizer(binary = True, ngram_range=(3,3), max_features= 10000)
count_vectorizer_uni_bi = CountVectorizer(binary = True, ngram_range=(1,2), max_features= 10000)
count_vectorizer_uni_bi_tri = CountVectorizer(binary = True, ngram_range=(1,3), max_features= 10000)

cvect_uni = count_vectorizer_uni.fit_transform(norm_texts)
cvect_bi = count_vectorizer_bi.fit_transform(norm_texts)
cvect_tri = count_vectorizer_tri.fit_transform(norm_texts)
cvect_uni_bi = count_vectorizer_uni_bi.fit_transform(norm_texts)
cvect_uni_bi_tri = count_vectorizer_uni_bi_tri.fit_transform(norm_texts)

# %%
# без доп признаков

# униграммы
scores1_uni = pd.DataFrame(cross_validate(clf_svm, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni = pd.DataFrame(cross_validate(clf_rf, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni = pd.DataFrame(cross_validate(clf_lr, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni = pd.DataFrame(cross_validate(clf_nb, cvect_uni, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# биграммы
scores1_bi = pd.DataFrame(cross_validate(clf_svm, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_bi = pd.DataFrame(cross_validate(clf_rf, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_bi = pd.DataFrame(cross_validate(clf_lr, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_bi = pd.DataFrame(cross_validate(clf_nb, cvect_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# триграммы
scores1_tri = pd.DataFrame(cross_validate(clf_svm, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_tri = pd.DataFrame(cross_validate(clf_rf, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_tri = pd.DataFrame(cross_validate(clf_lr, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_tri = pd.DataFrame(cross_validate(clf_nb, cvect_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# уни- и биграммы
scores1_uni_bi = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# уни-, би-, и триграммы
scores1_uni_bi_tri = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi_tri = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi_tri = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi_tri = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi_tri, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
# без доп признаков

# униграммы
#X_train, X_test, y_train, y_test = train_test_split(cvect_uni, revs.rating, test_size=0.1, random_state=42)
#metr1_uni = get_metrics(y_test, trainTestClf(clf_svm, X_train, y_train, X_test))
#metr2_uni = get_metrics(y_test, trainTestClf(clf_rf, X_train, y_train, X_test))
#metr3_uni = get_metrics(y_test, trainTestClf(clf_lr, X_train, y_train, X_test))

# %%
class_res_svm = pd.DataFrame({
    "униграммы" : scores1_uni.mean(),
    "биграммы" : scores1_bi.mean(),
    "триграммы" : scores1_tri.mean(),
    "уни- и биграммы" : scores1_uni_bi.mean(),
    "уни-, би- и триграммы" : scores1_uni_bi_tri.mean()
})

print("Результаты для svm")
class_res_svm
# Out:
# Результаты для svm
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        0.476670   2.055828         1.815782               1.494694
# score_time      0.018526   0.112870         0.079458               0.077769
# test_accuracy   0.740002   0.579290         0.822299               0.821265
# test_f1         0.776527   0.702968         0.830582               0.829783
# test_precision  0.694697   0.550975         0.813037               0.811398
# test_recall     0.880940   0.970895         0.850452               0.850578
#
#                 униграммы
# fit_time         0.630446
# score_time       0.006004
# test_accuracy    0.811059
# test_f1          0.819327
# test_precision   0.803519
# test_recall      0.837349

# %%
class_res_rf = pd.DataFrame({
    "униграммы" : scores2_uni.mean(),
    "биграммы" : scores2_bi.mean(),
    "триграммы" : scores2_tri.mean(),
    "уни- и биграммы" : scores2_uni_bi.mean(),
    "уни-, би- и триграммы" : scores2_uni_bi_tri.mean()
})
print("Результаты для random forest")
class_res_rf
# Out:
# Результаты для random forest
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        4.484312   5.272390         4.155357               4.788729
# score_time      0.584234   0.951789         0.326047               0.354961
# test_accuracy   0.726115   0.572249         0.825270               0.820490
# test_f1         0.767646   0.699693         0.823710               0.819254
# test_precision  0.679365   0.546627         0.852618               0.845390
# test_recall     0.882958   0.971903         0.797030               0.795647
#
#                 униграммы
# fit_time         3.980638
# score_time       0.106472
# test_accuracy    0.816614
# test_f1          0.815225
# test_precision   0.842154
# test_recall      0.790604

# %%
class_res_lr = pd.DataFrame({
    "униграммы" : scores3_uni.mean(),
    "биграммы" : scores3_bi.mean(),
    "триграммы" : scores3_tri.mean(),
    "уни- и биграммы" : scores3_uni_bi.mean(),
    "уни-, би- и триграммы" : scores3_uni_bi_tri.mean()
})


print("Результаты для linear regression")
class_res_lr
# Out:
# Результаты для linear regression
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        0.634045   0.511951         1.740581               1.906586
# score_time      0.005203   0.007605         0.007206               0.006805
# test_accuracy   0.729538   0.581292         0.775403               0.782508
# test_f1         0.763932   0.702836         0.785929               0.792021
# test_precision  0.691698   0.552483         0.769839               0.777630
# test_recall     0.853727   0.965729         0.804717               0.808624
#
#                 униграммы
# fit_time         4.944314
# score_time       0.006003
# test_accuracy    0.751501
# test_f1          0.762714
# test_precision   0.747167
# test_recall      0.780149

# %%
class_res_nb = pd.DataFrame({
    "униграммы" : scores4_uni.mean(),
    "биграммы" : scores4_bi.mean(),
    "триграммы" : scores4_tri.mean(),
    "уни- и биграммы" : scores4_uni_bi.mean(),
    "уни-, би- и триграммы" : scores4_uni_bi_tri.mean()
})


print("Результаты для naive bayes")
class_res_nb
# Out:
# Результаты для naive bayes
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        5.459081   9.557547         6.394047               9.171398
# score_time      5.391451   5.769299         5.550002               6.844399
# test_accuracy   0.717071   0.579096         0.735159               0.736967
# test_f1         0.759622   0.703241         0.763143               0.765815
# test_precision  0.673198   0.550742         0.705272               0.704840
# test_recall     0.871991   0.972659         0.832560               0.839488
#
#                 униграммы
# fit_time         9.136698
# score_time       5.448436
# test_accuracy    0.633101
# test_f1          0.706262
# test_precision   0.599794
# test_recall      0.860155

# %%
class_result_svm = pd.DataFrame(class_res_svm["уни- и биграммы"])
class_result_rf = pd.DataFrame(class_res_rf["уни- и биграммы"])
class_result_lr = pd.DataFrame(class_res_lr["уни- и биграммы"])
class_result_nb = pd.DataFrame(class_res_nb["уни- и биграммы"])

class_result_svm = class_result_svm.transpose()
class_result_rf = class_result_rf.transpose()
class_result_lr = class_result_lr.transpose()
class_result_nb = class_result_nb.transpose()

# %% [markdown]
# Сочетание униграмм и биграм показывает лучшие результаты, будем использовать данный способ векторизации

# %% [markdown]
# Посмотрим на метрики классификации в текстах с обработкой отрицаний

# %%
cvect_uni_bi_neg = count_vectorizer_uni_bi.fit_transform(norm_texts_neg)


# уни- и биграммы
scores1_uni_bi_neg = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi_neg = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi_neg = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_uni_bi_neg = pd.DataFrame(cross_validate(clf_nb, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_uni_bi_neg = pd.DataFrame({
    "SVM" : scores1_uni_bi_neg.mean(),
    "Random forest" : scores2_uni_bi_neg.mean(),
    "Linear regression" : scores3_uni_bi_neg.mean(),
    "Naive Bayes" : scores4_uni_bi_neg.mean()
})

scores_uni_bi_neg
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.282511     0.014211       2.937494  0.418501
# score_time               0.006000     0.006604       0.106873  0.005004
# test_accuracy            0.781539     0.859247       0.823396  0.827078
# test_f1                  0.791552     0.860301       0.822757  0.834857
# test_precision           0.775399     0.873931       0.846229  0.818336
# test_recall              0.810390     0.848311       0.801062  0.853727

# %%
# Нахождение неверно классифицированных отзывов

def print_wrong_class(y_test, y_pred):
    inds = y_test[y_test.values != y_pred].index
    i = 0
    for idx, rev in revs_norm_neg.iterrows():
        i+=1
        if (idx in inds):
            print (idx, "\tclass=", rev.rating, '\n', rev.content, '\n\n', initial_revs.ix[idx].content, "\n")

# %%
X_train, X_test, y_train, y_test = train_test_split(cvect_uni_bi_neg, revs_norm_neg.rating, test_size=0.1, random_state=42)
classifier = clf_svm.fit(X=X_train, y=y_train)
y_pred = classifier.predict(X_test)

print_wrong_class (y_test, y_pred)
# Out:
# 58 	class= 0
#   описание игра русский язык указанный фактически таковой игра добавить игра убрать описание
#
#  В описании к игре Русский язык указан, фактически такового в игре нет
# Добавьте в игру или уберите из описания
#
# 63 	class= 1
#   крутяга ещё русский добавить сложно постоянно нужно вспоминать английский
#
#  Крутяг
# Ещё бы русский добавили
# А то сложно ,постоянно нужно вспоминать английский )))
#
# 161 	class= 1
#   добавить русский язык
#
#  ДОБАВЬТЕ РУССКИЙ ЯЗЫК
#
# 270 	class= 1
#   чудесный игра очень затянуть вернуть сказочный мир влюбиться игра гарри поттер вновь проблема язык не_возникнуть знать английский вообще иметь русский версия
#
#  Чудесная игра! Очень затянула, вернула в этот сказочный мир. Влюбилась в эту игру и в Гарри Поттера вновь ??. Проблемы с языком не возникли, так как хорошо знаю английский. Но вообще было бы здорово иметь русскую версию)
#
# 271 	class= 1
#   плохо английский догадаться понять идти речь смысл
#
#  Даже если ты плохо знаешь английский, можно догадаться и понять о чем идёт речь по смыслу
#
# 296 	class= 0
#   игра супер
#
#  Игра супер
#
# 298 	class= 1
#   весь сделать русский
#
#  Все хорошо, но сделайте на русском!
#
# 449 	class= 0
#   понятно
#
#  Не понятно
#
# 455 	class= 1
#   сделать русский корявый хотеть играть гарри потир
#
#  Сделайте уже русский хоть корявый какой нибудь я хочу играть в Гарри потира
#
# 506 	class= 1
#   звонок стажёра
#
#  5 звонков стажёра из 5
#
# 554 	class= 1
#   очень странно списать деньга карта стоимость указать рубль списать минута пройти отказ покупка итог игра скачать деньга не_заплатить
#
#  Очень странно списали деньги с карты, стоимость указана 15 рублей, списало 70, через 1 минуту прошёл отказ от покупки, в итоге игру скачал, а денег не заплатил. ?????
#
# 603 	class= 1
#   время убить пока не_надоесть
#
#  Время убить можно, пока что не надоело
#
# 674 	class= 0
#   списать 164р вор
#
#  Списали 164р, воры
#
# 776 	class= 1
#   кровь пол дойти неделя итог заход игра начаться заново делать
#
#  10 кровей на полу из 10
# Но!
# Дошёл до 2 недели, в итоге сейчас при заходе в игру, все началось заново
# Что делать?
#
# 983 	class= 1
#   пройти донат реально
#
#  Пройти без доната реально.
#
# 1777 	class= 0
#   почему белаз последний машина маленький
#
#  Почему Белаз(последняя машина) такой маленький?
#
# 2249 	class= 0
#   очень хотеться поиграть вылетать
#
#  Очень хотелось поиграть, но вылетает
#
# 2429 	class= 0
#   отображать не_штраф нарушение пдд итог вместе р попасть р
#
#  Отображает не все штрафы на нарушение пдд. В итоге вместе 250 р. попал на 3000 р.
#
# 2443 	class= 0
#   исправить срочно срок истекать
#
#  Исправьте срочно, а то срок истекает
#
# 2907 	class= 0
#   работать
#
#  Не работает
#
# 3155 	class= 0
#   такой уродство поменяться не_листать приватный просматривать нужно менять что-то делать не_разработчик не_подумать переходить привата какой-то музыка соответственно обработка самый видео крутой не_стоить тот минус который перечислить выше
#
#  Такое уродство! Поменялось не много, но теперь нельзя листать приватное просто просматривая, а нужно его менять или что-то с этом делать. А если мне этого не надо?! Разработчики, вы не подумали?! Переходить с привата на какую-то музыку соответственно тоже нельзя. Да обработка самого видео крутая, но это не стоит тех минусов, которые я перечислила выше...
#
# 3159 	class= 1
#   убрать обновление
#
#  Как убрать обновление
#
# 3166 	class= 0
#   почему начать уменьшиться лайк внезапно
#
#  Почему начали уменьшатся лайки?
# И это вдруг внезапно
#
# 3213 	class= 1
#   восстановить приватный мюзикл
#
#  Как восстановить приватные мюзиклы
#
# 3287 	class= 0
#   я ожидать больший новый версия получить два лайк теперь музыка привить взять я жалеть обновить ходить старый версия норма
#
#  Я ожидала большего от новой версии, а получила второй «Лайк». Теперь нельзя даже музыку из привита взять! Я уже жалею что обновила! Ходила со старой версией и было норм!
#
# 3447 	class= 1
#   игра понравиться очень количество реклама перебор нафиг такой игра сидеть половина час реклама смотреть
#
#  Игра мне понравилась даже очень , но количество рекламы это уже перебор , нафиг такие игры если сидишь по пол часа рекламу смотришь
#
# 3468 	class= 0
#   весь быть игра реклама сторонний приложение
#
#  Вся суть игры реклама сторонних приложений.
#
# 3479 	class= 0
#   игра увлечь очень милый затягивать реклама выйти сделать маленький игруль рейтинг подняться
#
#  Вроде игра увлекла, очень милая и затягивает, но из-за рекламы вышла! Сделайте меньше и тогда игруля в рейтинге поднимется.
#
# 3631 	class= 0
#   достать
#
#  Достали уже
#
# 3666 	class= 1
#   игра понравиться реклама
#
#  Игра понравилась но много рекламы.
#
# 3733 	class= 0
#   обновление не_известно кто приходить сообщение появляться окошко сообщение весь пока не_зайти чат не_узнать ты написать
#
#  После обновления теперь не известно от кого приходит сообщение, появляется окошко сообщение и всё, теперь пока не зайдёшь в чаты, не узнаешь, кто тебе написал.
#
# 3919 	class= 0
#   неудобно работать контакт не_логичный интерфейс мессенджер создать общение продолжать делать соцсеть нахер читать гениальный статус
#
#  Неудобно работать с контактами не логичный интерфейс для мессенджера созданного для общения! Продолжают делать из него соцсеть! Нахера? Чтобы читать "гениальные" статусы?
#
# 4073 	class= 0
#   последний обновление вкладка показывать миниатюра не_активный сообщение приходить не_понятно кто
#
#  После последнего обновления когда вкладка «показывать миниатюры» не активна, сообщения приходят не понятно от кого!!!
#
# 4216 	class= 1
#   них- качать настолько убогий идея реализация ещё не_находить автор исковеркать быть социальный сеть опустить самый важный элемент напихать большой юмор юмор настолько убогий навсегда травмировать личность человек сделать имбицил весь сердце просить посмотреть топлёс ютуба узнать что-нибудь крутой стать человек посмотреть обзор приложение просить дерьмовый танцевать танец юмор жерьмовый перепевать песнь камера медуза котом- крутой посмотреть стендап поперечный просить
#
#  Если вы один из них- качайте. Настолько убогой идеи и реализации я ещё не находил. Авторы исковеркали суть социальной сети, опустив самые важные элементы и напихав побольше юмора. При чем этот юмор настолько убогий, что может навсегда травмировать личность человека и сделать из него имбицила. Пожалуйста, всем сердцем прошу, посмотрите Топлес на ютуб, узнайте , что-нибудь крутое, станьте людьми. Посмотрите обзоры на это приложение, прошу, их много. Это дерьмово танцевать один и тот же танец. В этом нет юмора. Это жерьмово перепевать песни( кроме Камера на медузу с котом- он крут). Посмотрите лучше стендап Поперечного, прошу
#
# 4255 	class= 1
#   подписчик долго набирать регистрироваться подписчик делать хотеть вернуть
#
#  У меня было 234 подписчика я их долго набирала! А потом когда регистрировалась у меня был 1 подписчик!!!! Что мне делать я хочу их вернуть!!!
#
# 4415 	class= 0
#   орать всратый видос приложение вк
#
#  ору со всратых видосов этого приложения в вк
#
# 4654 	class= 0
#   чисто подушить удав
#
#  Чисто для того чтобы подушить удава
#
# 4754 	class= 1
#   последний обновление куда-то деться информация доход заходить помощник расход доход месяц куда-то переехать
#
#  После последнего обновления куда-то делась информация о доходах. Заходишь в «мой помощник», расходы есть, а доходов за месяц нет. Или они куда-то «переехали»?
#
# 4783 	class= 1
#   выкидывать приложение не_мочь зайти вообще пароль не_предлагать ввести
#
#  Выкидывает из приложения, не могу зайти вообще, даже пароль не предлагает ввести
#
# 4784 	class= 1
#   вызов функция повторить платёж приложение вылетать зависать белые экран
#
#  При вызове функции «Повторить платёж» приложение вылетает или зависает с белым экраном.
#
# 5041 	class= 0
#   сделать хороший защита всякий взлом зачем звонилка
#
#  Сделайте лучше хорошую защиту от всяких взломов!!! Зачем эти звонилки
#
# 5147 	class= 0
#   сделать перевод деньга банк комиссия втб быть самый крутой
#
#  Сделайте переводы денег на другой банк   Без комиссии как на ВТБ тогда будете самые крутые
#
# 5482 	class= 0
#   мочь выйти друг прямая эфир не_друг вообще никто не_мочь пригласить
#
#  Не могу выйти с другом в прямой эфир.. и не только с другом вообще никого не могу пригласить!!!!
#
# 5663 	class= 1
#   послать
#
#  Пошли вы в...
#
# 5750 	class= 0
#   советовать лаг
#
#  Не советую, лаги
#
# 5756 	class= 0
#   молодец пацан такой приложение угробить
#
#  Молодцы пацаны, такое приложение угробили....
#
# 5849 	class= 0
#   здравствовать целое устраивать платный музыка вид приложение сделать цветовой схема который пользователь смочь менять сам
#
#  Здравствуйте, в целом все устраивает кроме платной музыки и вида приложения, может все же сделаете цветовые схемы которые пользователи смогу менять сами?
#
# 5930 	class= 0
#   добавить голосовой сообщение музыка
#
#  Добавьте голосовые сообщения и музыку на 7.1.2!!!
#
# 5943 	class= 0
#   ребята админ просить добавить тёмный тема вк
#
#  Ребята админы.
# Прошу добавьте пожалуйста тёмную тему для вк
#
# 5989 	class= 1
#   фуууа музыка платный
#
#  Фуууу музыка платная ....
#
# 6032 	class= 0
#   обновление дизайн стать откровенно блевотный приложение начать жрать память свой ебучить кеш прямо инстагра совпадение который удалить не_удалить приложение часто вылетать майла ру научиться делать удобный клиент не_такой который нравиться я не_эксперт по-моему задача пользователь приятно удобно пользоваться ваш приложение
#
#  После обновления дизайн стал откровенно блевотным. Приложение начало жрать память своим ебучим кешем (прямо как инстаграм, совпадение?..), который нельзя удалить не удалив приложение. Часто вылетает. Майл.ру, научитесь пожалуйста делать удобные клиенты, а не такие, которые нравятся вам. Я конечно не эксперт, но по-моему у вас есть задача, что бы пользователям было приятно и удобно пользоваться вашим приложением.
#
# 6056 	class= 0
#   красиво грамотно бать приложение парашка стать
#
#  Так красиво и грамотно у*бать все приложение, парашкой стало
#
# 6070 	class= 0
#   бомба
#
#  Просто бомба
#
# 6104 	class= 1
#   сегодняшний день не_видеть запись стена они другой
#
#  С сегодняшнего дня я не вижу записи на стене. Их будто нет. Не у меня, ни у других.
#
# 6116 	class= 0
#   надоесть ставить музыка пауза сворачивать приложение разворачивание начинать играть
#
#  Как же надоело, когда ставишь музыку на паузу, сворачиваешь приложение, и при разворачивании она начинает играть.
#
# 6213 	class= 0
#   приезжать ждать клиент гора очистка парковка красиво гражданин водитель
#
#  Приезжают, ждут клиента, потом гора очисток на парковке. Не красиво, граждане водители
#
# 6531 	class= 1
#   ребята чек поездка история отправить куда-нибудь смс почта др
#
#  Ребята, как чек о поездке из истории отправить куда-нибудь (смс, почта и др)?
#
# 6709 	class= 1
#   я удалить очень страшный испукалс уранил тилифон баюс очинь очинь страшный играаа
#
#  Я удалю очень страшна я испукалса и уранил тилифон я баюс очинь очинь страшная играаа
#
# 6807 	class= 1
#   версия вылетать исправить
#
#  У этой версии вылетает исправьте
#
# 6850 	class= 0
#   работать игра норма
#
#  Не работает а так то игра норм :(
#
# 7199 	class= 0
#   купить пак 75р какой-то причина не_прийти деньга списать игра крутой прийти исправить
#
#  Купил пак за 75р,он по каким-то причинам не пришёл,а деньги списали .
# А так игра крутая,как придёт - исправлю.
#
# 7356 	class= 1
#   сделать увеличение уменьшение фото двойной тап заблокировать экран переход приложение свайп не_отображаться получить сообщение
#
#  1. Сделайте, пожалуйста, увеличение/уменьшение фото двойным тапом.
# 2. С заблокированного экрана, при переходе в приложение свайпом, не отображаются полученные сообщения.
#
# 7437 	class= 0
#   рассадник разный род жулик идиот сделать посмотреть весь продавать человек
#
#  Рассадник для разного рода жуликов. Плюс идиоты сделали, чтобы можно было посмотреть всё что продает человек.
#
# 7704 	class= 0
#   сделать поиск недвижимость карта мобильный приложение сразу весь стать лёгкий искать необходимый
#
#  Сделайте пожалуйста поиск недвижимости по карте в мобильном приложении. Сразу всем станет легче искать необходимое.
#
# 7734 	class= 1
#   очень клевый не_портиться носить половина год
#
#  Очень клевые и не портятся, ношу уже почти пол года ??
#
# 7976 	class= 0
#   пока ещё не_пришлый
#
#  Пока ещё ничего не пришло...
#
# 7991 	class= 0
#   весь отлично начаться проблема заказ
#
#  Все отлично , лишь только начались проблемы с заказами ..
#
# 8031 	class= 1
#   цена очень дешёвый
#
#  цены очень дешевы
#
# 8060 	class= 1
#   долгий доставка
#
#  Долгая доставка
#
# 8127 	class= 0
#   супер
#
#  Супер
#
# 8422 	class= 1
#   один проблема гореть аду
#
#  От вас одни проблемы !!! Горите в аду
#
# 8533 	class= 1
#   ребята частый обновлять скидывать моросить продолжать
#
#  Ребят почаще обновляли скидывайте, а то моросить продолжает
#
# 8728 	class= 0
#   обновление шазам простой очень нравиться он прикрутить столько не_нужный фигня не_понятно бесить листать свой шазам год четыре назад приложение решать прогрузиться весь заново
#
#  До обновления когда шазам был простым он очень мне нравился,сейчас к нему прикрутили столько не нужной мне фигни что не понятно что где! Бесит когда ты листаешь свои шазамы года три/четыре назад и приложение решает прогрузиться и всё заново.
#
# 8753 	class= 1
#   добрый время сутки уже год любить шазам постоянно пользоваться последний время перестать распознавать песнь подводить телефон радио играть известный песня высвечиваться нет результат нет совпадение исправить
#
#  Доброго времени суток! Уже много лет люблю Шазам и постоянно им пользуюсь.
# Последнее время перестал распознавать песни. Подвожу телефон к радио, где играет известная песня, а высвечивается «Нет результатов. Нет совпадений». Как это можно исправить?
# Спасибо!
#
# 8788 	class= 1
#   исправить ошибка проигрываться музыка секунда просить вернуть возможность прослушивать законный секунда свой песнь подряд не_заходить каждый
#
#  Спасибо, что исправили ошибку, когда на проигрывалась музыка по 30 секунд! Прошу сейчас верните возможность прослушивать по 30 законных секунд все свои песни подряд, а не заходя в каждую! Спасибо!!
#
# 8889 	class= 0
#   крутой55555
#
#  Крутой55555
#
# 9007 	class= 0
#   починить плиз
#
#  Почините плиз
#
# 9037 	class= 0
#   писать очередь оттуда избавить
#
#  Пишет что в очереди. Как ее оттуда избавить?
#
# 9061 	class= 1
#   весь запускаться приложение очень долго
#
#  Всё хорошо , но запускается  приложение очень долго ((( это минус !
#
# 9085 	class= 0
#   находить самый популярный песня
#
#  Находит 1 из 20 даже самых популярных песен....
#
# 9166 	class= 1
#   реально вековой приложение
#
#  Реально вековое приложение!)
#
# 9923 	class= 1
#   где голосовать
#
#  Где голосовать?
#
# 10068 	class= 1
#   сделать карта свободный езда твёрдый
#
#  Сделайте карту с свободной ездой! А так все хорошо, твёрдые 8/10!
#
# 10101 	class= 1
#   найтись весь выгодный цена приходить заказать товар тот который прислать указанный срок дарить что-то
#
#  Найдётся всё, по выгодной цене. Приходят все заказанные товары, а те которые пришли после указанного срока дарят!) это что-то) спасибо
#
# 10130 	class= 1
#   товар не_приходить установленный срок деньга реально возвращать проверить
#
#  Если товар не приходит в установленные сроки деньги реально возвращают, проверено ?
#
# 10146 	class= 1
#   выиграть акция угадать цена
#
#  Выиграл в акции угадай цену !!!
#
# 10164 	class= 1
#   нравиться очень делать заказ не_прийти казать срок деньга сразу вернуть истечение некоторый срок заказ прийти хотеть повторно оплатить сразу ответить не_нужно указанный время не_доставить вино вещь подарок очень нравиться данный приложение
#
#  Нравится очень , делала заказ , не пришёл в казанный срок. Деньги сразу вернули . По истечении некоторого срока заказ все же пришёл . Хотела повторно оплатить , сразу ответили , что не нужно. И так как в указанное время не доставили это уже их вина и вещь в подарок . Спасибо , очень нравится данное приложение
#
# 10270 	class= 0
#   заказать вещий не_один не_дошлый день рекомендовать
#
#  Заказал три вещи и не одна не дошла за 60 дней. Не рекомендую
#
# 10278 	class= 1
#   уже идти день отслеживание видеть вопрос получить данный товар
#
#  Уже идёт 58 день, нет отслеживания, и вижу вопрос «вы получили данный товар?»
#
# 10355 	class= 1
#   один заказ не_получить день вернуть деньга заказ прийти 90-ый день написать разработчик желание оплатить повторно получить ответ ваш заказ не_доставить срок произвести возврат полный стоимость повторно принять оплата товар не_мочь получить товар окончание срок доставка считать небольшой подарок длительный ожидание круто
#
#  Один заказ не получил за 75 дне, вернули деньги, заказ всё-таки пришел на 90-ый день, написал разработчику с желанием оплатить повторно, на что получил ответ: "Так как ваш заказ не был доставлен в срок, мы произвели возврат его полной стоимости. Повторно принять оплату за товар мы не можем. Если вы получите товар по окончании срока доставки, считайте его небольшим подарком от нас за длительное ожидание."
# Круто!!!
#
# 10447 	class= 0
#   заказ шесть прислать
#
#  Только два заказа из шести пришли
#
# 11042 	class= 1
#   недавний обновление начать лагать жутко исправить
#
#  После недавнего обновления начало лагать жутко. Исправьте это пожалуйста!
#
# 11165 	class= 1
#   мочь посмотреть история поездка календарь нужно посмотреть конкретный дата август нажимать число открываться последний месяц май
#
#  Не могу посмотреть историю поездок из календаря. Нужно посмотреть конкретную дату за август 2017, нажимаю на число, а открывается последний месяц (май 2018) :((
#
# 11171 	class= 1
#   вообще не_показывать навигатор стоить один место
#
#  вообще не показывает навигатор стоит на одном месте
#
# 11195 	class= 0
#   теперь время не_найти дорога
#
#  Теперь все время не может найти дорогу
#
# 11206 	class= 1
#   добрый день просьба включить приложение яндекс навигатор москва знак том грузовой каркас ехать грузовой авто свыше том планировать маршрут ездить не_нарушать правило пдд
#
#  Добрый день. Просьба , включить в приложения яндекс навигатор , для Москвы , знак 2.5 т. Грузовой каркас. Чтоб можно было тем кто едет на грузовом авто свыше 2.5 т, планировали маршруты там где им можно ездить и не нарушали правила ПДД. Спасибо
#
# 11356 	class= 1
#   обновить приложение айпада матерь уехать загород звонить кричать алиса появиться не_работать нажимать голосовой поиск чёрный экран приехать разобраться проблема обидный создаться такой ситуация ровный место дополнение подглючивать алиса ответ
#
#  Обновил приложение на айпаде матери. Уехала загород. Звонит мне и кричит, что какая то Алиса появилась и ничего не работает. Нажимает голосовой поиск и черный экран.
# Как приедет разберусь в чем проблема, но обидно что создалась такая ситуация на ровном месте.
#
# Дополнение: Подглючивает Алиса, но спасибо за ответ.
#
# 11551 	class= 0
#   последний обновление уменьшиться указатель поворот время пробка неудобно особенно указатель зачем выделить ограничение скорость текущий скорость спидометр знак скорость дорога метр повернуть налево дорога не_показывать просить увеличить указатель время пожелание- сделать возможность отказываться предложить маршрут принудительный поиск альтернативный маршрут отменить тупо предложить мало
#
#  После последнего обновления уменьшились указатели поворота, время и пробки. Неудобно, особенно указатели. Зачем так выделили ограничение скорости и текущую скорость? У нас и так есть спидометр и знаки скорости на дорогах, а вот через сколько метров повернуть налево дорога не показывает. Прошу увеличить хотя бы указатели и время!
# А также пожелание- пожалуйста, сделайте возможность отказываться от предложенного маршрута и принудительного поиска альтернативного маршрута вместо отмененного. Ведь тупо предложить 3 маршрута-это мало.
#
# 11872 	class= 0
#   автор очень не_обычный хороший игра затягивать практический игра этот реклама заставлять удалить игра пара день убрать рамка низ реклама сам реклама народ стать играть весь привязаться реклама
#
#  Автор с очень не обычными и хорошими играми. Затягивают практический все игры!! Но.? Эти рекламы заставляют удалить игру через пару дней...
# Уберите рамку в низу рекламы и саму  рекламу и народ станет играть больше.
# Все привязались к этой рекламе!!!!
#
# 11877 	class= 0
#   игра норма
#
#  Игра норм
#
# 12035 	class= 0
#   один реклама игра отстой
#
#  Одна реклама. Игра отстой
#
# 12059 	class= 0
#   отключать интернет телефон запуск игра
#
#  ОТКЛЮЧАЙТЕ ИНТЕРНЕТ НА ТЕЛЕФОНЕ перед запуском игры!
#
# 12099 	class= 0
#   сам компания хороший курьер красавчик вид бонус промокод заказать паперонить сантиметр промокод привезти оплатить открывать колбаса нижний слой тест подгореть итальянский сантиметр рубль нормальный норма подгореть тесто немного гавайский ранний заказывать отличный пицца заказать сегодня привезти пересушить пицца начинка печь пересушить итог заказ номер доставка привезти мина ранний сумма заказ рубль
#
#  Сама компания хорошая,Курьеры красавчики.
# Но виде бонуса по промокоду заказал
# Паперони 25 см по промокоду привезли оплатил открываю колбаса и нижний слой теста подгорел.
# Итальянская 35 см 692 руб нормальная все норм но подгорела тесто немного.
# Гавайская раньше заказывал было хорошо отличная пицца Заказала сегодня
# Привезли пересушенную пиццу начинку в печи пересушили.
# Итог 3/3 Заказ номер 260 доставку привезли за 30 мин раньше.
# Сумма заказа 1300 руб.
#
# 12103 	class= 0
#   действовать ваш промкод
#
#  Не действует ваш промкод 808
#
# 12168 	class= 1
#   ребята вы приложение городок железногорск пригород красноярск красноярск город который проживать миллион человек жалко хотеться попробовать ваш пицца протестировать приложение нацелить вы красноярск скоро
#
#  Ребята, у Вас в приложении есть такой городок, как Железногорск (пригород Красноярска), а вот Красноярска, города в котором проживает более миллиона человек нет. Жалко, хотелось бы попробовать Вашу пиццу и протестировать приложение. Нацелены ли Вы на Красноярск и если да, то как скоро?
#
# 12203 	class= 0
#   доставка дать организация работать отказываться вообще товар отличный
#
#  Доставка данной организации работать похоже отказывается вообще, а так товары у вас отличные
#
# 12350 	class= 1
#   что-то невероятный доставка минута 15-20 момент заказ весь очень вкусно огромный
#
#  Это что-то невероятное! Доставка была спустя минут 15-20 с момента заказа! Все очень вкусно! Спасибо огромное!
#
# 12403 	class= 0
#   пиздабола
#
#  Пиздаболы
#
# 12405 	class= 0
#   закончиться картоха
#
#  Закончилась картоха
#
# 12496 	class= 0
#   проверить адрес москва никуда не_доставлять удалить приложение
#
#  Проверили 3 адреса по Москве - никуда не доставляют! Удалили приложение
#
# 12606 	class= 0
#   постоянно игра перекидывать апп стор
#
#  Постоянно в игре перекидывает в апп стор
#
# 12870 	class= 1
#   качать один реклама
#
#  Не качайте, одна реклама!!!
#
# 12972 	class= 1
#   реклама
#
#  Минус только реклама
#
# 13304 	class= 0
#   заходить приложение телефон сразу отключаться
#
#  Захожу в приложение и телефон сразу отключается хоть там 100%
#
# 13431 	class= 0
#   вернуть обратно функция сохранять фото видео фотоплёнка айфон
#
#  Верните обратно функцию чтоб можно было сохранять фото и видео в фотопленку на айфоне ??
#
# 13580 	class= 1
#   весь есдить не_работать вернуть нефига покупать китайский телефон приложение хорошоя
#
#  Все хорошо.есди не работает то верните себя.ибо нефиг покупать китайские телефоны с али.а так приложение хорошое
#
# 13592 	class= 0
#   жить крым пытаться переключить писать такой место не_существовать кидать краснодар збс
#
#  Живу в Крыму а когда пытаюсь переключить то пишет что такого места не существует и кидает на Краснодар ... збс.
#
# 13688 	class= 0
#   закрывать наш вакансия объясненить причина вакансия полностью соответствовать правило законодательство рф
#
#  Закрывают наши вакансии без объяснени причин, хотя вакансия полностью соответствует правилам и законодательству РФ
#
# 13728 	class= 0
#   вообще никакой вакансия
#
#  Вообще нет никаких вакансий.
#
# 14041 	class= 1
#   добрый день программа нравиться очень часто вылетать подвисать
#
#  Добрый день . Программа нравится . Но Очень Часто вылетает и подвисает .
#
# 14177 	class= 1
#   пользоваться регулярно
#
#  Пользуюсь регулярно!
#
# 14500 	class= 1
#   работать режим навигатор фоновый режим
#
#  Не работает в режиме навигатора в фоновом режиме!
#
# 14681 	class= 1
#   ваш приложение не_давать потеряться
#
#  Спасибо вам за то, что ваше приложение не даёт мне потеряться:)
#
# 14694 	class= 1
#   почему список город ялта
#
#  Почему в списке городов нет Ялты?
#
# 15252 	class= 1
#   восстановить пароль работать отлично
#
#  Спасибо, что восстановили пароль! Работает всегда отлично!
#
# 15265 	class= 1
#   быстрый переключение почтовый ящик не_продуманно один картинка сложно общий папка входящая отсутствовать остальной приложение хороший
#
#  Быстрое переключение между почтовыми ящиками не  продуманно. По одним картинкам сложно . Общая папка для всех входящих отсутствует. В остальном приложение хорошее.
#
# 15342 	class= 1
#   добавить нормальный чёрный список версия браузер иной отправитель не_мочь написать письмо сразу попадать не_спам не_корзина вообще не_приходить ставить звезда автомат
#
#  Когда вы уже добавите нормальный черный список, как в версии с браузера??? Чтоб тот, или иной отправитель не мог написать, но и письма его сразу попадали не в спам, и не в корзину, а вообще не приходили? Ставлю 5 звезд автоматом...
#
# 15380 	class= 1
#   сообщение сортироваться легко отказаться рассылка сторонний компания
#
#  Здорово, что сообщения сортируются и так легко можно отказаться от рассылок сторонних компаний.
#
# 15777 	class= 0
#   почему видио не_грузиться зайцев
#
#  Почему видио не грузиться через зайцев?
#
# 15850 	class= 1
#   отличие программа зуб давать пацан успеть качать
#
#  Отличие программа зуб даю пацаны ???? только успейте качать !!!!
#
# 15891 	class= 0
#   скачать музыка вк
#
#  Как скачать музыку с вк?
#
# 16078 	class= 0
#   добрый вечер последний неделя возникать проблема построение маршрут авто адрес закладка писать не_удаться построить маршрут инуть работать скорость
#
#  Добрый вечер. В последнюю неделю возникает проблема с построением маршрута на авто до адреса в закладках. Пишет не удалось построить маршрут!! Инет работает скорость более 100.
#
# 16142 	class= 0
#   весь супер гуд прекрасный момент прошлый не_приложение напросто закрываться повторный удаление перезагрузка аппарат не_помогать фак
#
#  Всё было супер гуд!  Но в один прекрасный момент прошло что то не так…приложение просто напросто закрывается....ни повторное удаление, ни перезагрузка аппарата не помогают....фак!
#
# 16211 	class= 1
#   сделать маршрут сбрасывать ориентация карта возвращаться автоматически север верх
#
#  Пожалуйста сделайте, чтобы после того как маршрут сбрасываю, что бы ориентация карты возвращалась автоматически север верху. :)
#
# 16535 	class= 1
#   смысл показывать балл пробка минута ехать домой работа далёкий мочь пользоваться это приложение
#
#  Так а в чем смысл? У меня показывает только сколько баллов пробки, и сколько минут ехать домой и на работу? А дальше? Как я могу пользоваться этим приложением?
#
# 16548 	class= 1
#   будт добрый сделать приложение стабильно работать территория украина я понимать проблема связать поисковый система маил ру сделать приложение украина работать довольный
#
#  Будте добры, сделайте чтоб приложение стабильно работало на территории Украины. Я понимаю, что проблема связана с поисковой системой, но вот Маил ру сделал приложение для Украины, все работает и все довольны.
#
# 16644 	class= 1
#   хотеться видеть музыка количество скатить минута не_удобно смотреть сначала показывать мина каждый день музыка качать
#
#  Хотелось бы видеть сколько музыки по количеству скачено , в минутах не удобно смотреть и сначала он показывал 947 мин потом 935 ,а сейчас 907 ,хотя я каждый день музыку качаю
#
# 16825 	class= 0
#   скачивать музыка фоновый прослушок не_воспроизводить новое добавить писать дело интернет интернет нормальный исправить
#
#  Не скачивает музыку для фоновой прослушки и не воспроизводит новые добавленные. Пишет дело в интернете. Но с интернетом все нормально!!!! Исправьте уже, ну!!!
#
# 16930 	class= 0
#   пересесть сегодня пятёрка семёрка обычно скачать вк бум заходить приложение авторизоваться вк появляться белый экран загрузка первоначальный состояние авторизация вк ок
#
#  пересел сегодня с пятёрки на семерку
# как обычно скачал вк и бум
# как только заходишь в приложение и авторизуешься через вк - появляется белый экран с загрузкой и просто то же первоначальное состояние «авторизация ВК/ОК»
#
# 17105 	class= 0
#   дерьмоприложение работать кома
#
#  Дерьмоприложение работающие только благодаря тем, кому за 50
#
# 17259 	class= 0
#   исчезнуть комментарий фото весь тупить
#
#  Исчезли комментарии под фото! Все тупит
#
# 17622 	class= 0
#   теперь вообще музыка нормальный не_послушать
#
#  Теперь вообще музыку нормально не послушать
#
# 17764 	class= 0
#   месяц бесплатно хотеть попробовать послушать простой выскакивать листок надпись скачивать музыка слушать музыка тд полоска слушать музыка наполняться зелёный весь нечего не_звучать
#
#  1 месяц бесплатно я хочу попробовать послушать проста выскакивает листок с надписями скачивайте музыку,слушайте музыку и тд.просто полоска под слушайте музыку наполняется зелёным и всё нечего не звучит!!!!!
#
# 17822 	class= 1
#   не_песнь находить почему название не_находить нужно обязательно мой артист писать искать хороший
#
#  Но не все песни находит... почему по названию не находит ,а нужно обязательно по моему артиста писать и искать ... а так хорош
#
# 17891 	class= 1
#   почему-то два день подряд не_работать поиск проблема интернет
#
#  Но почему-то уже второй день подряд не работает поиск, проблем с интернетом нет
#
# 17902 	class= 0
#   почему контакт песня получаться найти нужный песня добавить максимум
#
#  Почему в контакте больше песен чем здесь ? Не получается найти нужную песню, добавьте до максимуму !
#
# 17908 	class= 0
#   ало куда топить
#
#  Ало ? Куда вы так топите ?
#
# 18172 	class= 1
#   игра вообще не_открываться
#
#  игра вообще не открывается
#
# 18338 	class= 1
#   работать ровно
#
#  Работает ровно..
#
# 18359 	class= 0
#   вздумать качать куча бесплатный аналог хороший производительность
#
#  НЕ ВЗДУМАЙТЕ КАЧАТЬ ЕСТЬ КУЧА БЕСПЛАТНЫХ АНАЛОГОВ С ЛУЧШЕЙ ПРОИЗВОДИТЕЛЬНОСТЬЮ!!!
#
# 18409 	class= 1
#   реклама не_мешать соединение стабильный неделя пользоваться прекрасно
#
#  Реклама не мешает, соединение стабильное, 2 недели пользуюсь прекрасно. Спасибо
#
# 18410 	class= 0
#   сразу не_писать
#
#  Сразу не пишут, что 850?
#
# 18701 	class= 0
#   я думать фейсбук нереально сделать ещё неюзабельный справиться вслед ещё купить убить инстагра
#
#  Я думал, что фейсбук уже нереально сделать ещё более неюзабельным. Но они справились.
# А вслед за тем ещё купили и убили Инстаграм.
#
# 18866 	class= 0
#   капец
#
#  ?капец
#
# 18986 	class= 0
#   пропасть звук видео обновиться бог
#
#  Пропал звук видео, обновились как боги...
#
# 19367 	class= 1
#   игра не_запускаться
#
#  Игра не запускается
#
# 19661 	class= 0
#   сабж
#
#  сабж
#
# 20019 	class= 0
#   поддержка мы понимать должный неудобно яндекс отличный работа убивать далёкий приложение основный конкурент удачный сделка
#
#  В поддержке говорят «Мы понимаем, как это должно быть неудобно»
#
# Яндекс, отличная работа!!!! Убивайте дальше приложение основного конкурента, удачная сделка!
#
# 20042 	class= 1
#   последний время водитель часто отменять заказ
#
#  Последнее время водители часто отменяют заказы. А так все хорошо
#
# 20342 	class= 0
#   мучиться несколько год это тормозной интерфейс не_предполагать качественный альтернатива перейти яндексовский
#
#  Мучался несколько лет с этим тормозным интерфейсом, даже не предполагая, что есть качественная альтернатива. Перешел на яндексовский.
#
# 20775 	class= 0
#   приложение забронировать не_мочь писать не_существовать поездка
#
#  Что с приложением, ничего забронировать не могу, пишет, что не существует поездки.
#
# 20792 	class= 0
#   приходить смс код подтверждение
#
#  Не приходит смс с кодом подтверждения.
#
# 20944 	class= 0
#   очень коммерческий перевозка приложение
#
#  Очень много коммерческих перевозок в приложении
#
# 21096 	class= 1
#   нажимать отправить сообщение особенно один это пассажир писать отсутствовать строка ввод текст внизу дико неудобно просить исправить
#
#  Нажимаешь «Отправить сообщение» - особенно если в первый раз этому пассажиру пишешь - иногда отсутствует строка для ввода текста внизу.
# Дико неудобно, прошу исправить.
#
# 21099 	class= 1
#   неделя два назад писать приложение постоянно требовать ввести логин пароль пользовиться невозможно сейчас стать весь отлично знать думать исправить
#
#  Недели две назад писал о том, что приложение постоянно требуют ввести логин и пароль. Пользоватся было невозможно. Сейчас стало всё отлично. Не знаю уж как но думаю что они исправили
#
# 21366 	class= 0
#   видео не_воспроизводить идти звук работать картинка не_двигаться не_понимать причина
#
#  Видео не воспроизводит. Идёт звук, все работает, а картинка не двигается, не понимаю в чем причина
#
# 21663 	class= 1
#   я очень нравиться долго искать приложение брат посоветовать нравиться оно бесплатный предисловие скачать один приложение не_быть говорить какой восстановить свой покупка не_водянка знак не_убраться музыка не_открыться деньга вернуть быть пользоваться продолжать дух не_забывать приложение обновлять огромный
#
#  Мне очень нравится. Долго искала это приложение, брат посоветовал! Нравится то, что оно бесплатное.
# Предисловие: скачала одно приложение(не буду говорить какое), восстановила все свои покупки, и не водянок знак не убрался, музыка не открылась(Деньги вернули)
#
# Буду пользоваться!!! Продолжайте в том же духе, не забывайте про приложение( обновляйте его)! Спасибо огромное
#
# 22207 	class= 0
#   рынок садовод загонять барахло
#
#  Как будто с рынка Садовод загоняют барахло:)
#
# 22234 	class= 0
#   цена старый модель кроссовок 7к магазин 2500-3000
#
#  Цена за старую модель кроссовок 7к в магазине 2500-3000?
#
# 22312 	class= 0
#   я пользоваться приложение год пара год очень активно заработать скидка нахватать нооооо очень разочаровать балл стать уходить невероятный скорость год не_слишком активный покупка остаться свой платиновый бриллиантовый скидка том е балл не_фиксироваться скидка сохраниться нужно заказывать постоянно невероятный скорость теперь пропасть желание
#
#  Я пользуюсь приложением около 3 лет.Пару лет очень активно и уже заработала скидку 15% и чуть чуть нахватало до 20% НООООО
# я была очень разочарована, когда баллы стали уходить в минус с такой невероятной скоростью, что я за год не слишком активных покупок осталась без своей платиновой и почти бриллиантовой скидки. Т.е баллы не фиксируются!!!!чтоб скидка сохранилась, нужно заказывать постоянно и с невероятной скоростью!!! Теперь просто даже пропало желание((((
#
# 22415 	class= 0
#   приобретать магазин товар отправлять не_который заказывать вернуть товар нереально надо день минимум потерять
#
#  Не приобретайте в этом магазине. Товар отправляют не тот который заказываешь. Вернуть товар. Нереально. Надо день минимум потерять.
#
# 22430 	class= 1
#   пара покупка делать ламода сервис примерка доставка отменный единственный последний время напрягать обилие реклама вечер включать ребёнок мультик ютуба не_включаться пока ваш реклама не_пройти мочь исключить контент ваш реклама показывать думать ребёнок пойти покупка
#
#  Пару покупок делал в ламоде, сервис с примеркой и Доставкой отменный.
# Единственное что в последнее время напрягает обилие рекламы, по вечерам включаю ребёнку мультики на ютубе, а они не включаются пока ваша реклама не пройдёт, вы же можете исключить контент где вашу рекламу показывают, неужели правда думаете что дети пойдут за покупками к вам.
#
# 22431 	class= 0
#   ценник не_гуманный распродажа фиктивный
#
#  Ценник не гуманный, распродажи фиктивные
#
# 22479 	class= 0
#   весь обувь китайский подделка минута развалиться кроссовок покупать возврат делать очень сложно
#
#  Вся обувь китайская подделка, через 15 минут развалились кроссовки!!! Не покупайте у них ничего! Возврат делать очень сложно !

# %% [markdown]
# Считываем словарь тональностей из файла

# %%
sent = pd.read_csv('words_sent.csv', sep=';', header=None, names =['word', 'sent', '1', '2', '3'])

# %%
Dict = sent.groupby('word')['sent'].mean().to_dict()

# %%
tone = np.zeros((len(norm_texts_neg), 4))

# %%
Dict.get('ужасный', 0)
# Out:
# -1.25

# %% [markdown]
# Определяем общее значение тональности по словарю

# %%
# нормальзованное значение тональности
for i, text in enumerate(norm_texts_neg_splitted):
    count = 0
    for j, word in enumerate(text):        
        neg = False
        if (word.startswith("не_")):
            s = Dict.get(word[3:], 0)
            neg = True
        else:
            s = Dict.get(word, 0)

        if s != 0:
            count += 1
            if (neg):
                tone[i, 0] += -s
            else:
                tone[i, 0] += s
    if count:
        tone[i, 0] = tone[i, 0]/count

# %%
tone = tone - tone.min()
tone = tone /tone.max()

# %%
from scipy import sparse

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0].reshape(tone[:, 0].shape[0], 1))))

# %%
scores1_tone_dict_norm = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_tone_dict_norm = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_tone_dict_norm = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_tone_dict_norm = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_tone_dict_norm = pd.DataFrame({
    "SVM" : scores1_tone_dict_norm.mean(),
    "Random forest" : scores2_tone_dict_norm.mean(),
    "Linear regression" : scores3_tone_dict_norm.mean(),
    "Naive Bayes" : scores4_tone_dict_norm.mean()
})

scores_tone_dict_norm
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 2.969158     0.024218       2.968919  0.596708
# score_time               0.007005     0.012209       0.121866  0.032284
# test_accuracy            0.785286     0.859247       0.830761  0.827142
# test_f1                  0.794715     0.860316       0.829253  0.834910
# test_precision           0.779402     0.873836       0.857548  0.818445
# test_recall              0.812532     0.848437       0.803712  0.853727

# %%
#class_result_svm = class_result_svm.append(pd.Series(metr1, name="+ тональный словарь"))
#class_result_rf = class_result_rf.append(pd.Series(metr2, name="+ тональный словарь"))
#class_result_lr = class_result_lr.append(pd.Series(metr3, name="+ тональный словарь"))

#print("---svm---", class_result_svm)
#print("---lr---", class_result_rf)
#print("---rf---", class_result_lr)

# %%
tone = np.zeros((len(norm_texts_neg), 4))

# общее значение тональности
for i, text in enumerate(norm_texts_neg_splitted):
    count = 0
    for j, word in enumerate(text):  
        neg = False
        if (word.startswith("не_")):
            s = Dict.get(word[3:], 0)
            neg = True
        else:
            s = Dict.get(word, 0)

        if s != 0:
            count += 1
            if (neg):
                tone[i, 0] += -s
            else:
                tone[i, 0] += s

# %%
for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()
# Out:
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()

# %%
tone
# Out:
# array([[ 0.59982639,         nan,         nan,         nan],
#        [ 0.53819444,         nan,         nan,         nan],
#        [ 0.49045139,         nan,         nan,         nan],
#        ...,
#        [ 0.48487103,         nan,         nan,         nan],
#        [ 0.51215278,         nan,         nan,         nan],
#        [ 0.47743056,         nan,         nan,         nan]])

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0].reshape(tone[:, 0].shape[0], 1))))

# %%
scores1_tone_dict = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_tone_dict = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_tone_dict = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_tone_dict = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_tone_dict = pd.DataFrame({
    "SVM" : scores1_tone_dict.mean(),
    "Random forest" : scores2_tone_dict.mean(),
    "Linear regression" : scores3_tone_dict.mean(),
    "Naive Bayes" : scores4_tone_dict.mean()
})

scores_tone_dict
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.652374     0.014812       2.800392  0.463330
# score_time               0.006004     0.007404       0.097473  0.005603
# test_accuracy            0.785350     0.860603       0.831214  0.828887
# test_f1                  0.794584     0.862660       0.830891  0.836319
# test_precision           0.780579     0.869983       0.853208  0.821098
# test_recall              0.810893     0.856626       0.810893  0.853854

# %% [markdown]
# Ненормализованная разметка тональности работает лучше

# %%
# количество слов

for i, text in enumerate(norm_texts_neg_splitted):
    tone[i, 1] = len(text)

for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0:1])))

scores1_words_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_words_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_words_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_words_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_words_num = pd.DataFrame({
    "SVM" : scores1_words_num.mean(),
    "Random forest" : scores2_words_num.mean(),
    "Linear regression" : scores3_words_num.mean(),
    "Naive Bayes" : scores4_words_num.mean()
})

scores_words_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.602367     0.013811       2.873649  0.418304
# score_time               0.006805     0.007005       0.097262  0.005400
# test_accuracy            0.785350     0.860603       0.834766  0.828887
# test_f1                  0.794584     0.862660       0.833072  0.836319
# test_precision           0.780579     0.869983       0.863143  0.821098
# test_recall              0.810893     0.856626       0.806230  0.853854

# %% [markdown]
# Признак ухудшает качество классификации для метода Случайного леса, для остальных не меняет - плохой признак, не будем включать

# %%
#class_result_svm = class_result_svm.append(pd.Series(metr1, name="+ количество слов"))
#class_result_rf = class_result_rf.append(pd.Series(metr2, name="+ количество слов"))
#class_result_lr = class_result_lr.append(pd.Series(metr3, name="+ количество слов"))

#print("---svm---", class_result_svm)
#print("---lr---", class_result_rf)
#print("---rf---", class_result_lr)

# %% [markdown]
# Считаем количество восклицательных знаков

# %%
initial_revs.drop(initial_revs.index.difference(revs_norm_neg.index), inplace=True)
initial_revs['rating'] = revs_norm_neg['rating']

for i, text in enumerate(initial_revs.content):
    num = 0
    for e in text:
        if e == '!':
            num += 1
            #tone[i, 1] = 1
    tone[i, 1] = num

# %%
for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0:1])))

scores1_excl_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_excl_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_excl_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_excl_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_excl_num = pd.DataFrame({
    "SVM" : scores1_excl_num.mean(),
    "Random forest" : scores2_excl_num.mean(),
    "Linear regression" : scores3_excl_num.mean(),
    "Naive Bayes" : scores4_excl_num.mean()
})

scores_excl_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.545591     0.013610       2.812409  0.378866
# score_time               0.006200     0.006204       0.098070  0.005203
# test_accuracy            0.785350     0.860603       0.829792  0.828887
# test_f1                  0.794584     0.862660       0.829031  0.836319
# test_precision           0.780579     0.869983       0.853134  0.821098
# test_recall              0.810893     0.856626       0.807238  0.853854

# %% [markdown]
# норм, оставим

# %% [markdown]
# Считаем количество глаголов в повелительном наклонении (встречаются часто в отрицательных отзывах)

# %%
def getImperatives(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = 0
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        if (lexInfo.tag.POS == 'VERB'):
            if (lexInfo.tag.mood == 'impr'):
                ans += 1
    if (ans > 0):
        return ans
    else:
        return 0
    return ans

initial_revs['imps'] = [getImperatives(line) for line in initial_revs.content]

# %%
tone[:,2] = list(initial_revs['imps'])

for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0:2])))

scores1_imper_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_imper_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_imper_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_imper_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_imper_num = pd.DataFrame({
    "SVM" : scores1_imper_num.mean(),
    "Random forest" : scores2_imper_num.mean(),
    "Linear regression" : scores3_imper_num.mean(),
    "Naive Bayes" : scores4_imper_num.mean()
})

scores_imper_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.729225     0.015011       2.859234  0.451121
# score_time               0.006604     0.007205       0.098474  0.005204
# test_accuracy            0.784122     0.860603       0.833926  0.828757
# test_f1                  0.793152     0.862660       0.832450  0.836255
# test_precision           0.779903     0.869983       0.860616  0.820732
# test_recall              0.808752     0.856626       0.807365  0.854106

# %% [markdown]
# вроде норм

# %% [markdown]
# Считаем количество вопросительных слов. Встречаются в негативных отзывах ("Пропала кнопка вызова. Где её найти?!?!")

# %%
interrogative_words = ["где", "как", "зачем", "почему", "какой"]

for i, text in enumerate(norm_texts_neg_splitted):
    count = 0
    for j, word in enumerate(text):        
        if (word in interrogative_words):
            count += 1
    tone[i, 3] = count

# %%
for i in range(tone.shape[1]):
    tone[:, i] = tone[:, i] - tone[:, i].min()
    tone[:, i] = tone[:, i] /tone[:, i].max()

# %%
cvect_uni_bi_neg.shape
# Out:
# (15481, 10000)

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0:3])))

scores1_interr_num = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_interr_num = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_interr_num = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores4_interr_num = pd.DataFrame(cross_validate(clf_nb, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores_interr_num = pd.DataFrame({
    "SVM" : scores1_interr_num.mean(),
    "Random forest" : scores2_interr_num.mean(),
    "Linear regression" : scores3_interr_num.mean(),
    "Naive Bayes" : scores4_interr_num.mean()
})

scores_interr_num
# Out:
#                 Linear regression  Naive Bayes  Random forest       SVM
# fit_time                 1.615555     0.015203       2.901427  0.535787
# score_time               0.006796     0.007614       0.097271  0.005403
# test_accuracy            0.785220     0.860862       0.828242  0.827982
# test_f1                  0.794355     0.862845       0.828167  0.835610
# test_precision           0.780543     0.870643       0.848491  0.819692
# test_recall              0.810516     0.856374       0.810010  0.853854

# %%
scores_uni_bi_neg['SVM']
# Out:
# fit_time          0.418501
# score_time        0.005004
# test_accuracy     0.827078
# test_f1           0.834857
# test_precision    0.818336
# test_recall       0.853727
# Name: SVM, dtype: float64

# %%
result_metrics_svm = pd.DataFrame({
    "1 + обработка отрицаний" : scores_uni_bi_neg['SVM'],
    "2 + словарь тональности" : scores_tone_dict['SVM'],
    "3 + количество восклицательных знаков" : scores_excl_num['SVM'],
    "4 + количество глаголов в повел. накл." : scores_imper_num['SVM'],
    "5 + количество вопросительных слов" : scores_interr_num['SVM']
    
})

result_metrics_svm
# Out:
#                 1 + обработка отрицаний  2 + словарь тональности  \
# fit_time                       0.418501                 0.463330
# score_time                     0.005004                 0.005603
# test_accuracy                  0.827078                 0.828887
# test_f1                        0.834857                 0.836319
# test_precision                 0.818336                 0.821098
# test_recall                    0.853727                 0.853854
#
#                 3 + количество восклицательных знаков  \
# fit_time                                     0.378866
# score_time                                   0.005203
# test_accuracy                                0.828887
# test_f1                                      0.836319
# test_precision                               0.821098
# test_recall                                  0.853854
#
#                 4 + количество глаголов в повел. накл.  \
# fit_time                                      0.451121
# score_time                                    0.005204
# test_accuracy                                 0.828757
# test_f1                                       0.836255
# test_precision                                0.820732
# test_recall                                   0.854106
#
#                 5 + количество вопросительных слов
# fit_time                                  0.535787
# score_time                                0.005403
# test_accuracy                             0.827982
# test_f1                                   0.835610
# test_precision                            0.819692
# test_recall                               0.853854

# %%
result_metrics_nb = pd.DataFrame({
    "1 + обработка отрицаний" : scores_uni_bi_neg['Naive Bayes'],
    "2 + словарь тональности" : scores_tone_dict['Naive Bayes'],
    "3 + количество восклицательных знаков" : scores_excl_num['Naive Bayes'],
    "4 + количество глаголов в повел. накл." : scores_imper_num['Naive Bayes'],
    "5 + количество вопросительных слов" : scores_interr_num['Naive Bayes']

})

result_metrics_nb
# Out:
#                 1 + обработка отрицаний  2 + словарь тональности  \
# fit_time                       0.014211                 0.014812
# score_time                     0.006604                 0.007404
# test_accuracy                  0.859247                 0.860603
# test_f1                        0.860301                 0.862660
# test_precision                 0.873931                 0.869983
# test_recall                    0.848311                 0.856626
#
#                 3 + количество восклицательных знаков  \
# fit_time                                     0.013610
# score_time                                   0.006204
# test_accuracy                                0.860603
# test_f1                                      0.862660
# test_precision                               0.869983
# test_recall                                  0.856626
#
#                 4 + количество глаголов в повел. накл.  \
# fit_time                                      0.015011
# score_time                                    0.007205
# test_accuracy                                 0.860603
# test_f1                                       0.862660
# test_precision                                0.869983
# test_recall                                   0.856626
#
#                 5 + количество вопросительных слов
# fit_time                                  0.015203
# score_time                                0.007614
# test_accuracy                             0.860862
# test_f1                                   0.862845
# test_precision                            0.870643
# test_recall                               0.856374

# %%
result_metrics_rf = pd.DataFrame({
    "1 + обработка отрицаний" : scores_uni_bi_neg['Random forest'],
    "2 + словарь тональности" : scores_tone_dict['Random forest'],
    "3 + количество восклицательных знаков" : scores_excl_num['Random forest'],
    "4 + количество глаголов в повел. накл." : scores_imper_num['Random forest'],
    "5 + количество вопросительных слов" : scores_interr_num['Random forest']

})

result_metrics_rf
# Out:
#                 1 + обработка отрицаний  2 + словарь тональности  \
# fit_time                       2.937494                 2.800392
# score_time                     0.106873                 0.097473
# test_accuracy                  0.823396                 0.831214
# test_f1                        0.822757                 0.830891
# test_precision                 0.846229                 0.853208
# test_recall                    0.801062                 0.810893
#
#                 3 + количество восклицательных знаков  \
# fit_time                                     2.812409
# score_time                                   0.098070
# test_accuracy                                0.829792
# test_f1                                      0.829031
# test_precision                               0.853134
# test_recall                                  0.807238
#
#                 4 + количество глаголов в повел. накл.  \
# fit_time                                      2.859234
# score_time                                    0.098474
# test_accuracy                                 0.833926
# test_f1                                       0.832450
# test_precision                                0.860616
# test_recall                                   0.807365
#
#                 5 + количество вопросительных слов
# fit_time                                  2.901427
# score_time                                0.097271
# test_accuracy                             0.828242
# test_f1                                   0.828167
# test_precision                            0.848491
# test_recall                               0.810010

# %%
result_metrics_lr = pd.DataFrame({
    "1 + обработка отрицаний" : scores_uni_bi_neg['Linear regression'],
    "2 + словарь тональности" : scores_tone_dict['Linear regression'],
    "3 + количество восклицательных знаков" : scores_excl_num['Linear regression'],
    "4 + количество глаголов в повел. накл." : scores_imper_num['Linear regression'],
    "5 + количество вопросительных слов" : scores_interr_num['Linear regression']

})

result_metrics_lr
# Out:
#                 1 + обработка отрицаний  2 + словарь тональности  \
# fit_time                       1.282511                 1.652374
# score_time                     0.006000                 0.006004
# test_accuracy                  0.781539                 0.785350
# test_f1                        0.791552                 0.794584
# test_precision                 0.775399                 0.780579
# test_recall                    0.810390                 0.810893
#
#                 3 + количество восклицательных знаков  \
# fit_time                                     1.545591
# score_time                                   0.006200
# test_accuracy                                0.785350
# test_f1                                      0.794584
# test_precision                               0.780579
# test_recall                                  0.810893
#
#                 4 + количество глаголов в повел. накл.  \
# fit_time                                      1.729225
# score_time                                    0.006604
# test_accuracy                                 0.784122
# test_f1                                       0.793152
# test_precision                                0.779903
# test_recall                                   0.808752
#
#                 5 + количество вопросительных слов
# fit_time                                  1.615555
# score_time                                0.006796
# test_accuracy                             0.785220
# test_f1                                   0.794355
# test_precision                            0.780543
# test_recall                               0.810516

# %%
X_train, X_test, y_train, y_test = train_test_split(train, revs_norm_neg.rating, test_size=0.1) #random_state = 42
classifier = clf_nb.fit(X=X_train, y=y_train)
y_pred = classifier.predict(X_test)

print_wrong_class (y_test, y_pred)
# Out:
# 71 	class= 1
#   учить английский идиот автор молодец вы-быдло ставить единица хорошеть игра ваш проблема стыдно автор молодец продолжать развиваться
#
#  Учите английский,идиоты.Авторы молодцы,если вы-быдло ставящее единицу хорошей игре то это только ваша проблема,стыдно за вас.Авторы,вы молодцы продолжайте развиваться.
#
# 106 	class= 1
#   не_игра
#
#  Как, если не на играх?
#
# 399 	class= 1
#   русский язык
#
#  Да, когда будет русский язык ??
#
# 442 	class= 0
#   добавить русский язык
#
#  Добавьте русский язык
#
# 525 	class= 1
#   почему снять рубль игра стоить
#
#  Почему сняли 70 рублей, если игра стоит 15?
#
# 671 	class= 1
#   габен рог крик
#
#  С Габена с рогами в крик
#
# 755 	class= 1
#   исправить баг айфон 4с
#
#  исправили баг на айфоне 4с ?
#
# 774 	class= 1
#   написать тот кто кровь смываться тело отправлять чистилище правда мысль не_возникать кровь пол тело я рекомендовать поправить брифинг явно человек тупить момент
#
#  Написано что тех, у кого кровь смывается С ТЕЛА отправлять в чистилище. По правде даже мысли не возникает что кровь НА ПОЛУ это тоже тело. Я бы рекомендовал как то поправить брифинг, явно много людей тупит на этом моменте.
#
# 994 	class= 0
#   некоторый уровень очень сложный невозможно пройти дополнение очень дорогой хороший интернет андроид скачать играть
#
#  Некоторые уровни очень сложные. Невозможно пройти, дополнения очень дорогие. Лучше с интернета на андроид скачать и играть???
#
# 1015 	class= 0
#   весь донат реально дорогой
#
#  Все бы ничего но донат реально дорогой
#
# 1256 	class= 0
#   скучный не_интересный игра понятно её хвалить
#
#  Скучная и не интересная игра. Не понятно за что все её хвалят?
#
# 1460 	class= 0
#   адаптация х
#
#  И где адаптация под Х?
#
# 1583 	class= 0
#   ооочень однообразно один
#
#  Ооочень однообразно, первая лучше. 2
#
# 1786 	class= 1
#   вливать бабнуть просить не_кретичный
#
#  Вливать бабло просит но не кретично.
#
# 1801 	class= 1
#   день играть
#
#  3 день играю
#
# 1850 	class= 0
#   желе покупка большой не_купить
#
#  Не желе о покупке. Больше у вас ничего не куплю.
#
# 1892 	class= 0
#   игра отличный простой затягивать пройти один часть два восторг два звезда том буквально бесить отключить замедление взрыв разработчик добавить возможность реально раздражать
#
#  Игра отличная, простая, но затягивает! Прошел и первую часть и от второй в восторге! Но две звезды, т.к. Буквально бесит, что нельзя отключить замедление при взрывах! Разработчики, добавьте эту возможность, ну реально раздражает!!!
#
# 2080 	class= 0
#   игра норма недароботка
#
#  Игра норм,только есть недароботки
#
# 2185 	class= 1
#   игра прикольный достать частый реклама прийтись удалить реклама скоро смс впихать отправить смс посмотреть
#
#  Игра прикольная!!! Но достала частая реклама пришлось удалить. Рекламу скоро в смс впихают что бы отправить смс посмотри ее
#
# 2288 	class= 1
#   понимать правило
#
#  Не понимаю правил
#
# 2760 	class= 1
#   регестрироваться очень давно доступ утерять апаратый поменяться вообщий скачать приложение начать регистрироваться опа писать номер снилс существовать добавить не_мочь старый регистрация понятие удалить найти её
#
#  Регестрировался очень давно, доступ был утерян, и апарат поменялся, вообщем скачал приложение начал регистрировался, и тут опа пишет что номер Снилс уже существует, и добавить я его не могу, и старую регистрацию без понятия как удалить или найти её!
#
# 2846 	class= 1
#   приложение обновление стать понятный функционал
#
#  Приложение после обновления стало более понятное и функционал больше
#
# 2909 	class= 1
#   особенность дмитрия медведев
#
#  Спасибо. В особенности Дмитрию Медведеву.
#
# 3296 	class= 1
#   где обновление айфон андроид рука пауза делать айфон
#
#  Где обновление для айфонов?! На Андроидах можно без рук паузу делать, а на айфонах нет! Как же так?
#
# 3567 	class= 1
#   убрать реклама
#
#  Уберите рекламу????
#                                     ?
#
# 3638 	class= 0
#   отличный игра понравиться реклама тонна
#
#  Отличная игра мне понравилось но вот рекламы просто тонны
#
# 3816 	class= 1
#   почему не_кто сообщение очень стать не_удобно
#
#  Почему не видно от кого сообщение,? Очень стало не удобно!!!
#
# 4022 	class= 1
#   обновление приложение перестать показывать кто пришлый сообщение настройка не_менять помочь
#
#  После обновления приложения перестала показывать от кого пришло сообщение((((( Настройки не меняла. Помогите
#
# 4033 	class= 1
#   последний обновление не_кто приходить сообщение настройка стоить обычно обычный смс нормальный приходить включать миниатюра кто сообщение текст видный что
#
#  После последнего обновления не видно от кого приходят сообщения. В настройках стоит все как обычно. Обычные смс нормально приходят.
# Если включать миниатюры, то видно от кого сообщение, но и сам текст виден, что ни к чему...
#
# 4105 	class= 1
#   увеличить человек количество участник группа
#
#  Увеличьте хотя бы до 500 человек количество участников в группах.
#
# 4186 	class= 1
#   ребята эт квать новый версия старый скоро перестать работать
#
#  Ребят Эт и есть квай только новая версия старая скоро перестанет работать
#
# 4206 	class= 0
#   гавный
#
#  Гавна
#
# 4216 	class= 1
#   них- качать настолько убогий идея реализация ещё не_находить автор исковеркать быть социальный сеть опустить самый важный элемент напихать большой юмор юмор настолько убогий навсегда травмировать личность человек сделать имбицил весь сердце просить посмотреть топлёс ютуба узнать что-нибудь крутой стать человек посмотреть обзор приложение просить дерьмовый танцевать танец юмор жерьмовый перепевать песнь камера медуза котом- крутой посмотреть стендап поперечный просить
#
#  Если вы один из них- качайте. Настолько убогой идеи и реализации я ещё не находил. Авторы исковеркали суть социальной сети, опустив самые важные элементы и напихав побольше юмора. При чем этот юмор настолько убогий, что может навсегда травмировать личность человека и сделать из него имбицила. Пожалуйста, всем сердцем прошу, посмотрите Топлес на ютуб, узнайте , что-нибудь крутое, станьте людьми. Посмотрите обзоры на это приложение, прошу, их много. Это дерьмово танцевать один и тот же танец. В этом нет юмора. Это жерьмово перепевать песни( кроме Камера на медузу с котом- он крут). Посмотрите лучше стендап Поперечного, прошу
#
# 4290 	class= 0
#   бестолковый приложение
#
#  Бестолковое приложение
#
# 4869 	class= 1
#   обновление попытка зайти приложение оно стать вылетать начинать загружаться просить приложить палец приходить смс вход момент вылетать
#
#  После обновления, при попытке зайти в приложение, оно стало вылетать. Начинает загружаться, просит приложить палец, приходит смс о входе и в этот момент вылетает.
#
# 4967 	class= 1
#   почему не_состояние счёт карта наложение арест узнать арест стоя банкомат сделать инф человек видеть причина списать деньга наложить арест
#
#  Почему не видно состояние счетов и карт при наложении арестов? Узнаешь об аресте,стоя у банкомата! Сделайте инфу,чтобы человек видел,за что и по какой причине списаны деньги или наложен арест! Спасибо
#
# 5287 	class= 1
#   почему мой аккаунт трансляция нету маска телефон другой аккаунт исправить
#
#  Почему под моим аккаунтом в трансляции нету масок? С этого же телефона под другим аккаунтом они есть , как мне это исправить ?
#
# 5360 	class= 1
#   почему пропасть гифка
#
#  Почему пропали гифки?????
#
# 5366 	class= 1
#   заходить приложение аккаунт браузер писать извинить произойти ошибка делать вообще
#
#  Не заходит с приложения в аккаунт, только с браузера! Пишет «извините, произошла ошибка» что делать теперь вообще?
#
# 5445 	class= 1
#   мочь понять почему приложение сначала гифа сторис исчезнуть
#
#  Не могу понять,почему у меня в приложении сначала были Гифы для сторис,а теперь исчезли???
#
# 5648 	class= 0
#   сделать синхронизация конец конец весь ещё не_работать синхронизация вк
#
#  Сделайте синхронизацию в конце концов! Всё ещё не работает синхронизация с вк((
#
# 5654 	class= 1
#   почему-то видео лента не_проигрываться сразу нажимать сразу идти звук неудобно ранний запускаться автоматически листать лента
#
#  Почему-то видео в ленте не проигрываются сразу, на них надо нажимать и они сразу идут со звуком тогда((( это неудобно! Раньше они запускались автоматически, когда листаешь ленту!!!!
#
# 5981 	class= 1
#   сделать перемотка ютуба
#
#  Сделайте перемотку как в ютубе
#
# 6031 	class= 0
#   весь работать приложение отличный общение юмор том далее вернуть сохранёнка любить слушать музыка интернет не_везде ловить хотеть сохранить музыка вернуть
#
#  Всё работает хорошо, приложение отличное для общения, юмора и т.д....НО ВЕРНИТЕ СОХРАНЁНКИ?люблю слушать музыку, а интернет не везде ловит(((( нас много, кто этого хотел бы???хотя бы сохранённую музыку верните,а??потом 5*?
#
# 6213 	class= 0
#   приезжать ждать клиент гора очистка парковка красиво гражданин водитель
#
#  Приезжают, ждут клиента, потом гора очисток на парковке. Не красиво, граждане водители
#
# 6282 	class= 1
#   один машина не_найти
#
#  Ни одной машины не возможно найти!
#
# 6297 	class= 1
#   ставить пять не_сервис который не_жёсткий отбор водитель ставить вы заслужить оценка никто заставить клиент мириться весь захотеть сделать цена поездка не_далеко двое стоить разница рубль дорогой автобус следовать поднять сервис набрать квалифицировать персонал оценка пять стоять не_цена качество не_старое гниловатый сарай
#
#  Ставлю пять просто так, не за то, что у вас сервис, которого нет, не за то, что у вас жесткий отбор водителей, потому что этого тоже нет, а ставлю просто так. Вы заслужили эту оценку как никто, вы заставили нас клиентов мириться со всем, что только вы захотите сделать, лишь потому что цена поездки не далеко на двоих у вас стоит с разницей в 22 рубля дороже чем на автобусе. Но следовало бы вам поднять сервис и набрать квалифицированного персонала и тогда оценка пять будет стоять не за цену, а за качество. А сейчас вы не лучше старого и гниловатого сарая!
#
# 6490 	class= 0
#   привязывать карта приложение иначе прекрасный день лишиться свой деньга
#
#  Не привязывайте к карту в этом приложении!! Иначе в один прекрасный день лишитесь своих денег!!!
#
# 6570 	class= 1
#   отличный такси приезжать оперативно прямо поставить точка цена очень приятный другой компания фирменный шапочка такси издалёка хотеться чуточку внимание нанимать водитель очень просить сменить логотип окно загрузка приложение тот несколько мгновение покидать ощущение что-то не_догрузиться поэтому видный 3ех цветной квадратик
#
#  Отличное такси, приезжают оперативно прямо в поставленную точку, цена очень приятная относительно других компаний. Благодаря фирменной «шапочке» такси всегда видно издалека.
#
# Хотелось бы только чуточку больше внимания к нанимаемым водителям. И я вас очень прошу сменить логотип и окно загрузки приложения (те несколько мгновений). Не покидает ощущение, что что-то не догрузилось и поэтому видны только эти 3ех цветные квадратики ?
#
# 6576 	class= 1
#   вчера поездка яндекс такси карта не_хватить деньга её оплата прийтись расплатиться наличный сегодня деньга появиться сумма повторно списаться карта звонок служба поддержать средство вернуться минута огромный уважение большинство знакомый вы стоить будущее пример подражание
#
#  Вчера после поездки на Яндекс такси на карте не хватило денег для её оплаты. Пришлось расплатится наличными. Сегодня же, когда деньги появились, сумма повторно списалась с карты. По звонку в службу поддержи средства вернулись через 10 минут. Огромное спасибо и уважение от меня и большинства знакомых, за вами стоит будущее, вы — пример для подражания??
#
# 6627 	class= 0
#   я ваш ма иметь ох1рел1
#
#  Я вашу ма... имел !!!!вы что там ох1рел1 ?!
#
# 7198 	class= 1
#   очень недарабртка лично заметить подправить меню магазин листать неудобно бегунок чтоль какой-то листание задеваться листать вытаскиваться купить найти отображаться количество монета доить улучшение уровень предприятие не_удобно отправлять исследование не_продукт тот который нудже отправить исследование очень странно сделать соотношение время количество еда дерево думать расписывать не_стоить мина болтша получить ждать мина получить меньша такой время тд игра неудобно выполнять задание житель закрыть реплек онидать следующий задание пока не_понять ловить преступник затний давать очень дорогой кристалл штука рубль жесть мочь что-то забыть надеяться прислушаться игра новый классный недароботка
#
#  Очень много недарабрток .
# Лично я заметила то, что можно было бы подправить.
# 1. Когда меню магазина листаешь неудобно, потому что нет бегунка чтоль какого-то. При листании задевается то , что листаешь и вытаскивается , чтобы купить.
# 2. Не нашла, где отображаются количество монет доя улучшения уровня предприятий. Это не удобно.
# 3.  Когда отправляешь исследование, не видно сколько есть продуктов из тех, которые нуджеы, чтобы отправить исследование.
# 4. Очень странно сделано соотношение времени и количество еды и дерева. Думаю расписывать не стоит. За 1,5 мин болтше можно получить, чем ждать 5 мин и получить  меньш за такое же время и тд.
# 5. При игре неудобно , когда выполняешь задание жителя нельзя закрыть его реплеку , чтобы онидал следующее задание.
# 6. Пока не поняла, зачем ловить преступников и что затних дают.
# 7. Очень дорогие кристаллы.. 20 штук 75 руб жесть.
# Могла что-то забыть, надеюсь вы прислушаетесь. Игра новая классная, но недароботок много.
#
# 8231 	class= 1
#   уважаемый разработчик вылететь телеграмма писать зарегестрируться аккаунт давно ввод номер соединение интернет делать
#
#  Уважаемые разработчики, у меня вылетел телеграмм, пишет «зарегестрируйтесь», хотя аккаунт уже давно есть, после ввода номера - «нет соединения с интернетом», что делать?
#
# 8378 	class= 1
#   обновление начать пропадать диалог не_быть убирать звёздочка приложение ещё такой проблема часто слушать телега музыка приходить голосовой прослушивание снова заходить диалог музыка включать заново мочь исправить версия пк бывать голосовой оч тихий музыка играть телега не_слышать затихать приходиться выклый музыка мочь чёт сделать
#
#  После обновления начал пропадать фон в диалогах не буду убирать звездочку все равно спасибо за приложение ,ещё такая проблема я часто слушаю через телегу музыку но когда мне вдруг приходит голосовое то после его прослушивание надо снова заходить в диалог с музыкой и включать заново ,можете как то исправить? В версии для пк там бывает голосовое оч тихое и я его через музыку что играет в телеге не слышу хоть и она затихает, приходится выкл музыку ,можете тоже чёт сделать?
#
# 8401 	class= 0
#   полноценный возможность сохранять музыка добавить
#
#  Полноценную возможность сохранять музыку добавьте
#
# 8430 	class= 1
#   сделать ввод номер выдавать ошибка заблокировать
#
#  Сделайте что нибудь, вводу номер , выдаёт ошибку. Неужели заблокировали ?
#
# 8481 	class= 1
#   я наверное тот единица который действительно не_работать телеграм делать войти не_мочь телеграм ужасно нет один мессенджер близко стоящий удобство
#
#  Я, наверное, из тех единиц, у которых действительно не работает телеграм. Что делать? Даже войти не могу.
# Без телеграм ужасно. Нет ни одного мессенджера даже близко стоящего по удобству.
#
# 8586 	class= 1
#   рнк лох
#
#  РНК лох
#
# 8917 	class= 0
#   шазазамил песня оффлайна включить инуть песнь
#
#  Шазазамил песню оффлайн включил инет а песни нет, спасибо
#
# 9047 	class= 0
#   быть грузия один песнь не_знать
#
#  Был в Грузии, ни одной песни не знает.
# ??????????
#
# 9097 	class= 1
#   сделать слово песнь ручной вводить
#
#  Сделайте так что б можно было слова песни в ручную вводить
#
# 9470 	class= 1
#   нарикание работать один уровень авить
#
#  Нариканий нет ! Работает на одном уровне с авито .
#
# 9702 	class= 1
#   иметь шанс победить тот помойка авить звать
#
#  Имеет все шансы победить ту помойку, что мы авито зовем
#
# 9716 	class= 1
#   заходить один день уведомление бонус не_начисляться следующий день снова сначала
#
#  Когда заходишь в первый раз в день с уведомления, бонусы не начисляются, а на следующий день снова сначала.
#
# 9871 	class= 1
#   блиннна разроба пжжж убрать лагиия реклама удалить игра
#
#  Блиннн разробы Пжжж уберите лагиии и рекламу или я удалю игру пожалуйста
#
# 9998 	class= 0
#   хороший игра глючить безумно
#
#  Хорошая игра, но глючит безумно!!!
#
# 10020 	class= 0
#   быть добрый избавиться лаг игра
#
#  Будьте добры избавьтесь от лагов в игре)
#
# 10275 	class= 1
#   доставка бывать очень долгий вино не_сайт почта россия отметка видеть груз россия болтаться месяц два получиться деньга возвращаться посылка приходить день
#
#  Доставка конечно бывает очень долгая, но вина не Сайта,  а почты России. В отметках видишь, что груз в России где то болтается от месяца до двух. При этом, как получилось у меня деньги возвращаются, а посылка приходит через 4 дня.
#
# 10279 	class= 0
#   заказ не_прийти шикарный ответ разработчик мы очень жаль средний время доставка день я ваш ответ очень помочь
#
#  Из 8 заказов ни один не пришел. Шикарный ответ разработчика:"Нам очень жаль, среднее время доставки 30 дней". Мне ваш ответ очень помог, спасибо ?
#
# 10498 	class= 1
#   день почта забрать куча свой заказ оказаться тот заказ который вернуть деньга стать не_удобно получаться заранее вернуть вещий деньга написать служба помощь помочь разобраться мой ситуация ответить срок доставка не_успеть доставить заказ возместить деньга сервис большой служба помощь делать успех больший процветание супер
#
#  На днях из почты забрала кучу своих заказов и там оказались те заказы за которых мне вернули деньги. Как мне стало не удобно. Получается, как бы, заранее я вернула вещи деньгами и написала в службу помощи помочь разобраться в моей ситуации. А мне ответили, что из-за того, что в срок доставки не успели доставить заказ они возместили деньгами?????? вот это сервис. Спасибо большое службу помощи за все что вы делаете для нас. Успехов вам больших и процветания ?????? вы супер??????????
#
# 10504 	class= 0
#   очень долгий доставка алиэкспрес быстрый намного
#
#  Очень долгая доставка! С алиэкспреса быстрее намного!
#
# 10515 	class= 1
#   весь товар который заказывать получить такой ситуация день товар не_прийти вернуть деньга поздний получить доставка долгий основное россия блуждать
#
#  Все товары, которые заказывала получила. Даже такая ситуация была, что за 75 дней товар не пришёл, вернули деньги, а позже я его всё-таки получила. Доставка долгая, но в основном по России блуждает.
#
# 10605 	class= 1
#   здравствовать отличный приложение один неудобство приложение мой заказ заходить свой профиль отображаться текущий завершить заказ текущий заказ иметься два кнопка отслеживание подтвердить получение кнопка находиться очень близко друг друг располагаться один несколько промахнуться мимо отслеживание подтвердить получение заказ ещё путь разместить кнопка разный сторона профиль не_один точно никто не_промахнуться не_нажать не_тот кнопка услышать подправить
#
#  Здравствуйте,отличное приложение, но есть одно неудобство. В приложении, в моих заказах ку да мы заходим через свой профиль, отображаются текущие и завершённые заказы, в текущих заказах имеется две кнопки отслеживания и подтвердить получение , эти кнопки находятся очень близко друг к другу и располагаются одна над другой, я несколько раз промахнулся мимо отслеживания и подтвердил получение, хотя заказ был ещё в пути! Пожалуйста, разместите кнопки по разные стороны профиля, а не одну над другой, так точно никто не промахнется и не нажмёт не ту кнопку! Спасибо если меня услышат и подправят!
#
# 10856 	class= 1
#   снять ограничение товар список корзина желание реально не_хватать не_один такой ход
#
#  Снимите уже ограничения товаров в списках корЗины и желаний! Реально не хватает ... и я не одна такая, по ходу!
#
# 10864 	class= 0
#   обновление работоспособность приложение оставлять желать хороший
#
#  После обновления работоспособность приложения оставляет желать лучшего
#
# 10931 	class= 1
#   я заказывать оплачивать приезжать нужно это стоить ждать приложение
#
#  Я заказываю, оплачиваю и мне приезжает то что нужно! Этого и стоит ждать от приложения! Спасибо
#
# 10939 	class= 1
#   не_претензия приложение месяц не_работать раздел халява слово вообще список товар показывать пытаться выбрать значок загрузка весь я выигрывать хотеться ещё починить плиз весь заработать
#
#  Вот никогда не было претензий к приложению, но уже месяц, а то и два не работает раздел «халява» от слова вообще. Список товаров показывает, а как только пытаюсь выбрать, значок загрузки и всё. Я уже там один раз выигрывала, хочется ещё))) почините, плиз!
# Спасибо, всё заработало!!!
#
# 10999 	class= 0
#   здравствовать разроботчик оброшяться просьба понизить цена товар потомучьто уш очень дорого самолёт каторый прославиться ютуба стыть 3000тысяча
#
#  Здравствуйте разроботчики я оброшяюсь к вам с просьбой  понизить цены на товар  потомучьто уш очень  дорого даже самолёт  каторый прославился в ютубе стоет теперь 3000тысячи
#
# 11042 	class= 1
#   недавний обновление начать лагать жутко исправить
#
#  После недавнего обновления начало лагать жутко. Исправьте это пожалуйста!
#
# 11170 	class= 0
#   нет функция выбор категория автомобиль лично интересовать выбор грузовик сделать
#
#  Нет функции выбор категории автомобиля. А именно, лично меня интересует выбор грузовика. Сделаете будет 5+
#
# 11419 	class= 1
#   исправить
#
#  Вроде исправили
#
# 11788 	class= 1
#   безумный количество реклама игра лагаета маленький лаг приходиться перепроходить игра вылетать счастие редко
#
#  Безумное количество рекламы это раз,два игра лагает после малейшего лага приходится перепроходить,три игра вылетает,конечно на счастье редко.
#
# 11877 	class= 0
#   игра норма
#
#  Игра норм
#
# 12152 	class= 1
#   добавить возможность ввод несколько промокод обидный день рождение приложение ввести промокод
#
#  Добавьте возможность ввода нескольких промокодов. Обидно, когда День рождения , а в приложение можно ввести только один промокод (
#
# 12403 	class= 0
#   пиздабола
#
#  Пиздаболы
#
# 12659 	class= 0
#   человек скучно
#
#  Ну люди ну скучно(((((
#
# 12981 	class= 0
#   надеяться получить нажива алчный людишки
#
#  Надеюсь вы получите наживу, алчные людишки.
#
# 13151 	class= 0
#   вернитеий
#
#  Вернитеее
#
# 13228 	class= 0
#   такой проблема не_телефон обновить приложение весь прекрасно сообщение не_отправляться писать интернет
#
#  Такая проблема не только у меня .Телефон обновлён .Приложение тоже .Все прекрасно ,но Сообщения не отправляются ,пишет ,что интернета нет .Не хорошо )
#
# 13539 	class= 1
#   почему маска время меняться любимый маска постоянно исчезать не_время обидный
#
#  Но почему маски все время меняются?
# Любимые маски, постоянно, исчезают не во время.... обидно
#
# 13592 	class= 0
#   жить крым пытаться переключить писать такой место не_существовать кидать краснодар збс
#
#  Живу в Крыму а когда пытаюсь переключить то пишет что такого места не существует и кидает на Краснодар ... збс.
#
# 13621 	class= 1
#   мочь найти раздел кнопка мочь найти сотрудник ю
#
#  Не могу найти раздел/кнопку где я мог бы сам найти сотрудников ю
#
# 13651 	class= 1
#   писать нету сеть вай-фай пробой нету исправт
#
#  Пишет что нету сети, хотя с вай-фаем пробоем нету, исправте пожалуйста.
#
# 13836 	class= 1
#   положительный
#
#  Положительный
#
# 13930 	class= 0
#   поисковик работать не_адекватно работа основное студент коекакер приложение не_конкурентный отношение существующий
#
#  Поисковик работает не адекватно, работа в основном для студентов и коекакеров, Приложение совсем не конкурентное по отношению к уже существующем...
#
# 14063 	class= 1
#   очень удобно служба поддержка оперативно реагировать обновление начать приложение вылетать отписать сп отреагировать буквально течение 30-60 минута
#
#  Очень удобно! + служба поддержки оперативно реагирует, после обновления начало приложение вылетать, отписал в СП отреагировали буквально в течение 30-60 минут
#
# 14143 	class= 1
#   сделать умолчание ставить вид карта
#
#  Сделайте, пожалуйста, чтобы можно было по умолчанию ставить вид всех карт.
#
# 14735 	class= 1
#   вчера проехать ваш приложение пробка навигатор показывать перекрыть улица вести максимально оптимальный маршрут
#
#  Спасибо что вчера проехала благодаря вашему приложению без пробок ! Навигатор показывал все перекрытые улицы и вел максимально по оптимальным маршрутам !
#
# 14908 	class= 1
#   постоянно пользоваться мелочь старый маньячный сюда попасть шесть двор один указатель серьёзно молодец создатель собрать столько информация воедино мег столько город я отзыв пользоваться пара общаться служба поддержка полный адекват никакой рафинировать штамп три день плач счастие вы мы написать не_мочь работать приветливо дело советовать весь мама сегодня новый телефон скачать сначала отпираться настойчивый приплатить проникнуться общий товарищ идти очень дорогой светлый карма чистый чакра не_растерять удобно мой санкт-петербургский мерсизый
#
#  Постоянно пользуюсь. От мелочей «эээ, старая маньячная - это где...» до «как сюда попасть, здесь шесть  дворов и ни одного указателя». Серьезно, вы молодцы, создатели: собрать столько информации воедино - это мега. И в стольких городах. Я даже отзывами пользуюсь. И пару раз общалась со службой поддержки - полный адекват, никаких рафинированных штампов «мы третий день плачем от счастья, что Вы нам написали, не можем работать», а приветливо и по делу. Советую всем, маме сегодня на новый телефон скачала: она сначала отпиралась, но я была бы настойчива как будто мне приплатили. И она прониклась! В общем, спасибо вам, товарищи, вы идёте очень верно дорогой. Светлой кармы, чистой чакры вам и не растерять все то, что так удобно. Мои Санкт-Петербургские  мерсизы!
#
# 14916 	class= 0
#   целый день ездить город поиск душевой уголок этот чудо программа приводить магазин свет том плата один попадание часы поиск
#
#  Целый день ездил по городу в поиске душевого уголка, но эта чудо программа приводила нас в магазины «все для света» и т.п. Ни одного попадания за 5 часов поиска!
#
# 14945 	class= 1
#   постоянно пользоваться мелочь старый маньячный сюда попасть шесть двор один указатель серьёзно молодец создатель собрать столько информация воедино мег столько город я отзыв пользоваться пара общаться служба поддержка полный адекват никакой рафинировать штамп три день плач счастие вы мы написать не_мочь работать приветливо дело советовать весь мама сегодня новый телефон скачать сначала отпираться настойчивый приплатить проникнуться общий товарищ идти очень дорогой светлый карма чистый чакра не_растерять удобно мой санкт-петербургский мерсизый
#
#  Постоянно пользуюсь. От мелочей «эээ, старая маньячная - это где...» до «как сюда попасть, здесь шесть  дворов и ни одного указателя». Серьезно, вы молодцы, создатели: собрать столько информации воедино - это мега. И в стольких городах. Я даже отзывами пользуюсь. И пару раз общалась со службой поддержки - полный адекват, никаких рафинированных штампов «мы третий день плачем от счастья, что Вы нам написали, не можем работать», а приветливо и по делу. Советую всем, маме сегодня на новый телефон скачала: она сначала отпиралась, но я была бы настойчива как будто мне приплатили. И она прониклась! В общем, спасибо вам, товарищи, вы идёте очень верно дорогой. Светлой кармы, чистой чакры вам и не растерять все то, что так удобно. Мои Санкт-Петербургские  мерсизы!
#
# 15123 	class= 1
#   нормальный
#
#  Нормально
#
# 15839 	class= 1
#   реклама посмотреть
#
#  Даже рекламу посмотрел
#
# 16162 	class= 1
#   приложение прекрасный оно развиваться очень радовать знать вход здание яндекс такси оно использовать яндекс карта каждый построить маршрут заканчиваться карта один сторона мой дом подъезд находиться сторона не_таксист сообразительный приходиться идти пешком звонить объяснять проехать куда обратиться проблема
#
#  Приложение прекрасное. И то, что оно развивается очень радует. Но знает ли про входы в здания яндекс.такси? Оно использует яндекс.карты? Просто каждый раз построенный маршрут заканчивается на карте с одной стороны моего дома, а все подъезды находятся с другой стороны. И не все таксисты сообразительные, иногда приходится идти к ним пешком или звонить и объяснять как проехать. Куда обратиться с этой проблемой?
#
# 16321 	class= 1
#   оффлайна карта загружаться вместе мск питер отдельно тверская область загрузить приходиться
#
#  Оффлайн бы карты еще загружались все вместе, а то от Мск до Питера отдельно Тверскую область загрузить приходилось
#
# 16467 	class= 1
#   яндекс карта подключить фай дом показывать мой местоположение точно пользование мегафон оператор местоположение показывать несколько километр сторона проблема
#
#  Яндекс.Карты при подключённом вай фай дома показывает мое местоположение точно, при пользовании от МегаФон, это мой оператор, местоположение показывает на несколько километров в сторону
# В чем проблема?
#
# 16474 	class= 0
#   доиграться
#
#  Доигрались :)))
#
# 16545 	class= 1
#   исправить проблема значок
#
#  Спасибо, что исправили проблему со значками)
#
# 16858 	class= 1
#   чо приложение не_понять сначала писать ошибка соединение интернет работать жать прослушать песня писать превысить время ожидание тп крч не_кома советовать лишний затрата время
#
#  чо с приложением не пойму???
# сначала пишет « ошибка соединения » хотя интернет работает, а потом когда жмёшь чтобы прослушать песню то пишет « превышен времени ожидание » и тп
# крч не кому советую, лишние затраты времени
#
# 17158 	class= 0
#   послать опу
#
#  Пошли в ОПу
#
# 17280 	class= 1
#   вчерашний обновление приложение зависнуть не_сто не_реагировать
#
#  После вчерашнего обновления приложение зависло и не на сто не реагирует.
#
# 17450 	class= 0
#   советовать
#
#  Не советую
#
# 17676 	class= 0
#   бог маркетинг описание обновление не_забыть не_один студент использовать ваш приложение исправлять свой косяк скорый время весь работать высокий уровень не_хватить написать
#
#  Боги МАРКЕТИНГА в описание обновления!!!, не забыли, то что не одни студенты используют ваше приложение!!!????, а то что исправляете свои косяки?, но в скором времени всё будет работать на высшем уровне, не хватило написать!???
#
# 17743 	class= 1
#   плач р каждый месяц инстаграмм написать р подписка стоить почему
#
#  А я плачу 299 р каждый месяц, а в Инстаграмм написано 99 р сейчас подписка стоит... почему так?
#
# 17826 	class= 0
#   я не_нравиться весь платнооооо
#
#  Мне не нравится потому что всё платнооооо!!!  ?
#
# 17907 	class= 1
#   огонь подписка стоить рубль аккаунт разный устройство
#
#  Просто огонь!подписка стоит 149 руб!один аккаунт на 5 разных устройствах !
#
# 18016 	class= 1
#   слушать плейлист дать думать найти один музычка песнь начинать играть хороший оформить подписка скидос работа плейлист
#
#  Слушаю плейлист от 27.04.18 дай думаю найду одну музычку..и бац!!!песни через три она начинает играть....лучшие!оформил подписку по скидосу...Спасибо!за работу плейлистов.
#
# 18071 	class= 0
#   нравиться смотреть реклама вперёд качать разраб убить стульчак унитаз
#
#  Нравиться смотреть рекламу вперёд качай, разраб убей себя стульчаком от унитаза
#
# 18172 	class= 1
#   игра вообще не_открываться
#
#  игра вообще не открывается
#
# 18191 	class= 1
#   нормальный
#
#  Нормально
#
# 18306 	class= 1
#   много реклама
#
#  Много рекламы
#
# 18312 	class= 0
#   хах
#
#  Хаха
#
# 18386 	class= 0
#   работать
#
#  Не работает
#
# 18480 	class= 1
#   работать подписка дороговатый
#
#  Работает, подписка дороговата
#
# 18533 	class= 0
#   телеграм это впн не_работать нужный
#
#  Телеграм под этим впн не работает - зачем он тогда нужен?
#
# 18665 	class= 1
#   единственный нормальный рабочий приложение
#
#  Единственное нормальное рабочее приложение
#
# 18802 	class= 0
#   разработчик просьба увеличить размер приложение очень память не_использоваться мегабайт вообще око особенно интернет лиметировать просьба увеличить размер гб
#
#  Разработчики, просьба увеличить размер приложения. У меня очень много памяти не используется, 300 мегабайт для меня вообще ни очам особенно когда интернет лиметированный. Просьба увеличить размер до 1,5 Гб ))
#
# 18883 	class= 1
#   обращать внимание великоскрепной комментарий имя качественный оригинальный плохо второсортный отечественный плагиат любить кома не_нравиться валита чебурнуть вк фейсбук
#
#  Не обращайте внимание на великоскрепные комментарии. Им все качественное и оригинальное - плохо. А вот второсортный отечественный плагиат эти они любят)
# Кому не нравится - валите в чебурнет (вк) без вас на фейсбуке будет лучше
#
# 18938 	class= 0
#   дорогой мой разработчик делать обновление весь понятно выйти фейсбук слово выход злой такой
#
#  Дорогие мои разработчики, если вы делаете обновление, то так, чтобы всем было понятно что и как. Как мне выйти из фейсбука, где слово выход????????! Злая такая (()))(
#
# 19011 	class= 0
#   сделать возможность отложить публикация очень удобно пока
#
#  Пожалуйста, сделайте возможность отложенных публикаций! Очень удобно было бы!!! Пока 2*
#
# 19220 	class= 1
#   обновление перестать запускаться
#
#  После обновления перестала Запускаться
#
# 19431 	class= 1
#   вылетать летать
#
#  Не вылетает а летает
#
# 19483 	class= 0
#   я нужно офлайна супер игра зачем обязательно подключ интернет очень старый хороший игра
#
#  Мне нужно офлайн. Но супер игра.
# Зачем обязательно подключ интернет.
# Очень старая лучшая игра. А сейчас ....
#
# 19497 	class= 1
#   обновление стать вылететь вообще не_мочь зайти уровень
#
#  После обновления стала вылететь.Вообще не могу зайти в уровень
#
# 19621 	class= 1
#   я не_нравиться
#
#  Я вам не нравлюсь
#
# 19644 	class= 0
#   подводить утка толк
#
#  Сколько раз подводили утки! От них толку нет
#
# 19795 	class= 0
#   сервис еле тянуть
#
#  Сервис еле тянет
#
# 20152 	class= 1
#   нужный возможность вызвать такси время мина я не_знать ехать поэтому хотеть позаботиться заранее вызывать два минута подъезд
#
#  Нужна возможность вызвать такси ко времени.
# Например мне надо через 30 мин.
# Я же не знаю, сколько он будет ехать... Поэтому хочу позаботиться об этом заранее. Вызываю,  А он уже через две минуты у подъезда.
#
# 20436 	class= 0
#   долго скачиваться урок переводить
#
#  Долго скачивается как на уроке переводить???
#
# 20485 	class= 0
#   установить приложение очень удобный функция мгновенный перевод перевод текст попадать объектив камера этот функция не_работать
#
#  Установил приложение так как очень удобная функция мгновенный перевод. Перевод текста попадающего в объектив камеры. Но у меня эта функция не работает (((
#
# 20599 	class= 0
#   нет татарский язык
#
#  Нет татарского языка!!!
#
# 20810 	class= 1
#   быть такой ситуация забронировать место назначить время не_прислать минута итог вопрос почему не_брать трубка почему опаздывать отказаться ехать наезд очень спокойно хотеться иметь возможность оставить соответствующий отзыв такой попутчик другой видеть оценивать свой время исходить компетенция такой человек начало поездка отзыв оставить тк попутчик отменить бронь момент начало поездка соответственно не_дать возможность другой человек осуществить поездка
#
#  Была такая ситуация, что забронировали место, в назначенное время не пришли, только спустя 20 минут. В итоге после вопроса почему не берут трубку и почему опаздывают отказались ехать, хотя и все это было без наезда, очень спокойно. Хотелось бы иметь возможность оставить соответствующий отзыв таким попутчикам, чтобы другие видели и оценивали своё время исходя из компетенции таких людей. После начала поездки  отзыв уже нельзя было оставить, тк попутчик отменил бронь в момент начала поездки,и, соответственно, не дал возможность другим людям осуществить поездку
#
# 20882 	class= 1
#   я забронировать вчера поездка сегодня заходить бронь показывать подключение проверять невозможно посмотреть другой поездка телефон перезагрузить сайт норма исправить
#
#  Я забронировала вчера поездку, сегодня захожу, а брони нет и показывает, что нет подключения. Проверяла, есть!) Невозможно посмотреть другие поездки, даже телефон перезагрузила. На сайте все норм. Исправьте, пожалуйста!
#
# 21009 	class= 1
#   вопрос разработчик участиться случай человек бронировать поездка итог не_приходить назначить время абонент не_отвечать оставлять отзыв тот человек который бронировать поездка не_прислать видеть человек забронировать поездка итог не_прийти назначить время
#
#  Вопрос к разработчикам! Участились случаи , люди бронируют поездки и в итоге после не приходят в назначенное время и абонент не отвечает ! Возможно как то оставлять отзыв о тех людях , которые бронировали поездку и не пришли ?!! Пусть все видят , что этот человек , может забронировать поездку и в итоге не придти в назначенное время !!!
#
# 21293 	class= 0
#   оценить не_знать работа отлично легко удобно один проблема скачивание компьютер пропадать звук видео
#
#  Как оценить не знаю! В работе все отлично,легко и удобно! Одна проблема! При скачивании на компьютер пропадает звук у видео
#
# 21313 	class= 0
#   максимальный разрешение видео наложение музыка сохранить видео получаться очень размывчатый
#
#  При максимальном разрешении видео при наложении музыки сохранённое видео получается ОЧЕНЬ РАЗМЫВЧАТЫМ !!!
#
# 21376 	class= 1
#   клевый приложение срок удалить баннер рекламный 149р
#
#  Спасибо за клевое приложение. На какой срок я удалю баннер рекламный на 149р?
#
# 21918 	class= 0
#   реклама мор играть
#
#  Рекламы море играть не возможно
#
# 21935 	class= 1
#   один карта вообще не_пройти метр
#
#  Первую карту вообще не пройти на 1153 метре
#
# 21995 	class= 0
#   цена большой дешёвый магазин официальный бренд кошмар не_скачивать
#
#  Цены большие, дешевое в магазине при чем в официальных брендах! Кошмар лучше бы не скачивал!!!!!!!
#
# 22088 	class= 1
#   нормальный
#
#  Нормально
#
# 22100 	class= 1
#   приложение перестать открываться
#
#  Приложение перестало открываться.....
#
# 22207 	class= 0
#   рынок садовод загонять барахло
#
#  Как будто с рынка Садовод загоняют барахло:)
#
# 22339 	class= 0
#   китайский ширпотреб цена известный бренд товар магазин шар-дар ещё лох находить
#
#  Китайский ширпотреб по цене известных брендов. Товар из магазина шаром-даром.  Или все по 50?)))). И где ещё лохов находите.
#
# 22382 	class= 0
#   цена огромный магазин дешёвый купить товар не_соответствовать цена
#
#  Цены огромные , в магазине дешевле купить! Товар не соответствует цене.
#
# 22489 	class= 0
#   цена не_такой маленькая качество изделие очень хромать полусапожки аккуратный носка неделя выглядеть носить год пять не_снимать кожа облупиться подошва отклеиться парк дешёвый плащёвка очень марка жарка пуговица карман отвалиться неделя
#
#  Цены не такие уж и маленькие.
# Качество изделий очень хромает.
# Полусапожки при аккуратной нОске через неделю выглядели так, как будто их носили лет пять, не снимая.
# «Кожа» облупилась, подошва отклеилась.
# Парка внутри из дешевой плащевки, очень маркой и жаркой.
# Пуговицы и карманы отвалились через неделю.
