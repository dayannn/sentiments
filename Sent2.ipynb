# %%
import numpy as np
import pandas as pd
import re

# %%
revs = pd.DataFrame.from_csv("./res.csv", encoding="cp1251")

initial_revs = revs.copy()

revs
# Out:
#        rating                                            content
# 0           5  Интересный сюжет, затягивает. Много времени ух...
# 1           4  Плюсы: \r\n1. Игра интересная 2. Образы учител...
# 2           3  Огорчил тот факт , что суть игры заключается в...
# 3           5  Была постоянная ошибка с подключением, почти н...
# 4           1  ... сделайте русскую озвучку и будет 5 звёзд :...
# 5           3                         Почему нет русского языка?
# 6           1                                                  !
# 7           1              Постоянные проблемы с подключением!!!
# 8           5  Все идеально но отсутствия русского языка даёт...
# 9           1          Где великий и могучий??? Сделайте русский
# 10          4  Thanks for the game, I fancy it pretty much, h...
# 11          2                  Добавьте русский язык пожалуйста(
# 12          5  Игра отличная, отсутствие русского языка не ме...
# ...

# %%
    #drop eng reviews
revs.drop(revs[revs.content.str.contains ("[A-Za-z]")].index, inplace=True)
    #drop reviews with rating 3-4
revs.drop(revs[(revs.rating == 3) | (revs.rating == 4)].index, inplace=True)
    #drop empty reviews
revs.drop(revs[revs.content == ""].index, inplace=True)

revs
# Out:
#        rating                                            content
# 0           5  Интересный сюжет, затягивает. Много времени ух...
# 4           1  ... сделайте русскую озвучку и будет 5 звёзд :...
# 6           1                                                  !
# 7           1              Постоянные проблемы с подключением!!!
# 8           5  Все идеально но отсутствия русского языка даёт...
# 9           1          Где великий и могучий??? Сделайте русский
# 11          2                  Добавьте русский язык пожалуйста(
# 16          1  В описании приложения, написали что есть русск...
# 17          1              Пожалуйста сделайте русский язык!!!!!
# 18          2  Зашла в игру, поиграла ровно минуту и всё, эне...
# 22          5  Почему игра не запускается, перекидывает на ст...
# 23          1  Когда же ждать заявленный в описании русский я...
# 24          2  Русского языка нет, но английский понимаю - та...
# ...

# %%
revs['rating'][(revs.rating == 1) | (revs.rating == 2)] = 0
revs['rating'][revs.rating == 5] = 1

revs
# Out:
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#        rating                                            content
# 0           1  Интересный сюжет, затягивает. Много времени ух...
# 4           0  ... сделайте русскую озвучку и будет 5 звёзд :...
# 6           0                                                  !
# 7           0              Постоянные проблемы с подключением!!!
# ...

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

stop_words = set(stopwords.words('russian'))

# %%
def strtonormalform(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None) :#союзы, предлоги и т.п. не сохраняем
            ans = ans + ' ' + lex
    return ans

revs_norm = revs.copy()
revs_norm['content'] = revs_norm['content'].apply(strtonormalform)
    #drop empty reviews
revs_norm.drop(revs_norm[revs_norm.content == ""].index, inplace=True)

revs_norm
# Out:
#        rating                                            content
# 0           1   интересный сюжет затягивать много время уходи...
# 4           0      сделать русский озвучка быть звезда понимание
# 6           0
# 7           0                    постоянный проблема подключение
# 8           1   весь идеально отсутствие русский язык давать ...
# 9           0                где великий могучий сделать русский
# 11          0                              добавить русский язык
# 16          0   описание приложение написать русский язык фак...
# 17          0                               сделать русский язык
# 18          0   зайти игра поиграть ровно минута весь энергия...
# 22          1   почему игра запускаться перекидывать страница...
# 23          0                ждать заявить описание русский язык
# 24          0   русский язык нет английский понимать небольшо...
# 25          1   товарищ учить иностранный язык игра замечател...
# ...

# %%
#revs_norm.to_csv("normalized_revs.csv")
revs_norm = pd.DataFrame.from_csv("./normalized_revs.csv", encoding="cp1251")

# %%
def strtonormalform_with_neg(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    flag = False
    for word in words:
        if (word == "не"):
            flag = True
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None) and (word not in stop_words) :#союзы, предлоги и т.п. не сохраняем
            if (flag):
                flag = False
                lex = "не_" + lex
            ans = ans + ' ' + lex
    return ans

revs_norm_neg = revs_norm_neg.copy()
revs_norm_neg['content'] = revs['content'].apply(strtonormalform_with_neg)
    #drop empty reviews
revs_norm_neg.drop(revs_norm_neg[revs_norm_neg.content == ""].index, inplace=True)

revs_norm_neg
# Out:
#        rating                                            content
# 0           1   интересный сюжет затягивать много время уходи...
# 4           0           сделать русский озвучка звезда понимание
# 7           0                    постоянный проблема подключение
# 8           1   весь идеально отсутствие русский язык давать ...
# 9           0                где великий могучий сделать русский
# 11          0                              добавить русский язык
# 16          0   описание приложение написать русский язык фак...
# 17          0                               сделать русский язык
# 18          0   зайти игра поиграть ровно минута весь энергия...
# 22          1   почему игра не_запускаться перекидывать стран...
# 23          0                ждать заявить описание русский язык
# 24          0   русский язык английский понимать небольшой не...
# 25          1   товарищ учить иностранный язык игра замечател...
# ...

# %%
revs.rating.describe()
# Out:
# count    15497.000000
# mean         0.513196
# std          0.499842
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: rating, dtype: float64

# %%
print ('Количество положительных отзывов составляет {}% от всей выборки'.format(round(float(sum(revs.rating)) / len(revs.rating) * 100, 2)))
print ('Количество положительных отзывов составляет {}% от всей выборки'.format(round(float(len(revs.rating )- sum(revs.rating)) / len(revs.rating) * 100, 2)))
print ('Размер обучающей выборки: {}'.format(revs.shape[0]))
# Out:
# Количество положительных отзывов составляет 51.32% от всей выборки
# Количество положительных отзывов составляет 48.68% от всей выборки
# Размер обучающей выборки: 15497

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.cross_validation import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.model_selection import RandomizedSearchCV
from nltk.corpus import stopwords
from sklearn.model_selection import cross_validate 
from sklearn.metrics import recall_score

import string
# Out:
# C:\Users\dayan\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import sklearn.metrics

def trainTestClf(clf, X_train, y_train, X_test):
    clf.fit(X_train, y_train)
    return clf.predict(X_test)

def get_metrics(y_test, y_pred):
    accuracy = sklearn.metrics.accuracy_score(y_true = y_test, y_pred = y_pred)
    precision = sklearn.metrics.precision_score(y_true = y_test, y_pred = y_pred)
    recall = sklearn.metrics.recall_score(y_true = y_test, y_pred = y_pred)
    f1_score = sklearn.metrics.f1_score(y_true = y_test, y_pred = y_pred)
    
    return {
        "accuracy" : accuracy,
        "precision" : precision,
        "recall" : recall,
        "f1_score" : f1_score
    }

def print_metrics(metrics, vType ='-', cType='-'):
    print("Vectorizing: ", vType, ". Classifier: ", cType, sep='')

    print("accuracy = %.3f" % metrics["accuracy"])
    print("precision = %.3f" % metrics["precision"])
    print("recall = %.3f" % metrics["recall"])
    print("F-мера = %.3f" % metrics["f1_score"])

# %%
from sklearn import svm
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn import linear_model
from sklearn.model_selection import train_test_split
clf_svm = svm.LinearSVC()
clf_nb = MultinomialNB()
clf_rf = RandomForestClassifier()
clf_lr = linear_model.LogisticRegression(C=1e5)

# %%
norm_texts = revs_norm.content.copy()
norm_texts_splitted = revs_norm.content.str.split().copy()

# %%
scoring = ['accuracy', 'precision', 'recall', 'f1']

# %%
#from sklearn.feature_extraction.text import TfidfVectorizer

#tiv = TfidfVectorizer()
#nwd = tiv.fit_transform(norm_texts)

# %%
stop_words
# Out:
# {'а',
#  'без',
#  'более',
#  'больше',
#  'будет',
#  'будто',
#  'бы',
#  'был',
#  'была',
#  'были',
#  'было',
#  'быть',
#  'в',
#  'вам',
#  'вас',
#  'вдруг',
#  'ведь',
#  'во',
#  'вот',
#  'впрочем',
#  'все',
#  'всегда',
#  'всего',
#  'всех',
#  'всю',
#  'вы',
#  'где',
#  'да',
#  'даже',
#  'два',
#  'для',
#  'до',
#  'другой',
#  'его',
#  'ее',
#  'ей',
#  'ему',
#  'если',
#  'есть',
#  'еще',
#  'ж',
#  'же',
#  'за',
#  'зачем',
#  'здесь',
#  'и',
#  'из',
#  'или',
#  'им',
#  'иногда',
#  'их',
#  'к',
#  'как',
#  'какая',
#  'какой',
#  'когда',
#  'конечно',
#  'кто',
#  'куда',
#  'ли',
#  'лучше',
#  'между',
#  'меня',
#  'мне',
#  'много',
#  'может',
#  'можно',
#  'мой',
#  'моя',
#  'мы',
#  'на',
#  'над',
#  'надо',
#  'наконец',
#  'нас',
#  'не',
#  'него',
#  'нее',
#  'ней',
#  'нельзя',
#  'нет',
#  'ни',
#  'нибудь',
#  'никогда',
#  'ним',
#  'них',
#  'ничего',
#  'но',
#  'ну',
#  'о',
#  'об',
#  'один',
#  'он',
#  'она',
#  'они',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer_uni = CountVectorizer(binary = True, ngram_range=(1,1), max_features= 10000)
count_vectorizer_bi = CountVectorizer(binary = True, ngram_range=(2,2), max_features= 10000)
count_vectorizer_tri = CountVectorizer(binary = True, ngram_range=(3,3), max_features= 10000)
count_vectorizer_uni_bi = CountVectorizer(binary = True, ngram_range=(1,2), max_features= 10000)
count_vectorizer_uni_bi_tri = CountVectorizer(binary = True, ngram_range=(1,3), max_features= 10000)

cvect_uni = count_vectorizer_uni.fit_transform(norm_texts)
cvect_bi = count_vectorizer_bi.fit_transform(norm_texts)
cvect_tri = count_vectorizer_tri.fit_transform(norm_texts)
cvect_uni_bi = count_vectorizer_uni_bi.fit_transform(norm_texts)
cvect_uni_bi_tri = count_vectorizer_uni_bi_tri.fit_transform(norm_texts)

# %%
scores = pd.DataFrame(cross_validate(clf_svm, cvect_uni, revs.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
scores.mean()
# Out:
# fit_time          0.610430
# score_time        0.005003
# test_accuracy     0.819900
# test_f1           0.828253
# test_precision    0.810985
# test_recall       0.847607
# dtype: float64

# %%
norm_texts = revs_norm.content.copy()
norm_texts_neg = revs_norm_neg.content.copy()
norm_texts_neg_splitted = revs_norm_neg.content.str.split().copy()
count_vectorizer_uni_bi = CountVectorizer(binary = True, ngram_range=(1,2), max_features= 10000)
cvect_uni_bi = count_vectorizer_uni_bi.fit_transform(norm_texts)
cvect_uni_bi_neg = count_vectorizer_uni_bi.fit_transform(norm_texts_neg)



# уни- и биграммы
scores1_uni_bi = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi, revs_norm.rating, scoring=scoring, cv=5, return_train_score=False))
scores1_uni_bi_neg = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi_neg, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
print(scores1_uni_bi.mean())
print(scores1_uni_bi_neg.mean())
# Out:
# fit_time          0.528179
# score_time        0.005208
# test_accuracy     0.824997
# test_f1           0.833273
# test_precision    0.815124
# test_recall       0.853641
# dtype: float64
# fit_time          0.392884
# score_time        0.004803
# test_accuracy     0.827078
# test_f1           0.834857
# test_precision    0.818336
# test_recall       0.853727
# dtype: float64

# %%
# без доп признаков

# униграммы
scores1_uni = pd.DataFrame(cross_validate(clf_svm, cvect_uni, revs.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni = pd.DataFrame(cross_validate(clf_rf, cvect_uni, revs.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni = pd.DataFrame(cross_validate(clf_lr, cvect_uni, revs.rating, scoring=scoring, cv=5, return_train_score=False))

# биграммы
scores1_bi = pd.DataFrame(cross_validate(clf_svm, cvect_bi, revs.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_bi = pd.DataFrame(cross_validate(clf_rf, cvect_bi, revs.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_bi = pd.DataFrame(cross_validate(clf_lr, cvect_bi, revs.rating, scoring=scoring, cv=5, return_train_score=False))

# триграммы
scores1_tri = pd.DataFrame(cross_validate(clf_svm, cvect_tri, revs.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_tri = pd.DataFrame(cross_validate(clf_rf, cvect_tri, revs.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_tri = pd.DataFrame(cross_validate(clf_lr, cvect_tri, revs.rating, scoring=scoring, cv=5, return_train_score=False))

# уни- и биграммы
scores1_uni_bi = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi, revs.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi, revs.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi, revs.rating, scoring=scoring, cv=5, return_train_score=False))

# уни-, би-, и триграммы
scores1_uni_bi_tri = pd.DataFrame(cross_validate(clf_svm, cvect_uni_bi_tri, revs.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni_bi_tri = pd.DataFrame(cross_validate(clf_rf, cvect_uni_bi_tri, revs.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni_bi_tri = pd.DataFrame(cross_validate(clf_lr, cvect_uni_bi_tri, revs.rating, scoring=scoring, cv=5, return_train_score=False))

# %%
# без доп признаков

# униграммы
#X_train, X_test, y_train, y_test = train_test_split(cvect_uni, revs.rating, test_size=0.1, random_state=42)
#metr1_uni = get_metrics(y_test, trainTestClf(clf_svm, X_train, y_train, X_test))
#metr2_uni = get_metrics(y_test, trainTestClf(clf_rf, X_train, y_train, X_test))
#metr3_uni = get_metrics(y_test, trainTestClf(clf_lr, X_train, y_train, X_test))

# %%
class_res_svm = pd.DataFrame({
    "униграммы" : scores1_uni.mean(),
    "биграммы" : scores1_bi.mean(),
    "триграммы" : scores1_tri.mean(),
    "уни- и биграммы" : scores1_uni_bi.mean(),
    "уни-, би- и триграммы" : scores1_uni_bi_tri.mean()
})

print("Результаты для svm")
class_res_svm
# Out:
# Результаты для svm
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        0.275195   0.669476         0.609429               0.725517
# score_time      0.005004   0.004804         0.006208               0.006204
# test_accuracy   0.750595   0.593855         0.824997               0.823642
# test_f1         0.782319   0.708092         0.833273               0.832064
# test_precision  0.708820   0.561093         0.815124               0.813991
# test_recall     0.873508   0.959637         0.853641               0.852384
#
#                 униграммы
# fit_time         1.043141
# score_time       0.006805
# test_accuracy    0.819900
# test_f1          0.828253
# test_precision   0.810985
# test_recall      0.847607

# %%
class_res_rf = pd.DataFrame({
    "униграммы" : scores2_uni.mean(),
    "биграммы" : scores2_bi.mean(),
    "триграммы" : scores2_tri.mean(),
    "уни- и биграммы" : scores2_uni_bi.mean(),
    "уни-, би- и триграммы" : scores2_uni_bi_tri.mean()
})
print("Результаты для random forest")
class_res_rf
# Out:
# Результаты для random forest
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        4.690135   4.809824         3.211480               3.428635
# score_time      0.563195   0.839792         0.103886               0.111884
# test_accuracy   0.737238   0.587144         0.814287               0.816479
# test_f1         0.772237   0.705298         0.810661               0.814181
# test_precision  0.695576   0.556666         0.849069               0.845860
# test_recall     0.868732   0.962403         0.776566               0.785993
#
#                 униграммы
# fit_time         4.578211
# score_time       0.122087
# test_accuracy    0.812028
# test_f1          0.808861
# test_precision   0.844231
# test_recall      0.776940

# %%
class_res_lr = pd.DataFrame({
    "униграммы" : scores3_uni.mean(),
    "биграммы" : scores3_bi.mean(),
    "триграммы" : scores3_tri.mean(),
    "уни- и биграммы" : scores3_uni_bi.mean(),
    "уни-, би- и триграммы" : scores3_uni_bi_tri.mean()
})


print("Результаты для linear regression")
class_res_lr
# Out:
# Результаты для linear regression
#                 биграммы  триграммы  уни- и биграммы  уни-, би- и триграммы  \
# fit_time        0.488948   0.243974         1.719422               1.569915
# score_time      0.006404   0.007205         0.007005               0.007605
# test_accuracy   0.734011   0.598695         0.787700               0.785957
# test_f1         0.763366   0.709178         0.797815               0.796346
# test_precision  0.702639   0.564681         0.780707               0.779519
# test_recall     0.836541   0.953224         0.817052               0.815669
#
#                 униграммы
# fit_time         5.673330
# score_time       0.006804
# test_accuracy    0.753305
# test_f1          0.764891
# test_precision   0.748806
# test_recall      0.782849

# %%
class_result_svm = pd.DataFrame(class_res_svm["уни- и биграммы"])
class_result_rf = pd.DataFrame(class_res_rf["уни- и биграммы"])
class_result_lr = pd.DataFrame(class_res_lr["уни- и биграммы"])

class_result_svm = class_result_svm.transpose()
class_result_rf = class_result_rf.transpose()
class_result_lr = class_result_lr.transpose()

# %% [markdown]
# Сочетание униграмм и биграм показывает лучшие результаты, будем использовать данный способ векторизации

# %%
# Нахождение неверно классифицированных отзывов

def print_wrong_class(y_test, y_pred):
    inds = y_test[y_test.values != y_pred].index
    i = 0
    for idx, rev in revs.iterrows():
        i+=1
        if (idx in inds):
            print (idx, "\tclass=", rev.rating, '\n', rev.content, '\n\n', initial_revs.ix[idx].content, "\n")

# %%
X_train, X_test, y_train, y_test = train_test_split(cvect_uni_bi_neg, revs.rating, test_size=0.1, random_state=42)
classifier = clf_svm.fit(X=X_train, y=y_train)
y_pred = classifier.predict(X_test)

print_wrong_class (y_test, y_pred)
# Out:
# 18 	class= 0
#   зайти игра поиграть ровно минута весь энергия кончиться нужно ждать несколько часы пока восстановиться шикарно
#
#  Зашла в игру, поиграла ровно минуту и всё, энергия кончилась, нужно ждать несколько часов пока восстановится. Шикарно ?
#
# 63 	class= 1
#   крутяга ещё русский добавить сложно постоянно нужно вспоминать английский
#
#  Крутяг
# Ещё бы русский добавили
# А то сложно ,постоянно нужно вспоминать английский )))
#
# 161 	class= 1
#   добавить русский язык
#
#  ДОБАВЬТЕ РУССКИЙ ЯЗЫК
#
# 270 	class= 1
#   чудесный игра очень затянуть вернуть этот сказочный мир влюбиться этот игра гарри поттер вновь проблема язык возникнуть хорошо знать английский вообще быть иметь русский версия
#
#  Чудесная игра! Очень затянула, вернула в этот сказочный мир. Влюбилась в эту игру и в Гарри Поттера вновь ??. Проблемы с языком не возникли, так как хорошо знаю английский. Но вообще было бы здорово иметь русскую версию)
#
# 271 	class= 1
# ...

# %% [markdown]
# Считываем словарь тональностей из файла

# %%
sent = pd.read_csv('words_sent.csv', sep=';', header=None, names =['word', 'sent', '1', '2', '3'])

# %%
Dict = sent.groupby('word')['sent'].mean().to_dict()

# %%
tone = np.zeros((len(norm_texts_neg), 4))

# %%
Dict.get('ужасный', 0)
# Out:
# -1.25

# %%
initial_revs.content.size
# Out:
# 22493

# %% [markdown]
# Определяем общее значение тональности по словарю

# %%
# нормальзованное значение тональности
for i, text in enumerate(norm_texts_neg_splitted):
    count = 0
    for j, word in enumerate(text):        
        s = Dict.get(word, 0)
        if s != 0:
            count += 1
            if j >= 1:
                if text[j-1][0] == 'не':
                    s = - s
            tone[i, 0] += s
    if count:
        tone[i, 0] = tone[i, 0]/count

# %%
from scipy import sparse

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0].reshape(tone[:, 0].shape[0], 1))))

# %%
scores1_uni = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))


print(scores1_uni.mean())
print(scores2_uni.mean())
print(scores3_uni.mean())
# Out:
# fit_time          0.424105
# score_time        0.005204
# test_accuracy     0.828370
# test_f1           0.835532
# test_precision    0.821842
# test_recall       0.851587
# dtype: float64
# fit_time          2.730148
# score_time        0.094864
# test_accuracy     0.821071
# test_f1           0.820356
# test_precision    0.844303
# test_recall       0.798795
# dtype: float64
# fit_time          1.175636
# score_time        0.005799
# test_accuracy     0.796783
# test_f1           0.804571
# test_precision    0.793757
# test_recall       0.817697
# dtype: float64

# %%
#class_result_svm = class_result_svm.append(pd.Series(metr1, name="+ тональный словарь"))
#class_result_rf = class_result_rf.append(pd.Series(metr2, name="+ тональный словарь"))
#class_result_lr = class_result_lr.append(pd.Series(metr3, name="+ тональный словарь"))

#print("---svm---", class_result_svm)
#print("---lr---", class_result_rf)
#print("---rf---", class_result_lr)

# %%
# общее значение тональности
for i, text in enumerate(norm_texts_neg_splitted):
    count = 0
    for j, word in enumerate(text):        
        s = Dict.get(word, 0)
        if s != 0:
            count += 1
            if j >= 1:
                if text[j-1][0] == 'не':
                    s = - s
            tone[i, 0] += s

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0].reshape(tone[:, 0].shape[0], 1))))

# %%
scores1_uni = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))


print(scores1_uni.mean())
print(scores2_uni.mean())
print(scores3_uni.mean())
# Out:
# fit_time          0.512772
# score_time        0.005601
# test_accuracy     0.830114
# test_f1           0.837138
# test_precision    0.823673
# test_recall       0.852973
# dtype: float64
# fit_time          2.796994
# score_time        0.097077
# test_accuracy     0.826756
# test_f1           0.825667
# test_precision    0.851338
# test_recall       0.802324
# dtype: float64
# fit_time          1.119600
# score_time        0.005596
# test_accuracy     0.799948
# test_f1           0.807127
# test_precision    0.798227
# test_recall       0.818327
# dtype: float64

# %% [markdown]
# Ненормализованная разметка тональности работает лучше

# %%
# количество слов

for i, text in enumerate(norm_texts_neg_splitted):
    tone[i, 1] = len(text)

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0:1])))

scores1_uni = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))


print(scores1_uni.mean())
print(scores2_uni.mean())
print(scores3_uni.mean())
# Out:
# fit_time          0.720916
# score_time        0.006801
# test_accuracy     0.830114
# test_f1           0.837138
# test_precision    0.823673
# test_recall       0.852973
# dtype: float64
# fit_time          3.328504
# score_time        0.109482
# test_accuracy     0.832182
# test_f1           0.830506
# test_precision    0.860005
# test_recall       0.804215
# dtype: float64
# fit_time          1.122597
# score_time        0.006204
# test_accuracy     0.799948
# test_f1           0.807127
# test_precision    0.798227
# test_recall       0.818327
# dtype: float64

# %% [markdown]
# плохой признак, не будем включать

# %%
#class_result_svm = class_result_svm.append(pd.Series(metr1, name="+ количество слов"))
#class_result_rf = class_result_rf.append(pd.Series(metr2, name="+ количество слов"))
#class_result_lr = class_result_lr.append(pd.Series(metr3, name="+ количество слов"))

#print("---svm---", class_result_svm)
#print("---lr---", class_result_rf)
#print("---rf---", class_result_lr)

# %% [markdown]
# Считаем количество восклицательных знаков

# %%
initial_revs.drop(initial_revs.index.difference(revs_norm_neg.index), inplace=True)
initial_revs['rating'] = revs_norm_neg['rating']

for i, text in enumerate(initial_revs.content):
    for e in text:
        if e == '!':
            tone[i, 1] = 1
            #tone[i, 1] += 1

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0:1])))

scores1_uni = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))


print(scores1_uni.mean())
print(scores2_uni.mean())
print(scores3_uni.mean())
# Out:
# fit_time          0.790763
# score_time        0.007204
# test_accuracy     0.830114
# test_f1           0.837138
# test_precision    0.823673
# test_recall       0.852973
# dtype: float64
# fit_time          3.003141
# score_time        0.109878
# test_accuracy     0.825852
# test_f1           0.825418
# test_precision    0.848280
# test_recall       0.804717
# dtype: float64
# fit_time          1.162627
# score_time        0.006204
# test_accuracy     0.799948
# test_f1           0.807127
# test_precision    0.798227
# test_recall       0.818327
# dtype: float64

# %% [markdown]
# норм, оставим

# %% [markdown]
# Считаем количество глаголов в повелительном наклонении (встречаются часто в отрицательных отзывах)

# %%
def getImperatives(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = 0
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        if (lexInfo.tag.POS == 'VERB'):
            if (lexInfo.tag.mood == 'impr'):
                ans += 1
    if (ans > 0):
        return 1
    else:
        return 0
    return ans

initial_revs['imps'] = [getImperatives(line) for line in initial_revs.content]

# %%
tone[:,2] = list(initial_revs['imps'])

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0:2])))

scores1_uni = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))


print(scores1_uni.mean())
print(scores2_uni.mean())
print(scores3_uni.mean())
# Out:
# fit_time          0.956880
# score_time        0.006004
# test_accuracy     0.830243
# test_f1           0.837310
# test_precision    0.823694
# test_recall       0.853351
# dtype: float64
# fit_time          2.795194
# score_time        0.100472
# test_accuracy     0.829212
# test_f1           0.825791
# test_precision    0.863483
# test_recall       0.792752
# dtype: float64
# fit_time          1.216661
# score_time        0.005804
# test_accuracy     0.802081
# test_f1           0.809240
# test_precision    0.800537
# test_recall       0.820344
# dtype: float64

# %% [markdown]
# вроде норм

# %% [markdown]
# Считаем количество вопросительных слов. Встречаются в негативных отзывах ("Пропала кнопка вызова. Где её найти?!?!")

# %%
interrogative_words = ["где", "как", "зачем", "почему", "какой"]

for i, text in enumerate(norm_texts_neg_splitted):
    count = 0
    for j, word in enumerate(text):        
        if (word in interrogative_words):
            count += 1
    if (count > 0):
        tone[i, 3] = 1

# %%
cvect_uni_bi_neg.shape
# Out:
# (15481, 10000)

# %%
train = sparse.csr_matrix(np.hstack((cvect_uni_bi_neg.todense(), tone[:, 0:3])))

scores1_uni = pd.DataFrame(cross_validate(clf_svm, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores2_uni = pd.DataFrame(cross_validate(clf_rf, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))
scores3_uni = pd.DataFrame(cross_validate(clf_lr, train, revs_norm_neg.rating, scoring=scoring, cv=5, return_train_score=False))


print(scores1_uni.mean())
print(scores2_uni.mean())
print(scores3_uni.mean())
# Out:
# fit_time          0.822993
# score_time        0.004803
# test_accuracy     0.830179
# test_f1           0.837214
# test_precision    0.823759
# test_recall       0.853099
# dtype: float64
# fit_time          2.804400
# score_time        0.094659
# test_accuracy     0.826046
# test_f1           0.823292
# test_precision    0.857819
# test_recall       0.792372
# dtype: float64
# fit_time          1.444023
# score_time        0.006004
# test_accuracy     0.800983
# test_f1           0.807926
# test_precision    0.799785
# test_recall       0.818455
# dtype: float64

# %%
clf_rf.fit(X=X_train, y=y_train)
