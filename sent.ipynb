# %%
import urllib.request, json, xmltodict
import numpy as np
import pandas as pd
import re


def get_revs_for_app(appID):
    response = urllib.request.urlopen("https://itunes.apple.com/ru/rss/customerreviews/id=%s/sortBy=mostRecent/xml" % appID)
    j = xmltodict.parse(response.read())
    data = json.dumps(j)
    response.close()
    d = json.loads(data)

    feed = d.get("feed")
    entrys = feed.get("entry")
    reviews = []
    index = 0

    for entry in entrys:

        rating = entry.get("im:rating")
        if rating == None:
            continue

        title = entry.get("title")
        content = entry.get("content")[0].get("#text")
        author = entry.get("author").get("name")

        if rating != None:
            index = index + 1
            # print str(index) + ": " + rating + " --- " + author + " --- " + title + " --- " + content
            review = [rating, author, title, content]
            reviews.append(review)
    return reviews

# %%
app_id_list = ["1333256716", "1249864455", "525818839", "891194610", "1345968745", "1367959794", "835599320",
              "1348173937", "310633997", "1338605092", "492224193", "389801252", "564177498", "472650686",
              "1323957120", "1031509294", "417281773", "1272640583", "686449807", "284993459", "1016489154",
              "1366598056", "1117424833", "436672029", "474500851", "1336527043", "894649641", "1233739175",
              "447188370", "1130805026", "1129811786", "481627348", "511310430", "1351489785", "1357073746",
              "313877526", "1054372220", "398465290", "520797969", "1210244851", "1319500389", "1025707485",
              "284882215", "880047117", "368677368", "414706506", "341329033", "1354452189", "997362197", 
              "293778748", "1352789579", "777645417", "304878510", "587366035"];
reviews = []

for id in app_id_list:
    reviews.extend(get_revs_for_app(id))

# %%
revs = pd.DataFrame(reviews, columns=["rating", "author", "title", "content"])
revs.drop('author', inplace=True, axis=1)
revs.drop('title', inplace=True, axis=1)
revs.to_csv("res.csv")

revs

my_own_dict = ["донат", "вылетать", "тормозить", "добавить"]

def bad_words_count(line):
    count = 0
    for word in my_own_dict:
        count += sum(1 for _ in re.finditer(r'%s' % re.escape(word), line))
    return count

revs['bad_words'] = revs['content'].apply(bad_words_count)
revs
# Out:
#      rating                                            content  bad_words
# 0         1  Удаляю из-за отсутствия русского языка. Пожалу...          0
# 1         1                                  Где русский язык?          0
# 2         1                                  Add Russia please          0
# 3         1                                 Нет Русского языка          0
# 4         1  Уважаемые разработчики, как можно выпустить иг...          1
# 5         1                                  Русский язык где?          0
# 6         2  Почему на английском языке? Добавьте пожалуйст...          0
# 7         2  Ответили разработчики, попросили написать в по...          0
# 8         2  Add Russian language!!!!! I really like “Harry...          0
# 9         1  Играть просто стыдно. Гейплей, сюжет отсутству...          0
# 10        4                                                ???          0
# 11        5                  Добавьте русский язык пожалуйста!          0
# 12        1  Очень жду Русский язык ,написано что он есть ,...          0
# 13        4             still waiting for Russian localization          0
# 14        1                               Pls sup Rus language          0
# 15        5             Спасибо!!! Очень интересно играть! 👍👍👍          0
# 16        1  В описании к игре Русский язык указан, фактиче...          0
# 17        1  Зачем указывать языки которых нет и ничего не ...          0
# 18        1                   Добавьте пожалуйста русский язык          0
# 19        5  Game is amazing, interesting and makes me feel...          0
# 20        2  Графика хорошая интересно но ни х... не понятн...          0
# 21        5  Крутяг\nЕщё бы русский добавили\nА то сложно ,...          0
# 22        5                      Когда русский язык добавят???          0
# 23        4  Ребят я надеюсь вы работаете над русским языко...          0
# 24        1                                      Русский язык.          0
# 25        1               Пол дня не заходит в игру, не грузит          0
# 26        1  Пишет, что нет соединения с сервером. Не могу ...          0
# 27        3  Отсутствует русский язык.\nБез него нету атмос...          0
# 28        1  Зачем заявлять, что есть русский язык, если на...          0
# 29        5  Учите английский,идиоты.Авторы молодцы,если вы...          0
# ...     ...                                                ...        ...
# 2628      3  Не меняет цвет в эффектах, возмещении. Не прои...          0
# 2629      3  Программа отличная,но она просто ужасно зависа...          0
# 2630      1  При использовании программы приходят СМС сообщ...          0
# 2631      5  Очень хорошое предложение с большими возможнос...          0
# 2632      4  8.05 я сделала подписку на 1 месяц . Сегодня 1...          0
# 2633      3  Приложение обожаю,юзаю уже сто лет.Но последне...          0
# 2634      5  Как отписаться от подписки??? Я его уже удалил...          0
# 2635      1  Один клик-отключилась музыка в телефоне, включ...          0
# 2636      1  Каким-то чудесным образом оказалось, что подпи...          0
# 2637      1  Сняли 349 рублей за месячную подписку, которую...          0
# 2638      4  Обожаю приложение, пользуюсь несколько лет, зн...          0
# 2639      2  Хорошая программа...Была когда-то.Теперь это п...          1
# 2640      1  Я не знаю что произошло с программой, но она с...          0
# 2641      1  Подписалась на пробный период (1 неделя). Там ...          0
# 2642      1  Ужасно греетеся телефон при использовании! Под...          0
# 2643      2  Рекламу бывает невозможно закрыть, постоянно п...          0
# 2644      2  Ужасно тормозит после обновления! Сделайте что...          0
# 2645      1  добрый день. после установки данного приложени...          0
# 2646      3               Испортили приложение тонной рекламы!          0
# 2647      5  Случайно купил подписку на ваше приложение на ...          0
# 2648      1  Я подключила пробную версию бесплатно на месяц...          0
# 2649      1  Здравствуйте! Нажала на пробную подписку, а у ...          0
# 2650      3  Давно пользуюсь, все нравилось и устраивало. З...          0
# 2651      1  После последних обновлений постоянно реклама. ...          0
# 2652      1  Я СЛУЧАЙНО ПОДПИСАЛАСЬ И СПИСАЛИ 1299!!! Что д...          0
# 2653      5  В таком крутом приложение нет 3D текста,добавь...          0
# 2654      5  Приложения самое лучше для редактирование фото...          0
# 2655      3  Очень сильно портит качество фото. Может есть ...          0
# 2656      3  Нет возможности создать свой стикер 😐 и очень ...          0
# 2657      4  ..но качество сильно портится. Пользовалась то...          0
#
# [2658 rows x 3 columns]

# %%
#drop eng reviews
revs.drop(revs[revs.content.str.contains ("[A-Za-z]")].index, inplace=True)
#drop reviews with rating 3-4
revs.drop(revs[(revs.rating == "3") | (revs.rating == "4")].index, inplace=True)

revs
# Out:
#      rating                                            content  bad_words
# 0         1  Удаляю из-за отсутствия русского языка. Пожалу...          0
# 1         1                                  Где русский язык?          0
# 3         1                                 Нет Русского языка          0
# 4         1  Уважаемые разработчики, как можно выпустить иг...          1
# 5         1                                  Русский язык где?          0
# 6         2  Почему на английском языке? Добавьте пожалуйст...          0
# 7         2  Ответили разработчики, попросили написать в по...          0
# 9         1  Играть просто стыдно. Гейплей, сюжет отсутству...          0
# 11        5                  Добавьте русский язык пожалуйста!          0
# 12        1  Очень жду Русский язык ,написано что он есть ,...          0
# 15        5             Спасибо!!! Очень интересно играть! 👍👍👍          0
# 16        1  В описании к игре Русский язык указан, фактиче...          0
# 17        1  Зачем указывать языки которых нет и ничего не ...          0
# 18        1                   Добавьте пожалуйста русский язык          0
# 20        2  Графика хорошая интересно но ни х... не понятн...          0
# 21        5  Крутяг\nЕщё бы русский добавили\nА то сложно ,...          0
# 22        5                      Когда русский язык добавят???          0
# 24        1                                      Русский язык.          0
# 25        1               Пол дня не заходит в игру, не грузит          0
# 26        1  Пишет, что нет соединения с сервером. Не могу ...          0
# 28        1  Зачем заявлять, что есть русский язык, если на...          0
# 29        5  Учите английский,идиоты.Авторы молодцы,если вы...          0
# 31        1  Когда будет русский язык???? Как только вы его...          0
# 32        1  Пока не русифицируете игру будет стоять оценка...          0
# 33        1  Неплохая задумка, наконец то есть возможность ...          0
# 34        5  Добавьте русский язык пожалуйста, игра просто ...          0
# 36        1                              Добавьте русский язык          0
# 37        1  Позор, а не игра по Поттериане! Геймплея как т...          0
# 38        1  Кастрировать разработчиков за плевок в душу ис...          0
# 43        5              Игра очень качественная и интересная.          0
# ...     ...                                                ...        ...
# 2609      2  Постоянно выбрасывает на рекламу, автоматическ...          0
# 2610      2  Приложение было бы отличным, если бы постоянно...          0
# 2612      2  Раньше было лучше, реклама каждую минуту, нево...          0
# 2616      1  Уберите рекламу о вашем золотом аккаунте, она ...          0
# 2618      5                Как сделать эффект распада на фото?          0
# 2619      1  Это ужасное приложение с кучей рекламы. Невозм...          0
# 2620      1    Перегревает телефон ,вечно лагает и вылетает...          0
# 2621      1  Здравствуйте,я случайно купила подписку на 225...          0
# 2623      1  Когда хочу нажать на фото чтобы редактировать ...          0
# 2624      1  Здравствуйте! Ваша программа просто замечатель...          0
# 2625      2  Приложение мне очень нравится и до недавнего в...          0
# 2630      1  При использовании программы приходят СМС сообщ...          0
# 2631      5  Очень хорошое предложение с большими возможнос...          0
# 2634      5  Как отписаться от подписки??? Я его уже удалил...          0
# 2635      1  Один клик-отключилась музыка в телефоне, включ...          0
# 2636      1  Каким-то чудесным образом оказалось, что подпи...          0
# 2637      1  Сняли 349 рублей за месячную подписку, которую...          0
# 2639      2  Хорошая программа...Была когда-то.Теперь это п...          1
# 2640      1  Я не знаю что произошло с программой, но она с...          0
# 2641      1  Подписалась на пробный период (1 неделя). Там ...          0
# 2642      1  Ужасно греетеся телефон при использовании! Под...          0
# 2643      2  Рекламу бывает невозможно закрыть, постоянно п...          0
# 2644      2  Ужасно тормозит после обновления! Сделайте что...          0
# 2645      1  добрый день. после установки данного приложени...          0
# 2647      5  Случайно купил подписку на ваше приложение на ...          0
# 2648      1  Я подключила пробную версию бесплатно на месяц...          0
# 2649      1  Здравствуйте! Нажала на пробную подписку, а у ...          0
# 2651      1  После последних обновлений постоянно реклама. ...          0
# 2652      1  Я СЛУЧАЙНО ПОДПИСАЛАСЬ И СПИСАЛИ 1299!!! Что д...          0
# 2654      5  Приложения самое лучше для редактирование фото...          0
#
# [1928 rows x 3 columns]

# %%
revs['rating'][revs.rating == "5"] = 1
revs['rating'][(revs.rating == "1") | (revs.rating == "2")] = 0

revs
# Out:
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\dayan\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#      rating                                            content  bad_words
# 0         0  Удаляю из-за отсутствия русского языка. Пожалу...          0
# 1         0                                  Где русский язык?          0
# 3         0                                 Нет Русского языка          0
# 4         0  Уважаемые разработчики, как можно выпустить иг...          1
# 5         0                                  Русский язык где?          0
# 6         0  Почему на английском языке? Добавьте пожалуйст...          0
# 7         0  Ответили разработчики, попросили написать в по...          0
# 9         0  Играть просто стыдно. Гейплей, сюжет отсутству...          0
# 11        1                  Добавьте русский язык пожалуйста!          0
# 12        0  Очень жду Русский язык ,написано что он есть ,...          0
# 15        1             Спасибо!!! Очень интересно играть! 👍👍👍          0
# 16        0  В описании к игре Русский язык указан, фактиче...          0
# 17        0  Зачем указывать языки которых нет и ничего не ...          0
# 18        0                   Добавьте пожалуйста русский язык          0
# 20        0  Графика хорошая интересно но ни х... не понятн...          0
# 21        1  Крутяг\nЕщё бы русский добавили\nА то сложно ,...          0
# 22        1                      Когда русский язык добавят???          0
# 24        0                                      Русский язык.          0
# 25        0               Пол дня не заходит в игру, не грузит          0
# 26        0  Пишет, что нет соединения с сервером. Не могу ...          0
# 28        0  Зачем заявлять, что есть русский язык, если на...          0
# 29        1  Учите английский,идиоты.Авторы молодцы,если вы...          0
# 31        0  Когда будет русский язык???? Как только вы его...          0
# 32        0  Пока не русифицируете игру будет стоять оценка...          0
# 33        0  Неплохая задумка, наконец то есть возможность ...          0
# 34        1  Добавьте русский язык пожалуйста, игра просто ...          0
# 36        0                              Добавьте русский язык          0
# 37        0  Позор, а не игра по Поттериане! Геймплея как т...          0
# 38        0  Кастрировать разработчиков за плевок в душу ис...          0
# 43        1              Игра очень качественная и интересная.          0
# ...     ...                                                ...        ...
# 2609      0  Постоянно выбрасывает на рекламу, автоматическ...          0
# 2610      0  Приложение было бы отличным, если бы постоянно...          0
# 2612      0  Раньше было лучше, реклама каждую минуту, нево...          0
# 2616      0  Уберите рекламу о вашем золотом аккаунте, она ...          0
# 2618      1                Как сделать эффект распада на фото?          0
# 2619      0  Это ужасное приложение с кучей рекламы. Невозм...          0
# 2620      0    Перегревает телефон ,вечно лагает и вылетает...          0
# 2621      0  Здравствуйте,я случайно купила подписку на 225...          0
# 2623      0  Когда хочу нажать на фото чтобы редактировать ...          0
# 2624      0  Здравствуйте! Ваша программа просто замечатель...          0
# 2625      0  Приложение мне очень нравится и до недавнего в...          0
# 2630      0  При использовании программы приходят СМС сообщ...          0
# 2631      1  Очень хорошое предложение с большими возможнос...          0
# 2634      1  Как отписаться от подписки??? Я его уже удалил...          0
# 2635      0  Один клик-отключилась музыка в телефоне, включ...          0
# 2636      0  Каким-то чудесным образом оказалось, что подпи...          0
# 2637      0  Сняли 349 рублей за месячную подписку, которую...          0
# 2639      0  Хорошая программа...Была когда-то.Теперь это п...          1
# 2640      0  Я не знаю что произошло с программой, но она с...          0
# 2641      0  Подписалась на пробный период (1 неделя). Там ...          0
# 2642      0  Ужасно греетеся телефон при использовании! Под...          0
# 2643      0  Рекламу бывает невозможно закрыть, постоянно п...          0
# 2644      0  Ужасно тормозит после обновления! Сделайте что...          0
# 2645      0  добрый день. после установки данного приложени...          0
# 2647      1  Случайно купил подписку на ваше приложение на ...          0
# 2648      0  Я подключила пробную версию бесплатно на месяц...          0
# 2649      0  Здравствуйте! Нажала на пробную подписку, а у ...          0
# 2651      0  После последних обновлений постоянно реклама. ...          0
# 2652      0  Я СЛУЧАЙНО ПОДПИСАЛАСЬ И СПИСАЛИ 1299!!! Что д...          0
# 2654      1  Приложения самое лучше для редактирование фото...          0
#
# [1928 rows x 3 columns]

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
def strtonormalform(line, should_delete = {'PREP', 'CONJ', 'PRCL', 'INTJ'}):
    ans = ''
    words = re.findall(r"[\w]+[\w|-]*", line)
    for word in words:
        lexInfo = morph.parse(word)[0]
        lex = lexInfo.normal_form
        if (lexInfo.tag.POS not in should_delete) and (re.match(r"[-+]?\d+$", lex) is None) :#союзы, предлоги и т.п. не сохраняем
            ans = ans + ' ' + lex
    return ans

revs['content'] = revs['content'].apply(strtonormalform)
revs.to_pickle('revs')
revs

#revs['bad_words'] = [1 if for text in revs.content]
# Out:
#      rating                                            content  bad_words
# 0         0   удалять отсутствие русский язык добавить русский          0
# 1         0                                   где русский язык          0
# 3         0                                   нет русский язык          0
# 4         0   уважаемый разработчик можно выпустить игра че...          1
# 5         0                                   русский язык где          0
# 6         0            почему английский язык добавить русский          0
# 7         0   ответить разработчик попросить написать подде...          0
# 9         0   играть стыдно гейплей сюжет отсутствовать так...          0
# 11        1                              добавить русский язык          0
# 12        0        очень ждать русский язык написать он он нет          0
# 15        1                             очень интересно играть          0
# 16        0   описание игра русский язык указанный фактичес...          0
# 17        0   зачем указывать язык который нет ничто менять...          0
# 18        0                              добавить русский язык          0
# 20        0   график хороший интересно х понятно тыкать уга...          0
# 21        1   крутяга ещё русский добавить сложно постоянно...          0
# 22        1                              русский язык добавить          0
# 24        0                                       русский язык          0
# 25        0                половина день заходить игра грузить          0
# 26        0       писать нет соединение сервер мочь зайти игра          0
# 28        0   зачем заявлять русский язык самый дело он нет...          0
# 29        1   учить английский идиот автор молодец вы-быдло...          0
# 31        0   быть русский язык вы он добавить вы быть один...          0
# 32        0   пока русифицировать игра быть стоять оценка и...          0
# 33        0   неплохой задумка наконец возможность создать ...          0
# 34        1   добавить русский язык игра супер график сожал...          0
# 36        0                              добавить русский язык          0
# 37        0   позор игра поттериана геймплей таковой нет ка...          0
# 38        0   кастрировать разработчик плевок душить истинн...          0
# 43        1                 игра очень качественный интересный          0
# ...     ...                                                ...        ...
# 2609      0   постоянно выбрасывать реклама автоматически н...          0
# 2610      0   приложение быть отличный постоянно подвисало ...          0
# 2612      0   ранний быть хороший реклама каждый минута нев...          0
# 2616      0   убрать реклама ваш золото аккаунт она очень с...          0
# 2618      1                         сделать эффект распад фото          0
# 2619      0   ужасный приложение куча реклама невозможно ра...          0
# 2620      0         перегревать телефон вечно лагаета вылетать          0
# 2621      0   здравствовать я случайно купить подписка 2250...          0
# 2623      0   хотеть нажать фото редактировать происходить ...          0
# 2624      0   здравствовать ваш программа замечательный я г...          0
# 2625      0   приложение я очень нравиться недавний время в...          0
# 2630      0   использование программа приходить смс сообщен...          0
# 2631      1      очень хорошоя предложение больший возможность          0
# 2634      1   отписаться подписка я он уже удалить плата вз...          0
# 2635      0   один клик-отключиться музыка телефон включить...          0
# 2636      0   какой-то чудесный образ оказаться подписать м...          0
# 2637      0   снять рубль месячный подписка который я оформ...          0
# 2639      0   хороший программа быть когда-то теперь прилож...          1
# 2640      0   я знать произойти программа она стать очень п...          0
# 2641      0   подписаться пробный период неделя там прописа...          0
# 2642      0   ужасно греетести телефон использование подраб...          0
# 2643      0   реклама бывать невозможно закрыть постоянно п...          0
# 2644      0     ужасно тормозить обновление сделать что-нибудь          0
# 2645      0   добрый день установка данный приложение я быт...          0
# 2647      1   случайно купить подписка ваш приложение год х...          0
# 2648      0   я подключить пробный версия бесплатно месяц б...          0
# 2649      0   здравствовать нажать пробный подписка я списа...          0
# 2651      0   последний обновление постоянно реклама постоя...          0
# 2652      0              я случайно подписаться списать делать          0
# 2654      1   приложение самый хороший редактирование фото ...          0
#
# [1928 rows x 3 columns]

# %%
import sklearn.metrics

def trainTestClf(clf, X_train, y_train, X_test):
    clf.fit(X_train, y_train)
    return clf.predict(X_test)

def printF2(y_test, y_pred, vType ='tf-idf', cType='Bayess'):
    print("Vectorizing: ", vType, ". Classifier: ", cType, sep='')

    print("accuracy = %.3f" % sklearn.metrics.accuracy_score(y_true = y_test, y_pred = y_pred))
    print("precision = %.3f" % sklearn.metrics.precision_score(y_true = y_test, y_pred = y_pred))
    print("recall = %.3f" % sklearn.metrics.recall_score(y_true = y_test, y_pred = y_pred))
    print("F-мера = %.3f" % sklearn.metrics.f1_score(y_true = y_test, y_pred = y_pred))

# %%
# Out:
# <1x328 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(binary = True)
X_train = vectorizer.fit_transform(revs.iloc[:1600]['content'])
X_test = vectorizer.transform(revs.iloc[1600:]['content'])

from scipy.sparse import hstack
from scipy import sparse
sTest = sparse.csr_matrix(revs.bad_words[1600:])
sTrain = sparse.csr_matrix(revs.bad_words[:1600])


#hstack((X_test, sTest))
#hstack(X_train, revs.bad_words[:1600])

X_tr = pd.DataFrame({'bad_words': revs.bad_words[:1600], 'vec' : list(X_train)})
X_te = pd.DataFrame({'bad_words': revs.bad_words[1600:], 'vec' : list(X_test)})

y_train, y_test = revs.rating[:1600], revs.rating[1600:]
y_test = y_test.astype('bool')
y_train = y_train.astype('bool')
X_train, X_test
# Out:
# (<1600x3702 sparse matrix of type '<class 'numpy.int64'>'
#  	with 16057 stored elements in Compressed Sparse Row format>,
#  <328x3702 sparse matrix of type '<class 'numpy.int64'>'
#  	with 3827 stored elements in Compressed Sparse Row format>)

# %%
from sklearn import svm

clf = svm.LinearSVC()
printF2(y_test, trainTestClf(clf, X_train, y_train, X_test), vType = "Boolean", cType = 'svm')
#printF2(y_test, trainTestClf(clf, X_tr, y_train, X_te), vType = "Boolean", cType = 'svm')
# Out:
# Vectorizing: Boolean. Classifier: svm
# accuracy = 0.829
# precision = 0.745
# recall = 0.880
# F-мера = 0.807
